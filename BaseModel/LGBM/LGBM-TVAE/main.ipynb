# %% [markdown]
# ## Baseline Model

# %%
import warnings

from lightgbm import LGBMClassifier
import pandas as pd
import numpy as np

warnings.filterwarnings("ignore")

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix
from sklearn.ensemble import HistGradientBoostingClassifier, RandomForestClassifier

def eval_classification(y_true, y_pred, name=""):
    acc = accuracy_score(y_true, y_pred)
    f1_macro = f1_score(y_true, y_pred, average="macro")
    f1_weighted = f1_score(y_true, y_pred, average="weighted")
    print(f"{name} Accuracy: {acc:.4f} | F1-macro: {f1_macro:.4f} | F1-weighted: {f1_weighted:.4f}")
    return acc, f1_macro, f1_weighted

def save_preds_csv(X_test, y_true, y_pred, filename):
    out = X_test.copy()
    out["y_true"] = y_true
    out["y_pred"] = y_pred
    out.to_csv(filename, index=False, encoding="utf-8-sig")
    print(f"Saved: {filename}")

def derive_groups_from_train(train_df, k_baseline_dict, min_group_size=2):
    """
    Returns: type_to_group dict, groups dict
    Uses only train_df to avoid test leakage.
    Phân loại các 'type' thành near/mid/far dựa trên trung bình độ lệch tuyệt đối (abs_diff)
    """
    df_temp = train_df.copy()
    df_temp["k_eff_expected"] = df_temp["load"].map(k_baseline_dict)
    if df_temp["k_eff_expected"].isnull().any():
        known_loads = np.array(list(k_baseline_dict.keys()))
        for idx, row in df_temp[df_temp["k_eff_expected"].isnull()].iterrows():
            closest_load = known_loads[np.abs(known_loads - row["load"]).argmin()]
            df_temp.loc[idx, "k_eff_expected"] = k_baseline_dict[closest_load]     
    df_temp["abs_diff"] = (df_temp["efficiency"] - df_temp["k_eff_expected"]).abs()
    type_stats = (
        df_temp.groupby("type")["abs_diff"]
        .agg(n="count", mean="mean")
        .sort_values("mean")
        .reset_index()
    )
    types = type_stats["type"].tolist()
    x = type_stats["mean"].to_numpy()
    n = len(x)
    # Prefix sums for O(1) segment SSE
    S1 = np.concatenate([[0.0], np.cumsum(x)])
    S2 = np.concatenate([[0.0], np.cumsum(x * x)])
    def seg_sse(i, j):
        m = j - i + 1
        sum1 = S1[j + 1] - S1[i]
        sum2 = S2[j + 1] - S2[i]
        mu = sum1 / m
        return sum2 - 2 * mu * sum1 + m * mu * mu

    K = 3
    INF = 1e18
    dp = np.full((K + 1, n + 1), INF)
    cut = np.full((K + 1, n + 1), -1, dtype=int)

    dp[0, 0] = 0.0
    for k in range(1, K + 1):
        for t in range(1, n + 1):
            p_min = (k - 1) * min_group_size
            p_max = t - min_group_size
            if p_max < p_min:
                continue
            best_cost, best_p = INF, -1
            for p in range(p_min, p_max + 1):
                cost = dp[k - 1, p] + seg_sse(p, t - 1)
                if cost < best_cost:
                    best_cost, best_p = cost, p
            dp[k, t] = best_cost
            cut[k, t] = best_p

    if np.isinf(dp[K, n]):
        raise RuntimeError("No valid split found. Try min_group_size=1 or check types count.")
    bounds = []
    t = n
    for k in range(K, 0, -1):
        p = cut[k, t]
        bounds.append((p, t))
        t = p
    bounds.reverse()
    group_names = ["near", "mid", "far"] 
    groups = {}
    for name, (a, b) in zip(group_names, bounds):
        groups[name] = types[a:b]

    type_to_group = {t: g for g, ts in groups.items() for t in ts}
    return type_to_group, groups, type_stats


# ----- Load your saved split files -----
train_random = pd.read_csv('../../../GenerativeModel/TAVEGenData/wpt_train_random_aug_tvae.csv')
test_random  = pd.read_csv('../../../random-split/wpt_test_random.csv')

# Sanity check expected columns
expected_cols = {"type", "load", "efficiency"}
for name, d in [("train_random", train_random), ("test_random", test_random)]:
    missing = expected_cols - set(d.columns)
    if missing:
        raise ValueError(f"{name} is missing columns: {missing}")

# Make sure numeric columns are numeric
for d in [train_random, test_random]:
    d["load"] = pd.to_numeric(d["load"], errors="coerce")
    d["efficiency"] = pd.to_numeric(d["efficiency"], errors="coerce")
    d["type"] = d["type"].astype(str)
    d.dropna(subset=["type", "load", "efficiency"], inplace=True)

# Features / target
FEATURES = ["load", "efficiency"]
TARGET = "type"

# =========================
def add_advanced_features(df, k_baseline_dict, type_to_group_dict):
    df = df.copy()
    df["k_eff_expected"] = df["load"].map(k_baseline_dict)
    if df["k_eff_expected"].isnull().any():
        known_loads = np.array(list(k_baseline_dict.keys()))
        for idx, row in df[df["k_eff_expected"].isnull()].iterrows():
            closest_load = known_loads[np.abs(known_loads - row["load"]).argmin()]
            df.loc[idx, "k_eff_expected"] = k_baseline_dict[closest_load]  
    # 2. Độ lệch (Difference) và Tỷ lệ (Ratio)
    df["eff_diff"] = df["efficiency"] - df["k_eff_expected"]
    df["eff_ratio"] = df["efficiency"] / df["k_eff_expected"]
    # 3. Ước tính tổn hao công suất (Power Loss Proxy)
    # P_loss = Load * (1 / (Efficiency / 100) - 1)
    df["p_loss"] = df["load"] * (1 / (df["efficiency"] / 100.0) - 1)
    # Tổn hao công suất của Class K
    df["k_p_loss"] = df["load"] * (1 / (df["k_eff_expected"] / 100.0) - 1)
    # Độ lệch suy hao do vật thể lạ gây ra
    df["p_loss_diff"] = df["p_loss"] - df["k_p_loss"]

    df["dist_zone_name"] = df["type"].map(type_to_group_dict).fillna("far")
    # Mã hóa thành số
    zone_mapping = {"near": 1, "mid": 2, "far": 3}
    df["dist_zone"] = df["dist_zone_name"].map(zone_mapping)
    # 4. Phân vùng Dải tải (Load Zone)
    # Giả sử dải tải từ 0.5 đến 3.0, chia làm 3 vùng: Nhẹ (1), Vừa (2), Nặng (3)
    df['load_zone'] = pd.cut(df['load'], bins=3, labels=[1, 2, 3]).astype(float)
    return df

k_baseline_train_r = train_random[train_random["type"] == "K"].groupby("load")["efficiency"].mean().to_dict()
type_to_group, groups_dict, stats = derive_groups_from_train(train_random, k_baseline_train_r)
print("Results of grouping the Types:", groups_dict)

train_random_fe = add_advanced_features(train_random, k_baseline_train_r, type_to_group)
test_random_fe = add_advanced_features(test_random, k_baseline_train_r, type_to_group)

FEATURES_NEW = [
    "load", "efficiency", 
    "eff_diff", "eff_ratio", 
    "p_loss_diff", "load_zone", "dist_zone"
]
# =========================
X_train_r = train_random_fe[FEATURES_NEW]
y_train_r = train_random_fe[TARGET]
X_test_r  = test_random_fe[FEATURES_NEW]
y_test_r  = test_random_fe[TARGET]
# Out:
# Results of grouping the Types: {'near': ['K', 'H', 'J'], 'mid': ['G', 'I', 'F', 'E', 'D', 'B'], 'far': ['C', 'A']}

# %% [markdown]
# ## Optuna

# %%
import optuna
import lightgbm as lgb
import json
from sklearn.model_selection import StratifiedKFold, cross_val_score

def objective(trial):
 
    param = {
        'objective': 'multiclass',
        'num_class': 11,
        'metric': 'multi_logloss',
        'verbosity': -1,
        'random_state': 42,
        'class_weight': 'balanced',
        
        'boosting_type': trial.suggest_categorical('boosting_type', ['gbdt', 'dart']),
        
        'n_estimators': trial.suggest_int('n_estimators', 100, 1500), 
        'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 2, 12), 
        'num_leaves': trial.suggest_int('num_leaves', 4, 256),
        
        'lambda_l1': trial.suggest_float('lambda_l1', 1e-8, 10.0, log=True),
        'lambda_l2': trial.suggest_float('lambda_l2', 1e-8, 10.0, log=True),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.4, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.4, 1.0),
        'bagging_freq': trial.suggest_int('bagging_freq', 1, 7),
        'min_split_gain': trial.suggest_float('min_split_gain', 0, 1.0),

        'device': 'gpu',          
        'gpu_platform_id': 0,      
        'gpu_device_id': 0,
    }

    clf = lgb.LGBMClassifier(**param)
    
    # 3-fold StratifiedKFold
    cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

    scores = cross_val_score(clf, X_train_r, y_train_r, cv=cv, scoring='f1_macro', n_jobs=-1)
    
    return scores.mean()

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=150, show_progress_bar=True)

best_params = study.best_params
best_params.update({
    'objective': 'multiclass',
    'num_class': 11,
    'metric': 'multi_logloss',
    'verbosity': -1,
    'random_state': 42,
    'device': 'gpu',          
    'gpu_platform_id': 0,      
    'gpu_device_id': 0,
})

with open("best_lgbm_params.json", "w") as f:
    json.dump(best_params, f, indent=4)

print(f"Best Score: {study.best_value}")
# Out:
# [I 2026-03-13 21:24:28,479] A new study created in memory with name: no-name-c5e1eb81-83a3-4032-a784-9f89dc4d12f9
#   0%|          | 0/150 [00:00<?, ?it/s]
# [I 2026-03-13 21:24:41,424] Trial 0 finished with value: 0.6525995736330982 and parameters: {'boosting_type': 'dart', 'n_estimators': 316, 'learning_rate': 0.15596374633827514, 'max_depth': 7, 'num_leaves': 73, 'lambda_l1': 0.17608604022215407, 'lambda_l2': 0.023786973288553254, 'min_child_samples': 81, 'feature_fraction': 0.9234375706143292, 'bagging_fraction': 0.8147732946855177, 'bagging_freq': 7, 'min_split_gain': 0.016395476464887482}. Best is trial 0 with value: 0.6525995736330982.
# [I 2026-03-13 21:25:00,826] Trial 1 finished with value: 0.6805971641601175 and parameters: {'boosting_type': 'dart', 'n_estimators': 1299, 'learning_rate': 0.0062596407636647455, 'max_depth': 2, 'num_leaves': 41, 'lambda_l1': 0.1822097807724766, 'lambda_l2': 0.08576620724729665, 'min_child_samples': 88, 'feature_fraction': 0.5226882763723113, 'bagging_fraction': 0.5515159819792065, 'bagging_freq': 1, 'min_split_gain': 0.6845734922682876}. Best is trial 1 with value: 0.6805971641601175.
# [I 2026-03-13 21:25:32,713] Trial 2 finished with value: 0.6673505866163171 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1438, 'learning_rate': 0.006078028165663866, 'max_depth': 3, 'num_leaves': 214, 'lambda_l1': 6.2623864475542366e-06, 'lambda_l2': 0.0009579293681513833, 'min_child_samples': 31, 'feature_fraction': 0.6968672629210433, 'bagging_fraction': 0.5064065320216872, 'bagging_freq': 6, 'min_split_gain': 0.029561338065240417}. Best is trial 1 with value: 0.6805971641601175.
# [I 2026-03-13 21:25:52,870] Trial 3 finished with value: 0.683198066581116 and parameters: {'boosting_type': 'dart', 'n_estimators': 841, 'learning_rate': 0.04260956031306829, 'max_depth': 7, 'num_leaves': 189, 'lambda_l1': 3.5839219583360577e-06, 'lambda_l2': 1.0849440937385789e-07, 'min_child_samples': 32, 'feature_fraction': 0.7692282225455953, 'bagging_fraction': 0.8675296672494162, 'bagging_freq': 1, 'min_split_gain': 0.8700721496891763}. Best is trial 3 with value: 0.683198066581116.
# [I 2026-03-13 21:26:17,299] Trial 4 finished with value: 0.675835964999008 and parameters: {'boosting_type': 'dart', 'n_estimators': 790, 'learning_rate': 0.0037246724490451566, 'max_depth': 8, 'num_leaves': 220, 'lambda_l1': 0.0013925245306920105, 'lambda_l2': 0.010301506016453547, 'min_child_samples': 20, 'feature_fraction': 0.8421584799108621, 'bagging_fraction': 0.4056422682569349, 'bagging_freq': 1, 'min_split_gain': 0.024053147771472827}. Best is trial 3 with value: 0.683198066581116.
# [I 2026-03-13 21:26:25,401] Trial 5 finished with value: 0.6709773418830057 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 450, 'learning_rate': 0.0018227586102192183, 'max_depth': 5, 'num_leaves': 53, 'lambda_l1': 3.2342912348343985e-05, 'lambda_l2': 2.807722874664587e-07, 'min_child_samples': 71, 'feature_fraction': 0.8205373787019672, 'bagging_fraction': 0.7507713167155234, 'bagging_freq': 7, 'min_split_gain': 0.2590514099953737}. Best is trial 3 with value: 0.683198066581116.
# [I 2026-03-13 21:26:49,159] Trial 6 finished with value: 0.6990791746636097 and parameters: {'boosting_type': 'dart', 'n_estimators': 1487, 'learning_rate': 0.014663667286866846, 'max_depth': 2, 'num_leaves': 194, 'lambda_l1': 0.3678720543768389, 'lambda_l2': 2.2281458057554553, 'min_child_samples': 43, 'feature_fraction': 0.8884530105746669, 'bagging_fraction': 0.6718603173228566, 'bagging_freq': 2, 'min_split_gain': 0.6575636970207435}. Best is trial 6 with value: 0.6990791746636097.
# [I 2026-03-13 21:27:02,017] Trial 7 finished with value: 0.6458687495950312 and parameters: {'boosting_type': 'dart', 'n_estimators': 602, 'learning_rate': 0.19026814860589586, 'max_depth': 12, 'num_leaves': 81, 'lambda_l1': 7.671907955346575e-08, 'lambda_l2': 0.00014970008575889308, 'min_child_samples': 35, 'feature_fraction': 0.4269508208060263, 'bagging_fraction': 0.5831440295684198, 'bagging_freq': 5, 'min_split_gain': 0.5694728463168919}. Best is trial 6 with value: 0.6990791746636097.
# [I 2026-03-13 21:27:17,163] Trial 8 finished with value: 0.6856180752507589 and parameters: {'boosting_type': 'dart', 'n_estimators': 1203, 'learning_rate': 0.07625328464047525, 'max_depth': 2, 'num_leaves': 35, 'lambda_l1': 0.00010430123494724902, 'lambda_l2': 0.32233828127731406, 'min_child_samples': 27, 'feature_fraction': 0.9329506585885883, 'bagging_fraction': 0.8710185634481767, 'bagging_freq': 6, 'min_split_gain': 0.8247098717907908}. Best is trial 6 with value: 0.6990791746636097.
# [I 2026-03-13 21:27:23,668] Trial 9 finished with value: 0.6570924286708287 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 235, 'learning_rate': 0.0417648529385198, 'max_depth': 9, 'num_leaves': 32, 'lambda_l1': 1.326589093039222e-08, 'lambda_l2': 0.03538008352248454, 'min_child_samples': 33, 'feature_fraction': 0.737839699995898, 'bagging_fraction': 0.7633780129194612, 'bagging_freq': 7, 'min_split_gain': 0.3931644166841116}. Best is trial 6 with value: 0.6990791746636097.
# [I 2026-03-13 21:27:30,824] Trial 10 finished with value: 0.6913824046000788 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1016, 'learning_rate': 0.0133618789064051, 'max_depth': 5, 'num_leaves': 151, 'lambda_l1': 9.883585828244303, 'lambda_l2': 4.167137540158074, 'min_child_samples': 58, 'feature_fraction': 0.9939216208575126, 'bagging_fraction': 0.978114659191182, 'bagging_freq': 3, 'min_split_gain': 0.6747715458159897}. Best is trial 6 with value: 0.6990791746636097.
# [I 2026-03-13 21:27:39,431] Trial 11 finished with value: 0.7217922002251281 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1047, 'learning_rate': 0.016376454367987354, 'max_depth': 4, 'num_leaves': 148, 'lambda_l1': 1.4566281753492856, 'lambda_l2': 8.263098093142505, 'min_child_samples': 60, 'feature_fraction': 0.9944724567566514, 'bagging_fraction': 0.9870441007763479, 'bagging_freq': 3, 'min_split_gain': 0.6670196590772779}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:27:49,135] Trial 12 finished with value: 0.6838364210386599 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1495, 'learning_rate': 0.01711868074672912, 'max_depth': 4, 'num_leaves': 133, 'lambda_l1': 8.20644295437697, 'lambda_l2': 9.115675015720294, 'min_child_samples': 52, 'feature_fraction': 0.6088047539740582, 'bagging_fraction': 0.6605143675093381, 'bagging_freq': 3, 'min_split_gain': 0.984094473671272}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:28:01,321] Trial 13 finished with value: 0.68929010160424 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1090, 'learning_rate': 0.016052753138749005, 'max_depth': 4, 'num_leaves': 167, 'lambda_l1': 0.016534338247852373, 'lambda_l2': 7.276677254047444e-06, 'min_child_samples': 7, 'feature_fraction': 0.8982270675010836, 'bagging_fraction': 0.9777285758969889, 'bagging_freq': 3, 'min_split_gain': 0.46151715031641966}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:28:15,109] Trial 14 finished with value: 0.7037624873714724 and parameters: {'boosting_type': 'dart', 'n_estimators': 936, 'learning_rate': 0.03014238624797673, 'max_depth': 2, 'num_leaves': 114, 'lambda_l1': 0.2508924937651198, 'lambda_l2': 0.7924524356542066, 'min_child_samples': 53, 'feature_fraction': 0.9763788510485664, 'bagging_fraction': 0.6712835714413411, 'bagging_freq': 2, 'min_split_gain': 0.6627285877613854}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:28:29,538] Trial 15 finished with value: 0.6497338231037363 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 884, 'learning_rate': 0.0357678761346495, 'max_depth': 5, 'num_leaves': 93, 'lambda_l1': 0.007598609121389811, 'lambda_l2': 0.4074504283979975, 'min_child_samples': 100, 'feature_fraction': 0.9728495796454499, 'bagging_fraction': 0.600116318046996, 'bagging_freq': 4, 'min_split_gain': 0.2843077190894226}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:28:41,541] Trial 16 finished with value: 0.6576084961965629 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 638, 'learning_rate': 0.0010634080195727907, 'max_depth': 4, 'num_leaves': 110, 'lambda_l1': 1.4842868932789004, 'lambda_l2': 0.0013297180169577333, 'min_child_samples': 58, 'feature_fraction': 0.6787561546194025, 'bagging_fraction': 0.8851239184018164, 'bagging_freq': 2, 'min_split_gain': 0.7954248234121067}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:29:03,328] Trial 17 finished with value: 0.660075453913854 and parameters: {'boosting_type': 'dart', 'n_estimators': 1023, 'learning_rate': 0.07342634954624613, 'max_depth': 6, 'num_leaves': 247, 'lambda_l1': 0.019567833544439986, 'lambda_l2': 1.3008703830902072e-05, 'min_child_samples': 68, 'feature_fraction': 0.8143127823120023, 'bagging_fraction': 0.7362915374876138, 'bagging_freq': 4, 'min_split_gain': 0.5508743087972183}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:29:18,166] Trial 18 finished with value: 0.6589752536995847 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1235, 'learning_rate': 0.02780614870681761, 'max_depth': 11, 'num_leaves': 123, 'lambda_l1': 0.0021629685397699097, 'lambda_l2': 0.6210508825312081, 'min_child_samples': 47, 'feature_fraction': 0.9871146421938795, 'bagging_fraction': 0.4659415343759665, 'bagging_freq': 2, 'min_split_gain': 0.9199773725891853}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:29:30,455] Trial 19 finished with value: 0.6649282560675744 and parameters: {'boosting_type': 'dart', 'n_estimators': 711, 'learning_rate': 0.006069912107942127, 'max_depth': 3, 'num_leaves': 6, 'lambda_l1': 0.6789911311344979, 'lambda_l2': 0.004114245598757342, 'min_child_samples': 68, 'feature_fraction': 0.6393509149049076, 'bagging_fraction': 0.6612371727141511, 'bagging_freq': 4, 'min_split_gain': 0.7389987850799624}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:29:47,376] Trial 20 finished with value: 0.6654909375596941 and parameters: {'boosting_type': 'dart', 'n_estimators': 930, 'learning_rate': 0.09767793915808787, 'max_depth': 3, 'num_leaves': 152, 'lambda_l1': 0.06357169587145313, 'lambda_l2': 1.1762936092910737e-08, 'min_child_samples': 81, 'feature_fraction': 0.8565156123593004, 'bagging_fraction': 0.9280663470919412, 'bagging_freq': 3, 'min_split_gain': 0.4056788424039153}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:30:09,216] Trial 21 finished with value: 0.6941949716713852 and parameters: {'boosting_type': 'dart', 'n_estimators': 1347, 'learning_rate': 0.010249314118864096, 'max_depth': 2, 'num_leaves': 190, 'lambda_l1': 1.1205970494258883, 'lambda_l2': 2.208312897072749, 'min_child_samples': 54, 'feature_fraction': 0.8846732879949393, 'bagging_fraction': 0.6720355677597586, 'bagging_freq': 2, 'min_split_gain': 0.636145948928995}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:30:25,527] Trial 22 finished with value: 0.7051951307041772 and parameters: {'boosting_type': 'dart', 'n_estimators': 1110, 'learning_rate': 0.024216744638467045, 'max_depth': 2, 'num_leaves': 175, 'lambda_l1': 0.5868530761743425, 'lambda_l2': 8.711146175565844, 'min_child_samples': 44, 'feature_fraction': 0.9343523895846001, 'bagging_fraction': 0.7993823934553098, 'bagging_freq': 2, 'min_split_gain': 0.5593333914176849}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:30:45,050] Trial 23 finished with value: 0.7045046339733952 and parameters: {'boosting_type': 'dart', 'n_estimators': 1098, 'learning_rate': 0.02258126679362347, 'max_depth': 3, 'num_leaves': 166, 'lambda_l1': 3.137246226869407, 'lambda_l2': 0.19629642744121292, 'min_child_samples': 43, 'feature_fraction': 0.9521411900079012, 'bagging_fraction': 0.8159012839474448, 'bagging_freq': 2, 'min_split_gain': 0.5408755842163604}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:31:05,617] Trial 24 finished with value: 0.701733486789 and parameters: {'boosting_type': 'dart', 'n_estimators': 1161, 'learning_rate': 0.02199625821915972, 'max_depth': 4, 'num_leaves': 164, 'lambda_l1': 3.106009655179751, 'lambda_l2': 8.416932057425338, 'min_child_samples': 42, 'feature_fraction': 0.9502176229013851, 'bagging_fraction': 0.8175405617016924, 'bagging_freq': 3, 'min_split_gain': 0.509780020778118}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:31:27,334] Trial 25 finished with value: 0.7042757893416057 and parameters: {'boosting_type': 'dart', 'n_estimators': 1093, 'learning_rate': 0.008670091497236973, 'max_depth': 3, 'num_leaves': 140, 'lambda_l1': 0.03997657585965639, 'lambda_l2': 0.12274808188042773, 'min_child_samples': 20, 'feature_fraction': 0.7852277508963208, 'bagging_fraction': 0.8238382005189158, 'bagging_freq': 1, 'min_split_gain': 0.2943465935971645}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:31:33,562] Trial 26 finished with value: 0.7051749936480753 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1328, 'learning_rate': 0.062471002084798534, 'max_depth': 6, 'num_leaves': 174, 'lambda_l1': 2.985519856245442, 'lambda_l2': 1.2211018810901881, 'min_child_samples': 64, 'feature_fraction': 0.9303993503964085, 'bagging_fraction': 0.9361765014351957, 'bagging_freq': 2, 'min_split_gain': 0.5818899016012975}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:31:42,326] Trial 27 finished with value: 0.6981745919592868 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1323, 'learning_rate': 0.051683952758737724, 'max_depth': 6, 'num_leaves': 255, 'lambda_l1': 0.0010296281353035202, 'lambda_l2': 1.620674761159248, 'min_child_samples': 65, 'feature_fraction': 0.8712017084999661, 'bagging_fraction': 0.9281111542848897, 'bagging_freq': 4, 'min_split_gain': 0.7510515658139868}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:31:50,723] Trial 28 finished with value: 0.6990106978000501 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1369, 'learning_rate': 0.0611195707523129, 'max_depth': 9, 'num_leaves': 214, 'lambda_l1': 0.08303012040284323, 'lambda_l2': 9.87937406829671, 'min_child_samples': 76, 'feature_fraction': 0.918829618024866, 'bagging_fraction': 0.9935197336988235, 'bagging_freq': 3, 'min_split_gain': 0.42565656866769114}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:31:57,454] Trial 29 finished with value: 0.6658307075755504 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1225, 'learning_rate': 0.11363941926140853, 'max_depth': 6, 'num_leaves': 182, 'lambda_l1': 0.005071459451907553, 'lambda_l2': 0.008805898935923902, 'min_child_samples': 80, 'feature_fraction': 0.913240878615385, 'bagging_fraction': 0.9306072195289331, 'bagging_freq': 1, 'min_split_gain': 0.597087636776026}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:32:32,422] Trial 30 finished with value: 0.690656247448862 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 981, 'learning_rate': 0.0037989169265341353, 'max_depth': 7, 'num_leaves': 235, 'lambda_l1': 0.39166726868578894, 'lambda_l2': 0.04535392386140142, 'min_child_samples': 62, 'feature_fraction': 0.7823367504011547, 'bagging_fraction': 0.9041479992553907, 'bagging_freq': 5, 'min_split_gain': 0.16866263504954798}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:32:42,966] Trial 31 finished with value: 0.6966174687440932 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1124, 'learning_rate': 0.021808327212600242, 'max_depth': 5, 'num_leaves': 171, 'lambda_l1': 3.2315083345665157, 'lambda_l2': 0.1981657108269242, 'min_child_samples': 45, 'feature_fraction': 0.9569274427649519, 'bagging_fraction': 0.7843098937287988, 'bagging_freq': 2, 'min_split_gain': 0.5206494603546428}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:33:16,668] Trial 32 finished with value: 0.7099487244916615 and parameters: {'boosting_type': 'dart', 'n_estimators': 1261, 'learning_rate': 0.021246361007495853, 'max_depth': 3, 'num_leaves': 147, 'lambda_l1': 2.772528714944151, 'lambda_l2': 1.0653637761160795, 'min_child_samples': 39, 'feature_fraction': 0.950640169429177, 'bagging_fraction': 0.8354046328011491, 'bagging_freq': 2, 'min_split_gain': 0.5958416429294442}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:33:52,029] Trial 33 finished with value: 0.6874881255263406 and parameters: {'boosting_type': 'dart', 'n_estimators': 1289, 'learning_rate': 0.01003998940781152, 'max_depth': 4, 'num_leaves': 149, 'lambda_l1': 0.13836426459538428, 'lambda_l2': 1.2278115285481188, 'min_child_samples': 49, 'feature_fraction': 0.5435046643862158, 'bagging_fraction': 0.8536013786305885, 'bagging_freq': 2, 'min_split_gain': 0.734133761462306}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:33:53,195] Trial 34 finished with value: 0.6901539380116949 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 105, 'learning_rate': 0.05050736425955939, 'max_depth': 3, 'num_leaves': 206, 'lambda_l1': 9.716006465441907, 'lambda_l2': 2.8168748410905162, 'min_child_samples': 38, 'feature_fraction': 0.9217342595699051, 'bagging_fraction': 0.9521703699877213, 'bagging_freq': 1, 'min_split_gain': 0.5972558297244199}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:34:22,616] Trial 35 finished with value: 0.688818497146597 and parameters: {'boosting_type': 'dart', 'n_estimators': 1397, 'learning_rate': 0.030738235304241007, 'max_depth': 8, 'num_leaves': 104, 'lambda_l1': 0.9458017752949113, 'lambda_l2': 0.05841613798595131, 'min_child_samples': 59, 'feature_fraction': 0.9964425744023729, 'bagging_fraction': 0.7854143218462738, 'bagging_freq': 3, 'min_split_gain': 0.46643138423179614}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:34:30,777] Trial 36 finished with value: 0.6996892137584134 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 792, 'learning_rate': 0.008250239067876258, 'max_depth': 2, 'num_leaves': 129, 'lambda_l1': 2.030715516559989, 'lambda_l2': 0.589452142248973, 'min_child_samples': 24, 'feature_fraction': 0.8391564860745603, 'bagging_fraction': 0.7123136156688175, 'bagging_freq': 1, 'min_split_gain': 0.36200716807022126}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:34:53,427] Trial 37 finished with value: 0.6925198205457384 and parameters: {'boosting_type': 'dart', 'n_estimators': 1310, 'learning_rate': 0.12990069635643323, 'max_depth': 7, 'num_leaves': 201, 'lambda_l1': 0.12232562221779049, 'lambda_l2': 4.692606527234882, 'min_child_samples': 12, 'feature_fraction': 0.9322851250273386, 'bagging_fraction': 0.838494721664524, 'bagging_freq': 2, 'min_split_gain': 0.6118545863032385}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:35:17,567] Trial 38 finished with value: 0.6588423096801682 and parameters: {'boosting_type': 'dart', 'n_estimators': 1243, 'learning_rate': 0.00348466095526384, 'max_depth': 6, 'num_leaves': 178, 'lambda_l1': 9.650879212183651e-06, 'lambda_l2': 0.000274784673947127, 'min_child_samples': 74, 'feature_fraction': 0.7288268082458554, 'bagging_fraction': 0.8965617446388323, 'bagging_freq': 1, 'min_split_gain': 0.7046318359478381}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:35:29,343] Trial 39 finished with value: 0.7016267822414376 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1169, 'learning_rate': 0.011975115833380602, 'max_depth': 3, 'num_leaves': 228, 'lambda_l1': 3.1488889783632413e-07, 'lambda_l2': 0.012744096238394375, 'min_child_samples': 38, 'feature_fraction': 0.8114767263127762, 'bagging_fraction': 0.9589137536170668, 'bagging_freq': 3, 'min_split_gain': 0.8416652071165736}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:36:08,611] Trial 40 finished with value: 0.6890550980333279 and parameters: {'boosting_type': 'dart', 'n_estimators': 1449, 'learning_rate': 0.01878541211145461, 'max_depth': 5, 'num_leaves': 142, 'lambda_l1': 0.49187336978258744, 'lambda_l2': 0.10261052903612368, 'min_child_samples': 30, 'feature_fraction': 0.4177120644040283, 'bagging_fraction': 0.8590116026644389, 'bagging_freq': 2, 'min_split_gain': 0.471882152026727}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:36:24,234] Trial 41 finished with value: 0.7063981202452715 and parameters: {'boosting_type': 'dart', 'n_estimators': 1055, 'learning_rate': 0.02437098010415951, 'max_depth': 2, 'num_leaves': 162, 'lambda_l1': 3.396418927839283, 'lambda_l2': 0.21542324405360014, 'min_child_samples': 43, 'feature_fraction': 0.9543104378708046, 'bagging_fraction': 0.7947424572542893, 'bagging_freq': 2, 'min_split_gain': 0.5430901194520794}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:36:39,126] Trial 42 finished with value: 0.6988857454760345 and parameters: {'boosting_type': 'dart', 'n_estimators': 1030, 'learning_rate': 0.039995617866542585, 'max_depth': 2, 'num_leaves': 155, 'lambda_l1': 3.5800198121732274, 'lambda_l2': 1.4766833023515777, 'min_child_samples': 87, 'feature_fraction': 0.8888143799990459, 'bagging_fraction': 0.7853544425522263, 'bagging_freq': 2, 'min_split_gain': 0.5785898608972893}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:36:57,782] Trial 43 finished with value: 0.6967395971038494 and parameters: {'boosting_type': 'dart', 'n_estimators': 1278, 'learning_rate': 0.025752869423523426, 'max_depth': 2, 'num_leaves': 181, 'lambda_l1': 0.3959427685534234, 'lambda_l2': 3.1530345549653327, 'min_child_samples': 39, 'feature_fraction': 0.953262476229289, 'bagging_fraction': 0.7264560180174325, 'bagging_freq': 3, 'min_split_gain': 0.6416805408677501}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:37:04,347] Trial 44 finished with value: 0.6790271302350374 and parameters: {'boosting_type': 'dart', 'n_estimators': 454, 'learning_rate': 0.013796714700462438, 'max_depth': 3, 'num_leaves': 160, 'lambda_l1': 6.070211017827915, 'lambda_l2': 0.4823446628883962, 'min_child_samples': 50, 'feature_fraction': 0.9986927991010203, 'bagging_fraction': 0.7581323646199308, 'bagging_freq': 1, 'min_split_gain': 0.7036046028532856}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:37:23,018] Trial 45 finished with value: 0.6817472997269166 and parameters: {'boosting_type': 'dart', 'n_estimators': 855, 'learning_rate': 0.005480670185465118, 'max_depth': 4, 'num_leaves': 138, 'lambda_l1': 1.2268437790523326, 'lambda_l2': 1.1371695976016802, 'min_child_samples': 54, 'feature_fraction': 0.8590342913448987, 'bagging_fraction': 0.8913077881383238, 'bagging_freq': 2, 'min_split_gain': 0.3453535371508608}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:37:31,436] Trial 46 finished with value: 0.6997700019268991 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1059, 'learning_rate': 0.01697411419661253, 'max_depth': 2, 'num_leaves': 120, 'lambda_l1': 0.20221135939893375, 'lambda_l2': 4.947810387799617, 'min_child_samples': 34, 'feature_fraction': 0.9404354629828049, 'bagging_fraction': 0.9552730357317335, 'bagging_freq': 3, 'min_split_gain': 0.7761979055453523}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:37:55,630] Trial 47 finished with value: 0.6905117410099199 and parameters: {'boosting_type': 'dart', 'n_estimators': 1158, 'learning_rate': 0.08507832272414559, 'max_depth': 8, 'num_leaves': 199, 'lambda_l1': 0.03678394170179824, 'lambda_l2': 3.8907932081135675e-05, 'min_child_samples': 62, 'feature_fraction': 0.9068492161542755, 'bagging_fraction': 0.9912194220433399, 'bagging_freq': 2, 'min_split_gain': 0.48774064678614726}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:38:01,381] Trial 48 finished with value: 0.6319777329194133 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 909, 'learning_rate': 0.1928368593713324, 'max_depth': 4, 'num_leaves': 98, 'lambda_l1': 7.393335057239209e-05, 'lambda_l2': 0.024697487555965802, 'min_child_samples': 56, 'feature_fraction': 0.9641042518797797, 'bagging_fraction': 0.7917612760293984, 'bagging_freq': 1, 'min_split_gain': 0.5519399451057243}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:38:22,568] Trial 49 finished with value: 0.7067746988694976 and parameters: {'boosting_type': 'dart', 'n_estimators': 1399, 'learning_rate': 0.03549000205364923, 'max_depth': 5, 'num_leaves': 172, 'lambda_l1': 5.384865953322195, 'lambda_l2': 2.0721618652479984e-06, 'min_child_samples': 48, 'feature_fraction': 0.8314506135095733, 'bagging_fraction': 0.8459001722291939, 'bagging_freq': 4, 'min_split_gain': 0.6762640680328655}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:38:48,556] Trial 50 finished with value: 0.6747051083368302 and parameters: {'boosting_type': 'dart', 'n_estimators': 1419, 'learning_rate': 0.035122211707533234, 'max_depth': 5, 'num_leaves': 57, 'lambda_l1': 0.9636150288459312, 'lambda_l2': 1.826154773486996e-06, 'min_child_samples': 27, 'feature_fraction': 0.4767133976928516, 'bagging_fraction': 0.6227454762547077, 'bagging_freq': 5, 'min_split_gain': 0.6829103462940741}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:39:07,082] Trial 51 finished with value: 0.7028451458288836 and parameters: {'boosting_type': 'dart', 'n_estimators': 1444, 'learning_rate': 0.061024841874026875, 'max_depth': 5, 'num_leaves': 173, 'lambda_l1': 4.908203812209713, 'lambda_l2': 4.918615466054816e-07, 'min_child_samples': 47, 'feature_fraction': 0.9730013632832091, 'bagging_fraction': 0.8460387886220303, 'bagging_freq': 4, 'min_split_gain': 0.6304773377802526}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:39:23,537] Trial 52 finished with value: 0.6954410250081847 and parameters: {'boosting_type': 'dart', 'n_estimators': 987, 'learning_rate': 0.0455593762916178, 'max_depth': 3, 'num_leaves': 190, 'lambda_l1': 2.025619151480237, 'lambda_l2': 1.1532078194127547e-08, 'min_child_samples': 41, 'feature_fraction': 0.8348993441778622, 'bagging_fraction': 0.8791200960058295, 'bagging_freq': 6, 'min_split_gain': 0.5788493089990798}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:39:41,852] Trial 53 finished with value: 0.7029101843777475 and parameters: {'boosting_type': 'dart', 'n_estimators': 1223, 'learning_rate': 0.03293496499308388, 'max_depth': 6, 'num_leaves': 147, 'lambda_l1': 9.424372737766914, 'lambda_l2': 4.822561608311863e-05, 'min_child_samples': 49, 'feature_fraction': 0.8795883386840171, 'bagging_fraction': 0.9191159165664725, 'bagging_freq': 4, 'min_split_gain': 0.6678638574743999}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:40:14,747] Trial 54 finished with value: 0.6838802015855268 and parameters: {'boosting_type': 'dart', 'n_estimators': 1496, 'learning_rate': 0.019087191368658978, 'max_depth': 4, 'num_leaves': 128, 'lambda_l1': 0.2516526806291958, 'lambda_l2': 3.2059966107722354e-08, 'min_child_samples': 62, 'feature_fraction': 0.9015576377096044, 'bagging_fraction': 0.8333686911901691, 'bagging_freq': 3, 'min_split_gain': 0.5048170897346719}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:40:33,519] Trial 55 finished with value: 0.7019162264457587 and parameters: {'boosting_type': 'dart', 'n_estimators': 1363, 'learning_rate': 0.025164513887634913, 'max_depth': 2, 'num_leaves': 160, 'lambda_l1': 0.6095464877791963, 'lambda_l2': 0.0008301004270774614, 'min_child_samples': 68, 'feature_fraction': 0.9351404001960453, 'bagging_fraction': 0.8620300014448133, 'bagging_freq': 5, 'min_split_gain': 0.8978789390358468}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:40:42,671] Trial 56 finished with value: 0.6847737719473299 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1273, 'learning_rate': 0.0395587851306506, 'max_depth': 5, 'num_leaves': 185, 'lambda_l1': 1.7527947978466132, 'lambda_l2': 0.31560078898334154, 'min_child_samples': 46, 'feature_fraction': 0.9762429959777214, 'bagging_fraction': 0.6979947152665414, 'bagging_freq': 2, 'min_split_gain': 0.4369825956193198}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:41:05,338] Trial 57 finished with value: 0.6576302775445874 and parameters: {'boosting_type': 'dart', 'n_estimators': 1160, 'learning_rate': 0.06514221209903472, 'max_depth': 3, 'num_leaves': 173, 'lambda_l1': 0.00035514966303516884, 'lambda_l2': 1.3524905106496843e-06, 'min_child_samples': 36, 'feature_fraction': 0.7457671817664849, 'bagging_fraction': 0.8045642133234928, 'bagging_freq': 3, 'min_split_gain': 0.5311688723066894}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:41:10,972] Trial 58 finished with value: 0.7001534720514394 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 702, 'learning_rate': 0.028243302567142418, 'max_depth': 4, 'num_leaves': 210, 'lambda_l1': 3.891044624868345, 'lambda_l2': 4.844413966119919, 'min_child_samples': 30, 'feature_fraction': 0.8688971653459203, 'bagging_fraction': 0.7633458895256577, 'bagging_freq': 4, 'min_split_gain': 0.6161444636281548}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:41:32,347] Trial 59 finished with value: 0.6964229255229677 and parameters: {'boosting_type': 'dart', 'n_estimators': 1065, 'learning_rate': 0.012060428555561909, 'max_depth': 2, 'num_leaves': 155, 'lambda_l1': 1.6045459715280042, 'lambda_l2': 9.69097002078176, 'min_child_samples': 52, 'feature_fraction': 0.9283475323136987, 'bagging_fraction': 0.96556678817709, 'bagging_freq': 2, 'min_split_gain': 0.7009767791326764}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:41:50,547] Trial 60 finished with value: 0.6842616872746037 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1188, 'learning_rate': 0.01451666574922334, 'max_depth': 3, 'num_leaves': 84, 'lambda_l1': 0.014203141488681676, 'lambda_l2': 0.22161323591330434, 'min_child_samples': 58, 'feature_fraction': 0.975423041915573, 'bagging_fraction': 0.9129930594797604, 'bagging_freq': 3, 'min_split_gain': 0.6535073510049012}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:42:19,861] Trial 61 finished with value: 0.6986408215084552 and parameters: {'boosting_type': 'dart', 'n_estimators': 1111, 'learning_rate': 0.02131228150098905, 'max_depth': 3, 'num_leaves': 167, 'lambda_l1': 5.257529608441441, 'lambda_l2': 0.7294236044740696, 'min_child_samples': 43, 'feature_fraction': 0.9579027348977289, 'bagging_fraction': 0.8184089776421872, 'bagging_freq': 2, 'min_split_gain': 0.5509079012574499}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:42:47,043] Trial 62 finished with value: 0.7085684491224605 and parameters: {'boosting_type': 'dart', 'n_estimators': 978, 'learning_rate': 0.02676328686236504, 'max_depth': 4, 'num_leaves': 193, 'lambda_l1': 2.622955681861678, 'lambda_l2': 0.14961325050317686, 'min_child_samples': 44, 'feature_fraction': 0.9452560808858659, 'bagging_fraction': 0.8083471405724525, 'bagging_freq': 2, 'min_split_gain': 0.5339623716486958}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:43:16,970] Trial 63 finished with value: 0.6934527325368128 and parameters: {'boosting_type': 'dart', 'n_estimators': 1001, 'learning_rate': 0.051071065811307166, 'max_depth': 12, 'num_leaves': 192, 'lambda_l1': 0.7617839438865713, 'lambda_l2': 2.1794528743941837, 'min_child_samples': 41, 'feature_fraction': 0.9022744282802023, 'bagging_fraction': 0.8745936295650878, 'bagging_freq': 2, 'min_split_gain': 0.5743029914322326}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:43:41,714] Trial 64 finished with value: 0.7013503020482093 and parameters: {'boosting_type': 'dart', 'n_estimators': 946, 'learning_rate': 0.02587130175280317, 'max_depth': 4, 'num_leaves': 177, 'lambda_l1': 2.1602059023239195, 'lambda_l2': 1.0859758312302992, 'min_child_samples': 50, 'feature_fraction': 0.9970248465244849, 'bagging_fraction': 0.7485629045825064, 'bagging_freq': 2, 'min_split_gain': 0.8009411428683765}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:44:02,438] Trial 65 finished with value: 0.6962028234509966 and parameters: {'boosting_type': 'dart', 'n_estimators': 842, 'learning_rate': 0.01680479189069627, 'max_depth': 6, 'num_leaves': 198, 'lambda_l1': 0.278070279265155, 'lambda_l2': 0.11820944669991827, 'min_child_samples': 71, 'feature_fraction': 0.9380514819191027, 'bagging_fraction': 0.5407794397056238, 'bagging_freq': 1, 'min_split_gain': 0.05335223443941539}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:44:32,122] Trial 66 finished with value: 0.7132447311089128 and parameters: {'boosting_type': 'dart', 'n_estimators': 1130, 'learning_rate': 0.03522847081745157, 'max_depth': 4, 'num_leaves': 143, 'lambda_l1': 5.901683868876003, 'lambda_l2': 0.304745353840791, 'min_child_samples': 45, 'feature_fraction': 0.6782404856390628, 'bagging_fraction': 0.9335779298439263, 'bagging_freq': 2, 'min_split_gain': 0.43652491729652965}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:44:54,559] Trial 67 finished with value: 0.6981449010292691 and parameters: {'boosting_type': 'dart', 'n_estimators': 1061, 'learning_rate': 0.034691869417468414, 'max_depth': 4, 'num_leaves': 136, 'lambda_l1': 9.465534764595072, 'lambda_l2': 0.28481624584899934, 'min_child_samples': 45, 'feature_fraction': 0.648662040789273, 'bagging_fraction': 0.7743838041366704, 'bagging_freq': 5, 'min_split_gain': 0.3856752609541401}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:45:49,063] Trial 68 finished with value: 0.6619733695749058 and parameters: {'boosting_type': 'dart', 'n_estimators': 1127, 'learning_rate': 0.020205056227866915, 'max_depth': 11, 'num_leaves': 118, 'lambda_l1': 6.730863026987447e-07, 'lambda_l2': 0.0034840478911202424, 'min_child_samples': 34, 'feature_fraction': 0.6962760480497081, 'bagging_fraction': 0.8083764254961112, 'bagging_freq': 3, 'min_split_gain': 0.4487649901537999}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:46:11,606] Trial 69 finished with value: 0.6911150115654499 and parameters: {'boosting_type': 'dart', 'n_estimators': 971, 'learning_rate': 0.031144666822981223, 'max_depth': 2, 'num_leaves': 147, 'lambda_l1': 0.07878830623693447, 'lambda_l2': 0.06338143421801004, 'min_child_samples': 39, 'feature_fraction': 0.5675625165390998, 'bagging_fraction': 0.9443368853943238, 'bagging_freq': 7, 'min_split_gain': 0.501056475734681}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:46:28,334] Trial 70 finished with value: 0.6996869491811548 and parameters: {'boosting_type': 'dart', 'n_estimators': 746, 'learning_rate': 0.024209537371113886, 'max_depth': 4, 'num_leaves': 161, 'lambda_l1': 5.306752391358838, 'lambda_l2': 0.01370355100126609, 'min_child_samples': 56, 'feature_fraction': 0.6804424906849226, 'bagging_fraction': 0.978765688786158, 'bagging_freq': 1, 'min_split_gain': 0.40904919487083435}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:47:01,141] Trial 71 finished with value: 0.7022644066943912 and parameters: {'boosting_type': 'dart', 'n_estimators': 1337, 'learning_rate': 0.041862268827696336, 'max_depth': 5, 'num_leaves': 144, 'lambda_l1': 3.1205775075844095, 'lambda_l2': 5.7400047457943755, 'min_child_samples': 45, 'feature_fraction': 0.6251259153311103, 'bagging_fraction': 0.8361655082826196, 'bagging_freq': 2, 'min_split_gain': 0.604382829854127}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:47:09,474] Trial 72 finished with value: 0.6944275997541789 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1253, 'learning_rate': 0.055996612652121656, 'max_depth': 5, 'num_leaves': 219, 'lambda_l1': 0.6688638124499101, 'lambda_l2': 2.8308658842756014, 'min_child_samples': 64, 'feature_fraction': 0.979967093575696, 'bagging_fraction': 0.9376402642694096, 'bagging_freq': 2, 'min_split_gain': 0.5331548799013013}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:47:36,932] Trial 73 finished with value: 0.6960624912049543 and parameters: {'boosting_type': 'dart', 'n_estimators': 1216, 'learning_rate': 0.07461948947309932, 'max_depth': 3, 'num_leaves': 155, 'lambda_l1': 1.2534873625821656, 'lambda_l2': 0.4144117976880048, 'min_child_samples': 36, 'feature_fraction': 0.9139867197473778, 'bagging_fraction': 0.9104013226618203, 'bagging_freq': 2, 'min_split_gain': 0.7394560559123129}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:48:02,069] Trial 74 finished with value: 0.6948584693217268 and parameters: {'boosting_type': 'dart', 'n_estimators': 1034, 'learning_rate': 0.046711552810334955, 'max_depth': 5, 'num_leaves': 132, 'lambda_l1': 2.745069635566259, 'lambda_l2': 0.7081849340832328, 'min_child_samples': 51, 'feature_fraction': 0.7964765163810362, 'bagging_fraction': 0.7989286961237894, 'bagging_freq': 3, 'min_split_gain': 0.48644633833357864}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:48:11,233] Trial 75 finished with value: 0.7085535503876557 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 881, 'learning_rate': 0.015305974464759578, 'max_depth': 7, 'num_leaves': 185, 'lambda_l1': 6.218273837871454, 'lambda_l2': 0.143614168707476, 'min_child_samples': 54, 'feature_fraction': 0.7158149659467582, 'bagging_fraction': 0.9950561476955433, 'bagging_freq': 2, 'min_split_gain': 0.5701892642392479}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:48:36,040] Trial 76 finished with value: 0.7066538340058962 and parameters: {'boosting_type': 'dart', 'n_estimators': 887, 'learning_rate': 0.011750721813550927, 'max_depth': 7, 'num_leaves': 183, 'lambda_l1': 7.534352311367346, 'lambda_l2': 0.13494471585372184, 'min_child_samples': 48, 'feature_fraction': 0.7133749567728771, 'bagging_fraction': 0.9795426468950531, 'bagging_freq': 2, 'min_split_gain': 0.5564543788620275}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:48:49,217] Trial 77 finished with value: 0.711464157621239 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 870, 'learning_rate': 0.00814606845698095, 'max_depth': 9, 'num_leaves': 185, 'lambda_l1': 5.528280271937253, 'lambda_l2': 0.15689011677487863, 'min_child_samples': 48, 'feature_fraction': 0.7385513592983719, 'bagging_fraction': 0.9749039923410499, 'bagging_freq': 2, 'min_split_gain': 0.6399570633027196}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:48:58,230] Trial 78 finished with value: 0.7063464773849297 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 878, 'learning_rate': 0.008283379576711406, 'max_depth': 8, 'num_leaves': 185, 'lambda_l1': 7.204041466130844, 'lambda_l2': 0.026734205868859048, 'min_child_samples': 54, 'feature_fraction': 0.7194934512377295, 'bagging_fraction': 0.979578509431372, 'bagging_freq': 1, 'min_split_gain': 0.6405594907088977}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:49:08,419] Trial 79 finished with value: 0.7088709378477399 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 763, 'learning_rate': 0.009939141104967845, 'max_depth': 8, 'num_leaves': 206, 'lambda_l1': 6.282119558270432, 'lambda_l2': 0.12381421750211286, 'min_child_samples': 48, 'feature_fraction': 0.7581296778594664, 'bagging_fraction': 0.9937562769671006, 'bagging_freq': 2, 'min_split_gain': 0.7145900941454395}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:49:20,937] Trial 80 finished with value: 0.6996997522392032 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 752, 'learning_rate': 0.00673813843346195, 'max_depth': 9, 'num_leaves': 204, 'lambda_l1': 1.4200044630145876, 'lambda_l2': 0.004658417716945017, 'min_child_samples': 59, 'feature_fraction': 0.674168380714293, 'bagging_fraction': 0.9989996839438531, 'bagging_freq': 3, 'min_split_gain': 0.6851333458309832}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:49:31,025] Trial 81 finished with value: 0.7027049840046761 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 822, 'learning_rate': 0.010309951912885603, 'max_depth': 9, 'num_leaves': 223, 'lambda_l1': 9.981829450861717, 'lambda_l2': 0.07606507276342718, 'min_child_samples': 56, 'feature_fraction': 0.7567841843652051, 'bagging_fraction': 0.9708618258817384, 'bagging_freq': 2, 'min_split_gain': 0.7265285279105228}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:49:42,742] Trial 82 finished with value: 0.7078411221309269 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 641, 'learning_rate': 0.00722030645133292, 'max_depth': 8, 'num_leaves': 196, 'lambda_l1': 4.917971038756254, 'lambda_l2': 0.14224780789724334, 'min_child_samples': 48, 'feature_fraction': 0.7199739159856207, 'bagging_fraction': 0.9906646067657979, 'bagging_freq': 2, 'min_split_gain': 0.619783512558189}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:49:52,769] Trial 83 finished with value: 0.7022952784828008 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 545, 'learning_rate': 0.0072002167200401045, 'max_depth': 8, 'num_leaves': 208, 'lambda_l1': 4.428128240858058, 'lambda_l2': 0.05026984956382141, 'min_child_samples': 52, 'feature_fraction': 0.768660267978328, 'bagging_fraction': 0.9973446265699359, 'bagging_freq': 2, 'min_split_gain': 0.7616130167603672}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:50:09,480] Trial 84 finished with value: 0.6944162130103139 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 607, 'learning_rate': 0.005413623331168474, 'max_depth': 10, 'num_leaves': 214, 'lambda_l1': 0.9595476597423044, 'lambda_l2': 0.17584951075824248, 'min_child_samples': 47, 'feature_fraction': 0.6591004482767326, 'bagging_fraction': 0.9532496795286567, 'bagging_freq': 2, 'min_split_gain': 0.7165251552913826}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:50:24,853] Trial 85 finished with value: 0.6897418520801164 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 527, 'learning_rate': 0.004563656103335233, 'max_depth': 9, 'num_leaves': 194, 'lambda_l1': 1.020498773459196e-08, 'lambda_l2': 0.041034314882262134, 'min_child_samples': 41, 'feature_fraction': 0.7019702559097575, 'bagging_fraction': 0.964708449967255, 'bagging_freq': 1, 'min_split_gain': 0.6231542803126756}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:50:37,336] Trial 86 finished with value: 0.7069730130605092 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 689, 'learning_rate': 0.009527031581967445, 'max_depth': 7, 'num_leaves': 229, 'lambda_l1': 2.113146132383154, 'lambda_l2': 0.01765457717702586, 'min_child_samples': 48, 'feature_fraction': 0.7625414009495907, 'bagging_fraction': 0.9251691583275024, 'bagging_freq': 2, 'min_split_gain': 0.6668789995657005}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:50:51,862] Trial 87 finished with value: 0.704313702259297 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 762, 'learning_rate': 0.009368485188073306, 'max_depth': 8, 'num_leaves': 243, 'lambda_l1': 1.8972172785284385, 'lambda_l2': 0.019001761186703825, 'min_child_samples': 54, 'feature_fraction': 0.7338807484248646, 'bagging_fraction': 0.9241546249059778, 'bagging_freq': 2, 'min_split_gain': 0.5944209566782034}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:51:03,785] Trial 88 finished with value: 0.6960670758000908 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 661, 'learning_rate': 0.01517777251770112, 'max_depth': 8, 'num_leaves': 224, 'lambda_l1': 0.315750867210337, 'lambda_l2': 0.08964671141204476, 'min_child_samples': 60, 'feature_fraction': 0.7512249788751462, 'bagging_fraction': 0.9874566781007754, 'bagging_freq': 2, 'min_split_gain': 0.6463459652763734}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:51:12,298] Trial 89 finished with value: 0.6891901141947508 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 704, 'learning_rate': 0.011363282317460538, 'max_depth': 10, 'num_leaves': 216, 'lambda_l1': 2.5523285665797735, 'lambda_l2': 0.007255880472457473, 'min_child_samples': 32, 'feature_fraction': 0.6038274486952883, 'bagging_fraction': 0.9434090826600462, 'bagging_freq': 1, 'min_split_gain': 0.7768167420894886}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:51:27,461] Trial 90 finished with value: 0.6902895116790836 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 656, 'learning_rate': 0.0132564697497293, 'max_depth': 7, 'num_leaves': 230, 'lambda_l1': 0.15984534363244965, 'lambda_l2': 0.5394813360285433, 'min_child_samples': 38, 'feature_fraction': 0.7684726268250182, 'bagging_fraction': 0.9007180788290667, 'bagging_freq': 2, 'min_split_gain': 0.8269685695363187}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:51:40,367] Trial 91 finished with value: 0.7096321737370025 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 808, 'learning_rate': 0.007668524761545517, 'max_depth': 7, 'num_leaves': 199, 'lambda_l1': 5.455974570006032, 'lambda_l2': 0.030441524986462246, 'min_child_samples': 48, 'feature_fraction': 0.7942827012236136, 'bagging_fraction': 0.9719850686970948, 'bagging_freq': 2, 'min_split_gain': 0.67319403437801}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:51:53,277] Trial 92 finished with value: 0.7028151887927342 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 803, 'learning_rate': 0.007334990758962142, 'max_depth': 7, 'num_leaves': 198, 'lambda_l1': 5.586882483369892, 'lambda_l2': 0.02739083780108721, 'min_child_samples': 44, 'feature_fraction': 0.7884385733119105, 'bagging_fraction': 0.9633747310308693, 'bagging_freq': 2, 'min_split_gain': 0.6671290702520607}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:52:15,223] Trial 93 finished with value: 0.6884313333039862 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 929, 'learning_rate': 0.009152088553424424, 'max_depth': 7, 'num_leaves': 204, 'lambda_l1': 0.45170653294408053, 'lambda_l2': 0.3054529063298015, 'min_child_samples': 51, 'feature_fraction': 0.8017805694353524, 'bagging_fraction': 0.9433963474386451, 'bagging_freq': 2, 'min_split_gain': 0.6214348738594265}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:52:30,399] Trial 94 finished with value: 0.7017505059332066 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 782, 'learning_rate': 0.005691216631763542, 'max_depth': 9, 'num_leaves': 187, 'lambda_l1': 1.299197212361271, 'lambda_l2': 0.1365978591440239, 'min_child_samples': 49, 'feature_fraction': 0.6954351045204222, 'bagging_fraction': 0.9990960671730607, 'bagging_freq': 2, 'min_split_gain': 0.5917461994881253}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:52:41,958] Trial 95 finished with value: 0.6807812769731116 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 728, 'learning_rate': 0.004614485104692077, 'max_depth': 7, 'num_leaves': 236, 'lambda_l1': 4.042936818613911, 'lambda_l2': 0.0015011878428302875, 'min_child_samples': 56, 'feature_fraction': 0.7187518761209113, 'bagging_fraction': 0.4389737418329487, 'bagging_freq': 3, 'min_split_gain': 0.6871093642615924}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:53:00,712] Trial 96 finished with value: 0.6921908382436813 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 676, 'learning_rate': 0.0030500828746892394, 'max_depth': 8, 'num_leaves': 108, 'lambda_l1': 2.159438646878861, 'lambda_l2': 0.07998330181947448, 'min_child_samples': 46, 'feature_fraction': 0.7392283702793337, 'bagging_fraction': 0.9782467732048257, 'bagging_freq': 2, 'min_split_gain': 0.6554672857673564}. Best is trial 11 with value: 0.7217922002251281.
# ...
# [I 2026-03-13 21:56:35,733] Trial 118 finished with value: 0.7079966259595855 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1134, 'learning_rate': 0.028825316056727696, 'max_depth': 6, 'num_leaves': 136, 'lambda_l1': 1.4291413526408119, 'lambda_l2': 1.4559376455541118, 'min_child_samples': 96, 'feature_fraction': 0.8762912030747052, 'bagging_fraction': 0.9730786885988157, 'bagging_freq': 6, 'min_split_gain': 0.8801195783490584}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:56:43,748] Trial 119 finished with value: 0.7116694832146181 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 896, 'learning_rate': 0.02103170791831371, 'max_depth': 7, 'num_leaves': 146, 'lambda_l1': 2.3296075449394067, 'lambda_l2': 3.4834047296470776, 'min_child_samples': 53, 'feature_fraction': 0.890399855716181, 'bagging_fraction': 0.9603436877372243, 'bagging_freq': 2, 'min_split_gain': 0.7821413230077667}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:56:53,811] Trial 120 finished with value: 0.6955664062020582 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 957, 'learning_rate': 0.020158881343098515, 'max_depth': 6, 'num_leaves': 145, 'lambda_l1': 1.636531195789725e-05, 'lambda_l2': 3.3449636882296856, 'min_child_samples': 66, 'feature_fraction': 0.85632503842357, 'bagging_fraction': 0.9513610198396597, 'bagging_freq': 3, 'min_split_gain': 0.8219842622322251}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:57:03,661] Trial 121 finished with value: 0.7117373994125161 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 854, 'learning_rate': 0.014016638988388683, 'max_depth': 7, 'num_leaves': 150, 'lambda_l1': 2.327445460404274, 'lambda_l2': 6.719482430208097, 'min_child_samples': 54, 'feature_fraction': 0.8857210108898432, 'bagging_fraction': 0.9610051504433252, 'bagging_freq': 2, 'min_split_gain': 0.7869711851824501}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:57:13,468] Trial 122 finished with value: 0.7085020381684344 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 893, 'learning_rate': 0.015968485633930243, 'max_depth': 7, 'num_leaves': 163, 'lambda_l1': 2.2222572988752916, 'lambda_l2': 8.195132270329516, 'min_child_samples': 53, 'feature_fraction': 0.8910481143399205, 'bagging_fraction': 0.9607407556992872, 'bagging_freq': 2, 'min_split_gain': 0.7756612500067702}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:57:24,708] Trial 123 finished with value: 0.7001190415056376 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 850, 'learning_rate': 0.013839788887889438, 'max_depth': 7, 'num_leaves': 170, 'lambda_l1': 0.7563080944838114, 'lambda_l2': 2.1403907213795375, 'min_child_samples': 54, 'feature_fraction': 0.8436347617675825, 'bagging_fraction': 0.8778926153925412, 'bagging_freq': 2, 'min_split_gain': 0.9284540640050722}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:57:32,549] Trial 124 finished with value: 0.7046602534170985 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 927, 'learning_rate': 0.02089725741190351, 'max_depth': 7, 'num_leaves': 149, 'lambda_l1': 4.270371844882866, 'lambda_l2': 6.865161519541605, 'min_child_samples': 58, 'feature_fraction': 0.8525666072540025, 'bagging_fraction': 0.9329100484983585, 'bagging_freq': 2, 'min_split_gain': 0.832933038306765}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:57:41,520] Trial 125 finished with value: 0.7154384039665356 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1028, 'learning_rate': 0.01896565701931039, 'max_depth': 8, 'num_leaves': 158, 'lambda_l1': 2.5752596153913374, 'lambda_l2': 3.673435189812204, 'min_child_samples': 55, 'feature_fraction': 0.871874383988072, 'bagging_fraction': 0.9835977165418552, 'bagging_freq': 2, 'min_split_gain': 0.7874489866603449}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:57:53,290] Trial 126 finished with value: 0.7075621628587333 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1013, 'learning_rate': 0.01241552282270871, 'max_depth': 7, 'num_leaves': 155, 'lambda_l1': 1.0386992049317396, 'lambda_l2': 4.015010468249915, 'min_child_samples': 61, 'feature_fraction': 0.867168475758152, 'bagging_fraction': 0.9784145832269687, 'bagging_freq': 2, 'min_split_gain': 0.8071531471935801}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:58:05,436] Trial 127 finished with value: 0.7021916646338179 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1055, 'learning_rate': 0.018678559411282124, 'max_depth': 8, 'num_leaves': 159, 'lambda_l1': 0.001170793337086772, 'lambda_l2': 4.218467871500991, 'min_child_samples': 55, 'feature_fraction': 0.8816535328838833, 'bagging_fraction': 0.9614963897126996, 'bagging_freq': 2, 'min_split_gain': 0.7795921110338054}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:58:13,240] Trial 128 finished with value: 0.7119323990718348 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 968, 'learning_rate': 0.016785033416480737, 'max_depth': 8, 'num_leaves': 166, 'lambda_l1': 2.4829893740277607, 'lambda_l2': 2.0644301240067264, 'min_child_samples': 51, 'feature_fraction': 0.82478868230101, 'bagging_fraction': 0.9839837971626381, 'bagging_freq': 1, 'min_split_gain': 0.8576542628731745}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:58:23,120] Trial 129 finished with value: 0.6934045395252708 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 990, 'learning_rate': 0.016096345738395697, 'max_depth': 8, 'num_leaves': 165, 'lambda_l1': 2.0576222668367577e-06, 'lambda_l2': 1.4157195211995375, 'min_child_samples': 52, 'feature_fraction': 0.8245320732017557, 'bagging_fraction': 0.9465695865496166, 'bagging_freq': 1, 'min_split_gain': 0.9328162391561019}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:58:31,076] Trial 130 finished with value: 0.7108662965979947 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 959, 'learning_rate': 0.014346546187994696, 'max_depth': 8, 'num_leaves': 140, 'lambda_l1': 1.5097563518087755, 'lambda_l2': 2.1183047579767185, 'min_child_samples': 58, 'feature_fraction': 0.8374724217608086, 'bagging_fraction': 0.9854485949953733, 'bagging_freq': 1, 'min_split_gain': 0.8710343902846284}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:58:39,781] Trial 131 finished with value: 0.7072021268129727 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1033, 'learning_rate': 0.016997403482643735, 'max_depth': 9, 'num_leaves': 175, 'lambda_l1': 2.257367510166708, 'lambda_l2': 9.735673237032781, 'min_child_samples': 50, 'feature_fraction': 0.8056343129913561, 'bagging_fraction': 0.922756600680364, 'bagging_freq': 1, 'min_split_gain': 0.8156520656884576}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:58:48,649] Trial 132 finished with value: 0.7032758444399955 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1082, 'learning_rate': 0.01119789178464289, 'max_depth': 8, 'num_leaves': 151, 'lambda_l1': 9.95626868242778, 'lambda_l2': 0.40151826929119455, 'min_child_samples': 63, 'feature_fraction': 0.8930901418584519, 'bagging_fraction': 0.955450814074579, 'bagging_freq': 4, 'min_split_gain': 0.7660814093739529}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:58:55,744] Trial 133 finished with value: 0.7082756691534323 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 879, 'learning_rate': 0.023940646680071977, 'max_depth': 7, 'num_leaves': 169, 'lambda_l1': 3.923472597142695, 'lambda_l2': 6.035031507291334, 'min_child_samples': 53, 'feature_fraction': 0.8586100015894438, 'bagging_fraction': 0.9686666100181088, 'bagging_freq': 2, 'min_split_gain': 0.7882704995394579}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:59:03,831] Trial 134 finished with value: 0.7111763305959936 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 924, 'learning_rate': 0.019144356135025836, 'max_depth': 9, 'num_leaves': 132, 'lambda_l1': 2.480411167336267, 'lambda_l2': 1.0947287601938867, 'min_child_samples': 60, 'feature_fraction': 0.8252433208334159, 'bagging_fraction': 0.9826270329083477, 'bagging_freq': 2, 'min_split_gain': 0.9589438832675019}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:59:11,807] Trial 135 finished with value: 0.7161929017826519 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 867, 'learning_rate': 0.015172078303741001, 'max_depth': 7, 'num_leaves': 158, 'lambda_l1': 6.7140914976806325, 'lambda_l2': 2.9788877011937, 'min_child_samples': 55, 'feature_fraction': 0.8385418343152249, 'bagging_fraction': 0.943383658978732, 'bagging_freq': 3, 'min_split_gain': 0.8342751266951627}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:59:20,166] Trial 136 finished with value: 0.7116768840967396 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 967, 'learning_rate': 0.015210297655655161, 'max_depth': 7, 'num_leaves': 164, 'lambda_l1': 6.499004103486778, 'lambda_l2': 3.239298035496921, 'min_child_samples': 55, 'feature_fraction': 0.8743923680610892, 'bagging_fraction': 0.9412235499337674, 'bagging_freq': 3, 'min_split_gain': 0.8489535756251189}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:59:28,004] Trial 137 finished with value: 0.7097069654891954 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 982, 'learning_rate': 0.015795065687695873, 'max_depth': 7, 'num_leaves': 164, 'lambda_l1': 7.023007560051508, 'lambda_l2': 0.7376534862675227, 'min_child_samples': 57, 'feature_fraction': 0.833104302403513, 'bagging_fraction': 0.9398862922325534, 'bagging_freq': 3, 'min_split_gain': 0.8866512572250488}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:59:42,551] Trial 138 finished with value: 0.6912731643873541 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1046, 'learning_rate': 0.013533989963244994, 'max_depth': 7, 'num_leaves': 156, 'lambda_l1': 0.002744239741505053, 'lambda_l2': 2.200782059926513, 'min_child_samples': 55, 'feature_fraction': 0.8747526105617881, 'bagging_fraction': 0.9075256431399322, 'bagging_freq': 3, 'min_split_gain': 0.8573261840500268}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 21:59:52,445] Trial 139 finished with value: 0.7082054399386971 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 944, 'learning_rate': 0.012057066469769529, 'max_depth': 6, 'num_leaves': 159, 'lambda_l1': 4.209947675712001, 'lambda_l2': 4.723489864577382, 'min_child_samples': 51, 'feature_fraction': 0.8444830001253734, 'bagging_fraction': 0.9236808383517617, 'bagging_freq': 3, 'min_split_gain': 0.8335751555133022}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 22:00:10,457] Trial 140 finished with value: 0.6758313859703174 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1009, 'learning_rate': 0.0013589061777509253, 'max_depth': 8, 'num_leaves': 172, 'lambda_l1': 6.739750595509185, 'lambda_l2': 1.4344818393108396, 'min_child_samples': 59, 'feature_fraction': 0.8612954950169895, 'bagging_fraction': 0.9436986811522604, 'bagging_freq': 3, 'min_split_gain': 0.8627674819402605}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 22:00:19,299] Trial 141 finished with value: 0.7111203254454228 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 847, 'learning_rate': 0.014664871817609528, 'max_depth': 7, 'num_leaves': 144, 'lambda_l1': 2.843025407518019, 'lambda_l2': 6.656936954011626, 'min_child_samples': 55, 'feature_fraction': 0.9114125503747206, 'bagging_fraction': 0.9604640506786671, 'bagging_freq': 3, 'min_split_gain': 0.8413126639761854}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 22:00:28,651] Trial 142 finished with value: 0.7009662806077945 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 904, 'learning_rate': 0.017912382004285732, 'max_depth': 7, 'num_leaves': 149, 'lambda_l1': 1.5870392076635942, 'lambda_l2': 2.9536357064194525, 'min_child_samples': 53, 'feature_fraction': 0.9005517780035743, 'bagging_fraction': 0.9316609380423952, 'bagging_freq': 3, 'min_split_gain': 0.7956309306139354}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 22:00:38,841] Trial 143 finished with value: 0.7001563101192015 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 963, 'learning_rate': 0.019542906233978464, 'max_depth': 8, 'num_leaves': 164, 'lambda_l1': 0.0003469911455469093, 'lambda_l2': 3.750257107025339, 'min_child_samples': 50, 'feature_fraction': 0.8189742332506423, 'bagging_fraction': 0.9496129668468357, 'bagging_freq': 3, 'min_split_gain': 0.9072258050552108}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 22:00:46,215] Trial 144 finished with value: 0.7110198002580496 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 941, 'learning_rate': 0.021145345395210992, 'max_depth': 7, 'num_leaves': 178, 'lambda_l1': 4.615195270031575, 'lambda_l2': 0.5461079534476293, 'min_child_samples': 67, 'feature_fraction': 0.8782419134304814, 'bagging_fraction': 0.9694150052686357, 'bagging_freq': 4, 'min_split_gain': 0.8155981981857401}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 22:00:52,785] Trial 145 finished with value: 0.714522808456581 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 880, 'learning_rate': 0.02585934627006962, 'max_depth': 7, 'num_leaves': 136, 'lambda_l1': 2.8544403137150356, 'lambda_l2': 0.9331215599273173, 'min_child_samples': 58, 'feature_fraction': 0.84874735009809, 'bagging_fraction': 0.986767300301996, 'bagging_freq': 3, 'min_split_gain': 0.7327984689720792}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 22:00:58,436] Trial 146 finished with value: 0.7046966401997197 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 829, 'learning_rate': 0.02808720386009402, 'max_depth': 7, 'num_leaves': 137, 'lambda_l1': 9.461120590877934, 'lambda_l2': 0.8547566727952366, 'min_child_samples': 57, 'feature_fraction': 0.846914085141955, 'bagging_fraction': 0.9886962026174216, 'bagging_freq': 3, 'min_split_gain': 0.7436925824438771}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 22:01:06,550] Trial 147 finished with value: 0.7050021869871798 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1079, 'learning_rate': 0.03193894680253305, 'max_depth': 6, 'num_leaves': 153, 'lambda_l1': 0.9558309411563942, 'lambda_l2': 1.8235813323590857, 'min_child_samples': 63, 'feature_fraction': 0.8112635830393649, 'bagging_fraction': 0.9852916891951721, 'bagging_freq': 3, 'min_split_gain': 0.7656126446887881}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 22:01:09,493] Trial 148 finished with value: 0.7101668602798146 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 277, 'learning_rate': 0.025300433074865014, 'max_depth': 8, 'num_leaves': 15, 'lambda_l1': 3.2923570849868096, 'lambda_l2': 0.2347866047999364, 'min_child_samples': 60, 'feature_fraction': 0.7971778791297651, 'bagging_fraction': 0.9985173338499812, 'bagging_freq': 3, 'min_split_gain': 0.6829956253113096}. Best is trial 11 with value: 0.7217922002251281.
# [I 2026-03-13 22:01:16,739] Trial 149 finished with value: 0.6905804025330022 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 782, 'learning_rate': 0.016859247711930887, 'max_depth': 7, 'num_leaves': 159, 'lambda_l1': 5.801736241814311, 'lambda_l2': 0.38930622933705217, 'min_child_samples': 57, 'feature_fraction': 0.835755231312185, 'bagging_fraction': 0.6357365091654645, 'bagging_freq': 3, 'min_split_gain': 0.7312070571285703}. Best is trial 11 with value: 0.7217922002251281.
# Best Score: 0.7217922002251281

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import lightgbm as lgb


best_clf = lgb.LGBMClassifier(
        **study.best_params
)
best_clf.fit(X_train_r, y_train_r)
pred_r = best_clf.predict(X_test_r).ravel()

print("=== Baseline Classification on Random Split ===")
eval_classification(y_test_r, pred_r, name="RandomSplit")

print("\nClassification report (RandomSplit):")
print(classification_report(y_test_r, pred_r, digits=4))

cm_r = confusion_matrix(y_test_r, pred_r, labels=sorted(y_train_r.unique()))
cm_r_df = pd.DataFrame(cm_r, index=sorted(y_train_r.unique()), columns=sorted(y_train_r.unique()))
cm_r_df.to_csv("optuna_baseline_cm_random_tvae.csv", encoding="utf-8-sig")
print("Saved: optuna_baseline_cm_random_tvae.csv")

save_preds_csv(X_test_r, y_test_r.values, pred_r, "optuna_baseline_preds_random_cls_tvae.csv")

# Vẽ Confusion Matrix
plt.figure(figsize=(10,8))
sns.heatmap(confusion_matrix(y_test_r, pred_r), annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.9944724567566514, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9944724567566514
# [LightGBM] [Warning] lambda_l1 is set=1.4566281753492856, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.4566281753492856
# [LightGBM] [Warning] lambda_l2 is set=8.263098093142505, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.263098093142505
# [LightGBM] [Warning] bagging_fraction is set=0.9870441007763479, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9870441007763479
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] feature_fraction is set=0.9944724567566514, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9944724567566514
# [LightGBM] [Warning] lambda_l1 is set=1.4566281753492856, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.4566281753492856
# [LightGBM] [Warning] lambda_l2 is set=8.263098093142505, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.263098093142505
# [LightGBM] [Warning] bagging_fraction is set=0.9870441007763479, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9870441007763479
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000120 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1055
# [LightGBM] [Info] Number of data points in the train set: 1502, number of used features: 7
# [LightGBM] [Info] Start training from score -3.124898
# [LightGBM] [Info] Start training from score -2.803693
# [LightGBM] [Info] Start training from score -3.037887
# [LightGBM] [Info] Start training from score -2.760676
# [LightGBM] [Info] Start training from score -2.803693
# [LightGBM] [Info] Start training from score -2.957844
# [LightGBM] [Info] Start training from score -2.760676
# [LightGBM] [Info] Start training from score -1.683341
# [LightGBM] [Info] Start training from score -3.080446
# [LightGBM] [Info] Start training from score -2.094197
# [LightGBM] [Info] Start training from score -1.371753
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] feature_fraction is set=0.9944724567566514, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9944724567566514
# [LightGBM] [Warning] lambda_l1 is set=1.4566281753492856, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.4566281753492856
# [LightGBM] [Warning] lambda_l2 is set=8.263098093142505, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.263098093142505
# [LightGBM] [Warning] bagging_fraction is set=0.9870441007763479, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9870441007763479
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# === Baseline Classification on Random Split ===
# RandomSplit Accuracy: 0.7603 | F1-macro: 0.7002 | F1-weighted: 0.7528
#
# Classification report (RandomSplit):
#               precision    recall  f1-score   support
#
#            A     1.0000    1.0000    1.0000         4
#            B     1.0000    0.8000    0.8889        15
#            C     1.0000    1.0000    1.0000         2
#            D     0.6000    1.0000    0.7500         9
#            E     0.8750    0.5385    0.6667        13
#            F     0.0000    0.0000    0.0000         0
#            G     0.6667    0.8889    0.7619         9
#            H     0.6757    0.7576    0.7143        33
#            I     1.0000    0.3333    0.5000         3
#            J     0.7143    0.4348    0.5405        23
#            K     0.8250    0.9429    0.8800        35
#
#     accuracy                         0.7603       146
#    macro avg     0.7597    0.6996    0.7002       146
# weighted avg     0.7834    0.7603    0.7528       146
#
# Saved: optuna_baseline_cm_random_tvae.csv
# Saved: optuna_baseline_preds_random_cls_tvae.csv
