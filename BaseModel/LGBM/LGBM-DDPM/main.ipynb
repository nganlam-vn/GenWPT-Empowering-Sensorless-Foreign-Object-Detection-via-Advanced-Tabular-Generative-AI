# %% [markdown]
# ## Baseline Model

# %%
import warnings

from lightgbm import LGBMClassifier
import pandas as pd
import numpy as np

warnings.filterwarnings("ignore")

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix
from sklearn.ensemble import HistGradientBoostingClassifier, RandomForestClassifier

def eval_classification(y_true, y_pred, name=""):
    acc = accuracy_score(y_true, y_pred)
    f1_macro = f1_score(y_true, y_pred, average="macro")
    f1_weighted = f1_score(y_true, y_pred, average="weighted")
    print(f"{name} Accuracy: {acc:.4f} | F1-macro: {f1_macro:.4f} | F1-weighted: {f1_weighted:.4f}")
    return acc, f1_macro, f1_weighted

def save_preds_csv(X_test, y_true, y_pred, filename):
    out = X_test.copy()
    out["y_true"] = y_true
    out["y_pred"] = y_pred
    out.to_csv(filename, index=False, encoding="utf-8-sig")
    print(f"Saved: {filename}")

def derive_groups_from_train(train_df, k_baseline_dict, min_group_size=2):
    """
    Returns: type_to_group dict, groups dict
    Uses only train_df to avoid test leakage.
    Phân loại các 'type' thành near/mid/far dựa trên trung bình độ lệch tuyệt đối (abs_diff)
    """
    df_temp = train_df.copy()
    df_temp["k_eff_expected"] = df_temp["load"].map(k_baseline_dict)
    if df_temp["k_eff_expected"].isnull().any():
        known_loads = np.array(list(k_baseline_dict.keys()))
        for idx, row in df_temp[df_temp["k_eff_expected"].isnull()].iterrows():
            closest_load = known_loads[np.abs(known_loads - row["load"]).argmin()]
            df_temp.loc[idx, "k_eff_expected"] = k_baseline_dict[closest_load]     
    df_temp["abs_diff"] = (df_temp["efficiency"] - df_temp["k_eff_expected"]).abs()
    type_stats = (
        df_temp.groupby("type")["abs_diff"]
        .agg(n="count", mean="mean")
        .sort_values("mean")
        .reset_index()
    )
    types = type_stats["type"].tolist()
    x = type_stats["mean"].to_numpy()
    n = len(x)
    # Prefix sums for O(1) segment SSE
    S1 = np.concatenate([[0.0], np.cumsum(x)])
    S2 = np.concatenate([[0.0], np.cumsum(x * x)])
    def seg_sse(i, j):
        m = j - i + 1
        sum1 = S1[j + 1] - S1[i]
        sum2 = S2[j + 1] - S2[i]
        mu = sum1 / m
        return sum2 - 2 * mu * sum1 + m * mu * mu

    K = 3
    INF = 1e18
    dp = np.full((K + 1, n + 1), INF)
    cut = np.full((K + 1, n + 1), -1, dtype=int)

    dp[0, 0] = 0.0
    for k in range(1, K + 1):
        for t in range(1, n + 1):
            p_min = (k - 1) * min_group_size
            p_max = t - min_group_size
            if p_max < p_min:
                continue
            best_cost, best_p = INF, -1
            for p in range(p_min, p_max + 1):
                cost = dp[k - 1, p] + seg_sse(p, t - 1)
                if cost < best_cost:
                    best_cost, best_p = cost, p
            dp[k, t] = best_cost
            cut[k, t] = best_p

    if np.isinf(dp[K, n]):
        raise RuntimeError("No valid split found. Try min_group_size=1 or check types count.")
    bounds = []
    t = n
    for k in range(K, 0, -1):
        p = cut[k, t]
        bounds.append((p, t))
        t = p
    bounds.reverse()
    group_names = ["near", "mid", "far"] 
    groups = {}
    for name, (a, b) in zip(group_names, bounds):
        groups[name] = types[a:b]

    type_to_group = {t: g for g, ts in groups.items() for t in ts}
    return type_to_group, groups, type_stats


# ----- Load your saved split files -----
train_random = pd.read_csv('../../../GenerativeModel/TabDDPM/wpt_train_random_aug_tabddpm.csv')
test_random  = pd.read_csv('../../../random-split/wpt_test_random.csv')

# Sanity check expected columns
expected_cols = {"type", "load", "efficiency"}
for name, d in [("train_random", train_random), ("test_random", test_random)]:
    missing = expected_cols - set(d.columns)
    if missing:
        raise ValueError(f"{name} is missing columns: {missing}")

# Make sure numeric columns are numeric
for d in [train_random, test_random]:
    d["load"] = pd.to_numeric(d["load"], errors="coerce")
    d["efficiency"] = pd.to_numeric(d["efficiency"], errors="coerce")
    d["type"] = d["type"].astype(str)
    d.dropna(subset=["type", "load", "efficiency"], inplace=True)

# Features / target
FEATURES = ["load", "efficiency"]
TARGET = "type"

# =========================
def add_advanced_features(df, k_baseline_dict, type_to_group_dict):
    df = df.copy()
    df["k_eff_expected"] = df["load"].map(k_baseline_dict)
    if df["k_eff_expected"].isnull().any():
        known_loads = np.array(list(k_baseline_dict.keys()))
        for idx, row in df[df["k_eff_expected"].isnull()].iterrows():
            closest_load = known_loads[np.abs(known_loads - row["load"]).argmin()]
            df.loc[idx, "k_eff_expected"] = k_baseline_dict[closest_load]  
    # 2. Độ lệch (Difference) và Tỷ lệ (Ratio)
    df["eff_diff"] = df["efficiency"] - df["k_eff_expected"]
    df["eff_ratio"] = df["efficiency"] / df["k_eff_expected"]
    # 3. Ước tính tổn hao công suất (Power Loss Proxy)
    # P_loss = Load * (1 / (Efficiency / 100) - 1)
    df["p_loss"] = df["load"] * (1 / (df["efficiency"] / 100.0) - 1)
    # Tổn hao công suất của Class K
    df["k_p_loss"] = df["load"] * (1 / (df["k_eff_expected"] / 100.0) - 1)
    # Độ lệch suy hao do vật thể lạ gây ra
    df["p_loss_diff"] = df["p_loss"] - df["k_p_loss"]

    df["dist_zone_name"] = df["type"].map(type_to_group_dict).fillna("far")
    # Mã hóa thành số
    zone_mapping = {"near": 1, "mid": 2, "far": 3}
    df["dist_zone"] = df["dist_zone_name"].map(zone_mapping)
    # 4. Phân vùng Dải tải (Load Zone)
    # Giả sử dải tải từ 0.5 đến 3.0, chia làm 3 vùng: Nhẹ (1), Vừa (2), Nặng (3)
    df['load_zone'] = pd.cut(df['load'], bins=3, labels=[1, 2, 3]).astype(float)
    return df

k_baseline_train_r = train_random[train_random["type"] == "K"].groupby("load")["efficiency"].mean().to_dict()
type_to_group, groups_dict, stats = derive_groups_from_train(train_random, k_baseline_train_r)
print("Results of grouping the Types:", groups_dict)

train_random_fe = add_advanced_features(train_random, k_baseline_train_r, type_to_group)
test_random_fe = add_advanced_features(test_random, k_baseline_train_r, type_to_group)

FEATURES_NEW = [
    "load", "efficiency", 
    "eff_diff", "eff_ratio", 
    "p_loss_diff", "load_zone", "dist_zone"
]
# =========================
X_train_r = train_random_fe[FEATURES_NEW]
y_train_r = train_random_fe[TARGET]
X_test_r  = test_random_fe[FEATURES_NEW]
y_test_r  = test_random_fe[TARGET]
# Out:
# Results of grouping the Types: {'near': ['K', 'H', 'J', 'I', 'G'], 'mid': ['F', 'E', 'D', 'B'], 'far': ['C', 'A']}

# %% [markdown]
# ## Optuna

# %%
import optuna
import lightgbm as lgb
import json
from sklearn.model_selection import StratifiedKFold, cross_val_score

def objective(trial):
    # Định nghĩa không gian tìm kiếm RỘNG để "học rộng hơn"
    param = {
        'objective': 'multiclass',
        'num_class': 11,
        'metric': 'multi_logloss',
        'verbosity': -1,
        'random_state': 42,
        'class_weight': 'balanced',
        
        # Cho phép thử nghiệm cả 2 loại Boosting
        'boosting_type': trial.suggest_categorical('boosting_type', ['gbdt', 'dart']),
        
        # Mở rộng dải tham số
        'n_estimators': trial.suggest_int('n_estimators', 100, 1500), 
        'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 2, 12), 
        'num_leaves': trial.suggest_int('num_leaves', 4, 256),
        
        # Regularization cực rộng để tìm điểm tối ưu mới
        'lambda_l1': trial.suggest_float('lambda_l1', 1e-8, 10.0, log=True),
        'lambda_l2': trial.suggest_float('lambda_l2', 1e-8, 10.0, log=True),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.4, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.4, 1.0),
        'bagging_freq': trial.suggest_int('bagging_freq', 1, 7),
        'min_split_gain': trial.suggest_float('min_split_gain', 0, 1.0),
    }

    clf = lgb.LGBMClassifier(**param)
    
    # Sử dụng StratifiedKFold đơn thuần (thường dùng 5 hoặc 10 fold)
    cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
    
    # Tính điểm số trung bình
    scores = cross_val_score(clf, X_train_r, y_train_r, cv=cv, scoring='f1_macro', n_jobs=-1)
    
    return scores.mean()

# Khởi tạo và chạy tối ưu 200 lần
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=150, show_progress_bar=True)

# --- TRÍCH XUẤT VÀ LƯU KẾT QUẢ ---
best_params = study.best_params
best_params.update({
    'objective': 'multiclass',
    'num_class': 11,
    'metric': 'multi_logloss',
    'verbosity': -1,
    'random_state': 42
})

with open("best_lgbm_params.json", "w") as f:
    json.dump(best_params, f, indent=4)

print(f"Best Score: {study.best_value}")
# Out:
# [I 2026-03-14 13:45:49,043] A new study created in memory with name: no-name-a8e504ed-537e-4a28-ac13-6c4140afa1b8
#   0%|          | 0/150 [00:00<?, ?it/s]
# [I 2026-03-14 13:45:54,668] Trial 0 finished with value: 0.7325136041935939 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 874, 'learning_rate': 0.1966091063211548, 'max_depth': 3, 'num_leaves': 192, 'lambda_l1': 0.0030538596518084184, 'lambda_l2': 3.3083790024612335e-08, 'min_child_samples': 5, 'feature_fraction': 0.9424512799250164, 'bagging_fraction': 0.7502352860988102, 'bagging_freq': 5, 'min_split_gain': 0.42592883095914835}. Best is trial 0 with value: 0.7325136041935939.
# [I 2026-03-14 13:46:01,115] Trial 1 finished with value: 0.7478271517987493 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 902, 'learning_rate': 0.012166188443218205, 'max_depth': 12, 'num_leaves': 161, 'lambda_l1': 0.01044526286961283, 'lambda_l2': 1.9857583766815747e-05, 'min_child_samples': 24, 'feature_fraction': 0.7556270851559274, 'bagging_fraction': 0.8622855876695172, 'bagging_freq': 2, 'min_split_gain': 0.680303109991869}. Best is trial 1 with value: 0.7478271517987493.
# [I 2026-03-14 13:46:22,422] Trial 2 finished with value: 0.748995208250089 and parameters: {'boosting_type': 'dart', 'n_estimators': 1336, 'learning_rate': 0.08400946047980205, 'max_depth': 12, 'num_leaves': 242, 'lambda_l1': 0.21120718631741753, 'lambda_l2': 3.148364564991033e-05, 'min_child_samples': 69, 'feature_fraction': 0.9677700040583672, 'bagging_fraction': 0.492687619333364, 'bagging_freq': 6, 'min_split_gain': 0.7083708086705685}. Best is trial 2 with value: 0.748995208250089.
# [I 2026-03-14 13:46:28,636] Trial 3 finished with value: 0.7457796578523676 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1051, 'learning_rate': 0.026796563437898168, 'max_depth': 2, 'num_leaves': 64, 'lambda_l1': 0.017277481303792603, 'lambda_l2': 8.365156330816155e-06, 'min_child_samples': 95, 'feature_fraction': 0.7849877352170717, 'bagging_fraction': 0.8169323958521066, 'bagging_freq': 1, 'min_split_gain': 0.5259694584695845}. Best is trial 2 with value: 0.748995208250089.
# [I 2026-03-14 13:46:48,209] Trial 4 finished with value: 0.7505087249074256 and parameters: {'boosting_type': 'dart', 'n_estimators': 1497, 'learning_rate': 0.035282258892237, 'max_depth': 9, 'num_leaves': 177, 'lambda_l1': 3.209220369319672e-06, 'lambda_l2': 9.355521905360462e-05, 'min_child_samples': 41, 'feature_fraction': 0.4883100868239546, 'bagging_fraction': 0.5859648197226317, 'bagging_freq': 1, 'min_split_gain': 0.6950341104769132}. Best is trial 4 with value: 0.7505087249074256.
# [I 2026-03-14 13:46:49,757] Trial 5 finished with value: 0.7300996798238946 and parameters: {'boosting_type': 'dart', 'n_estimators': 172, 'learning_rate': 0.002587802223383596, 'max_depth': 3, 'num_leaves': 251, 'lambda_l1': 3.73308956011964e-06, 'lambda_l2': 5.3123965866222715e-08, 'min_child_samples': 11, 'feature_fraction': 0.46180305228285423, 'bagging_fraction': 0.7102751397217998, 'bagging_freq': 1, 'min_split_gain': 0.6423426729499162}. Best is trial 4 with value: 0.7505087249074256.
# [I 2026-03-14 13:46:50,672] Trial 6 finished with value: 0.7415665027931251 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 255, 'learning_rate': 0.08265911564320592, 'max_depth': 3, 'num_leaves': 207, 'lambda_l1': 0.0003955113845506134, 'lambda_l2': 7.659798524656623e-06, 'min_child_samples': 85, 'feature_fraction': 0.6475249051060625, 'bagging_fraction': 0.8078217261264631, 'bagging_freq': 5, 'min_split_gain': 0.10130826442422458}. Best is trial 4 with value: 0.7505087249074256.
# [I 2026-03-14 13:46:51,278] Trial 7 finished with value: 0.7097486937171483 and parameters: {'boosting_type': 'dart', 'n_estimators': 105, 'learning_rate': 0.004337537703572993, 'max_depth': 7, 'num_leaves': 32, 'lambda_l1': 2.3035950988423418e-05, 'lambda_l2': 0.00198614667602826, 'min_child_samples': 24, 'feature_fraction': 0.7015246673898163, 'bagging_fraction': 0.4155273520776267, 'bagging_freq': 5, 'min_split_gain': 0.5896603151727056}. Best is trial 4 with value: 0.7505087249074256.
# [I 2026-03-14 13:47:07,400] Trial 8 finished with value: 0.7396599311443302 and parameters: {'boosting_type': 'dart', 'n_estimators': 1072, 'learning_rate': 0.11846341253675462, 'max_depth': 6, 'num_leaves': 54, 'lambda_l1': 8.83172177240859e-07, 'lambda_l2': 4.465139327985001e-08, 'min_child_samples': 99, 'feature_fraction': 0.5115318174356572, 'bagging_fraction': 0.767362373918311, 'bagging_freq': 4, 'min_split_gain': 0.2033627717632247}. Best is trial 4 with value: 0.7505087249074256.
# [I 2026-03-14 13:47:17,618] Trial 9 finished with value: 0.7227088804316456 and parameters: {'boosting_type': 'dart', 'n_estimators': 730, 'learning_rate': 0.0058815838474074655, 'max_depth': 3, 'num_leaves': 191, 'lambda_l1': 2.989840509828766e-06, 'lambda_l2': 0.016367811605959362, 'min_child_samples': 96, 'feature_fraction': 0.7426741018910834, 'bagging_fraction': 0.9968715698896147, 'bagging_freq': 7, 'min_split_gain': 0.2879403919026654}. Best is trial 4 with value: 0.7505087249074256.
# [I 2026-03-14 13:47:37,908] Trial 10 finished with value: 0.7448288236124729 and parameters: {'boosting_type': 'dart', 'n_estimators': 1442, 'learning_rate': 0.03094879993965915, 'max_depth': 9, 'num_leaves': 110, 'lambda_l1': 1.1802412896516805e-08, 'lambda_l2': 0.07461592137746151, 'min_child_samples': 48, 'feature_fraction': 0.5701737557935375, 'bagging_fraction': 0.6084129627933567, 'bagging_freq': 3, 'min_split_gain': 0.9846842870479702}. Best is trial 4 with value: 0.7505087249074256.
# [I 2026-03-14 13:47:51,382] Trial 11 finished with value: 0.7426152585772714 and parameters: {'boosting_type': 'dart', 'n_estimators': 1451, 'learning_rate': 0.0471888806073825, 'max_depth': 12, 'num_leaves': 237, 'lambda_l1': 8.537381372263004, 'lambda_l2': 0.0001468944050075385, 'min_child_samples': 63, 'feature_fraction': 0.9987044109337146, 'bagging_fraction': 0.5430560094328788, 'bagging_freq': 7, 'min_split_gain': 0.8563123000888968}. Best is trial 4 with value: 0.7505087249074256.
# [I 2026-03-14 13:48:08,081] Trial 12 finished with value: 0.7407301936897052 and parameters: {'boosting_type': 'dart', 'n_estimators': 1302, 'learning_rate': 0.012833723188816641, 'max_depth': 10, 'num_leaves': 128, 'lambda_l1': 5.623420471702122, 'lambda_l2': 3.876396621457294, 'min_child_samples': 58, 'feature_fraction': 0.8720016751891029, 'bagging_fraction': 0.48770009778052714, 'bagging_freq': 6, 'min_split_gain': 0.7900306783375884}. Best is trial 4 with value: 0.7505087249074256.
# [I 2026-03-14 13:48:22,855] Trial 13 finished with value: 0.7470868606981407 and parameters: {'boosting_type': 'dart', 'n_estimators': 1181, 'learning_rate': 0.06993645757763287, 'max_depth': 10, 'num_leaves': 162, 'lambda_l1': 0.22556995735662966, 'lambda_l2': 1.2383567486317787e-06, 'min_child_samples': 73, 'feature_fraction': 0.6068582747640288, 'bagging_fraction': 0.6164732041188431, 'bagging_freq': 3, 'min_split_gain': 0.785318848572611}. Best is trial 4 with value: 0.7505087249074256.
# [I 2026-03-14 13:48:29,454] Trial 14 finished with value: 0.7407383699492569 and parameters: {'boosting_type': 'dart', 'n_estimators': 535, 'learning_rate': 0.026571731052755596, 'max_depth': 9, 'num_leaves': 224, 'lambda_l1': 4.614751183642787e-08, 'lambda_l2': 0.00038878759964947686, 'min_child_samples': 40, 'feature_fraction': 0.426998985291324, 'bagging_fraction': 0.42955977228274184, 'bagging_freq': 3, 'min_split_gain': 0.39598072798510114}. Best is trial 4 with value: 0.7505087249074256.
# [I 2026-03-14 13:48:49,506] Trial 15 finished with value: 0.7052630325304213 and parameters: {'boosting_type': 'dart', 'n_estimators': 1290, 'learning_rate': 0.0011820511024625805, 'max_depth': 11, 'num_leaves': 255, 'lambda_l1': 0.00011228820566607642, 'lambda_l2': 6.094330427537842e-07, 'min_child_samples': 73, 'feature_fraction': 0.8455767427431988, 'bagging_fraction': 0.6152454318283035, 'bagging_freq': 6, 'min_split_gain': 0.9476083019288635}. Best is trial 4 with value: 0.7505087249074256.
# [I 2026-03-14 13:49:04,152] Trial 16 finished with value: 0.7405402146401077 and parameters: {'boosting_type': 'dart', 'n_estimators': 1494, 'learning_rate': 0.19754844814487613, 'max_depth': 6, 'num_leaves': 163, 'lambda_l1': 0.27399284869401563, 'lambda_l2': 0.006019708803114008, 'min_child_samples': 48, 'feature_fraction': 0.5610018273120199, 'bagging_fraction': 0.5296074093321728, 'bagging_freq': 2, 'min_split_gain': 0.7248758847200809}. Best is trial 4 with value: 0.7505087249074256.
# [I 2026-03-14 13:49:24,285] Trial 17 finished with value: 0.7417070403426568 and parameters: {'boosting_type': 'dart', 'n_estimators': 1286, 'learning_rate': 0.042161601680417916, 'max_depth': 8, 'num_leaves': 98, 'lambda_l1': 2.600767615882128e-07, 'lambda_l2': 0.00012083963907656094, 'min_child_samples': 35, 'feature_fraction': 0.40583230983293117, 'bagging_fraction': 0.6516703875390448, 'bagging_freq': 4, 'min_split_gain': 0.5545137981889572}. Best is trial 4 with value: 0.7505087249074256.
# [I 2026-03-14 13:49:26,827] Trial 18 finished with value: 0.7525712538679453 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 632, 'learning_rate': 0.020211002897812417, 'max_depth': 11, 'num_leaves': 218, 'lambda_l1': 0.24765690339553972, 'lambda_l2': 0.1425401049955751, 'min_child_samples': 66, 'feature_fraction': 0.8597455340794105, 'bagging_fraction': 0.4925407407394507, 'bagging_freq': 6, 'min_split_gain': 0.430397390740229}. Best is trial 18 with value: 0.7525712538679453.
# [I 2026-03-14 13:49:29,324] Trial 19 finished with value: 0.745511148136529 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 549, 'learning_rate': 0.008348363396522101, 'max_depth': 10, 'num_leaves': 182, 'lambda_l1': 0.0005163157546080473, 'lambda_l2': 0.8322296802953713, 'min_child_samples': 83, 'feature_fraction': 0.857485654335034, 'bagging_fraction': 0.577492110312847, 'bagging_freq': 4, 'min_split_gain': 0.4031976011602996}. Best is trial 18 with value: 0.7525712538679453.
# [I 2026-03-14 13:49:32,034] Trial 20 finished with value: 0.738437500382508 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 397, 'learning_rate': 0.018567856655356887, 'max_depth': 8, 'num_leaves': 212, 'lambda_l1': 6.727346549861655e-05, 'lambda_l2': 0.10235503256529203, 'min_child_samples': 35, 'feature_fraction': 0.6646286923402938, 'bagging_fraction': 0.47842696501419396, 'bagging_freq': 2, 'min_split_gain': 0.3075336407528591}. Best is trial 18 with value: 0.7525712538679453.
# [I 2026-03-14 13:49:33,099] Trial 21 finished with value: 0.7420433225736781 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 718, 'learning_rate': 0.06015838771295613, 'max_depth': 11, 'num_leaves': 227, 'lambda_l1': 1.4446795602911726, 'lambda_l2': 0.0012496028660038147, 'min_child_samples': 64, 'feature_fraction': 0.9798647663262166, 'bagging_fraction': 0.4822887845410077, 'bagging_freq': 6, 'min_split_gain': 0.4873291769361707}. Best is trial 18 with value: 0.7525712538679453.
# [I 2026-03-14 13:49:34,115] Trial 22 finished with value: 0.7392778546868072 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 998, 'learning_rate': 0.10910233558549998, 'max_depth': 12, 'num_leaves': 175, 'lambda_l1': 0.21066464896452722, 'lambda_l2': 5.885179412191598e-05, 'min_child_samples': 73, 'feature_fraction': 0.9173475211276155, 'bagging_fraction': 0.5426301824897233, 'bagging_freq': 7, 'min_split_gain': 0.6447003750392052}. Best is trial 18 with value: 0.7525712538679453.
# [I 2026-03-14 13:49:36,116] Trial 23 finished with value: 0.7530188274966808 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 535, 'learning_rate': 0.01990062473831893, 'max_depth': 11, 'num_leaves': 207, 'lambda_l1': 0.03437536907832813, 'lambda_l2': 2.476271631169121e-06, 'min_child_samples': 55, 'feature_fraction': 0.8086139763228437, 'bagging_fraction': 0.6658454165891802, 'bagging_freq': 6, 'min_split_gain': 0.8654626167395767}. Best is trial 23 with value: 0.7530188274966808.
# [I 2026-03-14 13:49:38,140] Trial 24 finished with value: 0.7477686121555404 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 593, 'learning_rate': 0.02063291999794297, 'max_depth': 11, 'num_leaves': 206, 'lambda_l1': 0.020492308499690873, 'lambda_l2': 6.528053672874972e-07, 'min_child_samples': 54, 'feature_fraction': 0.8057915313998288, 'bagging_fraction': 0.6735679909190948, 'bagging_freq': 5, 'min_split_gain': 0.8804691322799212}. Best is trial 23 with value: 0.7530188274966808.
# [I 2026-03-14 13:49:39,953] Trial 25 finished with value: 0.7525088090697786 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 410, 'learning_rate': 0.011053046930614327, 'max_depth': 9, 'num_leaves': 131, 'lambda_l1': 0.0017335181772684045, 'lambda_l2': 3.5740993341280054e-06, 'min_child_samples': 43, 'feature_fraction': 0.9000529084865202, 'bagging_fraction': 0.7000420631798319, 'bagging_freq': 6, 'min_split_gain': 0.8602311672959261}. Best is trial 23 with value: 0.7530188274966808.
# [I 2026-03-14 13:49:41,471] Trial 26 finished with value: 0.7527572700073181 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 364, 'learning_rate': 0.008369236911603463, 'max_depth': 8, 'num_leaves': 139, 'lambda_l1': 0.001000275628561861, 'lambda_l2': 2.1263465767882652e-06, 'min_child_samples': 49, 'feature_fraction': 0.9136496906868296, 'bagging_fraction': 0.9326928988001206, 'bagging_freq': 6, 'min_split_gain': 0.8629811328513302}. Best is trial 23 with value: 0.7530188274966808.
# [I 2026-03-14 13:49:43,415] Trial 27 finished with value: 0.7355542859293577 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 368, 'learning_rate': 0.0036796068135659756, 'max_depth': 5, 'num_leaves': 134, 'lambda_l1': 0.050039633883906316, 'lambda_l2': 0.46806759398930703, 'min_child_samples': 58, 'feature_fraction': 0.8416795337027565, 'bagging_fraction': 0.9615261724956592, 'bagging_freq': 7, 'min_split_gain': 0.07818531237764226}. Best is trial 23 with value: 0.7530188274966808.
# [I 2026-03-14 13:49:46,068] Trial 28 finished with value: 0.7569035971955557 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 648, 'learning_rate': 0.007802056089424381, 'max_depth': 8, 'num_leaves': 7, 'lambda_l1': 0.0019895821809727547, 'lambda_l2': 1.454730080900178e-07, 'min_child_samples': 83, 'feature_fraction': 0.8036089632352814, 'bagging_fraction': 0.9112875976215171, 'bagging_freq': 6, 'min_split_gain': 0.9244163924137543}. Best is trial 28 with value: 0.7569035971955557.
# [I 2026-03-14 13:49:48,878] Trial 29 finished with value: 0.7575737432418771 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 812, 'learning_rate': 0.007318588715610084, 'max_depth': 5, 'num_leaves': 7, 'lambda_l1': 0.0029025769787147434, 'lambda_l2': 1.3456966382788648e-08, 'min_child_samples': 85, 'feature_fraction': 0.8087330994010632, 'bagging_fraction': 0.8948339320915562, 'bagging_freq': 5, 'min_split_gain': 0.9244798909556807}. Best is trial 29 with value: 0.7575737432418771.
# [I 2026-03-14 13:49:52,412] Trial 30 finished with value: 0.7503908455424363 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 829, 'learning_rate': 0.0022509243807252582, 'max_depth': 5, 'num_leaves': 9, 'lambda_l1': 0.004398287831457344, 'lambda_l2': 1.2228345412212941e-08, 'min_child_samples': 84, 'feature_fraction': 0.718035991195027, 'bagging_fraction': 0.890146096145789, 'bagging_freq': 5, 'min_split_gain': 0.9368983724794806}. Best is trial 29 with value: 0.7575737432418771.
# [I 2026-03-14 13:49:54,124] Trial 31 finished with value: 0.7579170247621111 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 475, 'learning_rate': 0.007531411264630231, 'max_depth': 7, 'num_leaves': 4, 'lambda_l1': 0.0014551636950663894, 'lambda_l2': 1.798017380744726e-07, 'min_child_samples': 88, 'feature_fraction': 0.8010123704397061, 'bagging_fraction': 0.9280359594733308, 'bagging_freq': 5, 'min_split_gain': 0.8095625484757905}. Best is trial 31 with value: 0.7579170247621111.
# [I 2026-03-14 13:49:56,820] Trial 32 finished with value: 0.7614045817454329 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 723, 'learning_rate': 0.006364694398252402, 'max_depth': 5, 'num_leaves': 6, 'lambda_l1': 0.0054207719837695185, 'lambda_l2': 1.8516588922292187e-07, 'min_child_samples': 89, 'feature_fraction': 0.79682387806723, 'bagging_fraction': 0.8834539688073557, 'bagging_freq': 5, 'min_split_gain': 0.9983761120780218}. Best is trial 32 with value: 0.7614045817454329.
# [I 2026-03-14 13:50:00,028] Trial 33 finished with value: 0.7588917770989566 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 932, 'learning_rate': 0.0061616998849386975, 'max_depth': 5, 'num_leaves': 4, 'lambda_l1': 0.005258505778924183, 'lambda_l2': 1.6232937772528624e-07, 'min_child_samples': 89, 'feature_fraction': 0.7656534361636392, 'bagging_fraction': 0.8851521589739115, 'bagging_freq': 4, 'min_split_gain': 0.9894211343089985}. Best is trial 32 with value: 0.7614045817454329.
# [I 2026-03-14 13:50:03,757] Trial 34 finished with value: 0.7571325441056399 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 902, 'learning_rate': 0.005334871392369637, 'max_depth': 4, 'num_leaves': 26, 'lambda_l1': 0.006929515217694069, 'lambda_l2': 2.1926291449720056e-07, 'min_child_samples': 90, 'feature_fraction': 0.7797125112705743, 'bagging_fraction': 0.8517076147892849, 'bagging_freq': 4, 'min_split_gain': 0.9976003607829654}. Best is trial 32 with value: 0.7614045817454329.
# [I 2026-03-14 13:50:08,090] Trial 35 finished with value: 0.7529813699161868 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 968, 'learning_rate': 0.0030764340545659723, 'max_depth': 5, 'num_leaves': 52, 'lambda_l1': 3.642082202726998e-05, 'lambda_l2': 1.1314366259214535e-08, 'min_child_samples': 92, 'feature_fraction': 0.7423804095442419, 'bagging_fraction': 0.8607374183333865, 'bagging_freq': 4, 'min_split_gain': 0.7744913187554782}. Best is trial 32 with value: 0.7614045817454329.
# [I 2026-03-14 13:50:11,323] Trial 36 finished with value: 0.7467202532188141 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 764, 'learning_rate': 0.0020552342226471906, 'max_depth': 6, 'num_leaves': 30, 'lambda_l1': 0.00013626134173007725, 'lambda_l2': 1.2149724673656165e-07, 'min_child_samples': 77, 'feature_fraction': 0.7664929861873657, 'bagging_fraction': 0.8156933655917731, 'bagging_freq': 5, 'min_split_gain': 0.9148793125083767}. Best is trial 32 with value: 0.7614045817454329.
# [I 2026-03-14 13:50:13,769] Trial 37 finished with value: 0.7510673927870295 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 852, 'learning_rate': 0.00634479813536106, 'max_depth': 4, 'num_leaves': 19, 'lambda_l1': 0.008050611081091624, 'lambda_l2': 3.538771783215996e-07, 'min_child_samples': 90, 'feature_fraction': 0.6706146915744906, 'bagging_fraction': 0.7633909602447984, 'bagging_freq': 5, 'min_split_gain': 0.9982120315039563}. Best is trial 32 with value: 0.7614045817454329.
# [I 2026-03-14 13:50:18,914] Trial 38 finished with value: 0.7452317814793559 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1136, 'learning_rate': 0.0015895927814866435, 'max_depth': 4, 'num_leaves': 75, 'lambda_l1': 0.06412244043371323, 'lambda_l2': 1.6137231835703858e-05, 'min_child_samples': 78, 'feature_fraction': 0.7268689680513785, 'bagging_fraction': 0.9563971293577486, 'bagging_freq': 3, 'min_split_gain': 0.7543619946336761}. Best is trial 32 with value: 0.7614045817454329.
# [I 2026-03-14 13:50:22,162] Trial 39 finished with value: 0.7526924045219882 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 942, 'learning_rate': 0.004499722298071964, 'max_depth': 7, 'num_leaves': 44, 'lambda_l1': 0.0003100119799080761, 'lambda_l2': 4.2342439627485145e-08, 'min_child_samples': 100, 'feature_fraction': 0.948103973209077, 'bagging_fraction': 0.8877417684728356, 'bagging_freq': 4, 'min_split_gain': 0.8149187521846286}. Best is trial 32 with value: 0.7614045817454329.
# [I 2026-03-14 13:50:23,298] Trial 40 finished with value: 0.7514182517415069 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 458, 'learning_rate': 0.010044669501503779, 'max_depth': 2, 'num_leaves': 75, 'lambda_l1': 0.0008454928621393523, 'lambda_l2': 9.189069272626146e-08, 'min_child_samples': 88, 'feature_fraction': 0.6894131211792938, 'bagging_fraction': 0.9956775517641294, 'bagging_freq': 5, 'min_split_gain': 0.9471440485993848}. Best is trial 32 with value: 0.7614045817454329.
# [I 2026-03-14 13:50:26,722] Trial 41 finished with value: 0.7564038895757356 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 866, 'learning_rate': 0.005516072085749824, 'max_depth': 4, 'num_leaves': 23, 'lambda_l1': 0.005077268651670415, 'lambda_l2': 2.496347938268214e-07, 'min_child_samples': 94, 'feature_fraction': 0.7822534429148327, 'bagging_fraction': 0.8505253190185507, 'bagging_freq': 4, 'min_split_gain': 0.9960610533859376}. Best is trial 32 with value: 0.7614045817454329.
# [I 2026-03-14 13:50:30,029] Trial 42 finished with value: 0.7617186633163783 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1045, 'learning_rate': 0.004656634507355207, 'max_depth': 5, 'num_leaves': 4, 'lambda_l1': 0.013284794936916545, 'lambda_l2': 1.6418614780153147e-08, 'min_child_samples': 79, 'feature_fraction': 0.82075755737142, 'bagging_fraction': 0.8349428838535183, 'bagging_freq': 4, 'min_split_gain': 0.9220376705098222}. Best is trial 42 with value: 0.7617186633163783.
# [I 2026-03-14 13:50:32,483] Trial 43 finished with value: 0.751738109014974 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1066, 'learning_rate': 0.015026988454858229, 'max_depth': 7, 'num_leaves': 6, 'lambda_l1': 0.01765935067183308, 'lambda_l2': 1.0454245213727086e-08, 'min_child_samples': 79, 'feature_fraction': 0.8244648622452984, 'bagging_fraction': 0.8010577247128242, 'bagging_freq': 5, 'min_split_gain': 0.8199487061476423}. Best is trial 42 with value: 0.7617186633163783.
# [I 2026-03-14 13:50:35,513] Trial 44 finished with value: 0.7529787892825753 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 787, 'learning_rate': 0.003481195929291183, 'max_depth': 6, 'num_leaves': 40, 'lambda_l1': 0.0024323721814128174, 'lambda_l2': 2.6702793554510464e-08, 'min_child_samples': 87, 'feature_fraction': 0.7533995727733971, 'bagging_fraction': 0.9199300961024878, 'bagging_freq': 5, 'min_split_gain': 0.9034146043008779}. Best is trial 42 with value: 0.7617186633163783.
# [I 2026-03-14 13:50:39,165] Trial 45 finished with value: 0.7548141229231901 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1148, 'learning_rate': 0.006858426979897652, 'max_depth': 5, 'num_leaves': 16, 'lambda_l1': 0.06822434071890034, 'lambda_l2': 3.072330322153718e-08, 'min_child_samples': 95, 'feature_fraction': 0.8863688032160277, 'bagging_fraction': 0.8835458466609047, 'bagging_freq': 4, 'min_split_gain': 0.9504601095157068}. Best is trial 42 with value: 0.7617186633163783.
# [I 2026-03-14 13:50:42,145] Trial 46 finished with value: 0.7518813521457464 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 684, 'learning_rate': 0.004614469291230196, 'max_depth': 6, 'num_leaves': 42, 'lambda_l1': 1.6454739160535705e-05, 'lambda_l2': 5.893865126874966e-08, 'min_child_samples': 80, 'feature_fraction': 0.8137776043837118, 'bagging_fraction': 0.7395478788071268, 'bagging_freq': 3, 'min_split_gain': 0.8279784115277086}. Best is trial 42 with value: 0.7617186633163783.
# [I 2026-03-14 13:50:43,041] Trial 47 finished with value: 0.747056925970004 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 266, 'learning_rate': 0.010100492584597867, 'max_depth': 3, 'num_leaves': 17, 'lambda_l1': 0.00026575022141367026, 'lambda_l2': 8.683670190594947e-06, 'min_child_samples': 100, 'feature_fraction': 0.8361148274167199, 'bagging_fraction': 0.8338578347318827, 'bagging_freq': 5, 'min_split_gain': 0.6930244830251064}. Best is trial 42 with value: 0.7617186633163783.
# [I 2026-03-14 13:50:46,787] Trial 48 finished with value: 0.7565553735401126 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1031, 'learning_rate': 0.002979216537779748, 'max_depth': 5, 'num_leaves': 54, 'lambda_l1': 0.011253957581561252, 'lambda_l2': 9.438747139880432e-07, 'min_child_samples': 69, 'feature_fraction': 0.7851917738719436, 'bagging_fraction': 0.9476235378266519, 'bagging_freq': 4, 'min_split_gain': 0.9009536236115044}. Best is trial 42 with value: 0.7617186633163783.
# [I 2026-03-14 13:50:48,563] Trial 49 finished with value: 0.7599841600404594 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1212, 'learning_rate': 0.014859125207216392, 'max_depth': 7, 'num_leaves': 34, 'lambda_l1': 1.0044572689290914, 'lambda_l2': 2.52970885850548e-08, 'min_child_samples': 9, 'feature_fraction': 0.6260303032963266, 'bagging_fraction': 0.793074050770055, 'bagging_freq': 3, 'min_split_gain': 0.737428965628455}. Best is trial 42 with value: 0.7617186633163783.
# [I 2026-03-14 13:50:50,752] Trial 50 finished with value: 0.7555611896435197 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1208, 'learning_rate': 0.012534980102242734, 'max_depth': 7, 'num_leaves': 33, 'lambda_l1': 0.7816296880886549, 'lambda_l2': 8.922625991645513e-08, 'min_child_samples': 75, 'feature_fraction': 0.5472346466116405, 'bagging_fraction': 0.800568131376269, 'bagging_freq': 3, 'min_split_gain': 0.7442436235538421}. Best is trial 42 with value: 0.7617186633163783.
# [I 2026-03-14 13:50:51,877] Trial 51 finished with value: 0.7573592906325733 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 928, 'learning_rate': 0.014817385854551111, 'max_depth': 6, 'num_leaves': 5, 'lambda_l1': 3.277423352794965, 'lambda_l2': 2.2410366545372448e-08, 'min_child_samples': 10, 'feature_fraction': 0.7087163969863303, 'bagging_fraction': 0.8991004614985134, 'bagging_freq': 3, 'min_split_gain': 0.9603707957466051}. Best is trial 42 with value: 0.7617186633163783.
# [I 2026-03-14 13:50:55,713] Trial 52 finished with value: 0.7511213828459589 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1080, 'learning_rate': 0.007350300991280355, 'max_depth': 5, 'num_leaves': 16, 'lambda_l1': 0.002688994683431194, 'lambda_l2': 3.909047350977809e-07, 'min_child_samples': 23, 'feature_fraction': 0.6122680355198733, 'bagging_fraction': 0.7776444526389082, 'bagging_freq': 4, 'min_split_gain': 0.8282599977751242}. Best is trial 42 with value: 0.7617186633163783.
# [I 2026-03-14 13:51:01,871] Trial 53 finished with value: 0.7535044169588953 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1204, 'learning_rate': 0.004094616146356188, 'max_depth': 7, 'num_leaves': 35, 'lambda_l1': 0.0008885592635008789, 'lambda_l2': 2.3167556570925836e-08, 'min_child_samples': 19, 'feature_fraction': 0.6105622835147925, 'bagging_fraction': 0.7286234342071243, 'bagging_freq': 2, 'min_split_gain': 0.6528025544950796}. Best is trial 42 with value: 0.7617186633163783.
# [I 2026-03-14 13:51:05,612] Trial 54 finished with value: 0.7476058570846891 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1007, 'learning_rate': 0.009321547288371878, 'max_depth': 4, 'num_leaves': 64, 'lambda_l1': 0.6816572608103477, 'lambda_l2': 6.326368065949144e-08, 'min_child_samples': 96, 'feature_fraction': 0.6389254421053391, 'bagging_fraction': 0.8288596959330882, 'bagging_freq': 5, 'min_split_gain': 0.001446310556565078}. Best is trial 42 with value: 0.7617186633163783.
# [I 2026-03-14 13:51:09,385] Trial 55 finished with value: 0.7573845998090083 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1365, 'learning_rate': 0.005403733816831822, 'max_depth': 6, 'num_leaves': 26, 'lambda_l1': 0.12978577313262998, 'lambda_l2': 2.2458808101901073e-07, 'min_child_samples': 69, 'feature_fraction': 0.8764676296859618, 'bagging_fraction': 0.982171968474404, 'bagging_freq': 5, 'min_split_gain': 0.5848351972917392}. Best is trial 42 with value: 0.7617186633163783.
# [I 2026-03-14 13:51:11,148] Trial 56 finished with value: 0.7539560427766331 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 743, 'learning_rate': 0.02635427513608457, 'max_depth': 3, 'num_leaves': 13, 'lambda_l1': 0.023831277042503547, 'lambda_l2': 2.1504675243308234e-08, 'min_child_samples': 86, 'feature_fraction': 0.7384393120131693, 'bagging_fraction': 0.8698396810151626, 'bagging_freq': 1, 'min_split_gain': 0.8967875391090352}. Best is trial 42 with value: 0.7617186633163783.
# [I 2026-03-14 13:51:12,900] Trial 57 finished with value: 0.7537188633878292 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 811, 'learning_rate': 0.016587963198422352, 'max_depth': 7, 'num_leaves': 5, 'lambda_l1': 0.011272044807075469, 'lambda_l2': 1.1000447262575866e-06, 'min_child_samples': 81, 'feature_fraction': 0.7599461327349107, 'bagging_fraction': 0.9130796763626889, 'bagging_freq': 4, 'min_split_gain': 0.9684772101842392}. Best is trial 42 with value: 0.7617186633163783.
# [I 2026-03-14 13:51:16,423] Trial 58 finished with value: 0.7497489293528493 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1112, 'learning_rate': 0.006324983978028467, 'max_depth': 5, 'num_leaves': 23, 'lambda_l1': 0.00020853469158385398, 'lambda_l2': 1.3223279125844968e-07, 'min_child_samples': 5, 'feature_fraction': 0.6816603621103697, 'bagging_fraction': 0.9334169052363587, 'bagging_freq': 4, 'min_split_gain': 0.8056303013354755}. Best is trial 42 with value: 0.7617186633163783.
# [I 2026-03-14 13:51:33,534] Trial 59 finished with value: 0.7509380013818605 and parameters: {'boosting_type': 'dart', 'n_estimators': 1261, 'learning_rate': 0.012529548962251858, 'max_depth': 2, 'num_leaves': 99, 'lambda_l1': 7.637038573683938e-06, 'lambda_l2': 4.71827583471005e-07, 'min_child_samples': 91, 'feature_fraction': 0.6327131720709884, 'bagging_fraction': 0.8398575059723555, 'bagging_freq': 3, 'min_split_gain': 0.8391887061251733}. Best is trial 42 with value: 0.7617186633163783.
# [I 2026-03-14 13:51:36,111] Trial 60 finished with value: 0.7544863801261926 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 697, 'learning_rate': 0.00846541458815977, 'max_depth': 6, 'num_leaves': 63, 'lambda_l1': 0.0007152312801230018, 'lambda_l2': 5.734161799014891e-06, 'min_child_samples': 88, 'feature_fraction': 0.8587402600106887, 'bagging_fraction': 0.8807381883271523, 'bagging_freq': 5, 'min_split_gain': 0.8866875859694514}. Best is trial 42 with value: 0.7617186633163783.
# [I 2026-03-14 13:51:39,575] Trial 61 finished with value: 0.7603516211935856 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1391, 'learning_rate': 0.005976226319230708, 'max_depth': 6, 'num_leaves': 29, 'lambda_l1': 0.13907114553521344, 'lambda_l2': 1.9935883239528513e-07, 'min_child_samples': 69, 'feature_fraction': 0.8797993740516111, 'bagging_fraction': 0.9990530408622464, 'bagging_freq': 5, 'min_split_gain': 0.5966604897514678}. Best is trial 42 with value: 0.7617186633163783.
# [I 2026-03-14 13:51:44,647] Trial 62 finished with value: 0.7522428704073345 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1422, 'learning_rate': 0.0047249902038316765, 'max_depth': 6, 'num_leaves': 35, 'lambda_l1': 0.12030310396253192, 'lambda_l2': 5.4719814422115914e-08, 'min_child_samples': 76, 'feature_fraction': 0.7960557313911628, 'bagging_fraction': 0.943687950858958, 'bagging_freq': 5, 'min_split_gain': 0.5005017050607012}. Best is trial 42 with value: 0.7617186633163783.
# [I 2026-03-14 13:51:48,094] Trial 63 finished with value: 0.7596400324388539 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1242, 'learning_rate': 0.007023173121298655, 'max_depth': 5, 'num_leaves': 14, 'lambda_l1': 0.4712739735194116, 'lambda_l2': 1.6648227118605485e-08, 'min_child_samples': 82, 'feature_fraction': 0.8307461121828217, 'bagging_fraction': 0.9683477538486621, 'bagging_freq': 5, 'min_split_gain': 0.6130306426006333}. Best is trial 42 with value: 0.7617186633163783.
# [I 2026-03-14 13:51:52,392] Trial 64 finished with value: 0.7623329827823251 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1351, 'learning_rate': 0.0038519273147720827, 'max_depth': 7, 'num_leaves': 50, 'lambda_l1': 0.6220517069884366, 'lambda_l2': 1.7634862084442532e-06, 'min_child_samples': 61, 'feature_fraction': 0.9435284024516948, 'bagging_fraction': 0.976426102943197, 'bagging_freq': 6, 'min_split_gain': 0.5998878678116426}. Best is trial 64 with value: 0.7623329827823251.
# [I 2026-03-14 13:51:57,679] Trial 65 finished with value: 0.7581519004510356 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1362, 'learning_rate': 0.0028422789981156584, 'max_depth': 8, 'num_leaves': 49, 'lambda_l1': 0.5878605618364505, 'lambda_l2': 4.222371175803141e-08, 'min_child_samples': 60, 'feature_fraction': 0.9509956087974551, 'bagging_fraction': 0.9770306084661622, 'bagging_freq': 6, 'min_split_gain': 0.5966283134397324}. Best is trial 64 with value: 0.7623329827823251.
# [I 2026-03-14 13:52:02,162] Trial 66 finished with value: 0.7609677878283496 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1261, 'learning_rate': 0.0024615304201826755, 'max_depth': 4, 'num_leaves': 84, 'lambda_l1': 1.9757943921571712, 'lambda_l2': 1.7603014179309113e-06, 'min_child_samples': 67, 'feature_fraction': 0.9213103642146685, 'bagging_fraction': 0.9719107058298384, 'bagging_freq': 7, 'min_split_gain': 0.6166309286023893}. Best is trial 64 with value: 0.7623329827823251.
# [I 2026-03-14 13:52:20,601] Trial 67 finished with value: 0.7210605767708264 and parameters: {'boosting_type': 'dart', 'n_estimators': 1241, 'learning_rate': 0.0020965464244805223, 'max_depth': 4, 'num_leaves': 85, 'lambda_l1': 2.493361057532593, 'lambda_l2': 2.4886529596010155e-05, 'min_child_samples': 63, 'feature_fraction': 0.9253515597559271, 'bagging_fraction': 0.9740096153197133, 'bagging_freq': 7, 'min_split_gain': 0.538950793010106}. Best is trial 64 with value: 0.7623329827823251.
# [I 2026-03-14 13:52:25,257] Trial 68 finished with value: 0.7597040462108198 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1313, 'learning_rate': 0.0035445260538663793, 'max_depth': 4, 'num_leaves': 64, 'lambda_l1': 0.35403153313279584, 'lambda_l2': 2.2899426273205825e-06, 'min_child_samples': 70, 'feature_fraction': 0.9772319917017527, 'bagging_fraction': 0.9666904964797162, 'bagging_freq': 7, 'min_split_gain': 0.6023959233269551}. Best is trial 64 with value: 0.7623329827823251.
# [I 2026-03-14 13:52:30,225] Trial 69 finished with value: 0.7432984196461255 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1404, 'learning_rate': 0.001319187807242209, 'max_depth': 3, 'num_leaves': 63, 'lambda_l1': 7.721110954084865, 'lambda_l2': 1.972531189049063e-06, 'min_child_samples': 59, 'feature_fraction': 0.9891121065730819, 'bagging_fraction': 0.9974008772707506, 'bagging_freq': 7, 'min_split_gain': 0.46015390386757526}. Best is trial 64 with value: 0.7623329827823251.
# [I 2026-03-14 13:52:34,851] Trial 70 finished with value: 0.7571228893607107 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1318, 'learning_rate': 0.002432939221894106, 'max_depth': 4, 'num_leaves': 76, 'lambda_l1': 1.1389113151132937, 'lambda_l2': 5.039177467695549e-06, 'min_child_samples': 71, 'feature_fraction': 0.9329547391397808, 'bagging_fraction': 0.9493562315143113, 'bagging_freq': 7, 'min_split_gain': 0.5582625548592035}. Best is trial 64 with value: 0.7623329827823251.
# [I 2026-03-14 13:52:40,291] Trial 71 finished with value: 0.7606715214374149 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1491, 'learning_rate': 0.0033554119834677248, 'max_depth': 5, 'num_leaves': 44, 'lambda_l1': 0.4912779995380276, 'lambda_l2': 5.4516252177799616e-05, 'min_child_samples': 67, 'feature_fraction': 0.963212926892487, 'bagging_fraction': 0.968735251135798, 'bagging_freq': 6, 'min_split_gain': 0.6188100479072216}. Best is trial 64 with value: 0.7623329827823251.
# [I 2026-03-14 13:52:45,154] Trial 72 finished with value: 0.7540103820625896 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1498, 'learning_rate': 0.0017819757623636619, 'max_depth': 4, 'num_leaves': 47, 'lambda_l1': 2.243787413937029, 'lambda_l2': 5.0112836517914546e-05, 'min_child_samples': 66, 'feature_fraction': 0.9777703366541532, 'bagging_fraction': 0.9914728066173973, 'bagging_freq': 6, 'min_split_gain': 0.6584140923783616}. Best is trial 64 with value: 0.7623329827823251.
# [I 2026-03-14 13:52:50,232] Trial 73 finished with value: 0.7648749547384858 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1458, 'learning_rate': 0.0037674886179777842, 'max_depth': 6, 'num_leaves': 114, 'lambda_l1': 0.3158626966325019, 'lambda_l2': 0.0003444161409990704, 'min_child_samples': 66, 'feature_fraction': 0.9607310572362924, 'bagging_fraction': 0.9593470350639431, 'bagging_freq': 7, 'min_split_gain': 0.7111287968705196}. Best is trial 73 with value: 0.7648749547384858.
# [I 2026-03-14 13:52:53,630] Trial 74 finished with value: 0.7496455423327614 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1461, 'learning_rate': 0.003964379856972569, 'max_depth': 8, 'num_leaves': 110, 'lambda_l1': 4.679819487844381, 'lambda_l2': 0.01295214214413249, 'min_child_samples': 66, 'feature_fraction': 0.9634078117543927, 'bagging_fraction': 0.912548121627137, 'bagging_freq': 6, 'min_split_gain': 0.7178161202791212}. Best is trial 73 with value: 0.7648749547384858.
# [I 2026-03-14 13:53:00,611] Trial 75 finished with value: 0.7587298665078857 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1386, 'learning_rate': 0.002619893593311309, 'max_depth': 6, 'num_leaves': 121, 'lambda_l1': 0.13576445394549902, 'lambda_l2': 0.00031150328342759273, 'min_child_samples': 56, 'feature_fraction': 0.9045186105823437, 'bagging_fraction': 0.9343428875234678, 'bagging_freq': 7, 'min_split_gain': 0.6787012266526038}. Best is trial 73 with value: 0.7648749547384858.
# [I 2026-03-14 13:53:05,327] Trial 76 finished with value: 0.761581195990025 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1452, 'learning_rate': 0.0032854535017558984, 'max_depth': 7, 'num_leaves': 56, 'lambda_l1': 1.3387433308979955, 'lambda_l2': 0.0014309667958563733, 'min_child_samples': 49, 'feature_fraction': 0.888391439430736, 'bagging_fraction': 0.952513969980546, 'bagging_freq': 6, 'min_split_gain': 0.6320973009824752}. Best is trial 73 with value: 0.7648749547384858.
# [I 2026-03-14 13:53:28,382] Trial 77 finished with value: 0.7482177331070609 and parameters: {'boosting_type': 'dart', 'n_estimators': 1459, 'learning_rate': 0.0033205551691655004, 'max_depth': 6, 'num_leaves': 98, 'lambda_l1': 1.6185126877747016, 'lambda_l2': 0.0007874865315905862, 'min_child_samples': 46, 'feature_fraction': 0.8911917208269369, 'bagging_fraction': 0.9577618765703437, 'bagging_freq': 6, 'min_split_gain': 0.6262070061877786}. Best is trial 73 with value: 0.7648749547384858.
# [I 2026-03-14 13:53:33,942] Trial 78 finished with value: 0.7492147006413927 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1347, 'learning_rate': 0.0015961448950293352, 'max_depth': 5, 'num_leaves': 143, 'lambda_l1': 0.31322488556147976, 'lambda_l2': 0.004110442468383912, 'min_child_samples': 61, 'feature_fraction': 0.959102348299156, 'bagging_fraction': 0.9839356730134805, 'bagging_freq': 6, 'min_split_gain': 0.5194383431815688}. Best is trial 73 with value: 0.7648749547384858.
# [I 2026-03-14 13:53:39,247] Trial 79 finished with value: 0.7580754508848878 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1437, 'learning_rate': 0.004747064950421967, 'max_depth': 8, 'num_leaves': 86, 'lambda_l1': 0.03866380461646149, 'lambda_l2': 0.0002170920775534235, 'min_child_samples': 51, 'feature_fraction': 0.9380466001341752, 'bagging_fraction': 0.9283452738548895, 'bagging_freq': 7, 'min_split_gain': 0.5694285104587895}. Best is trial 73 with value: 0.7648749547384858.
# [I 2026-03-14 13:53:46,000] Trial 80 finished with value: 0.7515406237640444 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1391, 'learning_rate': 0.002517547332884952, 'max_depth': 6, 'num_leaves': 86, 'lambda_l1': 0.1916022353661276, 'lambda_l2': 0.0006163830152068212, 'min_child_samples': 73, 'feature_fraction': 0.9144937966857135, 'bagging_fraction': 0.9013174494075195, 'bagging_freq': 6, 'min_split_gain': 0.6695614373309146}. Best is trial 73 with value: 0.7648749547384858.
# [I 2026-03-14 13:53:50,018] Trial 81 finished with value: 0.7573069288627781 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1473, 'learning_rate': 0.0038577847322554155, 'max_depth': 7, 'num_leaves': 30, 'lambda_l1': 1.070407013151862, 'lambda_l2': 0.002478585712982521, 'min_child_samples': 33, 'feature_fraction': 0.8735312689687784, 'bagging_fraction': 0.9586585215932446, 'bagging_freq': 7, 'min_split_gain': 0.7300559990231983}. Best is trial 73 with value: 0.7648749547384858.
# [I 2026-03-14 13:53:55,322] Trial 82 finished with value: 0.7554493232021962 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1278, 'learning_rate': 0.0030913813986232154, 'max_depth': 7, 'num_leaves': 58, 'lambda_l1': 0.08549557445038013, 'lambda_l2': 0.00012706374528081207, 'min_child_samples': 67, 'feature_fraction': 0.9938012964973596, 'bagging_fraction': 0.7874541474291662, 'bagging_freq': 6, 'min_split_gain': 0.6980854257224163}. Best is trial 73 with value: 0.7648749547384858.
# [I 2026-03-14 13:53:58,830] Trial 83 finished with value: 0.7610821062948349 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1336, 'learning_rate': 0.005108571071933353, 'max_depth': 6, 'num_leaves': 41, 'lambda_l1': 1.6468827771110943, 'lambda_l2': 1.540953401748407e-05, 'min_child_samples': 64, 'feature_fraction': 0.8977434426975299, 'bagging_fraction': 0.9773053957350507, 'bagging_freq': 7, 'min_split_gain': 0.6459840863719251}. Best is trial 73 with value: 0.7648749547384858.
# [I 2026-03-14 13:54:02,897] Trial 84 finished with value: 0.76022972229521 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1423, 'learning_rate': 0.005100368515210148, 'max_depth': 5, 'num_leaves': 41, 'lambda_l1': 1.9184360943015397, 'lambda_l2': 6.989866667755385e-05, 'min_child_samples': 64, 'feature_fraction': 0.8993553037561094, 'bagging_fraction': 0.998492945933023, 'bagging_freq': 7, 'min_split_gain': 0.580069054731722}. Best is trial 73 with value: 0.7648749547384858.
# [I 2026-03-14 13:54:07,591] Trial 85 finished with value: 0.7472333270255355 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1333, 'learning_rate': 0.0019660680758651133, 'max_depth': 6, 'num_leaves': 55, 'lambda_l1': 6.076375441368994, 'lambda_l2': 1.3661060670470216e-05, 'min_child_samples': 53, 'feature_fraction': 0.9248524724907213, 'bagging_fraction': 0.9415044396022889, 'bagging_freq': 7, 'min_split_gain': 0.5354631219588005}. Best is trial 73 with value: 0.7648749547384858.
# [I 2026-03-14 13:54:11,003] Trial 86 finished with value: 0.7403979550991783 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1380, 'learning_rate': 0.004287485569418984, 'max_depth': 5, 'num_leaves': 113, 'lambda_l1': 9.761654083555607, 'lambda_l2': 2.5219461552416397e-05, 'min_child_samples': 56, 'feature_fraction': 0.9436557189545058, 'bagging_fraction': 0.9776693297069246, 'bagging_freq': 7, 'min_split_gain': 0.6240618955135524}. Best is trial 73 with value: 0.7648749547384858.
# [I 2026-03-14 13:54:16,673] Trial 87 finished with value: 0.7561550091754171 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1484, 'learning_rate': 0.0026856566222880018, 'max_depth': 6, 'num_leaves': 22, 'lambda_l1': 0.42225012654650307, 'lambda_l2': 9.53340321250014e-06, 'min_child_samples': 61, 'feature_fraction': 0.883958608700417, 'bagging_fraction': 0.9669415133118588, 'bagging_freq': 6, 'min_split_gain': 0.6370752528989833}. Best is trial 73 with value: 0.7648749547384858.
# [I 2026-03-14 13:54:20,116] Trial 88 finished with value: 0.7520259301118286 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1415, 'learning_rate': 0.0058721131077182475, 'max_depth': 6, 'num_leaves': 70, 'lambda_l1': 3.7723379784918687, 'lambda_l2': 3.7964888233833334e-06, 'min_child_samples': 72, 'feature_fraction': 0.9043820492793102, 'bagging_fraction': 0.9255465418791353, 'bagging_freq': 7, 'min_split_gain': 0.3642417872667568}. Best is trial 73 with value: 0.7648749547384858.
# [I 2026-03-14 13:54:24,563] Trial 89 finished with value: 0.7536391093712066 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1298, 'learning_rate': 0.0031925234197725375, 'max_depth': 7, 'num_leaves': 40, 'lambda_l1': 0.5751633946704425, 'lambda_l2': 8.402837534211242, 'min_child_samples': 68, 'feature_fraction': 0.8546319014046955, 'bagging_fraction': 0.9839180871616938, 'bagging_freq': 6, 'min_split_gain': 0.47516187275698873}. Best is trial 73 with value: 0.7648749547384858.
# [I 2026-03-14 13:54:47,230] Trial 90 finished with value: 0.7378283322310607 and parameters: {'boosting_type': 'dart', 'n_estimators': 1347, 'learning_rate': 0.0037794064765384033, 'max_depth': 5, 'num_leaves': 93, 'lambda_l1': 0.1628564983261393, 'lambda_l2': 4.100935713617543e-05, 'min_child_samples': 64, 'feature_fraction': 0.8668264507253239, 'bagging_fraction': 0.9519611362508399, 'bagging_freq': 7, 'min_split_gain': 0.7774725947789576}. Best is trial 73 with value: 0.7648749547384858.
# [I 2026-03-14 13:54:50,399] Trial 91 finished with value: 0.7615754341950973 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1434, 'learning_rate': 0.005553991627493271, 'max_depth': 5, 'num_leaves': 44, 'lambda_l1': 1.7554346656201647, 'lambda_l2': 7.286060727087733e-05, 'min_child_samples': 64, 'feature_fraction': 0.8999310386482519, 'bagging_fraction': 0.9868365530414469, 'bagging_freq': 7, 'min_split_gain': 0.578341043326897}. Best is trial 73 with value: 0.7648749547384858.
# [I 2026-03-14 13:54:53,685] Trial 92 finished with value: 0.7601201157199609 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1453, 'learning_rate': 0.004839590109914525, 'max_depth': 5, 'num_leaves': 47, 'lambda_l1': 1.5107315984325873, 'lambda_l2': 0.00020762558770438783, 'min_child_samples': 74, 'feature_fraction': 0.8463295625027074, 'bagging_fraction': 0.9890150274557502, 'bagging_freq': 7, 'min_split_gain': 0.6468171023335415}. Best is trial 73 with value: 0.7648749547384858.
# [I 2026-03-14 13:54:57,797] Trial 93 finished with value: 0.7580055028523095 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1434, 'learning_rate': 0.005575607648078779, 'max_depth': 6, 'num_leaves': 58, 'lambda_l1': 0.2683416034225921, 'lambda_l2': 0.00048097250123396875, 'min_child_samples': 57, 'feature_fraction': 0.9664837571013527, 'bagging_fraction': 0.9621380350719528, 'bagging_freq': 7, 'min_split_gain': 0.5608550602283395}. Best is trial 73 with value: 0.7648749547384858.
# [I 2026-03-14 13:55:03,693] Trial 94 finished with value: 0.7585128500382546 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1500, 'learning_rate': 0.0022674990238951095, 'max_depth': 5, 'num_leaves': 28, 'lambda_l1': 2.7291073463594144, 'lambda_l2': 8.375947417242044e-05, 'min_child_samples': 50, 'feature_fraction': 0.9165967160404181, 'bagging_fraction': 0.9444087217306681, 'bagging_freq': 6, 'min_split_gain': 0.6089461066136096}. Best is trial 73 with value: 0.7648749547384858.
# [I 2026-03-14 13:55:07,785] Trial 95 finished with value: 0.763067755808429 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1393, 'learning_rate': 0.004098916161120921, 'max_depth': 4, 'num_leaves': 51, 'lambda_l1': 0.8704120321786766, 'lambda_l2': 7.937918159697367e-07, 'min_child_samples': 45, 'feature_fraction': 0.9310674120105549, 'bagging_fraction': 0.9697281382365183, 'bagging_freq': 6, 'min_split_gain': 0.687227031228267}. Best is trial 73 with value: 0.7648749547384858.
# ...
# [I 2026-03-14 13:56:46,299] Trial 118 finished with value: 0.763615505388929 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1007, 'learning_rate': 0.003150092762592882, 'max_depth': 3, 'num_leaves': 63, 'lambda_l1': 0.2824592297473155, 'lambda_l2': 1.447597470258318e-06, 'min_child_samples': 46, 'feature_fraction': 0.9136024182242948, 'bagging_fraction': 0.859475251815937, 'bagging_freq': 6, 'min_split_gain': 0.718621605030366}. Best is trial 99 with value: 0.7662982997475837.
# [I 2026-03-14 13:56:51,234] Trial 119 finished with value: 0.7596468074123045 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1035, 'learning_rate': 0.003048598295422379, 'max_depth': 3, 'num_leaves': 79, 'lambda_l1': 0.0682115427278333, 'lambda_l2': 1.04393788488106e-07, 'min_child_samples': 47, 'feature_fraction': 0.9413646227118447, 'bagging_fraction': 0.8297862997503489, 'bagging_freq': 6, 'min_split_gain': 0.7129711072804833}. Best is trial 99 with value: 0.7662982997475837.
# [I 2026-03-14 13:56:54,137] Trial 120 finished with value: 0.7580167384622424 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1005, 'learning_rate': 0.0033734634563281525, 'max_depth': 2, 'num_leaves': 61, 'lambda_l1': 0.28979803818199634, 'lambda_l2': 1.6441788750320399e-06, 'min_child_samples': 41, 'feature_fraction': 0.9852634163689917, 'bagging_fraction': 0.8581920660785539, 'bagging_freq': 6, 'min_split_gain': 0.7331919029263113}. Best is trial 99 with value: 0.7662982997475837.
# [I 2026-03-14 13:56:57,482] Trial 121 finished with value: 0.7640608028117192 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 979, 'learning_rate': 0.004614901480109208, 'max_depth': 3, 'num_leaves': 65, 'lambda_l1': 0.528942683506418, 'lambda_l2': 5.624113977474646e-06, 'min_child_samples': 45, 'feature_fraction': 0.9323790200074097, 'bagging_fraction': 0.8886386115180732, 'bagging_freq': 6, 'min_split_gain': 0.7820852246617798}. Best is trial 99 with value: 0.7662982997475837.
# [I 2026-03-14 13:57:01,183] Trial 122 finished with value: 0.76392184546342 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 968, 'learning_rate': 0.004754394682941303, 'max_depth': 3, 'num_leaves': 66, 'lambda_l1': 0.5271656402928141, 'lambda_l2': 5.848809553056488e-06, 'min_child_samples': 34, 'feature_fraction': 0.9139368737897798, 'bagging_fraction': 0.8890602325209992, 'bagging_freq': 6, 'min_split_gain': 0.7865714852248101}. Best is trial 99 with value: 0.7662982997475837.
# [I 2026-03-14 13:57:04,305] Trial 123 finished with value: 0.7598650859249965 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 900, 'learning_rate': 0.004632137349761552, 'max_depth': 3, 'num_leaves': 67, 'lambda_l1': 0.629356995503224, 'lambda_l2': 4.76699027728587e-06, 'min_child_samples': 42, 'feature_fraction': 0.9181250827498756, 'bagging_fraction': 0.8917065991925233, 'bagging_freq': 6, 'min_split_gain': 0.781634413379153}. Best is trial 99 with value: 0.7662982997475837.
# [I 2026-03-14 13:57:07,713] Trial 124 finished with value: 0.7635420880147392 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 978, 'learning_rate': 0.004950437408764528, 'max_depth': 3, 'num_leaves': 151, 'lambda_l1': 0.5464001974936197, 'lambda_l2': 6.546945090036241e-06, 'min_child_samples': 32, 'feature_fraction': 0.9105126570929346, 'bagging_fraction': 0.880317889298205, 'bagging_freq': 6, 'min_split_gain': 0.8056121549168085}. Best is trial 99 with value: 0.7662982997475837.
# [I 2026-03-14 13:57:10,545] Trial 125 finished with value: 0.7572318286244872 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 979, 'learning_rate': 0.005848633072564829, 'max_depth': 2, 'num_leaves': 149, 'lambda_l1': 0.43938084386808746, 'lambda_l2': 7.057340028318842e-06, 'min_child_samples': 33, 'feature_fraction': 0.9659040954106265, 'bagging_fraction': 0.8834478753861761, 'bagging_freq': 6, 'min_split_gain': 0.8252389350950351}. Best is trial 99 with value: 0.7662982997475837.
# [I 2026-03-14 13:57:14,252] Trial 126 finished with value: 0.7651099821556281 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 962, 'learning_rate': 0.0052256421552995275, 'max_depth': 3, 'num_leaves': 154, 'lambda_l1': 0.20409292453225605, 'lambda_l2': 1.0757564935473207e-05, 'min_child_samples': 34, 'feature_fraction': 0.9125734427188158, 'bagging_fraction': 0.8437345804646302, 'bagging_freq': 6, 'min_split_gain': 0.8668374813237495}. Best is trial 99 with value: 0.7662982997475837.
# [I 2026-03-14 13:57:17,716] Trial 127 finished with value: 0.7522712361205223 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 974, 'learning_rate': 0.005214954524819879, 'max_depth': 3, 'num_leaves': 186, 'lambda_l1': 0.217583026934694, 'lambda_l2': 9.438162352158498e-06, 'min_child_samples': 34, 'feature_fraction': 0.4679808547674535, 'bagging_fraction': 0.8244563600077892, 'bagging_freq': 6, 'min_split_gain': 0.8554517910506247}. Best is trial 99 with value: 0.7662982997475837.
# [I 2026-03-14 13:57:20,488] Trial 128 finished with value: 0.756515550225121 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 933, 'learning_rate': 0.007576855911450001, 'max_depth': 2, 'num_leaves': 155, 'lambda_l1': 0.3240258199248385, 'lambda_l2': 2.6688416531070573e-06, 'min_child_samples': 28, 'feature_fraction': 0.9102221519780133, 'bagging_fraction': 0.8103152540285607, 'bagging_freq': 6, 'min_split_gain': 0.8722953974772661}. Best is trial 99 with value: 0.7662982997475837.
# [I 2026-03-14 13:57:24,306] Trial 129 finished with value: 0.7547012978074817 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1023, 'learning_rate': 0.006583706455474487, 'max_depth': 3, 'num_leaves': 168, 'lambda_l1': 0.04068066759542203, 'lambda_l2': 4.543565126511478e-06, 'min_child_samples': 31, 'feature_fraction': 0.9999881528914771, 'bagging_fraction': 0.8486136804284429, 'bagging_freq': 6, 'min_split_gain': 0.8086843123891005}. Best is trial 99 with value: 0.7662982997475837.
# [I 2026-03-14 13:57:27,201] Trial 130 finished with value: 0.7581226337109954 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 884, 'learning_rate': 0.004829739624031015, 'max_depth': 2, 'num_leaves': 138, 'lambda_l1': 0.17721975659578235, 'lambda_l2': 2.783217347914696e-06, 'min_child_samples': 27, 'feature_fraction': 0.9134444455091537, 'bagging_fraction': 0.8942477056924689, 'bagging_freq': 5, 'min_split_gain': 0.7861612588185547}. Best is trial 99 with value: 0.7662982997475837.
# [I 2026-03-14 13:57:30,777] Trial 131 finished with value: 0.7587840004697478 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 950, 'learning_rate': 0.003652767887919082, 'max_depth': 3, 'num_leaves': 158, 'lambda_l1': 0.5461368436490025, 'lambda_l2': 1.507848296845412e-06, 'min_child_samples': 47, 'feature_fraction': 0.9246664659606633, 'bagging_fraction': 0.8402378622665176, 'bagging_freq': 6, 'min_split_gain': 0.7447406166854008}. Best is trial 99 with value: 0.7662982997475837.
# [I 2026-03-14 13:57:35,370] Trial 132 finished with value: 0.7602696052189483 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1052, 'learning_rate': 0.003598287711537403, 'max_depth': 3, 'num_leaves': 123, 'lambda_l1': 1.3022219593877395, 'lambda_l2': 4.410712532653865e-07, 'min_child_samples': 24, 'feature_fraction': 0.942529761791256, 'bagging_fraction': 0.8569510143375004, 'bagging_freq': 6, 'min_split_gain': 0.7364556023673252}. Best is trial 99 with value: 0.7662982997475837.
# [I 2026-03-14 13:57:38,127] Trial 133 finished with value: 0.7546681024125901 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1094, 'learning_rate': 0.005236657605186084, 'max_depth': 2, 'num_leaves': 61, 'lambda_l1': 2.516761110230497, 'lambda_l2': 2.7178310186307267e-07, 'min_child_samples': 35, 'feature_fraction': 0.958836100752384, 'bagging_fraction': 0.8800557194106575, 'bagging_freq': 6, 'min_split_gain': 0.8367195878686173}. Best is trial 99 with value: 0.7662982997475837.
# [I 2026-03-14 13:57:42,232] Trial 134 finished with value: 0.7583250597943954 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1067, 'learning_rate': 0.003150039875311553, 'max_depth': 3, 'num_leaves': 63, 'lambda_l1': 1.1422335272349302, 'lambda_l2': 2.185381272471074e-06, 'min_child_samples': 40, 'feature_fraction': 0.9703223083759267, 'bagging_fraction': 0.9044732974235206, 'bagging_freq': 6, 'min_split_gain': 0.19704613520280617}. Best is trial 99 with value: 0.7662982997475837.
# [I 2026-03-14 13:57:45,449] Trial 135 finished with value: 0.7598002614276674 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 980, 'learning_rate': 0.00845146807566084, 'max_depth': 4, 'num_leaves': 169, 'lambda_l1': 0.46435219394469257, 'lambda_l2': 1.1825054122766992e-05, 'min_child_samples': 43, 'feature_fraction': 0.9235658481875979, 'bagging_fraction': 0.8606023838627436, 'bagging_freq': 6, 'min_split_gain': 0.8067084979529542}. Best is trial 99 with value: 0.7662982997475837.
# [I 2026-03-14 13:57:48,878] Trial 136 finished with value: 0.7655266786445005 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1006, 'learning_rate': 0.004619586481389428, 'max_depth': 3, 'num_leaves': 57, 'lambda_l1': 0.33513884412609707, 'lambda_l2': 6.267218263172601e-06, 'min_child_samples': 33, 'feature_fraction': 0.9519925734371621, 'bagging_fraction': 0.8858501395143281, 'bagging_freq': 6, 'min_split_gain': 0.6653543156786118}. Best is trial 99 with value: 0.7662982997475837.
# [I 2026-03-14 13:58:00,999] Trial 137 finished with value: 0.7626506855203412 and parameters: {'boosting_type': 'dart', 'n_estimators': 914, 'learning_rate': 0.006110024192200951, 'max_depth': 3, 'num_leaves': 151, 'lambda_l1': 0.2513148471130158, 'lambda_l2': 6.7786468317739644e-06, 'min_child_samples': 29, 'feature_fraction': 0.9821574501063602, 'bagging_fraction': 0.8883635041229958, 'bagging_freq': 5, 'min_split_gain': 0.7718237671454428}. Best is trial 99 with value: 0.7662982997475837.
# [I 2026-03-14 13:58:04,405] Trial 138 finished with value: 0.7639590751386648 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1006, 'learning_rate': 0.004658893840489249, 'max_depth': 3, 'num_leaves': 55, 'lambda_l1': 0.10658004940780733, 'lambda_l2': 3.299651878609723e-05, 'min_child_samples': 32, 'feature_fraction': 0.9439232364915581, 'bagging_fraction': 0.8022124774646697, 'bagging_freq': 6, 'min_split_gain': 0.6619199409268754}. Best is trial 99 with value: 0.7662982997475837.
# [I 2026-03-14 13:58:06,951] Trial 139 finished with value: 0.7623190646155608 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1005, 'learning_rate': 0.004680509369666621, 'max_depth': 2, 'num_leaves': 56, 'lambda_l1': 0.12782442844217645, 'lambda_l2': 2.72442980370874e-05, 'min_child_samples': 32, 'feature_fraction': 0.8963553211716158, 'bagging_fraction': 0.802897745916281, 'bagging_freq': 6, 'min_split_gain': 0.6769303633763558}. Best is trial 99 with value: 0.7662982997475837.
# [I 2026-03-14 13:58:08,323] Trial 140 finished with value: 0.7497023179306433 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 861, 'learning_rate': 0.005715932170601494, 'max_depth': 3, 'num_leaves': 52, 'lambda_l1': 0.16601777077836904, 'lambda_l2': 1.5160335191308043e-05, 'min_child_samples': 34, 'feature_fraction': 0.9134366944078367, 'bagging_fraction': 0.40183327422384896, 'bagging_freq': 6, 'min_split_gain': 0.7216656036045855}. Best is trial 99 with value: 0.7662982997475837.
# [I 2026-03-14 13:58:10,101] Trial 141 finished with value: 0.7623662049034264 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 956, 'learning_rate': 0.004716689573858018, 'max_depth': 3, 'num_leaves': 59, 'lambda_l1': 0.3864281861054171, 'lambda_l2': 5.920879941031283e-06, 'min_child_samples': 37, 'feature_fraction': 0.9557826145550756, 'bagging_fraction': 0.842614891756243, 'bagging_freq': 6, 'min_split_gain': 0.6649958487544463}. Best is trial 99 with value: 0.7662982997475837.
# [I 2026-03-14 13:58:11,745] Trial 142 finished with value: 0.7641327192678392 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1036, 'learning_rate': 0.0037045896207590803, 'max_depth': 3, 'num_leaves': 64, 'lambda_l1': 0.5345450431156353, 'lambda_l2': 3.3195773584589303e-06, 'min_child_samples': 25, 'feature_fraction': 0.942971498402802, 'bagging_fraction': 0.8579070968334218, 'bagging_freq': 6, 'min_split_gain': 0.7855147002116386}. Best is trial 99 with value: 0.7662982997475837.
# [I 2026-03-14 13:58:13,398] Trial 143 finished with value: 0.7644227791003876 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1028, 'learning_rate': 0.003757458970034795, 'max_depth': 3, 'num_leaves': 145, 'lambda_l1': 0.5376368395116399, 'lambda_l2': 3.8113335277843864e-06, 'min_child_samples': 23, 'feature_fraction': 0.9416146809027348, 'bagging_fraction': 0.8966046157872665, 'bagging_freq': 6, 'min_split_gain': 0.7483037611807378}. Best is trial 99 with value: 0.7662982997475837.
# [I 2026-03-14 13:58:14,699] Trial 144 finished with value: 0.7553392880442583 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1029, 'learning_rate': 0.0033303258970587613, 'max_depth': 2, 'num_leaves': 144, 'lambda_l1': 0.0533472192602922, 'lambda_l2': 3.419707553115397e-06, 'min_child_samples': 24, 'feature_fraction': 0.9374183998514204, 'bagging_fraction': 0.9163479777678297, 'bagging_freq': 6, 'min_split_gain': 0.7235388802818238}. Best is trial 99 with value: 0.7662982997475837.
# [I 2026-03-14 13:58:16,705] Trial 145 finished with value: 0.7576715624319363 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1050, 'learning_rate': 0.003791927089436969, 'max_depth': 4, 'num_leaves': 64, 'lambda_l1': 0.24395993928413987, 'lambda_l2': 9.672800736007872e-06, 'min_child_samples': 25, 'feature_fraction': 0.9676889892802176, 'bagging_fraction': 0.900007635288682, 'bagging_freq': 6, 'min_split_gain': 0.7577580370642621}. Best is trial 99 with value: 0.7662982997475837.
# [I 2026-03-14 13:58:18,320] Trial 146 finished with value: 0.7595130163294996 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1120, 'learning_rate': 0.002676322434340918, 'max_depth': 3, 'num_leaves': 56, 'lambda_l1': 1.5373371766296178, 'lambda_l2': 3.3882629840439477e-06, 'min_child_samples': 17, 'feature_fraction': 0.9438386227837761, 'bagging_fraction': 0.8612914063515648, 'bagging_freq': 6, 'min_split_gain': 0.7454977203969005}. Best is trial 99 with value: 0.7662982997475837.
# [I 2026-03-14 13:58:19,853] Trial 147 finished with value: 0.7643117387701667 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 993, 'learning_rate': 0.0037371201114210447, 'max_depth': 3, 'num_leaves': 129, 'lambda_l1': 0.09965859391507963, 'lambda_l2': 2.1633087700214733e-05, 'min_child_samples': 18, 'feature_fraction': 0.9756537208791336, 'bagging_fraction': 0.8931135925795344, 'bagging_freq': 6, 'min_split_gain': 0.7799033476803997}. Best is trial 99 with value: 0.7662982997475837.
# [I 2026-03-14 13:58:21,278] Trial 148 finished with value: 0.7612284836797528 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 840, 'learning_rate': 0.0029050483558281472, 'max_depth': 3, 'num_leaves': 132, 'lambda_l1': 0.09212038200233627, 'lambda_l2': 1.9327014430627957e-05, 'min_child_samples': 21, 'feature_fraction': 0.9731720449974272, 'bagging_fraction': 0.8917353755610661, 'bagging_freq': 6, 'min_split_gain': 0.6650362521835804}. Best is trial 99 with value: 0.7662982997475837.
# [I 2026-03-14 13:58:23,013] Trial 149 finished with value: 0.7638106032506783 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 992, 'learning_rate': 0.003397991353696313, 'max_depth': 3, 'num_leaves': 125, 'lambda_l1': 0.1526533269456893, 'lambda_l2': 4.449577689292665e-05, 'min_child_samples': 15, 'feature_fraction': 0.9824405040444322, 'bagging_fraction': 0.8374975323499605, 'bagging_freq': 6, 'min_split_gain': 0.7781921881408396}. Best is trial 99 with value: 0.7662982997475837.
# Best Score: 0.7662982997475837

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import lightgbm as lgb

# Train model với tham số tốt nhất

best_clf = lgb.LGBMClassifier(
        **study.best_params
)
best_clf.fit(X_train_r, y_train_r)
pred_r = best_clf.predict(X_test_r).ravel()

print("=== Baseline Classification on Random Split ===")
eval_classification(y_test_r, pred_r, name="RandomSplit")

print("\nClassification report (RandomSplit):")
print(classification_report(y_test_r, pred_r, digits=4))

cm_r = confusion_matrix(y_test_r, pred_r, labels=sorted(y_train_r.unique()))
cm_r_df = pd.DataFrame(cm_r, index=sorted(y_train_r.unique()), columns=sorted(y_train_r.unique()))
cm_r_df.to_csv("optuna_baseline_cm_random_ddpm.csv", encoding="utf-8-sig")
print("Saved: optuna_baseline_cm_random_ddpm.csv")

save_preds_csv(X_test_r, y_test_r.values, pred_r, "optuna_baseline_preds_random_cls_ddpm.csv")

# Vẽ Confusion Matrix
plt.figure(figsize=(10,8))
sns.heatmap(confusion_matrix(y_test_r, pred_r), annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.9472775984869909, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9472775984869909
# [LightGBM] [Warning] lambda_l1 is set=0.8760301749294831, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.8760301749294831
# [LightGBM] [Warning] lambda_l2 is set=7.216834241383895e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.216834241383895e-07
# [LightGBM] [Warning] bagging_fraction is set=0.8612339275052868, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8612339275052868
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [LightGBM] [Warning] feature_fraction is set=0.9472775984869909, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9472775984869909
# [LightGBM] [Warning] lambda_l1 is set=0.8760301749294831, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.8760301749294831
# [LightGBM] [Warning] lambda_l2 is set=7.216834241383895e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.216834241383895e-07
# [LightGBM] [Warning] bagging_fraction is set=0.8612339275052868, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8612339275052868
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000150 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1079
# [LightGBM] [Info] Number of data points in the train set: 1502, number of used features: 7
# [LightGBM] [Info] Start training from score -3.124898
# [LightGBM] [Info] Start training from score -2.803693
# [LightGBM] [Info] Start training from score -3.037887
# [LightGBM] [Info] Start training from score -2.760676
# [LightGBM] [Info] Start training from score -2.803693
# [LightGBM] [Info] Start training from score -2.957844
# [LightGBM] [Info] Start training from score -2.760676
# [LightGBM] [Info] Start training from score -1.683341
# [LightGBM] [Info] Start training from score -3.080446
# [LightGBM] [Info] Start training from score -2.094197
# [LightGBM] [Info] Start training from score -1.371753
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] feature_fraction is set=0.9472775984869909, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9472775984869909
# [LightGBM] [Warning] lambda_l1 is set=0.8760301749294831, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.8760301749294831
# [LightGBM] [Warning] lambda_l2 is set=7.216834241383895e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.216834241383895e-07
# [LightGBM] [Warning] bagging_fraction is set=0.8612339275052868, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8612339275052868
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# === Baseline Classification on Random Split ===
# RandomSplit Accuracy: 0.7603 | F1-macro: 0.6942 | F1-weighted: 0.7549
#
# Classification report (RandomSplit):
#               precision    recall  f1-score   support
#
#            A     1.0000    1.0000    1.0000         4
#            B     1.0000    0.9333    0.9655        15
#            C     1.0000    1.0000    1.0000         2
#            D     0.7273    0.8889    0.8000         9
#            E     0.8750    0.5385    0.6667        13
#            F     0.0000    0.0000    0.0000         0
#            G     0.8182    1.0000    0.9000         9
#            H     0.6667    0.7879    0.7222        33
#            I     0.2000    0.3333    0.2500         3
#            J     0.8750    0.3043    0.4516        23
#            K     0.8250    0.9429    0.8800        35
#
#     accuracy                         0.7603       146
#    macro avg     0.7261    0.7026    0.6942       146
# weighted avg     0.8074    0.7603    0.7549       146
#
# Saved: optuna_baseline_cm_random_ddpm.csv
# Saved: optuna_baseline_preds_random_cls_ddpm.csv
