# %% [markdown]
# ## Baseline Model

# %%
import warnings

from lightgbm import LGBMClassifier
import pandas as pd
import numpy as np

warnings.filterwarnings("ignore")

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix
from sklearn.ensemble import HistGradientBoostingClassifier, RandomForestClassifier

def eval_classification(y_true, y_pred, name=""):
    acc = accuracy_score(y_true, y_pred)
    f1_macro = f1_score(y_true, y_pred, average="macro")
    f1_weighted = f1_score(y_true, y_pred, average="weighted")
    print(f"{name} Accuracy: {acc:.4f} | F1-macro: {f1_macro:.4f} | F1-weighted: {f1_weighted:.4f}")
    return acc, f1_macro, f1_weighted

def save_preds_csv(X_test, y_true, y_pred, filename):
    out = X_test.copy()
    out["y_true"] = y_true
    out["y_pred"] = y_pred
    out.to_csv(filename, index=False, encoding="utf-8-sig")
    print(f"Saved: {filename}")

def derive_groups_from_train(train_df, k_baseline_dict, min_group_size=2):
    """
    Returns: type_to_group dict, groups dict
    Uses only train_df to avoid test leakage.
    Phân loại các 'type' thành near/mid/far dựa trên trung bình độ lệch tuyệt đối (abs_diff)
    """
    df_temp = train_df.copy()
    df_temp["k_eff_expected"] = df_temp["load"].map(k_baseline_dict)
    if df_temp["k_eff_expected"].isnull().any():
        known_loads = np.array(list(k_baseline_dict.keys()))
        for idx, row in df_temp[df_temp["k_eff_expected"].isnull()].iterrows():
            closest_load = known_loads[np.abs(known_loads - row["load"]).argmin()]
            df_temp.loc[idx, "k_eff_expected"] = k_baseline_dict[closest_load]     
    df_temp["abs_diff"] = (df_temp["efficiency"] - df_temp["k_eff_expected"]).abs()
    type_stats = (
        df_temp.groupby("type")["abs_diff"]
        .agg(n="count", mean="mean")
        .sort_values("mean")
        .reset_index()
    )
    types = type_stats["type"].tolist()
    x = type_stats["mean"].to_numpy()
    n = len(x)
    # Prefix sums for O(1) segment SSE
    S1 = np.concatenate([[0.0], np.cumsum(x)])
    S2 = np.concatenate([[0.0], np.cumsum(x * x)])
    def seg_sse(i, j):
        m = j - i + 1
        sum1 = S1[j + 1] - S1[i]
        sum2 = S2[j + 1] - S2[i]
        mu = sum1 / m
        return sum2 - 2 * mu * sum1 + m * mu * mu

    K = 3
    INF = 1e18
    dp = np.full((K + 1, n + 1), INF)
    cut = np.full((K + 1, n + 1), -1, dtype=int)

    dp[0, 0] = 0.0
    for k in range(1, K + 1):
        for t in range(1, n + 1):
            p_min = (k - 1) * min_group_size
            p_max = t - min_group_size
            if p_max < p_min:
                continue
            best_cost, best_p = INF, -1
            for p in range(p_min, p_max + 1):
                cost = dp[k - 1, p] + seg_sse(p, t - 1)
                if cost < best_cost:
                    best_cost, best_p = cost, p
            dp[k, t] = best_cost
            cut[k, t] = best_p

    if np.isinf(dp[K, n]):
        raise RuntimeError("No valid split found. Try min_group_size=1 or check types count.")
    bounds = []
    t = n
    for k in range(K, 0, -1):
        p = cut[k, t]
        bounds.append((p, t))
        t = p
    bounds.reverse()
    group_names = ["near", "mid", "far"] 
    groups = {}
    for name, (a, b) in zip(group_names, bounds):
        groups[name] = types[a:b]

    type_to_group = {t: g for g, ts in groups.items() for t in ts}
    return type_to_group, groups, type_stats


# ----- Load your saved split files -----
train_random = pd.read_csv('../../../GenerativeModel/CTGANGenData/wpt_train_random_aug_ctgan.csv')
test_random  = pd.read_csv('../../../random-split/wpt_test_random.csv')

# Sanity check expected columns
expected_cols = {"type", "load", "efficiency"}
for name, d in [("train_random", train_random), ("test_random", test_random)]:
    missing = expected_cols - set(d.columns)
    if missing:
        raise ValueError(f"{name} is missing columns: {missing}")

# Make sure numeric columns are numeric
for d in [train_random, test_random]:
    d["load"] = pd.to_numeric(d["load"], errors="coerce")
    d["efficiency"] = pd.to_numeric(d["efficiency"], errors="coerce")
    d["type"] = d["type"].astype(str)
    d.dropna(subset=["type", "load", "efficiency"], inplace=True)

# Features / target
FEATURES = ["load", "efficiency"]
TARGET = "type"

# =========================
def add_advanced_features(df, k_baseline_dict, type_to_group_dict):
    df = df.copy()
    df["k_eff_expected"] = df["load"].map(k_baseline_dict)
    if df["k_eff_expected"].isnull().any():
        known_loads = np.array(list(k_baseline_dict.keys()))
        for idx, row in df[df["k_eff_expected"].isnull()].iterrows():
            closest_load = known_loads[np.abs(known_loads - row["load"]).argmin()]
            df.loc[idx, "k_eff_expected"] = k_baseline_dict[closest_load]  
    # 2. Độ lệch (Difference) và Tỷ lệ (Ratio)
    df["eff_diff"] = df["efficiency"] - df["k_eff_expected"]
    df["eff_ratio"] = df["efficiency"] / df["k_eff_expected"]
    # 3. Ước tính tổn hao công suất (Power Loss Proxy)
    # P_loss = Load * (1 / (Efficiency / 100) - 1)
    df["p_loss"] = df["load"] * (1 / (df["efficiency"] / 100.0) - 1)
    # Tổn hao công suất của Class K
    df["k_p_loss"] = df["load"] * (1 / (df["k_eff_expected"] / 100.0) - 1)
    # Độ lệch suy hao do vật thể lạ gây ra
    df["p_loss_diff"] = df["p_loss"] - df["k_p_loss"]

    df["dist_zone_name"] = df["type"].map(type_to_group_dict).fillna("far")
    # Mã hóa thành số
    zone_mapping = {"near": 1, "mid": 2, "far": 3}
    df["dist_zone"] = df["dist_zone_name"].map(zone_mapping)
    # 4. Phân vùng Dải tải (Load Zone)
    # Giả sử dải tải từ 0.5 đến 3.0, chia làm 3 vùng: Nhẹ (1), Vừa (2), Nặng (3)
    df['load_zone'] = pd.cut(df['load'], bins=3, labels=[1, 2, 3]).astype(float)
    return df

k_baseline_train_r = train_random[train_random["type"] == "K"].groupby("load")["efficiency"].mean().to_dict()
type_to_group, groups_dict, stats = derive_groups_from_train(train_random, k_baseline_train_r)
print("Results of grouping the Types:", groups_dict)

train_random_fe = add_advanced_features(train_random, k_baseline_train_r, type_to_group)
test_random_fe = add_advanced_features(test_random, k_baseline_train_r, type_to_group)

FEATURES_NEW = [
    "load", "efficiency", 
    "eff_diff", "eff_ratio", 
    "p_loss_diff", "load_zone", "dist_zone"
]
# =========================
X_train_r = train_random_fe[FEATURES_NEW]
y_train_r = train_random_fe[TARGET]
X_test_r  = test_random_fe[FEATURES_NEW]
y_test_r  = test_random_fe[TARGET]
# Out:
# Results of grouping the Types: {'near': ['K', 'H', 'J', 'G'], 'mid': ['E', 'D', 'I', 'B', 'F'], 'far': ['C', 'A']}

# %% [markdown]
# ## Optuna

# %%
import optuna
import lightgbm as lgb
import json
from sklearn.model_selection import StratifiedKFold, cross_val_score

def objective(trial):
    # Định nghĩa không gian tìm kiếm RỘNG để "học rộng hơn"
    param = {
        'objective': 'multiclass',
        'num_class': 11,
        'metric': 'multi_logloss',
        'verbosity': -1,
        'random_state': 42,
        'class_weight': 'balanced',
        
        # Cho phép thử nghiệm cả 2 loại Boosting
        'boosting_type': trial.suggest_categorical('boosting_type', ['gbdt', 'dart']),
        
        # Mở rộng dải tham số
        'n_estimators': trial.suggest_int('n_estimators', 100, 1500), 
        'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 2, 12), 
        'num_leaves': trial.suggest_int('num_leaves', 4, 256),
        
        # Regularization cực rộng để tìm điểm tối ưu mới
        'lambda_l1': trial.suggest_float('lambda_l1', 1e-8, 10.0, log=True),
        'lambda_l2': trial.suggest_float('lambda_l2', 1e-8, 10.0, log=True),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.4, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.4, 1.0),
        'bagging_freq': trial.suggest_int('bagging_freq', 1, 7),
        'min_split_gain': trial.suggest_float('min_split_gain', 0, 1.0),
    }

    clf = lgb.LGBMClassifier(**param)
    
    # Sử dụng StratifiedKFold đơn thuần (thường dùng 5 hoặc 10 fold)
    cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
    
    # Tính điểm số trung bình
    scores = cross_val_score(clf, X_train_r, y_train_r, cv=cv, scoring='f1_macro', n_jobs=-1)
    
    return scores.mean()

# Khởi tạo và chạy tối ưu 200 lần
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=150, show_progress_bar=True)

# --- TRÍCH XUẤT VÀ LƯU KẾT QUẢ ---
best_params = study.best_params
best_params.update({
    'objective': 'multiclass',
    'num_class': 11,
    'metric': 'multi_logloss',
    'verbosity': -1,
    'random_state': 42
})

with open("best_lgbm_params.json", "w") as f:
    json.dump(best_params, f, indent=4)

print(f"Best Score: {study.best_value}")
# Out:
# [I 2026-03-13 22:17:33,539] A new study created in memory with name: no-name-602b717f-36ef-42ba-9c6f-fdbd064937eb
#   0%|          | 0/150 [00:00<?, ?it/s]
# [I 2026-03-13 22:17:51,975] Trial 0 finished with value: 0.6838055666309565 and parameters: {'boosting_type': 'dart', 'n_estimators': 1110, 'learning_rate': 0.027643676641809757, 'max_depth': 4, 'num_leaves': 136, 'lambda_l1': 0.0021564045870453566, 'lambda_l2': 0.0015192690112029374, 'min_child_samples': 21, 'feature_fraction': 0.5532009806994018, 'bagging_fraction': 0.7926412449267799, 'bagging_freq': 5, 'min_split_gain': 0.38958718383373503}. Best is trial 0 with value: 0.6838055666309565.
# [I 2026-03-13 22:18:07,264] Trial 1 finished with value: 0.6574521065845852 and parameters: {'boosting_type': 'dart', 'n_estimators': 1004, 'learning_rate': 0.11621736839028757, 'max_depth': 5, 'num_leaves': 46, 'lambda_l1': 0.00015357166487555446, 'lambda_l2': 0.0016321150358927724, 'min_child_samples': 51, 'feature_fraction': 0.5899156490879178, 'bagging_fraction': 0.5987879807568892, 'bagging_freq': 7, 'min_split_gain': 0.2464454406849239}. Best is trial 0 with value: 0.6838055666309565.
# [I 2026-03-13 22:18:17,603] Trial 2 finished with value: 0.6253855595282588 and parameters: {'boosting_type': 'dart', 'n_estimators': 686, 'learning_rate': 0.0016125251493162615, 'max_depth': 10, 'num_leaves': 103, 'lambda_l1': 4.944593205505644e-05, 'lambda_l2': 0.06081478737478538, 'min_child_samples': 72, 'feature_fraction': 0.4613249014369232, 'bagging_fraction': 0.815645273423272, 'bagging_freq': 4, 'min_split_gain': 0.3200551728218607}. Best is trial 0 with value: 0.6838055666309565.
# [I 2026-03-13 22:18:28,536] Trial 3 finished with value: 0.6573338242618325 and parameters: {'boosting_type': 'dart', 'n_estimators': 823, 'learning_rate': 0.0016633764206164018, 'max_depth': 2, 'num_leaves': 250, 'lambda_l1': 0.00014428695204492532, 'lambda_l2': 0.004447997557504748, 'min_child_samples': 18, 'feature_fraction': 0.5606025953566163, 'bagging_fraction': 0.8633930925165716, 'bagging_freq': 1, 'min_split_gain': 0.8967403911928181}. Best is trial 0 with value: 0.6838055666309565.
# [I 2026-03-13 22:18:29,738] Trial 4 finished with value: 0.6841796305129008 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 199, 'learning_rate': 0.001983217780341034, 'max_depth': 8, 'num_leaves': 59, 'lambda_l1': 0.3176709698117975, 'lambda_l2': 1.4911343392866633e-07, 'min_child_samples': 23, 'feature_fraction': 0.7349846973173255, 'bagging_fraction': 0.9523953953402605, 'bagging_freq': 4, 'min_split_gain': 0.025887542770701044}. Best is trial 4 with value: 0.6841796305129008.
# [I 2026-03-13 22:18:35,007] Trial 5 finished with value: 0.684462233779084 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1250, 'learning_rate': 0.005131210113384048, 'max_depth': 7, 'num_leaves': 44, 'lambda_l1': 0.15850028749099324, 'lambda_l2': 2.6948629436593257e-05, 'min_child_samples': 23, 'feature_fraction': 0.8272059998671615, 'bagging_fraction': 0.8547302787517435, 'bagging_freq': 3, 'min_split_gain': 0.3333495226296467}. Best is trial 5 with value: 0.684462233779084.
# [I 2026-03-13 22:18:41,732] Trial 6 finished with value: 0.6875151540130756 and parameters: {'boosting_type': 'dart', 'n_estimators': 645, 'learning_rate': 0.03835495198549333, 'max_depth': 2, 'num_leaves': 256, 'lambda_l1': 3.891426486989477e-05, 'lambda_l2': 0.1540301007476062, 'min_child_samples': 34, 'feature_fraction': 0.4562540067700816, 'bagging_fraction': 0.9299494061890017, 'bagging_freq': 3, 'min_split_gain': 0.3235192381160805}. Best is trial 6 with value: 0.6875151540130756.
# [I 2026-03-13 22:18:57,260] Trial 7 finished with value: 0.6838931567586753 and parameters: {'boosting_type': 'dart', 'n_estimators': 1293, 'learning_rate': 0.04918749443059717, 'max_depth': 9, 'num_leaves': 195, 'lambda_l1': 0.36946191907474735, 'lambda_l2': 0.36418412369163566, 'min_child_samples': 79, 'feature_fraction': 0.5492751731449845, 'bagging_fraction': 0.5750112493456513, 'bagging_freq': 3, 'min_split_gain': 0.3767799431652129}. Best is trial 6 with value: 0.6875151540130756.
# [I 2026-03-13 22:18:59,790] Trial 8 finished with value: 0.6440848385427235 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1154, 'learning_rate': 0.0010537555563907878, 'max_depth': 6, 'num_leaves': 129, 'lambda_l1': 0.04596261340354021, 'lambda_l2': 0.6131592571248068, 'min_child_samples': 87, 'feature_fraction': 0.5815638493102736, 'bagging_fraction': 0.43483455011393823, 'bagging_freq': 3, 'min_split_gain': 0.7822243649964401}. Best is trial 6 with value: 0.6875151540130756.
# [I 2026-03-13 22:19:00,038] Trial 9 finished with value: 0.6862016318083185 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 212, 'learning_rate': 0.15331900998932427, 'max_depth': 2, 'num_leaves': 147, 'lambda_l1': 4.141357233918502, 'lambda_l2': 1.0392519298613e-08, 'min_child_samples': 95, 'feature_fraction': 0.7694388688455862, 'bagging_fraction': 0.5989000674348001, 'bagging_freq': 3, 'min_split_gain': 0.18378031217924617}. Best is trial 6 with value: 0.6875151540130756.
# [I 2026-03-13 22:19:04,342] Trial 10 finished with value: 0.6848963998543537 and parameters: {'boosting_type': 'dart', 'n_estimators': 493, 'learning_rate': 0.011478782623463479, 'max_depth': 12, 'num_leaves': 237, 'lambda_l1': 3.463555724852013e-08, 'lambda_l2': 7.154413369723299, 'min_child_samples': 44, 'feature_fraction': 0.995181726971291, 'bagging_fraction': 0.972014874337467, 'bagging_freq': 1, 'min_split_gain': 0.6427389965881226}. Best is trial 6 with value: 0.6875151540130756.
# [I 2026-03-13 22:19:04,655] Trial 11 finished with value: 0.6825379555640385 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 108, 'learning_rate': 0.19839310252803882, 'max_depth': 2, 'num_leaves': 198, 'lambda_l1': 1.1969427992085146e-06, 'lambda_l2': 2.511130386377333e-08, 'min_child_samples': 99, 'feature_fraction': 0.818017709630466, 'bagging_fraction': 0.6572513869258466, 'bagging_freq': 2, 'min_split_gain': 0.0785660462734348}. Best is trial 6 with value: 0.6875151540130756.
# [I 2026-03-13 22:19:05,900] Trial 12 finished with value: 0.6808340557338363 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 463, 'learning_rate': 0.0578906550508859, 'max_depth': 3, 'num_leaves': 186, 'lambda_l1': 5.591719625722236, 'lambda_l2': 1.0034919145019162e-05, 'min_child_samples': 38, 'feature_fraction': 0.42305438095029024, 'bagging_fraction': 0.47813044057654625, 'bagging_freq': 6, 'min_split_gain': 0.1606045730569693}. Best is trial 6 with value: 0.6875151540130756.
# [I 2026-03-13 22:19:06,701] Trial 13 finished with value: 0.6713112732445223 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 364, 'learning_rate': 0.08862934479842036, 'max_depth': 4, 'num_leaves': 86, 'lambda_l1': 3.7361673040908785e-06, 'lambda_l2': 1.3359381903561873e-06, 'min_child_samples': 66, 'feature_fraction': 0.7062645939722646, 'bagging_fraction': 0.7257291067046081, 'bagging_freq': 2, 'min_split_gain': 0.5802488481313429}. Best is trial 6 with value: 0.6875151540130756.
# [I 2026-03-13 22:19:12,565] Trial 14 finished with value: 0.7052963688782424 and parameters: {'boosting_type': 'dart', 'n_estimators': 694, 'learning_rate': 0.021877577012960225, 'max_depth': 2, 'num_leaves': 151, 'lambda_l1': 0.003741864730241139, 'lambda_l2': 0.0001333346279472191, 'min_child_samples': 5, 'feature_fraction': 0.8999619594865808, 'bagging_fraction': 0.5215866402391376, 'bagging_freq': 5, 'min_split_gain': 0.1711258286614809}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:19:20,401] Trial 15 finished with value: 0.696625160241276 and parameters: {'boosting_type': 'dart', 'n_estimators': 705, 'learning_rate': 0.016542669924163107, 'max_depth': 4, 'num_leaves': 8, 'lambda_l1': 0.002907807815226865, 'lambda_l2': 0.0001243088652270801, 'min_child_samples': 6, 'feature_fraction': 0.9470048939517288, 'bagging_fraction': 0.5082443787372779, 'bagging_freq': 5, 'min_split_gain': 0.41952800314933913}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:19:31,331] Trial 16 finished with value: 0.6967577367642401 and parameters: {'boosting_type': 'dart', 'n_estimators': 900, 'learning_rate': 0.01270898908448876, 'max_depth': 5, 'num_leaves': 6, 'lambda_l1': 0.004115241699798263, 'lambda_l2': 6.0767391636895605e-05, 'min_child_samples': 5, 'feature_fraction': 0.9268676303649308, 'bagging_fraction': 0.5147305541817601, 'bagging_freq': 5, 'min_split_gain': 0.48769995300836505}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:19:48,566] Trial 17 finished with value: 0.6903736580517089 and parameters: {'boosting_type': 'dart', 'n_estimators': 1439, 'learning_rate': 0.006831915920405381, 'max_depth': 6, 'num_leaves': 5, 'lambda_l1': 0.007852758111439513, 'lambda_l2': 3.4189421091108044e-06, 'min_child_samples': 5, 'feature_fraction': 0.898480674919529, 'bagging_fraction': 0.4036746407909374, 'bagging_freq': 6, 'min_split_gain': 0.5043022906173992}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:19:59,526] Trial 18 finished with value: 0.6945225508684095 and parameters: {'boosting_type': 'dart', 'n_estimators': 878, 'learning_rate': 0.01640367312478677, 'max_depth': 5, 'num_leaves': 158, 'lambda_l1': 0.01310993250830019, 'lambda_l2': 0.0001367566571531651, 'min_child_samples': 12, 'feature_fraction': 0.8903425921153444, 'bagging_fraction': 0.5251083289381603, 'bagging_freq': 5, 'min_split_gain': 0.7061702571432977}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:20:09,750] Trial 19 finished with value: 0.6824253411363671 and parameters: {'boosting_type': 'dart', 'n_estimators': 910, 'learning_rate': 0.00502076532979543, 'max_depth': 7, 'num_leaves': 105, 'lambda_l1': 0.0015356997296342005, 'lambda_l2': 6.027503860276173e-07, 'min_child_samples': 31, 'feature_fraction': 0.8645745152369794, 'bagging_fraction': 0.662400533653487, 'bagging_freq': 7, 'min_split_gain': 0.9992494696523401}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:20:15,016] Trial 20 finished with value: 0.6633753762372906 and parameters: {'boosting_type': 'dart', 'n_estimators': 576, 'learning_rate': 0.008166474566714366, 'max_depth': 3, 'num_leaves': 169, 'lambda_l1': 3.73221736941298e-06, 'lambda_l2': 5.6434687004440656e-05, 'min_child_samples': 60, 'feature_fraction': 0.991376241514206, 'bagging_fraction': 0.45953187326161354, 'bagging_freq': 6, 'min_split_gain': 0.49229819499674093}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:20:22,245] Trial 21 finished with value: 0.6746660829590018 and parameters: {'boosting_type': 'dart', 'n_estimators': 743, 'learning_rate': 0.02639474050577755, 'max_depth': 4, 'num_leaves': 6, 'lambda_l1': 0.0025386723829845014, 'lambda_l2': 0.00016557824681254883, 'min_child_samples': 8, 'feature_fraction': 0.937165908887401, 'bagging_fraction': 0.5310065811739998, 'bagging_freq': 5, 'min_split_gain': 0.49247207947033567}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:20:35,445] Trial 22 finished with value: 0.6821195821162248 and parameters: {'boosting_type': 'dart', 'n_estimators': 956, 'learning_rate': 0.01456077203916246, 'max_depth': 5, 'num_leaves': 24, 'lambda_l1': 0.000526209257605053, 'lambda_l2': 0.016499840953915875, 'min_child_samples': 14, 'feature_fraction': 0.937460136670649, 'bagging_fraction': 0.5182800129097023, 'bagging_freq': 5, 'min_split_gain': 0.21954876337478457}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:20:43,545] Trial 23 finished with value: 0.6967473698411876 and parameters: {'boosting_type': 'dart', 'n_estimators': 753, 'learning_rate': 0.020461519852105117, 'max_depth': 3, 'num_leaves': 82, 'lambda_l1': 0.034719656743974245, 'lambda_l2': 0.0014114747424646423, 'min_child_samples': 6, 'feature_fraction': 0.9310060782087868, 'bagging_fraction': 0.5606946456331644, 'bagging_freq': 6, 'min_split_gain': 0.4426823759092839}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:20:53,367] Trial 24 finished with value: 0.6878189992779115 and parameters: {'boosting_type': 'dart', 'n_estimators': 1046, 'learning_rate': 0.028516156081954874, 'max_depth': 3, 'num_leaves': 80, 'lambda_l1': 0.03659066140021365, 'lambda_l2': 0.0007637063040114205, 'min_child_samples': 26, 'feature_fraction': 0.8040931071897288, 'bagging_fraction': 0.5727619405345724, 'bagging_freq': 6, 'min_split_gain': 0.5990830701653371}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:21:01,396] Trial 25 finished with value: 0.6899029266452222 and parameters: {'boosting_type': 'dart', 'n_estimators': 791, 'learning_rate': 0.003810313768522921, 'max_depth': 3, 'num_leaves': 121, 'lambda_l1': 1.3862040805356977, 'lambda_l2': 1.2376596456115982e-05, 'min_child_samples': 15, 'feature_fraction': 0.8617340964119228, 'bagging_fraction': 0.6482703629726968, 'bagging_freq': 7, 'min_split_gain': 0.7198607657535476}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:21:10,736] Trial 26 finished with value: 0.6904017340254304 and parameters: {'boosting_type': 'dart', 'n_estimators': 572, 'learning_rate': 0.010208331986020868, 'max_depth': 6, 'num_leaves': 62, 'lambda_l1': 0.046656345768260374, 'lambda_l2': 0.02098944231102678, 'min_child_samples': 5, 'feature_fraction': 0.6686631731183524, 'bagging_fraction': 0.7265182878601772, 'bagging_freq': 4, 'min_split_gain': 0.12779934130382703}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:21:13,083] Trial 27 finished with value: 0.6884232387706287 and parameters: {'boosting_type': 'dart', 'n_estimators': 351, 'learning_rate': 0.019986195417765557, 'max_depth': 3, 'num_leaves': 222, 'lambda_l1': 0.012475345086995358, 'lambda_l2': 0.000579857018247386, 'min_child_samples': 43, 'feature_fraction': 0.9159593149482756, 'bagging_fraction': 0.4713191269890578, 'bagging_freq': 6, 'min_split_gain': 0.25837644417418015}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:21:24,918] Trial 28 finished with value: 0.6702557009567922 and parameters: {'boosting_type': 'dart', 'n_estimators': 837, 'learning_rate': 0.06492200445637133, 'max_depth': 5, 'num_leaves': 31, 'lambda_l1': 0.0004276403035446833, 'lambda_l2': 0.003936418558827841, 'min_child_samples': 30, 'feature_fraction': 0.967740456431309, 'bagging_fraction': 0.5511413436697641, 'bagging_freq': 5, 'min_split_gain': 0.0017293142504785641}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:21:31,211] Trial 29 finished with value: 0.6963502708653521 and parameters: {'boosting_type': 'dart', 'n_estimators': 607, 'learning_rate': 0.02723071315246007, 'max_depth': 4, 'num_leaves': 105, 'lambda_l1': 0.9558272782775723, 'lambda_l2': 0.0028524612575584777, 'min_child_samples': 19, 'feature_fraction': 0.8554835194078444, 'bagging_fraction': 0.6189517329765492, 'bagging_freq': 5, 'min_split_gain': 0.41797494076794195}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:21:43,209] Trial 30 finished with value: 0.671295041993313 and parameters: {'boosting_type': 'dart', 'n_estimators': 1081, 'learning_rate': 0.04206667602532038, 'max_depth': 4, 'num_leaves': 142, 'lambda_l1': 0.0821216001975184, 'lambda_l2': 0.00028243744765713745, 'min_child_samples': 12, 'feature_fraction': 0.7532445209800499, 'bagging_fraction': 0.6997392295248389, 'bagging_freq': 6, 'min_split_gain': 0.5458890734637534}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:21:50,684] Trial 31 finished with value: 0.6917633452578853 and parameters: {'boosting_type': 'dart', 'n_estimators': 701, 'learning_rate': 0.01957491805794029, 'max_depth': 4, 'num_leaves': 21, 'lambda_l1': 0.0029240962659037965, 'lambda_l2': 6.139442406209429e-05, 'min_child_samples': 5, 'feature_fraction': 0.9517545651328786, 'bagging_fraction': 0.4914048291252665, 'bagging_freq': 5, 'min_split_gain': 0.41246303106198867}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:21:58,254] Trial 32 finished with value: 0.7019868940550649 and parameters: {'boosting_type': 'dart', 'n_estimators': 743, 'learning_rate': 0.010947498750320044, 'max_depth': 3, 'num_leaves': 74, 'lambda_l1': 0.0013528599411006866, 'lambda_l2': 6.655520066348169e-06, 'min_child_samples': 12, 'feature_fraction': 0.9052748734657827, 'bagging_fraction': 0.4195262034157269, 'bagging_freq': 4, 'min_split_gain': 0.44846268758512786}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:22:03,365] Trial 33 finished with value: 0.7031795899410985 and parameters: {'boosting_type': 'dart', 'n_estimators': 770, 'learning_rate': 0.011145129774279547, 'max_depth': 2, 'num_leaves': 76, 'lambda_l1': 0.0007907674619254877, 'lambda_l2': 3.2029803954227938e-06, 'min_child_samples': 12, 'feature_fraction': 0.9047433532876794, 'bagging_fraction': 0.40816218349430405, 'bagging_freq': 4, 'min_split_gain': 0.26280810821097556}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:22:09,639] Trial 34 finished with value: 0.6909186318037664 and parameters: {'boosting_type': 'dart', 'n_estimators': 947, 'learning_rate': 0.009811083494110532, 'max_depth': 2, 'num_leaves': 63, 'lambda_l1': 5.044509157633396e-05, 'lambda_l2': 2.613785150761171e-07, 'min_child_samples': 18, 'feature_fraction': 0.7914290844253177, 'bagging_fraction': 0.4004990741761338, 'bagging_freq': 4, 'min_split_gain': 0.2771119345361935}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:22:12,505] Trial 35 finished with value: 0.6584414142381838 and parameters: {'boosting_type': 'dart', 'n_estimators': 500, 'learning_rate': 0.003018936535404378, 'max_depth': 2, 'num_leaves': 121, 'lambda_l1': 0.00011165910681327174, 'lambda_l2': 4.651995661978675e-06, 'min_child_samples': 25, 'feature_fraction': 0.6534174076113567, 'bagging_fraction': 0.4334498361303501, 'bagging_freq': 4, 'min_split_gain': 0.10756771433175252}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:22:17,471] Trial 36 finished with value: 0.6873422807972783 and parameters: {'boosting_type': 'dart', 'n_estimators': 996, 'learning_rate': 0.0062799480109522006, 'max_depth': 2, 'num_leaves': 44, 'lambda_l1': 0.0004679686127956126, 'lambda_l2': 1.814664015084676e-06, 'min_child_samples': 53, 'feature_fraction': 0.8905365006204657, 'bagging_fraction': 0.44452908776883787, 'bagging_freq': 4, 'min_split_gain': 0.35588081697807616}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:22:23,106] Trial 37 finished with value: 0.6729822715311183 and parameters: {'boosting_type': 'dart', 'n_estimators': 829, 'learning_rate': 0.013332568385396112, 'max_depth': 5, 'num_leaves': 95, 'lambda_l1': 0.0011184025591705546, 'lambda_l2': 1.194004104381922e-07, 'min_child_samples': 13, 'feature_fraction': 0.8423880615865613, 'bagging_fraction': 0.4155133330757824, 'bagging_freq': 4, 'min_split_gain': 0.29592828445501107}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:22:30,022] Trial 38 finished with value: 0.7029309090152114 and parameters: {'boosting_type': 'dart', 'n_estimators': 1142, 'learning_rate': 0.008766478802905287, 'max_depth': 3, 'num_leaves': 68, 'lambda_l1': 2.2361077439968688e-05, 'lambda_l2': 2.51720829822732e-05, 'min_child_samples': 21, 'feature_fraction': 0.8825743141645929, 'bagging_fraction': 0.4849248903104752, 'bagging_freq': 3, 'min_split_gain': 0.2089350634775667}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:22:38,611] Trial 39 finished with value: 0.6835358315102495 and parameters: {'boosting_type': 'dart', 'n_estimators': 1180, 'learning_rate': 0.0028426860354279237, 'max_depth': 12, 'num_leaves': 57, 'lambda_l1': 4.686092755873032e-06, 'lambda_l2': 2.08587603096261e-05, 'min_child_samples': 21, 'feature_fraction': 0.8862252835739403, 'bagging_fraction': 0.45285421195078923, 'bagging_freq': 2, 'min_split_gain': 0.20937941027209667}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:22:42,560] Trial 40 finished with value: 0.6574845459517413 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1329, 'learning_rate': 0.008066133019003599, 'max_depth': 11, 'num_leaves': 70, 'lambda_l1': 2.1247197517359698e-05, 'lambda_l2': 5.736395251461865e-06, 'min_child_samples': 26, 'feature_fraction': 0.7858357917280274, 'bagging_fraction': 0.7912515435716662, 'bagging_freq': 3, 'min_split_gain': 0.07921447397016573}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:22:47,591] Trial 41 finished with value: 0.7027423463751497 and parameters: {'boosting_type': 'dart', 'n_estimators': 883, 'learning_rate': 0.005345313560907967, 'max_depth': 3, 'num_leaves': 34, 'lambda_l1': 0.00016277917181969621, 'lambda_l2': 3.059120681895306e-05, 'min_child_samples': 12, 'feature_fraction': 0.9687359104685271, 'bagging_fraction': 0.4916340048439459, 'bagging_freq': 3, 'min_split_gain': 0.17119417996227762}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:22:50,408] Trial 42 finished with value: 0.6945303081165051 and parameters: {'boosting_type': 'dart', 'n_estimators': 660, 'learning_rate': 0.004154579430068394, 'max_depth': 2, 'num_leaves': 35, 'lambda_l1': 1.761998479504799e-05, 'lambda_l2': 2.445137951966224e-05, 'min_child_samples': 17, 'feature_fraction': 0.9833741218344236, 'bagging_fraction': 0.48629051671651935, 'bagging_freq': 3, 'min_split_gain': 0.1458695028348401}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:23:00,399] Trial 43 finished with value: 0.6814414434207473 and parameters: {'boosting_type': 'dart', 'n_estimators': 1144, 'learning_rate': 0.00562000876963897, 'max_depth': 8, 'num_leaves': 48, 'lambda_l1': 0.00017474087765731667, 'lambda_l2': 3.142986428095798e-06, 'min_child_samples': 11, 'feature_fraction': 0.824642554476677, 'bagging_fraction': 0.4551266135705116, 'bagging_freq': 4, 'min_split_gain': 0.04701440020711897}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:23:06,468] Trial 44 finished with value: 0.6984385091232351 and parameters: {'boosting_type': 'dart', 'n_estimators': 1022, 'learning_rate': 0.008232581773993589, 'max_depth': 3, 'num_leaves': 96, 'lambda_l1': 2.4537713249474757e-07, 'lambda_l2': 5.145142468495689e-07, 'min_child_samples': 22, 'feature_fraction': 0.9706616835281593, 'bagging_fraction': 0.4353727129736814, 'bagging_freq': 2, 'min_split_gain': 0.24754123401489808}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:23:13,284] Trial 45 finished with value: 0.7006671230028227 and parameters: {'boosting_type': 'dart', 'n_estimators': 1220, 'learning_rate': 0.009965852714653743, 'max_depth': 2, 'num_leaves': 75, 'lambda_l1': 0.00015237751189453634, 'lambda_l2': 1.0249894516644356e-06, 'min_child_samples': 11, 'feature_fraction': 0.9097622426754994, 'bagging_fraction': 0.488081805156209, 'bagging_freq': 3, 'min_split_gain': 0.1878522416929415}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:23:14,411] Trial 46 finished with value: 0.6966598880330966 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 767, 'learning_rate': 0.003981353222221281, 'max_depth': 3, 'num_leaves': 117, 'lambda_l1': 0.0007595591103157042, 'lambda_l2': 1.4514607400093818e-05, 'min_child_samples': 37, 'feature_fraction': 0.8742067869826502, 'bagging_fraction': 0.42139088297321775, 'bagging_freq': 3, 'min_split_gain': 0.30564630105249285}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:23:21,791] Trial 47 finished with value: 0.6884632516353211 and parameters: {'boosting_type': 'dart', 'n_estimators': 1359, 'learning_rate': 0.0023159414412103865, 'max_depth': 2, 'num_leaves': 52, 'lambda_l1': 4.9335732297294365e-05, 'lambda_l2': 7.053534553286967e-08, 'min_child_samples': 29, 'feature_fraction': 0.8387738952026809, 'bagging_fraction': 0.6155345975482314, 'bagging_freq': 4, 'min_split_gain': 0.21795506441572352}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:23:24,742] Trial 48 finished with value: 0.5650226483299688 and parameters: {'boosting_type': 'dart', 'n_estimators': 636, 'learning_rate': 0.0014924646064556676, 'max_depth': 3, 'num_leaves': 153, 'lambda_l1': 1.892317025041632e-05, 'lambda_l2': 5.274226050325451e-05, 'min_child_samples': 77, 'feature_fraction': 0.9619675284990883, 'bagging_fraction': 0.49469211652416534, 'bagging_freq': 2, 'min_split_gain': 0.35285861812930736}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:23:28,066] Trial 49 finished with value: 0.6677206374339287 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 851, 'learning_rate': 0.007086437634072657, 'max_depth': 9, 'num_leaves': 174, 'lambda_l1': 5.627349708460231e-07, 'lambda_l2': 0.00034906866370031553, 'min_child_samples': 10, 'feature_fraction': 0.5154354783644541, 'bagging_fraction': 0.5429891052129173, 'bagging_freq': 4, 'min_split_gain': 0.09504055624911834}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:23:31,406] Trial 50 finished with value: 0.6845427610085978 and parameters: {'boosting_type': 'dart', 'n_estimators': 522, 'learning_rate': 0.034351307409639396, 'max_depth': 4, 'num_leaves': 131, 'lambda_l1': 0.007287227139229089, 'lambda_l2': 7.735983517772078e-06, 'min_child_samples': 17, 'feature_fraction': 0.7360605749828543, 'bagging_fraction': 0.9243263375411845, 'bagging_freq': 3, 'min_split_gain': 0.1574733523292742}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:23:38,548] Trial 51 finished with value: 0.6990130906028823 and parameters: {'boosting_type': 'dart', 'n_estimators': 1294, 'learning_rate': 0.010547956910559734, 'max_depth': 2, 'num_leaves': 73, 'lambda_l1': 0.00018642252106611254, 'lambda_l2': 9.480212369778087e-07, 'min_child_samples': 9, 'feature_fraction': 0.9100173929832613, 'bagging_fraction': 0.4749772636029842, 'bagging_freq': 3, 'min_split_gain': 0.17968519164362565}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:23:45,382] Trial 52 finished with value: 0.7012124919010106 and parameters: {'boosting_type': 'dart', 'n_estimators': 1232, 'learning_rate': 0.012033948299360732, 'max_depth': 2, 'num_leaves': 72, 'lambda_l1': 9.559527472862698e-05, 'lambda_l2': 2.6513301585181994e-06, 'min_child_samples': 21, 'feature_fraction': 0.9994075992687245, 'bagging_fraction': 0.4952155051505957, 'bagging_freq': 3, 'min_split_gain': 0.041043966737231485}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:23:50,974] Trial 53 finished with value: 0.7005861878049694 and parameters: {'boosting_type': 'dart', 'n_estimators': 1083, 'learning_rate': 0.012231578684396071, 'max_depth': 2, 'num_leaves': 91, 'lambda_l1': 7.973537734977923e-05, 'lambda_l2': 3.61730494460087e-05, 'min_child_samples': 19, 'feature_fraction': 0.9972000415074607, 'bagging_fraction': 0.4226266970840108, 'bagging_freq': 1, 'min_split_gain': 0.03375348116557972}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:24:01,249] Trial 54 finished with value: 0.6926354360367388 and parameters: {'boosting_type': 'dart', 'n_estimators': 1473, 'learning_rate': 0.01587746017612703, 'max_depth': 3, 'num_leaves': 34, 'lambda_l1': 6.887981519505166e-06, 'lambda_l2': 2.192136571382797e-06, 'min_child_samples': 33, 'feature_fraction': 0.9559641919444507, 'bagging_fraction': 0.5065435719156002, 'bagging_freq': 3, 'min_split_gain': 0.052219509061811796}. Best is trial 14 with value: 0.7052963688782424.
# [I 2026-03-13 22:24:07,789] Trial 55 finished with value: 0.7100634228308178 and parameters: {'boosting_type': 'dart', 'n_estimators': 1208, 'learning_rate': 0.00508005641478468, 'max_depth': 2, 'num_leaves': 113, 'lambda_l1': 0.0011895011022332767, 'lambda_l2': 7.1453193135216275e-06, 'min_child_samples': 15, 'feature_fraction': 0.9287720186271724, 'bagging_fraction': 0.5867697628627251, 'bagging_freq': 2, 'min_split_gain': 0.24199441505153876}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:24:17,627] Trial 56 finished with value: 0.7021140289256831 and parameters: {'boosting_type': 'dart', 'n_estimators': 1395, 'learning_rate': 0.005017307056377261, 'max_depth': 3, 'num_leaves': 113, 'lambda_l1': 0.0015218298768391598, 'lambda_l2': 0.00010908571572271419, 'min_child_samples': 15, 'feature_fraction': 0.9210897153534686, 'bagging_fraction': 0.5905115795215815, 'bagging_freq': 1, 'min_split_gain': 0.31081727957695326}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:24:27,697] Trial 57 finished with value: 0.6949251831476827 and parameters: {'boosting_type': 'dart', 'n_estimators': 1402, 'learning_rate': 0.004604643217529804, 'max_depth': 4, 'num_leaves': 116, 'lambda_l1': 0.005885849252364408, 'lambda_l2': 0.00013445078250349225, 'min_child_samples': 15, 'feature_fraction': 0.9302772876733484, 'bagging_fraction': 0.5823076574895631, 'bagging_freq': 1, 'min_split_gain': 0.3177986759035663}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:24:29,456] Trial 58 finished with value: 0.6960801792288529 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1391, 'learning_rate': 0.003426932600435517, 'max_depth': 2, 'num_leaves': 106, 'lambda_l1': 0.013614920367600737, 'lambda_l2': 9.281978701957299e-05, 'min_child_samples': 8, 'feature_fraction': 0.872345571856248, 'bagging_fraction': 0.600969777295055, 'bagging_freq': 2, 'min_split_gain': 0.25797407363476416}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:24:37,525] Trial 59 finished with value: 0.6959640445455988 and parameters: {'boosting_type': 'dart', 'n_estimators': 1270, 'learning_rate': 0.005132465294844779, 'max_depth': 3, 'num_leaves': 143, 'lambda_l1': 0.0002731444089207704, 'lambda_l2': 0.0002715014501705916, 'min_child_samples': 25, 'feature_fraction': 0.9453129633556132, 'bagging_fraction': 0.6376909964920839, 'bagging_freq': 1, 'min_split_gain': 0.21100542912328613}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:24:48,932] Trial 60 finished with value: 0.6901386360654057 and parameters: {'boosting_type': 'dart', 'n_estimators': 1482, 'learning_rate': 0.006029611430563101, 'max_depth': 4, 'num_leaves': 170, 'lambda_l1': 0.0007605333800683588, 'lambda_l2': 0.0012469368515448094, 'min_child_samples': 15, 'feature_fraction': 0.845738389034734, 'bagging_fraction': 0.5421562823384755, 'bagging_freq': 2, 'min_split_gain': 0.13588019811805457}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:24:52,784] Trial 61 finished with value: 0.6985708853966441 and parameters: {'boosting_type': 'dart', 'n_estimators': 699, 'learning_rate': 0.007371308707887103, 'max_depth': 3, 'num_leaves': 131, 'lambda_l1': 0.0013006671580946796, 'lambda_l2': 9.825329642289366e-06, 'min_child_samples': 8, 'feature_fraction': 0.9071091513337773, 'bagging_fraction': 0.575476678658684, 'bagging_freq': 1, 'min_split_gain': 0.3499909575271526}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:24:54,580] Trial 62 finished with value: 0.6956829420397178 and parameters: {'boosting_type': 'dart', 'n_estimators': 413, 'learning_rate': 0.009089061210165717, 'max_depth': 3, 'num_leaves': 159, 'lambda_l1': 0.0018247783738409016, 'lambda_l2': 2.6555366838131885e-05, 'min_child_samples': 15, 'feature_fraction': 0.8889380955270799, 'bagging_fraction': 0.5250351946052156, 'bagging_freq': 2, 'min_split_gain': 0.384799702043252}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:24:59,406] Trial 63 finished with value: 0.6964969984302597 and parameters: {'boosting_type': 'dart', 'n_estimators': 932, 'learning_rate': 0.02225254063328628, 'max_depth': 2, 'num_leaves': 91, 'lambda_l1': 0.0003007810654026395, 'lambda_l2': 1.2767042266288717e-05, 'min_child_samples': 10, 'feature_fraction': 0.9208600512960218, 'bagging_fraction': 0.4448603223798755, 'bagging_freq': 1, 'min_split_gain': 0.2880942892157565}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:25:04,761] Trial 64 finished with value: 0.6947864280026484 and parameters: {'boosting_type': 'dart', 'n_estimators': 881, 'learning_rate': 0.0023067748533266434, 'max_depth': 3, 'num_leaves': 109, 'lambda_l1': 0.004279747773504897, 'lambda_l2': 3.701355618793081e-05, 'min_child_samples': 22, 'feature_fraction': 0.8758880118742822, 'bagging_fraction': 0.6887520371805189, 'bagging_freq': 4, 'min_split_gain': 0.23997042030891444}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:25:09,485] Trial 65 finished with value: 0.7043210056003972 and parameters: {'boosting_type': 'dart', 'n_estimators': 986, 'learning_rate': 0.006159978730905554, 'max_depth': 2, 'num_leaves': 84, 'lambda_l1': 1.1254708655535368e-08, 'lambda_l2': 9.467549436126893, 'min_child_samples': 14, 'feature_fraction': 0.9756598362906287, 'bagging_fraction': 0.4710417257364299, 'bagging_freq': 2, 'min_split_gain': 0.44833965067412895}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:25:14,524] Trial 66 finished with value: 0.7067568157101946 and parameters: {'boosting_type': 'dart', 'n_estimators': 995, 'learning_rate': 0.006122549690309099, 'max_depth': 2, 'num_leaves': 82, 'lambda_l1': 4.835790673835842e-08, 'lambda_l2': 0.19606525241607345, 'min_child_samples': 18, 'feature_fraction': 0.9751035597963602, 'bagging_fraction': 0.5637540623005904, 'bagging_freq': 2, 'min_split_gain': 0.17412513166002333}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:25:18,877] Trial 67 finished with value: 0.6655332713922771 and parameters: {'boosting_type': 'dart', 'n_estimators': 988, 'learning_rate': 0.006579379865788529, 'max_depth': 2, 'num_leaves': 99, 'lambda_l1': 2.1741238738393586e-08, 'lambda_l2': 1.698055101732324, 'min_child_samples': 92, 'feature_fraction': 0.9807662062748963, 'bagging_fraction': 0.46528235792727957, 'bagging_freq': 2, 'min_split_gain': 0.1776813560169394}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:25:24,543] Trial 68 finished with value: 0.7051187181800317 and parameters: {'boosting_type': 'dart', 'n_estimators': 1117, 'learning_rate': 0.008498415541825358, 'max_depth': 2, 'num_leaves': 87, 'lambda_l1': 1.1655108768455075e-07, 'lambda_l2': 4.789965104011214, 'min_child_samples': 49, 'feature_fraction': 0.9707294935107379, 'bagging_fraction': 0.5535898229266976, 'bagging_freq': 2, 'min_split_gain': 0.11421500223858659}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:25:29,989] Trial 69 finished with value: 0.6939455589086453 and parameters: {'boosting_type': 'dart', 'n_estimators': 1121, 'learning_rate': 0.01423957085434689, 'max_depth': 2, 'num_leaves': 87, 'lambda_l1': 1.2866715246020744e-07, 'lambda_l2': 6.102038370745362, 'min_child_samples': 58, 'feature_fraction': 0.9501095176337414, 'bagging_fraction': 0.5597934108868062, 'bagging_freq': 2, 'min_split_gain': 0.1141790737730437}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:25:31,473] Trial 70 finished with value: 0.6956312020035528 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1204, 'learning_rate': 0.008682205143344167, 'max_depth': 2, 'num_leaves': 81, 'lambda_l1': 1.0057764753233805e-08, 'lambda_l2': 0.2066044586511422, 'min_child_samples': 46, 'feature_fraction': 0.9789134372491923, 'bagging_fraction': 0.5358034957689907, 'bagging_freq': 2, 'min_split_gain': 0.0780847286120909}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:25:36,678] Trial 71 finished with value: 0.6669366279059008 and parameters: {'boosting_type': 'dart', 'n_estimators': 1082, 'learning_rate': 0.005873853267646552, 'max_depth': 2, 'num_leaves': 67, 'lambda_l1': 8.669748316134587e-08, 'lambda_l2': 3.4717828705174463, 'min_child_samples': 63, 'feature_fraction': 0.9648161787341296, 'bagging_fraction': 0.51108671027964, 'bagging_freq': 2, 'min_split_gain': 0.8154700254823599}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:25:41,708] Trial 72 finished with value: 0.6922342555385835 and parameters: {'boosting_type': 'dart', 'n_estimators': 1036, 'learning_rate': 0.00452514527331406, 'max_depth': 2, 'num_leaves': 59, 'lambda_l1': 6.06862869245842e-08, 'lambda_l2': 0.7551238395449087, 'min_child_samples': 28, 'feature_fraction': 0.9392605251498835, 'bagging_fraction': 0.5108667025204306, 'bagging_freq': 2, 'min_split_gain': 0.16124219472184714}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:25:46,511] Trial 73 finished with value: 0.7002404302403916 and parameters: {'boosting_type': 'dart', 'n_estimators': 964, 'learning_rate': 0.007235381185265646, 'max_depth': 2, 'num_leaves': 83, 'lambda_l1': 3.3751083563747654e-08, 'lambda_l2': 2.7991619120285676, 'min_child_samples': 18, 'feature_fraction': 0.9798726367702083, 'bagging_fraction': 0.556065696202964, 'bagging_freq': 2, 'min_split_gain': 0.19715823325059575}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:25:53,392] Trial 74 finished with value: 0.7053659493214175 and parameters: {'boosting_type': 'dart', 'n_estimators': 1168, 'learning_rate': 0.0172380770106184, 'max_depth': 3, 'num_leaves': 124, 'lambda_l1': 1.1230796052518821e-08, 'lambda_l2': 9.532849071860447, 'min_child_samples': 8, 'feature_fraction': 0.9357589143076228, 'bagging_fraction': 0.4787275466641035, 'bagging_freq': 3, 'min_split_gain': 0.23535717050557986}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:25:59,165] Trial 75 finished with value: 0.6840390046436564 and parameters: {'boosting_type': 'dart', 'n_estimators': 1172, 'learning_rate': 0.018241530771610275, 'max_depth': 2, 'num_leaves': 123, 'lambda_l1': 2.344321828048768e-08, 'lambda_l2': 0.8539144783894052, 'min_child_samples': 73, 'feature_fraction': 0.9305018477303518, 'bagging_fraction': 0.46900725431884127, 'bagging_freq': 2, 'min_split_gain': 0.23063197324726176}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:26:06,958] Trial 76 finished with value: 0.697509537916544 and parameters: {'boosting_type': 'dart', 'n_estimators': 1099, 'learning_rate': 0.02386605725657901, 'max_depth': 7, 'num_leaves': 136, 'lambda_l1': 1.098451108580723e-08, 'lambda_l2': 8.908224478516056, 'min_child_samples': 7, 'feature_fraction': 0.951123427063576, 'bagging_fraction': 0.61584198395633, 'bagging_freq': 3, 'min_split_gain': 0.12535327423833875}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:26:13,897] Trial 77 finished with value: 0.6897623230884032 and parameters: {'boosting_type': 'dart', 'n_estimators': 1138, 'learning_rate': 0.016802700950786002, 'max_depth': 3, 'num_leaves': 100, 'lambda_l1': 1.7166450684687156e-08, 'lambda_l2': 0.03183399089868044, 'min_child_samples': 41, 'feature_fraction': 0.8090697935603872, 'bagging_fraction': 0.5179244970118214, 'bagging_freq': 3, 'min_split_gain': 0.2805055912631319}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:26:17,598] Trial 78 finished with value: 0.6976861321553839 and parameters: {'boosting_type': 'dart', 'n_estimators': 787, 'learning_rate': 0.011502475301508554, 'max_depth': 2, 'num_leaves': 89, 'lambda_l1': 5.059803156905312e-08, 'lambda_l2': 4.611186174929607, 'min_child_samples': 51, 'feature_fraction': 0.8952893063566235, 'bagging_fraction': 0.5640082990112332, 'bagging_freq': 2, 'min_split_gain': 0.5257083928345163}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:26:25,582] Trial 79 finished with value: 0.686057681761136 and parameters: {'boosting_type': 'dart', 'n_estimators': 1191, 'learning_rate': 0.033253465803781995, 'max_depth': 4, 'num_leaves': 151, 'lambda_l1': 2.7632501896573225e-07, 'lambda_l2': 1.9110413839160931, 'min_child_samples': 5, 'feature_fraction': 0.6513644275523028, 'bagging_fraction': 0.5311258411594881, 'bagging_freq': 5, 'min_split_gain': 0.6350444922358667}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:26:31,362] Trial 80 finished with value: 0.6955303129067869 and parameters: {'boosting_type': 'dart', 'n_estimators': 1054, 'learning_rate': 0.013352987380669848, 'max_depth': 3, 'num_leaves': 78, 'lambda_l1': 1.1079489721686288e-06, 'lambda_l2': 9.878397337648082, 'min_child_samples': 24, 'feature_fraction': 0.857589931777985, 'bagging_fraction': 0.401570347398002, 'bagging_freq': 2, 'min_split_gain': 0.006037652070738628}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:26:36,265] Trial 81 finished with value: 0.7006477977405522 and parameters: {'boosting_type': 'dart', 'n_estimators': 871, 'learning_rate': 0.009320668143834443, 'max_depth': 3, 'num_leaves': 44, 'lambda_l1': 2.8561896076432063e-07, 'lambda_l2': 0.47756358077967737, 'min_child_samples': 11, 'feature_fraction': 0.9647750105593723, 'bagging_fraction': 0.5045832845758289, 'bagging_freq': 3, 'min_split_gain': 0.2583400454593008}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:26:40,877] Trial 82 finished with value: 0.6975019599194257 and parameters: {'boosting_type': 'dart', 'n_estimators': 925, 'learning_rate': 0.003399233313091775, 'max_depth': 2, 'num_leaves': 16, 'lambda_l1': 1.1472557845165386e-07, 'lambda_l2': 0.2957062965192565, 'min_child_samples': 13, 'feature_fraction': 0.9382470813620036, 'bagging_fraction': 0.474132991410924, 'bagging_freq': 3, 'min_split_gain': 0.15923316432948056}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:26:47,338] Trial 83 finished with value: 0.6922972549571723 and parameters: {'boosting_type': 'dart', 'n_estimators': 1013, 'learning_rate': 0.00548264296073839, 'max_depth': 3, 'num_leaves': 53, 'lambda_l1': 4.341598387688811e-08, 'lambda_l2': 0.06642854609489293, 'min_child_samples': 19, 'feature_fraction': 0.9834635644177552, 'bagging_fraction': 0.4873939061990444, 'bagging_freq': 3, 'min_split_gain': 0.0871096341132633}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:26:52,000] Trial 84 finished with value: 0.6938309746057262 and parameters: {'boosting_type': 'dart', 'n_estimators': 975, 'learning_rate': 0.007671903551209284, 'max_depth': 2, 'num_leaves': 125, 'lambda_l1': 1.5232356096894674e-06, 'lambda_l2': 0.09019400863008126, 'min_child_samples': 84, 'feature_fraction': 0.9676868749661098, 'bagging_fraction': 0.45695963562734254, 'bagging_freq': 2, 'min_split_gain': 0.19391427336381714}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:26:56,634] Trial 85 finished with value: 0.7087794786805014 and parameters: {'boosting_type': 'dart', 'n_estimators': 816, 'learning_rate': 0.006421337537472829, 'max_depth': 3, 'num_leaves': 112, 'lambda_l1': 1.73808729845572e-08, 'lambda_l2': 2.2483461555088278, 'min_child_samples': 7, 'feature_fraction': 0.9189266006498992, 'bagging_fraction': 0.43752611016844667, 'bagging_freq': 4, 'min_split_gain': 0.461773556605394}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:27:03,675] Trial 86 finished with value: 0.7004695779034087 and parameters: {'boosting_type': 'dart', 'n_estimators': 1276, 'learning_rate': 0.015230024617989927, 'max_depth': 2, 'num_leaves': 65, 'lambda_l1': 1.4700718211874366e-08, 'lambda_l2': 1.1476476904345982, 'min_child_samples': 8, 'feature_fraction': 0.9014455499649506, 'bagging_fraction': 0.7753750090464656, 'bagging_freq': 4, 'min_split_gain': 0.46556225944273855}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:27:11,859] Trial 87 finished with value: 0.684905685697697 and parameters: {'boosting_type': 'dart', 'n_estimators': 1241, 'learning_rate': 0.006534549340543522, 'max_depth': 8, 'num_leaves': 104, 'lambda_l1': 2.6216644980563478e-08, 'lambda_l2': 2.031508843356658, 'min_child_samples': 17, 'feature_fraction': 0.8800274471297268, 'bagging_fraction': 0.43624219042322143, 'bagging_freq': 5, 'min_split_gain': 0.5562107906562497}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:27:13,181] Trial 88 finished with value: 0.698002659474894 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 812, 'learning_rate': 0.0044013333114935735, 'max_depth': 3, 'num_leaves': 111, 'lambda_l1': 5.84262993217618e-08, 'lambda_l2': 4.59506163561475, 'min_child_samples': 7, 'feature_fraction': 0.9110487888362457, 'bagging_fraction': 0.411220375619857, 'bagging_freq': 4, 'min_split_gain': 0.39718492250503395}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:27:17,462] Trial 89 finished with value: 0.648362110608455 and parameters: {'boosting_type': 'dart', 'n_estimators': 733, 'learning_rate': 0.008175574042185219, 'max_depth': 11, 'num_leaves': 135, 'lambda_l1': 1.881287091318419e-07, 'lambda_l2': 5.111073395224369, 'min_child_samples': 13, 'feature_fraction': 0.40060625026733254, 'bagging_fraction': 0.428190253454674, 'bagging_freq': 4, 'min_split_gain': 0.33716123439140117}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:27:25,387] Trial 90 finished with value: 0.706971016679531 and parameters: {'boosting_type': 'dart', 'n_estimators': 1160, 'learning_rate': 0.010103795119866487, 'max_depth': 4, 'num_leaves': 98, 'lambda_l1': 5.262464083666659e-07, 'lambda_l2': 1.085583846801217, 'min_child_samples': 9, 'feature_fraction': 0.9232830371459289, 'bagging_fraction': 0.4476408331779426, 'bagging_freq': 7, 'min_split_gain': 0.23518941356947937}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:27:31,418] Trial 91 finished with value: 0.6969366121906756 and parameters: {'boosting_type': 'dart', 'n_estimators': 1149, 'learning_rate': 0.009973026157682585, 'max_depth': 2, 'num_leaves': 94, 'lambda_l1': 5.944906583751106e-07, 'lambda_l2': 1.3149460213913322, 'min_child_samples': 10, 'feature_fraction': 0.92371842604965, 'bagging_fraction': 0.4399823220390699, 'bagging_freq': 7, 'min_split_gain': 0.26933457467068245}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:27:39,439] Trial 92 finished with value: 0.6960954027153129 and parameters: {'boosting_type': 'dart', 'n_estimators': 1063, 'learning_rate': 0.008809915492844645, 'max_depth': 4, 'num_leaves': 86, 'lambda_l1': 4.980461818859944e-07, 'lambda_l2': 0.3638122300482631, 'min_child_samples': 6, 'feature_fraction': 0.9477783394746169, 'bagging_fraction': 0.44719027369485714, 'bagging_freq': 7, 'min_split_gain': 0.22248329089906513}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:27:46,119] Trial 93 finished with value: 0.6929047997328506 and parameters: {'boosting_type': 'dart', 'n_estimators': 1125, 'learning_rate': 0.011697063185232576, 'max_depth': 3, 'num_leaves': 101, 'lambda_l1': 9.453845287431332e-08, 'lambda_l2': 2.7074888695578636, 'min_child_samples': 14, 'feature_fraction': 0.9205596444140405, 'bagging_fraction': 0.4635976070383022, 'bagging_freq': 6, 'min_split_gain': 0.46560508330201855}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:27:53,440] Trial 94 finished with value: 0.6953753314300689 and parameters: {'boosting_type': 'dart', 'n_estimators': 1177, 'learning_rate': 0.01909171758774104, 'max_depth': 4, 'num_leaves': 115, 'lambda_l1': 3.80519504044153e-08, 'lambda_l2': 6.895497267033787, 'min_child_samples': 9, 'feature_fraction': 0.9980653046543273, 'bagging_fraction': 0.4765388272215356, 'bagging_freq': 4, 'min_split_gain': 0.24040622021142555}. Best is trial 55 with value: 0.7100634228308178.
# [I 2026-03-13 22:27:56,405] Trial 95 finished with value: 0.6949326906982196 and parameters: {'boosting_type': 'dart', 'n_estimators': 633, 'learning_rate': 0.006625391351469796, 'max_depth': 2, 'num_leaves': 79, 'lambda_l1': 1.5781068331835066e-08, 'lambda_l2': 1.0058790164697262, 'min_child_samples': 20, 'feature_fraction': 0.8967290405059913, 'bagging_fraction': 0.5473377037206505, 'bagging_freq': 6, 'min_split_gain': 0.37343458715518807}. Best is trial 55 with value: 0.7100634228308178.
# ...
# [I 2026-03-13 22:30:13,341] Trial 119 finished with value: 0.7043429881659007 and parameters: {'boosting_type': 'dart', 'n_estimators': 780, 'learning_rate': 0.008296739786454387, 'max_depth': 3, 'num_leaves': 24, 'lambda_l1': 1.174501253983485e-05, 'lambda_l2': 3.6964379204798415e-05, 'min_child_samples': 5, 'feature_fraction': 0.9424472914133039, 'bagging_fraction': 0.41888386400201894, 'bagging_freq': 4, 'min_split_gain': 0.17905009168144445}. Best is trial 118 with value: 0.7114078180979981.
# [I 2026-03-13 22:30:16,810] Trial 120 finished with value: 0.7100968608900903 and parameters: {'boosting_type': 'dart', 'n_estimators': 718, 'learning_rate': 0.010779110503979254, 'max_depth': 2, 'num_leaves': 167, 'lambda_l1': 4.2677245194766066e-05, 'lambda_l2': 4.6560345716257986e-07, 'min_child_samples': 5, 'feature_fraction': 0.9452216936105167, 'bagging_fraction': 0.4180586208977445, 'bagging_freq': 4, 'min_split_gain': 0.2847538862595874}. Best is trial 118 with value: 0.7114078180979981.
# [I 2026-03-13 22:30:20,041] Trial 121 finished with value: 0.7069917484329923 and parameters: {'boosting_type': 'dart', 'n_estimators': 701, 'learning_rate': 0.010772310513179286, 'max_depth': 2, 'num_leaves': 167, 'lambda_l1': 3.28492943696202e-05, 'lambda_l2': 3.484309979236741e-07, 'min_child_samples': 8, 'feature_fraction': 0.9466506134450018, 'bagging_fraction': 0.41607930148621874, 'bagging_freq': 4, 'min_split_gain': 0.2905650162975335}. Best is trial 118 with value: 0.7114078180979981.
# [I 2026-03-13 22:30:23,150] Trial 122 finished with value: 0.7205841702583258 and parameters: {'boosting_type': 'dart', 'n_estimators': 668, 'learning_rate': 0.01083850353987417, 'max_depth': 2, 'num_leaves': 178, 'lambda_l1': 3.372305056686988e-05, 'lambda_l2': 4.2942919060017713e-07, 'min_child_samples': 5, 'feature_fraction': 0.9430936965239558, 'bagging_fraction': 0.4176576885960583, 'bagging_freq': 4, 'min_split_gain': 0.29553509679095}. Best is trial 122 with value: 0.7205841702583258.
# [I 2026-03-13 22:30:26,640] Trial 123 finished with value: 0.7113036615072171 and parameters: {'boosting_type': 'dart', 'n_estimators': 713, 'learning_rate': 0.010607690311455942, 'max_depth': 2, 'num_leaves': 186, 'lambda_l1': 1.3617228251496942e-05, 'lambda_l2': 2.897806266420332e-07, 'min_child_samples': 5, 'feature_fraction': 0.9458047193265954, 'bagging_fraction': 0.41622311174618304, 'bagging_freq': 4, 'min_split_gain': 0.28536867533834787}. Best is trial 122 with value: 0.7205841702583258.
# [I 2026-03-13 22:30:29,920] Trial 124 finished with value: 0.7098741065644161 and parameters: {'boosting_type': 'dart', 'n_estimators': 710, 'learning_rate': 0.010237091525735735, 'max_depth': 2, 'num_leaves': 184, 'lambda_l1': 1.1568759781775718e-05, 'lambda_l2': 3.20948596975494e-07, 'min_child_samples': 5, 'feature_fraction': 0.9451660757003362, 'bagging_fraction': 0.4182209043199908, 'bagging_freq': 4, 'min_split_gain': 0.28053332123765196}. Best is trial 122 with value: 0.7205841702583258.
# [I 2026-03-13 22:30:32,954] Trial 125 finished with value: 0.710811016637441 and parameters: {'boosting_type': 'dart', 'n_estimators': 661, 'learning_rate': 0.014756945364920247, 'max_depth': 2, 'num_leaves': 194, 'lambda_l1': 1.2756589954096732e-05, 'lambda_l2': 3.492654816017395e-07, 'min_child_samples': 7, 'feature_fraction': 0.956632852484569, 'bagging_fraction': 0.40293383198768773, 'bagging_freq': 4, 'min_split_gain': 0.2874237657416618}. Best is trial 122 with value: 0.7205841702583258.
# [I 2026-03-13 22:30:35,927] Trial 126 finished with value: 0.7089927713199247 and parameters: {'boosting_type': 'dart', 'n_estimators': 657, 'learning_rate': 0.015256170965286206, 'max_depth': 2, 'num_leaves': 198, 'lambda_l1': 2.8298028790586603e-05, 'lambda_l2': 2.5213424552283624e-07, 'min_child_samples': 7, 'feature_fraction': 0.9564792241796316, 'bagging_fraction': 0.4030477995234694, 'bagging_freq': 4, 'min_split_gain': 0.28804600210187314}. Best is trial 122 with value: 0.7205841702583258.
# [I 2026-03-13 22:30:38,196] Trial 127 finished with value: 0.7031369201593108 and parameters: {'boosting_type': 'dart', 'n_estimators': 545, 'learning_rate': 0.015044350539783508, 'max_depth': 2, 'num_leaves': 198, 'lambda_l1': 3.0907044413007574e-05, 'lambda_l2': 3.3580063604077215e-07, 'min_child_samples': 7, 'feature_fraction': 0.962134093174029, 'bagging_fraction': 0.4060952752434205, 'bagging_freq': 4, 'min_split_gain': 0.2781744183942534}. Best is trial 122 with value: 0.7205841702583258.
# [I 2026-03-13 22:30:39,131] Trial 128 finished with value: 0.6859155940708149 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 661, 'learning_rate': 0.010939994738447074, 'max_depth': 2, 'num_leaves': 189, 'lambda_l1': 6.699481370667795e-06, 'lambda_l2': 9.209860040525916e-08, 'min_child_samples': 5, 'feature_fraction': 0.9506920745564242, 'bagging_fraction': 0.41482508504206705, 'bagging_freq': 4, 'min_split_gain': 0.34277253822154574}. Best is trial 122 with value: 0.7205841702583258.
# [I 2026-03-13 22:30:42,070] Trial 129 finished with value: 0.709740300194603 and parameters: {'boosting_type': 'dart', 'n_estimators': 626, 'learning_rate': 0.012328034843956419, 'max_depth': 2, 'num_leaves': 204, 'lambda_l1': 4.164415805600316e-05, 'lambda_l2': 4.919804999618537e-08, 'min_child_samples': 9, 'feature_fraction': 0.9345826654466617, 'bagging_fraction': 0.4249714685782471, 'bagging_freq': 4, 'min_split_gain': 0.3692073559152708}. Best is trial 122 with value: 0.7205841702583258.
# [I 2026-03-13 22:30:44,954] Trial 130 finished with value: 0.7107295319963735 and parameters: {'boosting_type': 'dart', 'n_estimators': 631, 'learning_rate': 0.012368072810108635, 'max_depth': 2, 'num_leaves': 208, 'lambda_l1': 1.8138415969016246e-05, 'lambda_l2': 2.5812524751273978e-08, 'min_child_samples': 9, 'feature_fraction': 0.9255832175666947, 'bagging_fraction': 0.4001748045491645, 'bagging_freq': 4, 'min_split_gain': 0.29375027647030383}. Best is trial 122 with value: 0.7205841702583258.
# [I 2026-03-13 22:30:47,792] Trial 131 finished with value: 0.7047012426104075 and parameters: {'boosting_type': 'dart', 'n_estimators': 613, 'learning_rate': 0.013548772816073189, 'max_depth': 2, 'num_leaves': 206, 'lambda_l1': 4.450216031954657e-05, 'lambda_l2': 3.419965608495895e-08, 'min_child_samples': 9, 'feature_fraction': 0.9279819313506396, 'bagging_fraction': 0.4007638611948069, 'bagging_freq': 4, 'min_split_gain': 0.32217888234616804}. Best is trial 122 with value: 0.7205841702583258.
# [I 2026-03-13 22:30:50,996] Trial 132 finished with value: 0.70585396668974 and parameters: {'boosting_type': 'dart', 'n_estimators': 703, 'learning_rate': 0.012376282843057284, 'max_depth': 2, 'num_leaves': 178, 'lambda_l1': 3.6680213234129126e-05, 'lambda_l2': 4.0999951680582626e-08, 'min_child_samples': 7, 'feature_fraction': 0.9568851768991449, 'bagging_fraction': 0.4243123453404342, 'bagging_freq': 4, 'min_split_gain': 0.3712621219658267}. Best is trial 122 with value: 0.7205841702583258.
# [I 2026-03-13 22:30:53,770] Trial 133 finished with value: 0.7165097458279067 and parameters: {'boosting_type': 'dart', 'n_estimators': 611, 'learning_rate': 0.010053333174761779, 'max_depth': 2, 'num_leaves': 205, 'lambda_l1': 1.5691650870537895e-05, 'lambda_l2': 2.1987836529181802e-07, 'min_child_samples': 5, 'feature_fraction': 0.9425429503968308, 'bagging_fraction': 0.4306324047127343, 'bagging_freq': 4, 'min_split_gain': 0.2952093022946304}. Best is trial 122 with value: 0.7205841702583258.
# [I 2026-03-13 22:30:56,714] Trial 134 finished with value: 0.7098916033621482 and parameters: {'boosting_type': 'dart', 'n_estimators': 612, 'learning_rate': 0.01067113929179815, 'max_depth': 2, 'num_leaves': 206, 'lambda_l1': 1.2579628591495332e-05, 'lambda_l2': 1.966632888193665e-07, 'min_child_samples': 5, 'feature_fraction': 0.9161123752941832, 'bagging_fraction': 0.433780946559407, 'bagging_freq': 4, 'min_split_gain': 0.29867705691923596}. Best is trial 122 with value: 0.7205841702583258.
# [I 2026-03-13 22:30:59,342] Trial 135 finished with value: 0.7128315823882362 and parameters: {'boosting_type': 'dart', 'n_estimators': 602, 'learning_rate': 0.011536520432079833, 'max_depth': 2, 'num_leaves': 205, 'lambda_l1': 1.56979316687784e-05, 'lambda_l2': 1.7507876657126414e-07, 'min_child_samples': 5, 'feature_fraction': 0.9365501384412158, 'bagging_fraction': 0.4328139319093116, 'bagging_freq': 4, 'min_split_gain': 0.2900960222910833}. Best is trial 122 with value: 0.7205841702583258.
# [I 2026-03-13 22:31:01,753] Trial 136 finished with value: 0.7103095422238018 and parameters: {'boosting_type': 'dart', 'n_estimators': 553, 'learning_rate': 0.01196616329827952, 'max_depth': 2, 'num_leaves': 208, 'lambda_l1': 1.4625100299198585e-05, 'lambda_l2': 1.8026925551923737e-07, 'min_child_samples': 5, 'feature_fraction': 0.9129242346849679, 'bagging_fraction': 0.43175676688000864, 'bagging_freq': 4, 'min_split_gain': 0.30651939378280796}. Best is trial 122 with value: 0.7205841702583258.
# [I 2026-03-13 22:31:04,149] Trial 137 finished with value: 0.70544885567108 and parameters: {'boosting_type': 'dart', 'n_estimators': 548, 'learning_rate': 0.014725474148560309, 'max_depth': 2, 'num_leaves': 209, 'lambda_l1': 1.3648741169541934e-05, 'lambda_l2': 1.602065010483403e-07, 'min_child_samples': 5, 'feature_fraction': 0.9380016802124129, 'bagging_fraction': 0.42854890284720915, 'bagging_freq': 4, 'min_split_gain': 0.36015617275990625}. Best is trial 122 with value: 0.7205841702583258.
# [I 2026-03-13 22:31:06,052] Trial 138 finished with value: 0.7045285976726477 and parameters: {'boosting_type': 'dart', 'n_estimators': 472, 'learning_rate': 0.011962205561349713, 'max_depth': 2, 'num_leaves': 235, 'lambda_l1': 4.622345616460041e-06, 'lambda_l2': 1.1048767690080978e-08, 'min_child_samples': 5, 'feature_fraction': 0.9089178676799873, 'bagging_fraction': 0.4007290231710882, 'bagging_freq': 4, 'min_split_gain': 0.2991878229927561}. Best is trial 122 with value: 0.7205841702583258.
# [I 2026-03-13 22:31:08,774] Trial 139 finished with value: 0.7078802012234239 and parameters: {'boosting_type': 'dart', 'n_estimators': 601, 'learning_rate': 0.012243693135406295, 'max_depth': 2, 'num_leaves': 194, 'lambda_l1': 1.5133725559106894e-05, 'lambda_l2': 1.6825303310592942e-07, 'min_child_samples': 10, 'feature_fraction': 0.9526092247806537, 'bagging_fraction': 0.4312597943399931, 'bagging_freq': 4, 'min_split_gain': 0.32415148476530303}. Best is trial 122 with value: 0.7205841702583258.
# [I 2026-03-13 22:31:11,554] Trial 140 finished with value: 0.7067552634517805 and parameters: {'boosting_type': 'dart', 'n_estimators': 613, 'learning_rate': 0.016088615224268278, 'max_depth': 2, 'num_leaves': 203, 'lambda_l1': 7.014322443815583e-06, 'lambda_l2': 7.708862363130147e-07, 'min_child_samples': 6, 'feature_fraction': 0.9292652621719094, 'bagging_fraction': 0.42098069205325006, 'bagging_freq': 4, 'min_split_gain': 0.2862000039320102}. Best is trial 122 with value: 0.7205841702583258.
# [I 2026-03-13 22:31:14,612] Trial 141 finished with value: 0.7080888488160016 and parameters: {'boosting_type': 'dart', 'n_estimators': 649, 'learning_rate': 0.00946252527993727, 'max_depth': 2, 'num_leaves': 214, 'lambda_l1': 2.1359993072921994e-05, 'lambda_l2': 6.496319621706426e-08, 'min_child_samples': 7, 'feature_fraction': 0.9135650679547727, 'bagging_fraction': 0.4373547064220006, 'bagging_freq': 4, 'min_split_gain': 0.3987319950575078}. Best is trial 122 with value: 0.7205841702583258.
# [I 2026-03-13 22:31:17,199] Trial 142 finished with value: 0.711754811666971 and parameters: {'boosting_type': 'dart', 'n_estimators': 563, 'learning_rate': 0.013763387539443235, 'max_depth': 2, 'num_leaves': 190, 'lambda_l1': 2.831557492258148e-06, 'lambda_l2': 2.3380971672172975e-07, 'min_child_samples': 5, 'feature_fraction': 0.8906928223770006, 'bagging_fraction': 0.4121751856154841, 'bagging_freq': 4, 'min_split_gain': 0.3095261368579543}. Best is trial 122 with value: 0.7205841702583258.
# [I 2026-03-13 22:31:19,650] Trial 143 finished with value: 0.7056998430162548 and parameters: {'boosting_type': 'dart', 'n_estimators': 560, 'learning_rate': 0.013543981229439294, 'max_depth': 2, 'num_leaves': 191, 'lambda_l1': 2.537067803921195e-06, 'lambda_l2': 2.1493234255827931e-07, 'min_child_samples': 5, 'feature_fraction': 0.8887252878141458, 'bagging_fraction': 0.4002470838662988, 'bagging_freq': 4, 'min_split_gain': 0.3109029086204963}. Best is trial 122 with value: 0.7205841702583258.
# [I 2026-03-13 22:31:21,780] Trial 144 finished with value: 0.700689455892189 and parameters: {'boosting_type': 'dart', 'n_estimators': 516, 'learning_rate': 0.020723597550651902, 'max_depth': 2, 'num_leaves': 184, 'lambda_l1': 9.955615086192427e-06, 'lambda_l2': 5.22903135140787e-07, 'min_child_samples': 10, 'feature_fraction': 0.9415943367227023, 'bagging_fraction': 0.41464364669831255, 'bagging_freq': 4, 'min_split_gain': 0.3395794841979385}. Best is trial 122 with value: 0.7205841702583258.
# [I 2026-03-13 22:31:24,889] Trial 145 finished with value: 0.6915093235702915 and parameters: {'boosting_type': 'dart', 'n_estimators': 677, 'learning_rate': 0.01829347067635746, 'max_depth': 2, 'num_leaves': 199, 'lambda_l1': 5.291832515560248e-05, 'lambda_l2': 1.1575522819047648e-07, 'min_child_samples': 7, 'feature_fraction': 0.8973401603902125, 'bagging_fraction': 0.4271064628912611, 'bagging_freq': 4, 'min_split_gain': 0.2754664891321252}. Best is trial 122 with value: 0.7205841702583258.
# [I 2026-03-13 22:31:27,891] Trial 146 finished with value: 0.7033309288216958 and parameters: {'boosting_type': 'dart', 'n_estimators': 631, 'learning_rate': 0.01113834355233818, 'max_depth': 2, 'num_leaves': 225, 'lambda_l1': 3.1154291406951486e-06, 'lambda_l2': 3.2252971906376067e-07, 'min_child_samples': 11, 'feature_fraction': 0.9316002235734103, 'bagging_fraction': 0.45336248541700264, 'bagging_freq': 4, 'min_split_gain': 0.3153062395463966}. Best is trial 122 with value: 0.7205841702583258.
# [I 2026-03-13 22:31:30,870] Trial 147 finished with value: 0.7032288315670239 and parameters: {'boosting_type': 'dart', 'n_estimators': 419, 'learning_rate': 0.014909844251718691, 'max_depth': 9, 'num_leaves': 180, 'lambda_l1': 2.0102193282437227e-05, 'lambda_l2': 5.9106102971721835e-08, 'min_child_samples': 5, 'feature_fraction': 0.960979906058942, 'bagging_fraction': 0.41214736793114126, 'bagging_freq': 4, 'min_split_gain': 0.29358788688457993}. Best is trial 122 with value: 0.7205841702583258.
# [I 2026-03-13 22:31:34,358] Trial 148 finished with value: 0.7019775906655018 and parameters: {'boosting_type': 'dart', 'n_estimators': 732, 'learning_rate': 0.012855041928492447, 'max_depth': 2, 'num_leaves': 211, 'lambda_l1': 0.00012158733629335591, 'lambda_l2': 1.698244465594732e-08, 'min_child_samples': 9, 'feature_fraction': 0.9111567093669038, 'bagging_fraction': 0.44167493604748004, 'bagging_freq': 5, 'min_split_gain': 0.2671734239892312}. Best is trial 122 with value: 0.7205841702583258.
# [I 2026-03-13 22:31:36,900] Trial 149 finished with value: 0.72001190908105 and parameters: {'boosting_type': 'dart', 'n_estimators': 569, 'learning_rate': 0.009782234115407067, 'max_depth': 2, 'num_leaves': 202, 'lambda_l1': 5.061041954597016e-06, 'lambda_l2': 5.907012987399927e-07, 'min_child_samples': 7, 'feature_fraction': 0.9715411798034682, 'bagging_fraction': 0.423925040241146, 'bagging_freq': 4, 'min_split_gain': 0.35769140169300206}. Best is trial 122 with value: 0.7205841702583258.
# Best Score: 0.7205841702583258

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import lightgbm as lgb

# Train model với tham số tốt nhất

best_clf = lgb.LGBMClassifier(
        **study.best_params
)
best_clf.fit(X_train_r, y_train_r)
pred_r = best_clf.predict(X_test_r).ravel()

print("=== Baseline Classification on Random Split ===")
eval_classification(y_test_r, pred_r, name="RandomSplit")

print("\nClassification report (RandomSplit):")
print(classification_report(y_test_r, pred_r, digits=4))

cm_r = confusion_matrix(y_test_r, pred_r, labels=sorted(y_train_r.unique()))
cm_r_df = pd.DataFrame(cm_r, index=sorted(y_train_r.unique()), columns=sorted(y_train_r.unique()))
cm_r_df.to_csv("optuna_baseline_cm_random_ctgan.csv", encoding="utf-8-sig")
print("Saved: optuna_baseline_cm_random_ctgan.csv")

save_preds_csv(X_test_r, y_test_r.values, pred_r, "optuna_baseline_preds_random_cls_ctgan.csv")

# Vẽ Confusion Matrix
plt.figure(figsize=(10,8))
sns.heatmap(confusion_matrix(y_test_r, pred_r), annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.9430936965239558, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9430936965239558
# [LightGBM] [Warning] lambda_l1 is set=3.372305056686988e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=3.372305056686988e-05
# [LightGBM] [Warning] lambda_l2 is set=4.2942919060017713e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.2942919060017713e-07
# [LightGBM] [Warning] bagging_fraction is set=0.4176576885960583, subsample=1.0 will be ignored. Current value: bagging_fraction=0.4176576885960583
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] feature_fraction is set=0.9430936965239558, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9430936965239558
# [LightGBM] [Warning] lambda_l1 is set=3.372305056686988e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=3.372305056686988e-05
# [LightGBM] [Warning] lambda_l2 is set=4.2942919060017713e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.2942919060017713e-07
# [LightGBM] [Warning] bagging_fraction is set=0.4176576885960583, subsample=1.0 will be ignored. Current value: bagging_fraction=0.4176576885960583
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000095 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1055
# [LightGBM] [Info] Number of data points in the train set: 1502, number of used features: 7
# [LightGBM] [Info] Start training from score -3.124898
# [LightGBM] [Info] Start training from score -2.803693
# [LightGBM] [Info] Start training from score -3.037887
# [LightGBM] [Info] Start training from score -2.760676
# [LightGBM] [Info] Start training from score -2.803693
# [LightGBM] [Info] Start training from score -2.957844
# [LightGBM] [Info] Start training from score -2.760676
# [LightGBM] [Info] Start training from score -1.683341
# [LightGBM] [Info] Start training from score -3.080446
# [LightGBM] [Info] Start training from score -2.094197
# [LightGBM] [Info] Start training from score -1.371753
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] feature_fraction is set=0.9430936965239558, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9430936965239558
# [LightGBM] [Warning] lambda_l1 is set=3.372305056686988e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=3.372305056686988e-05
# [LightGBM] [Warning] lambda_l2 is set=4.2942919060017713e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.2942919060017713e-07
# [LightGBM] [Warning] bagging_fraction is set=0.4176576885960583, subsample=1.0 will be ignored. Current value: bagging_fraction=0.4176576885960583
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# === Baseline Classification on Random Split ===
# RandomSplit Accuracy: 0.7808 | F1-macro: 0.7342 | F1-weighted: 0.7741
#
# Classification report (RandomSplit):
#               precision    recall  f1-score   support
#
#            A     1.0000    0.7500    0.8571         4
#            B     1.0000    0.8667    0.9286        15
#            C     0.6667    1.0000    0.8000         2
#            D     0.6429    1.0000    0.7826         9
#            E     1.0000    0.6154    0.7619        13
#            F     0.0000    0.0000    0.0000         0
#            G     1.0000    1.0000    1.0000         9
#            H     0.6410    0.7576    0.6944        33
#            I     0.7500    1.0000    0.8571         3
#            J     0.7500    0.3913    0.5143        23
#            K     0.8250    0.9429    0.8800        35
#
#     accuracy                         0.7808       146
#    macro avg     0.7523    0.7567    0.7342       146
# weighted avg     0.8058    0.7808    0.7741       146
#
# Saved: optuna_baseline_cm_random_ctgan.csv
# Saved: optuna_baseline_preds_random_cls_ctgan.csv
