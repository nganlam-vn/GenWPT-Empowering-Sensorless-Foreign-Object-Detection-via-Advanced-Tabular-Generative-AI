# %% [markdown]
# ## Baseline Model

# %%
import warnings

from lightgbm import LGBMClassifier
import pandas as pd
import numpy as np

warnings.filterwarnings("ignore")

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix
from sklearn.ensemble import HistGradientBoostingClassifier, RandomForestClassifier

def eval_classification(y_true, y_pred, name=""):
    acc = accuracy_score(y_true, y_pred)
    f1_macro = f1_score(y_true, y_pred, average="macro")
    f1_weighted = f1_score(y_true, y_pred, average="weighted")
    print(f"{name} Accuracy: {acc:.4f} | F1-macro: {f1_macro:.4f} | F1-weighted: {f1_weighted:.4f}")
    return acc, f1_macro, f1_weighted

def save_preds_csv(X_test, y_true, y_pred, filename):
    out = X_test.copy()
    out["y_true"] = y_true
    out["y_pred"] = y_pred
    out.to_csv(filename, index=False, encoding="utf-8-sig")
    print(f"Saved: {filename}")

def derive_groups_from_train(train_df, k_baseline_dict, min_group_size=2):
    df_temp = train_df.copy()
    df_temp["k_eff_expected"] = df_temp["load"].map(k_baseline_dict)
    if df_temp["k_eff_expected"].isnull().any():
        known_loads = np.array(list(k_baseline_dict.keys()))
        for idx, row in df_temp[df_temp["k_eff_expected"].isnull()].iterrows():
            closest_load = known_loads[np.abs(known_loads - row["load"]).argmin()]
            df_temp.loc[idx, "k_eff_expected"] = k_baseline_dict[closest_load]     
    df_temp["abs_diff"] = (df_temp["efficiency"] - df_temp["k_eff_expected"]).abs()
    type_stats = (
        df_temp.groupby("type")["abs_diff"]
        .agg(n="count", mean="mean")
        .sort_values("mean")
        .reset_index()
    )
    types = type_stats["type"].tolist()
    x = type_stats["mean"].to_numpy()
    n = len(x)
    # Prefix sums for O(1) segment SSE
    S1 = np.concatenate([[0.0], np.cumsum(x)])
    S2 = np.concatenate([[0.0], np.cumsum(x * x)])
    def seg_sse(i, j):
        m = j - i + 1
        sum1 = S1[j + 1] - S1[i]
        sum2 = S2[j + 1] - S2[i]
        mu = sum1 / m
        return sum2 - 2 * mu * sum1 + m * mu * mu

    K = 3
    INF = 1e18
    dp = np.full((K + 1, n + 1), INF)
    cut = np.full((K + 1, n + 1), -1, dtype=int)

    dp[0, 0] = 0.0
    for k in range(1, K + 1):
        for t in range(1, n + 1):
            p_min = (k - 1) * min_group_size
            p_max = t - min_group_size
            if p_max < p_min:
                continue
            best_cost, best_p = INF, -1
            for p in range(p_min, p_max + 1):
                cost = dp[k - 1, p] + seg_sse(p, t - 1)
                if cost < best_cost:
                    best_cost, best_p = cost, p
            dp[k, t] = best_cost
            cut[k, t] = best_p

    if np.isinf(dp[K, n]):
        raise RuntimeError("No valid split found. Try min_group_size=1 or check types count.")
    bounds = []
    t = n
    for k in range(K, 0, -1):
        p = cut[k, t]
        bounds.append((p, t))
        t = p
    bounds.reverse()
    group_names = ["near", "mid", "far"] 
    groups = {}
    for name, (a, b) in zip(group_names, bounds):
        groups[name] = types[a:b]

    type_to_group = {t: g for g, ts in groups.items() for t in ts}
    return type_to_group, groups, type_stats


# ----- Load split files -----
train_random = pd.read_csv('../../../random-split/wpt_train_random.csv')
test_random  = pd.read_csv('../../../random-split/wpt_test_random.csv')

# Sanity check expected columns
expected_cols = {"type", "load", "efficiency"}
for name, d in [("train_random", train_random), ("test_random", test_random)]:
    missing = expected_cols - set(d.columns)
    if missing:
        raise ValueError(f"{name} is missing columns: {missing}")

# Make sure numeric columns are numeric
for d in [train_random, test_random]:
    d["load"] = pd.to_numeric(d["load"], errors="coerce")
    d["efficiency"] = pd.to_numeric(d["efficiency"], errors="coerce")
    d["type"] = d["type"].astype(str)
    d.dropna(subset=["type", "load", "efficiency"], inplace=True)

# Features / target
FEATURES = ["load", "efficiency"]
TARGET = "type"

# =========================
def add_advanced_features(df, k_baseline_dict, type_to_group_dict):
    df = df.copy()
    df["k_eff_expected"] = df["load"].map(k_baseline_dict)
    if df["k_eff_expected"].isnull().any():
        known_loads = np.array(list(k_baseline_dict.keys()))
        for idx, row in df[df["k_eff_expected"].isnull()].iterrows():
            closest_load = known_loads[np.abs(known_loads - row["load"]).argmin()]
            df.loc[idx, "k_eff_expected"] = k_baseline_dict[closest_load]  
    # 2. Difference and Ratio
    df["eff_diff"] = df["efficiency"] - df["k_eff_expected"]
    df["eff_ratio"] = df["efficiency"] / df["k_eff_expected"]
    # 3. Power Loss Proxy
    # P_loss = Load * (1 / (Efficiency / 100) - 1)
    df["p_loss"] = df["load"] * (1 / (df["efficiency"] / 100.0) - 1)
    # Power Loss of Class K
    df["k_p_loss"] = df["load"] * (1 / (df["k_eff_expected"] / 100.0) - 1)
    # Difference in Power Loss due to Foreign Objects
    df["p_loss_diff"] = df["p_loss"] - df["k_p_loss"]

    df["dist_zone_name"] = df["type"].map(type_to_group_dict).fillna("far")
    # Encode distance zones: near=1, mid=2, far=3
    zone_mapping = {"near": 1, "mid": 2, "far": 3}
    df["dist_zone"] = df["dist_zone_name"].map(zone_mapping)
    # 4. Load Zone
    # Assume load bins from 0.5 to 3.0, divided into 3 zones: Light (1), Medium (2), Heavy (3)
    df['load_zone'] = pd.cut(df['load'], bins=3, labels=[1, 2, 3]).astype(float)
    return df

k_baseline_train_r = train_random[train_random["type"] == "K"].groupby("load")["efficiency"].mean().to_dict()
type_to_group, groups_dict, stats = derive_groups_from_train(train_random, k_baseline_train_r)
print("Results of grouping the Types:", groups_dict)

train_random_fe = add_advanced_features(train_random, k_baseline_train_r, type_to_group)
test_random_fe = add_advanced_features(test_random, k_baseline_train_r, type_to_group)

FEATURES_NEW = [
    "load", "efficiency", 
    "eff_diff", "eff_ratio", 
    "p_loss_diff", "load_zone", "dist_zone"
]
# =========================
X_train_r = train_random_fe[FEATURES_NEW]
y_train_r = train_random_fe[TARGET]
X_test_r  = test_random_fe[FEATURES_NEW]
y_test_r  = test_random_fe[TARGET]
# Out:
# Results of grouping the Types: {'near': ['K', 'H', 'J', 'I', 'G'], 'mid': ['F', 'E', 'D', 'B'], 'far': ['C', 'A']}

# %% [markdown]
# ## Optuna

# %%
import optuna
import lightgbm as lgb
import json
from sklearn.model_selection import StratifiedKFold, cross_val_score

def objective(trial):

    param = {
        'objective': 'multiclass',
        'num_class': 11,
        'metric': 'multi_logloss',
        'verbosity': -1,
        'random_state': 42,
        'class_weight': 'balanced',
        
        # Try 2 types of Boosting
        'boosting_type': trial.suggest_categorical('boosting_type', ['gbdt', 'dart']),
        
        'n_estimators': trial.suggest_int('n_estimators', 100, 1500), 
        'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 2, 12), 
        'num_leaves': trial.suggest_int('num_leaves', 4, 256),
        
        'lambda_l1': trial.suggest_float('lambda_l1', 1e-8, 10.0, log=True),
        'lambda_l2': trial.suggest_float('lambda_l2', 1e-8, 10.0, log=True),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.4, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.4, 1.0),
        'bagging_freq': trial.suggest_int('bagging_freq', 1, 7),
        'min_split_gain': trial.suggest_float('min_split_gain', 0, 1.0),
    }

    clf = lgb.LGBMClassifier(**param)
    
    # 3-fold Stratified CV
    cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
    
    scores = cross_val_score(clf, X_train_r, y_train_r, cv=cv, scoring='f1_macro', n_jobs=-1)
    
    return scores.mean()

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=150, show_progress_bar=True)

# --- SAVE BEST PARAMETERS ---
best_params = study.best_params
best_params.update({
    'objective': 'multiclass',
    'num_class': 11,
    'metric': 'multi_logloss',
    'verbosity': -1,
    'random_state': 42
})

with open("best_lgbm_params.json", "w") as f:
    json.dump(best_params, f, indent=4)

print(f"Best Score: {study.best_value}")
# Out:
# [I 2026-03-13 22:05:53,937] A new study created in memory with name: no-name-efdf1f80-d41d-4870-b583-ef0d4d728ec2
#   0%|          | 0/150 [00:00<?, ?it/s]
# [I 2026-03-13 22:05:59,112] Trial 0 finished with value: 0.742857732982099 and parameters: {'boosting_type': 'dart', 'n_estimators': 179, 'learning_rate': 0.01882590207002207, 'max_depth': 7, 'num_leaves': 243, 'lambda_l1': 0.00020073956446572854, 'lambda_l2': 2.8006673053637186e-08, 'min_child_samples': 69, 'feature_fraction': 0.4307105560609952, 'bagging_fraction': 0.6266137931382356, 'bagging_freq': 3, 'min_split_gain': 0.58315626086729}. Best is trial 0 with value: 0.742857732982099.
# [I 2026-03-13 22:06:04,175] Trial 1 finished with value: 0.7409641268512385 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1164, 'learning_rate': 0.025339633605532267, 'max_depth': 9, 'num_leaves': 26, 'lambda_l1': 5.395297895851772, 'lambda_l2': 0.06238991770586791, 'min_child_samples': 71, 'feature_fraction': 0.8839704290087081, 'bagging_fraction': 0.9191458109855556, 'bagging_freq': 5, 'min_split_gain': 0.726763638518848}. Best is trial 0 with value: 0.742857732982099.
# [I 2026-03-13 22:06:23,605] Trial 2 finished with value: 0.74254421065037 and parameters: {'boosting_type': 'dart', 'n_estimators': 1409, 'learning_rate': 0.0031933228329815554, 'max_depth': 6, 'num_leaves': 83, 'lambda_l1': 1.2254645939373687e-07, 'lambda_l2': 3.946002084877955e-05, 'min_child_samples': 52, 'feature_fraction': 0.9757901699103771, 'bagging_fraction': 0.6667781077106298, 'bagging_freq': 1, 'min_split_gain': 0.565141540952047}. Best is trial 0 with value: 0.742857732982099.
# [I 2026-03-13 22:06:27,720] Trial 3 finished with value: 0.7718365793539469 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 656, 'learning_rate': 0.11209292618484511, 'max_depth': 4, 'num_leaves': 248, 'lambda_l1': 4.802876967965437e-06, 'lambda_l2': 1.432222035893601e-06, 'min_child_samples': 65, 'feature_fraction': 0.7426553673525854, 'bagging_fraction': 0.884366806021085, 'bagging_freq': 7, 'min_split_gain': 0.9200550344219963}. Best is trial 3 with value: 0.7718365793539469.
# [I 2026-03-13 22:06:35,093] Trial 4 finished with value: 0.7538714900774887 and parameters: {'boosting_type': 'dart', 'n_estimators': 806, 'learning_rate': 0.01853705867922542, 'max_depth': 2, 'num_leaves': 99, 'lambda_l1': 0.0003018430200112154, 'lambda_l2': 1.0067277666638288e-08, 'min_child_samples': 37, 'feature_fraction': 0.48845099790267615, 'bagging_fraction': 0.4876216499144819, 'bagging_freq': 3, 'min_split_gain': 0.06182748049722653}. Best is trial 3 with value: 0.7718365793539469.
# [I 2026-03-13 22:06:37,466] Trial 5 finished with value: 0.7557206688576472 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 381, 'learning_rate': 0.0015714675193569355, 'max_depth': 7, 'num_leaves': 65, 'lambda_l1': 1.1020868213972334e-08, 'lambda_l2': 0.0522444684925194, 'min_child_samples': 17, 'feature_fraction': 0.5369183988100298, 'bagging_fraction': 0.9840673554539836, 'bagging_freq': 6, 'min_split_gain': 0.8071531543030955}. Best is trial 3 with value: 0.7718365793539469.
# [I 2026-03-13 22:06:38,080] Trial 6 finished with value: 0.7284566638381257 and parameters: {'boosting_type': 'dart', 'n_estimators': 143, 'learning_rate': 0.001028068868255833, 'max_depth': 11, 'num_leaves': 215, 'lambda_l1': 2.386764389585485, 'lambda_l2': 7.144572318202711e-07, 'min_child_samples': 36, 'feature_fraction': 0.7518364359265193, 'bagging_fraction': 0.7491459398925231, 'bagging_freq': 7, 'min_split_gain': 0.596904594234844}. Best is trial 3 with value: 0.7718365793539469.
# [I 2026-03-13 22:06:40,088] Trial 7 finished with value: 0.7556137251392668 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 716, 'learning_rate': 0.028064363110541064, 'max_depth': 8, 'num_leaves': 111, 'lambda_l1': 7.024985116160539e-08, 'lambda_l2': 0.0028456671187382532, 'min_child_samples': 98, 'feature_fraction': 0.6351048685457003, 'bagging_fraction': 0.923489632895717, 'bagging_freq': 1, 'min_split_gain': 0.3687923566663047}. Best is trial 3 with value: 0.7718365793539469.
# [I 2026-03-13 22:06:43,722] Trial 8 finished with value: 0.7137389788960061 and parameters: {'boosting_type': 'dart', 'n_estimators': 480, 'learning_rate': 0.004503948597645637, 'max_depth': 4, 'num_leaves': 75, 'lambda_l1': 5.494984023589904e-08, 'lambda_l2': 0.006655360803369847, 'min_child_samples': 70, 'feature_fraction': 0.6072987822868251, 'bagging_fraction': 0.5102508679339893, 'bagging_freq': 7, 'min_split_gain': 0.16468636975459272}. Best is trial 3 with value: 0.7718365793539469.
# [I 2026-03-13 22:06:46,538] Trial 9 finished with value: 0.7466784741022662 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 957, 'learning_rate': 0.04154338762782891, 'max_depth': 5, 'num_leaves': 166, 'lambda_l1': 0.4267428976581541, 'lambda_l2': 0.02699347007314917, 'min_child_samples': 13, 'feature_fraction': 0.9372913039911402, 'bagging_fraction': 0.5770229622465368, 'bagging_freq': 6, 'min_split_gain': 0.08124623831499911}. Best is trial 3 with value: 0.7718365793539469.
# [I 2026-03-13 22:06:47,230] Trial 10 finished with value: 0.7541925961176174 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 590, 'learning_rate': 0.17575978707926995, 'max_depth': 2, 'num_leaves': 170, 'lambda_l1': 6.366604242246507e-06, 'lambda_l2': 7.661937722885897, 'min_child_samples': 95, 'feature_fraction': 0.7683911452132669, 'bagging_fraction': 0.7982429386122198, 'bagging_freq': 4, 'min_split_gain': 0.956156142545098}. Best is trial 3 with value: 0.7718365793539469.
# [I 2026-03-13 22:06:47,522] Trial 11 finished with value: 0.7454825686309792 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 407, 'learning_rate': 0.18811599667507126, 'max_depth': 4, 'num_leaves': 6, 'lambda_l1': 2.8217986508515483e-06, 'lambda_l2': 2.2464732496481114e-05, 'min_child_samples': 10, 'feature_fraction': 0.5523646041829192, 'bagging_fraction': 0.9826728783672276, 'bagging_freq': 6, 'min_split_gain': 0.9960096096119774}. Best is trial 3 with value: 0.7718365793539469.
# [I 2026-03-13 22:06:47,973] Trial 12 finished with value: 0.768329559158439 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 377, 'learning_rate': 0.06171591276209457, 'max_depth': 10, 'num_leaves': 48, 'lambda_l1': 6.956938916775547e-06, 'lambda_l2': 0.8794819393352351, 'min_child_samples': 28, 'feature_fraction': 0.8202403703147704, 'bagging_fraction': 0.8281355331896405, 'bagging_freq': 6, 'min_split_gain': 0.8027122398118978}. Best is trial 3 with value: 0.7718365793539469.
# [I 2026-03-13 22:06:48,700] Trial 13 finished with value: 0.7516437850975025 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 942, 'learning_rate': 0.07210898541958642, 'max_depth': 12, 'num_leaves': 149, 'lambda_l1': 0.006797323422689217, 'lambda_l2': 2.629751246688376, 'min_child_samples': 34, 'feature_fraction': 0.8135414449227233, 'bagging_fraction': 0.8063347321366092, 'bagging_freq': 7, 'min_split_gain': 0.7928105600028956}. Best is trial 3 with value: 0.7718365793539469.
# [I 2026-03-13 22:06:49,121] Trial 14 finished with value: 0.7669516209357514 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 309, 'learning_rate': 0.08484203097176352, 'max_depth': 10, 'num_leaves': 210, 'lambda_l1': 7.553300710465748e-06, 'lambda_l2': 8.932352246536982e-07, 'min_child_samples': 53, 'feature_fraction': 0.7023208452509491, 'bagging_fraction': 0.8591021974225458, 'bagging_freq': 5, 'min_split_gain': 0.875349982410248}. Best is trial 3 with value: 0.7718365793539469.
# [I 2026-03-13 22:06:49,892] Trial 15 finished with value: 0.7440581948204322 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 579, 'learning_rate': 0.07422168504501135, 'max_depth': 9, 'num_leaves': 41, 'lambda_l1': 2.665100298747067e-05, 'lambda_l2': 0.0002473843985663698, 'min_child_samples': 54, 'feature_fraction': 0.863177558681387, 'bagging_fraction': 0.7318719987491189, 'bagging_freq': 5, 'min_split_gain': 0.34152295463899285}. Best is trial 3 with value: 0.7718365793539469.
# [I 2026-03-13 22:06:51,750] Trial 16 finished with value: 0.7621580419948217 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 703, 'learning_rate': 0.008950686586035912, 'max_depth': 12, 'num_leaves': 130, 'lambda_l1': 0.010249448206819152, 'lambda_l2': 1.7670185597518373e-06, 'min_child_samples': 25, 'feature_fraction': 0.6881887639583594, 'bagging_fraction': 0.8683646338520913, 'bagging_freq': 6, 'min_split_gain': 0.7167291692815124}. Best is trial 3 with value: 0.7718365793539469.
# [I 2026-03-13 22:06:52,585] Trial 17 finished with value: 0.7502632870992002 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 964, 'learning_rate': 0.1009651198198012, 'max_depth': 4, 'num_leaves': 252, 'lambda_l1': 9.298450545756596e-07, 'lambda_l2': 0.49683303523733, 'min_child_samples': 88, 'feature_fraction': 0.7983605130712582, 'bagging_fraction': 0.7997364099796495, 'bagging_freq': 7, 'min_split_gain': 0.8974880155838326}. Best is trial 3 with value: 0.7718365793539469.
# [I 2026-03-13 22:06:53,263] Trial 18 finished with value: 0.7589493506485582 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 267, 'learning_rate': 0.043496826346094995, 'max_depth': 10, 'num_leaves': 204, 'lambda_l1': 0.005383426952134534, 'lambda_l2': 0.0005821967953663296, 'min_child_samples': 83, 'feature_fraction': 0.8610621395886123, 'bagging_fraction': 0.4134025325506811, 'bagging_freq': 4, 'min_split_gain': 0.42089338804879733}. Best is trial 3 with value: 0.7718365793539469.
# [I 2026-03-13 22:06:55,464] Trial 19 finished with value: 0.7600160970643354 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1208, 'learning_rate': 0.010082898400114958, 'max_depth': 6, 'num_leaves': 49, 'lambda_l1': 6.959601435001434e-05, 'lambda_l2': 1.1757200956677162e-07, 'min_child_samples': 46, 'feature_fraction': 0.7073811370894917, 'bagging_fraction': 0.8786803102426715, 'bagging_freq': 3, 'min_split_gain': 0.7090779099596214}. Best is trial 3 with value: 0.7718365793539469.
# [I 2026-03-13 22:06:55,907] Trial 20 finished with value: 0.7550239271570959 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 535, 'learning_rate': 0.11734333070226736, 'max_depth': 3, 'num_leaves': 185, 'lambda_l1': 6.263051232118589e-07, 'lambda_l2': 1.8142191426679585e-05, 'min_child_samples': 5, 'feature_fraction': 0.9225602884710609, 'bagging_fraction': 0.7537954852696187, 'bagging_freq': 5, 'min_split_gain': 0.8740207083461934}. Best is trial 3 with value: 0.7718365793539469.
# [I 2026-03-13 22:06:56,430] Trial 21 finished with value: 0.7629862470197439 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 306, 'learning_rate': 0.055047944167016936, 'max_depth': 10, 'num_leaves': 224, 'lambda_l1': 1.257202196390443e-05, 'lambda_l2': 9.433633665249924e-07, 'min_child_samples': 60, 'feature_fraction': 0.7023532303376845, 'bagging_fraction': 0.8609503438447088, 'bagging_freq': 5, 'min_split_gain': 0.8438437593973657}. Best is trial 3 with value: 0.7718365793539469.
# [I 2026-03-13 22:06:56,725] Trial 22 finished with value: 0.7640199298306954 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 277, 'learning_rate': 0.10638630501156404, 'max_depth': 10, 'num_leaves': 235, 'lambda_l1': 1.1329748941392105e-06, 'lambda_l2': 2.8745775056095265e-07, 'min_child_samples': 61, 'feature_fraction': 0.6551006202347933, 'bagging_fraction': 0.8361404967981497, 'bagging_freq': 6, 'min_split_gain': 0.9956250812489906}. Best is trial 3 with value: 0.7718365793539469.
# [I 2026-03-13 22:06:56,935] Trial 23 finished with value: 0.7537161916095384 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 101, 'learning_rate': 0.13385792084221623, 'max_depth': 8, 'num_leaves': 197, 'lambda_l1': 4.223336713798132e-05, 'lambda_l2': 2.940852960072484e-06, 'min_child_samples': 46, 'feature_fraction': 0.7446678671223933, 'bagging_fraction': 0.9122278253168947, 'bagging_freq': 4, 'min_split_gain': 0.6493525792055886}. Best is trial 3 with value: 0.7718365793539469.
# [I 2026-03-13 22:06:57,413] Trial 24 finished with value: 0.7648092278058113 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 416, 'learning_rate': 0.06451439443463475, 'max_depth': 11, 'num_leaves': 136, 'lambda_l1': 0.0014537611763577392, 'lambda_l2': 8.34119236375184e-06, 'min_child_samples': 24, 'feature_fraction': 0.8218490080814708, 'bagging_fraction': 0.6882798292839978, 'bagging_freq': 7, 'min_split_gain': 0.9158355063684723}. Best is trial 3 with value: 0.7718365793539469.
# [I 2026-03-13 22:06:58,572] Trial 25 finished with value: 0.7517908700753955 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 688, 'learning_rate': 0.02944687586193738, 'max_depth': 9, 'num_leaves': 256, 'lambda_l1': 3.1266116985792764e-07, 'lambda_l2': 0.0001958080884068125, 'min_child_samples': 79, 'feature_fraction': 0.5968706437187795, 'bagging_fraction': 0.9381172646874253, 'bagging_freq': 5, 'min_split_gain': 0.7927347647069898}. Best is trial 3 with value: 0.7718365793539469.
# [I 2026-03-13 22:07:06,842] Trial 26 finished with value: 0.7651818936459532 and parameters: {'boosting_type': 'dart', 'n_estimators': 807, 'learning_rate': 0.04209429758931729, 'max_depth': 8, 'num_leaves': 226, 'lambda_l1': 1.098843730362276e-05, 'lambda_l2': 1.9172480219187769e-07, 'min_child_samples': 44, 'feature_fraction': 0.7200286130605428, 'bagging_fraction': 0.8066593699132205, 'bagging_freq': 6, 'min_split_gain': 0.48936300420665907}. Best is trial 3 with value: 0.7718365793539469.
# [I 2026-03-13 22:07:07,284] Trial 27 finished with value: 0.7751492586811666 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 487, 'learning_rate': 0.08108031406772348, 'max_depth': 11, 'num_leaves': 185, 'lambda_l1': 0.0011800748986650785, 'lambda_l2': 0.3468613499862302, 'min_child_samples': 64, 'feature_fraction': 0.7931444415451181, 'bagging_fraction': 0.8466531625350017, 'bagging_freq': 6, 'min_split_gain': 0.9100333119776071}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:07,721] Trial 28 finished with value: 0.7679505185372059 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 620, 'learning_rate': 0.19993943707008785, 'max_depth': 11, 'num_leaves': 185, 'lambda_l1': 0.11279961326985519, 'lambda_l2': 0.4595546079145645, 'min_child_samples': 65, 'feature_fraction': 0.7869332654653705, 'bagging_fraction': 0.7470122179753619, 'bagging_freq': 7, 'min_split_gain': 0.754264985285418}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:11,664] Trial 29 finished with value: 0.7483209364498938 and parameters: {'boosting_type': 'dart', 'n_estimators': 487, 'learning_rate': 0.013958177149776546, 'max_depth': 6, 'num_leaves': 113, 'lambda_l1': 0.0008660645789876836, 'lambda_l2': 0.2772603283968962, 'min_child_samples': 77, 'feature_fraction': 0.8447880847645679, 'bagging_fraction': 0.6325569345082361, 'bagging_freq': 3, 'min_split_gain': 0.6537301928696588}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:11,929] Trial 30 finished with value: 0.7630030390542585 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 211, 'learning_rate': 0.13813617131297262, 'max_depth': 7, 'num_leaves': 156, 'lambda_l1': 0.00012048559432351068, 'lambda_l2': 2.900412180479807, 'min_child_samples': 73, 'feature_fraction': 0.43254926666382865, 'bagging_fraction': 0.9484624383007926, 'bagging_freq': 2, 'min_split_gain': 0.9179765028858259}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:12,430] Trial 31 finished with value: 0.7716759464676665 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 686, 'learning_rate': 0.19387768830944196, 'max_depth': 11, 'num_leaves': 181, 'lambda_l1': 0.0746653777907662, 'lambda_l2': 0.29892569508951955, 'min_child_samples': 63, 'feature_fraction': 0.7807413400869089, 'bagging_fraction': 0.7728651216314543, 'bagging_freq': 7, 'min_split_gain': 0.7845635037461813}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:13,007] Trial 32 finished with value: 0.7649290240042236 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 826, 'learning_rate': 0.1395817159077401, 'max_depth': 12, 'num_leaves': 182, 'lambda_l1': 0.04778632390460154, 'lambda_l2': 0.17797892150271105, 'min_child_samples': 63, 'feature_fraction': 0.9185511112162319, 'bagging_fraction': 0.782606744196875, 'bagging_freq': 7, 'min_split_gain': 0.8339960514948954}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:13,615] Trial 33 finished with value: 0.754801128061533 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 666, 'learning_rate': 0.05492874525385978, 'max_depth': 11, 'num_leaves': 239, 'lambda_l1': 0.001172812337642273, 'lambda_l2': 0.00723198141795369, 'min_child_samples': 57, 'feature_fraction': 0.8271059447499025, 'bagging_fraction': 0.9023388239423915, 'bagging_freq': 6, 'min_split_gain': 0.9416574257626363}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:14,110] Trial 34 finished with value: 0.7638938222013127 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 492, 'learning_rate': 0.09137387170096223, 'max_depth': 9, 'num_leaves': 129, 'lambda_l1': 0.053695346948336116, 'lambda_l2': 1.0949123089463404, 'min_child_samples': 68, 'feature_fraction': 0.8893664454368176, 'bagging_fraction': 0.7166854639330527, 'bagging_freq': 7, 'min_split_gain': 0.6630360411867926}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:25,589] Trial 35 finished with value: 0.7652010147264644 and parameters: {'boosting_type': 'dart', 'n_estimators': 1113, 'learning_rate': 0.02279773084855916, 'max_depth': 12, 'num_leaves': 197, 'lambda_l1': 0.00031612862432365955, 'lambda_l2': 0.06615485087812151, 'min_child_samples': 49, 'feature_fraction': 0.7797632177324549, 'bagging_fraction': 0.8413050673210363, 'bagging_freq': 6, 'min_split_gain': 0.7538531709314816}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:26,293] Trial 36 finished with value: 0.7658190818140201 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 897, 'learning_rate': 0.15056377825481715, 'max_depth': 11, 'num_leaves': 84, 'lambda_l1': 1.1550835385883365, 'lambda_l2': 0.0014704137495583688, 'min_child_samples': 73, 'feature_fraction': 0.9846903594432844, 'bagging_fraction': 0.6456800443441918, 'bagging_freq': 7, 'min_split_gain': 0.5803697828712289}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:27,325] Trial 37 finished with value: 0.7638223835531335 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 748, 'learning_rate': 0.09794835054836487, 'max_depth': 5, 'num_leaves': 95, 'lambda_l1': 2.69871769131038e-06, 'lambda_l2': 0.019398448722334656, 'min_child_samples': 88, 'feature_fraction': 0.7346752614855172, 'bagging_fraction': 0.8310607539294659, 'bagging_freq': 6, 'min_split_gain': 0.509623645890091}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:29,195] Trial 38 finished with value: 0.7349422743012006 and parameters: {'boosting_type': 'dart', 'n_estimators': 360, 'learning_rate': 0.03431694836909606, 'max_depth': 10, 'num_leaves': 25, 'lambda_l1': 9.359687283475779, 'lambda_l2': 0.1336841126371118, 'min_child_samples': 41, 'feature_fraction': 0.657209720861268, 'bagging_fraction': 0.7754025021783926, 'bagging_freq': 7, 'min_split_gain': 0.8336805196613173}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:30,233] Trial 39 finished with value: 0.7618513765586016 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1445, 'learning_rate': 0.05619537019911423, 'max_depth': 8, 'num_leaves': 154, 'lambda_l1': 0.02365267557705308, 'lambda_l2': 9.381856963790385, 'min_child_samples': 32, 'feature_fraction': 0.8875928872952776, 'bagging_fraction': 0.8918886068218643, 'bagging_freq': 6, 'min_split_gain': 0.779224238653145}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:33,761] Trial 40 finished with value: 0.7512386363439946 and parameters: {'boosting_type': 'dart', 'n_estimators': 449, 'learning_rate': 0.018740687070352202, 'max_depth': 3, 'num_leaves': 171, 'lambda_l1': 1.3645706615085471e-08, 'lambda_l2': 4.631268252314592e-08, 'min_child_samples': 67, 'feature_fraction': 0.7630046136525056, 'bagging_fraction': 0.7001255356740131, 'bagging_freq': 2, 'min_split_gain': 0.23487936359356287}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:34,197] Trial 41 finished with value: 0.759703461639336 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 625, 'learning_rate': 0.19535913821995954, 'max_depth': 11, 'num_leaves': 185, 'lambda_l1': 0.27284887626209914, 'lambda_l2': 0.8110348958666102, 'min_child_samples': 65, 'feature_fraction': 0.7741861291023433, 'bagging_fraction': 0.7576824607508922, 'bagging_freq': 7, 'min_split_gain': 0.6860373622026253}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:34,712] Trial 42 finished with value: 0.7536432982326849 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 556, 'learning_rate': 0.17352841287894297, 'max_depth': 11, 'num_leaves': 223, 'lambda_l1': 0.2725255955053295, 'lambda_l2': 1.8766144124913133, 'min_child_samples': 60, 'feature_fraction': 0.7986077622859378, 'bagging_fraction': 0.9613227398555818, 'bagging_freq': 7, 'min_split_gain': 0.757613655501342}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:35,115] Trial 43 finished with value: 0.7406766981559078 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 634, 'learning_rate': 0.19927275174819212, 'max_depth': 12, 'num_leaves': 115, 'lambda_l1': 2.344668543219389, 'lambda_l2': 0.07703467858411278, 'min_child_samples': 55, 'feature_fraction': 0.7977689033196245, 'bagging_fraction': 0.5767930165010118, 'bagging_freq': 7, 'min_split_gain': 0.85939969459136}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:35,646] Trial 44 finished with value: 0.765029891690946 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 738, 'learning_rate': 0.11670904199979863, 'max_depth': 11, 'num_leaves': 141, 'lambda_l1': 0.002483745840592535, 'lambda_l2': 0.01690474246984319, 'min_child_samples': 71, 'feature_fraction': 0.8482838514293253, 'bagging_fraction': 0.8239325610491022, 'bagging_freq': 6, 'min_split_gain': 0.9625401715269766}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:36,961] Trial 45 finished with value: 0.7507963120797813 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 525, 'learning_rate': 0.0037513644577626924, 'max_depth': 10, 'num_leaves': 167, 'lambda_l1': 0.17400337895527718, 'lambda_l2': 0.35463074245542325, 'min_child_samples': 78, 'feature_fraction': 0.7436056308713037, 'bagging_fraction': 0.6812487549794203, 'bagging_freq': 7, 'min_split_gain': 0.7459430325528059}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:37,470] Trial 46 finished with value: 0.7594727143699309 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 598, 'learning_rate': 0.07694678796314072, 'max_depth': 12, 'num_leaves': 211, 'lambda_l1': 1.052467274298045, 'lambda_l2': 8.569155577937568e-05, 'min_child_samples': 51, 'feature_fraction': 0.6813890879971048, 'bagging_fraction': 0.7253121140155318, 'bagging_freq': 6, 'min_split_gain': 0.6232908980350745}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:38,534] Trial 47 finished with value: 0.7250548899546875 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 355, 'learning_rate': 0.1601529627535126, 'max_depth': 9, 'num_leaves': 197, 'lambda_l1': 0.08319871767778733, 'lambda_l2': 0.0038481958534034282, 'min_child_samples': 65, 'feature_fraction': 0.8289322182762869, 'bagging_fraction': 0.7643186825679014, 'bagging_freq': 7, 'min_split_gain': 0.0168376881122565}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:40,146] Trial 48 finished with value: 0.7459040021086224 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 441, 'learning_rate': 0.0015239179316189767, 'max_depth': 7, 'num_leaves': 61, 'lambda_l1': 0.016957536328253576, 'lambda_l2': 3.789175672538919, 'min_child_samples': 28, 'feature_fraction': 0.9457106020226927, 'bagging_fraction': 0.9946232025635492, 'bagging_freq': 5, 'min_split_gain': 0.8120052993353614}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:42,727] Trial 49 finished with value: 0.7636810301606444 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 893, 'learning_rate': 0.006458037463949605, 'max_depth': 11, 'num_leaves': 6, 'lambda_l1': 0.00046280251002303287, 'lambda_l2': 1.1531946308906073e-08, 'min_child_samples': 18, 'feature_fraction': 0.7801087165125141, 'bagging_fraction': 0.5812500918397583, 'bagging_freq': 6, 'min_split_gain': 0.5357681776467592}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:43,083] Trial 50 finished with value: 0.7593746322503391 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 206, 'learning_rate': 0.08517745218474454, 'max_depth': 10, 'num_leaves': 178, 'lambda_l1': 0.004016083606701367, 'lambda_l2': 0.9263041683083071, 'min_child_samples': 58, 'feature_fraction': 0.8751091685256371, 'bagging_fraction': 0.8524059748880004, 'bagging_freq': 7, 'min_split_gain': 0.8913627141005245}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:43,409] Trial 51 finished with value: 0.7548796036679869 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 313, 'learning_rate': 0.12595908123531024, 'max_depth': 10, 'num_leaves': 214, 'lambda_l1': 4.287937233696286e-06, 'lambda_l2': 3.588296266995406e-06, 'min_child_samples': 53, 'feature_fraction': 0.7190675049707637, 'bagging_fraction': 0.8740451798677986, 'bagging_freq': 4, 'min_split_gain': 0.9544994431607338}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:43,865] Trial 52 finished with value: 0.7596935150810884 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 371, 'learning_rate': 0.06840295698610499, 'max_depth': 9, 'num_leaves': 246, 'lambda_l1': 2.1696847185695793e-05, 'lambda_l2': 0.12365307482762349, 'min_child_samples': 39, 'feature_fraction': 0.6818916300720821, 'bagging_fraction': 0.8150775588685416, 'bagging_freq': 5, 'min_split_gain': 0.8689135231233535}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:44,503] Trial 53 finished with value: 0.7556270843044616 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 758, 'learning_rate': 0.08913538690420647, 'max_depth': 11, 'num_leaves': 209, 'lambda_l1': 0.00011708519548630002, 'lambda_l2': 0.036050661539357105, 'min_child_samples': 69, 'feature_fraction': 0.5962366321964724, 'bagging_fraction': 0.7804009851474966, 'bagging_freq': 6, 'min_split_gain': 0.9943881239647037}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:45,346] Trial 54 finished with value: 0.7569211824169465 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 549, 'learning_rate': 0.05011441598973813, 'max_depth': 2, 'num_leaves': 193, 'lambda_l1': 1.9407466366969947e-07, 'lambda_l2': 3.4200715515831197e-07, 'min_child_samples': 50, 'feature_fraction': 0.6274698900979694, 'bagging_fraction': 0.8599419447415768, 'bagging_freq': 5, 'min_split_gain': 0.8098224162664908}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:45,896] Trial 55 finished with value: 0.7625465903780527 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 652, 'learning_rate': 0.11128788900799451, 'max_depth': 5, 'num_leaves': 160, 'lambda_l1': 2.4768297884559614e-06, 'lambda_l2': 4.911101649887386, 'min_child_samples': 62, 'feature_fraction': 0.8002030318260631, 'bagging_fraction': 0.7397567208345074, 'bagging_freq': 6, 'min_split_gain': 0.7070801265127936}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:46,309] Trial 56 finished with value: 0.7581539054947856 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 156, 'learning_rate': 0.035124856866488995, 'max_depth': 10, 'num_leaves': 224, 'lambda_l1': 6.0305061753238505e-06, 'lambda_l2': 8.836495801548173e-07, 'min_child_samples': 55, 'feature_fraction': 0.7363629680589523, 'bagging_fraction': 0.8945161547752413, 'bagging_freq': 6, 'min_split_gain': 0.9153236209377931}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:46,609] Trial 57 finished with value: 0.763109614028065 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 245, 'learning_rate': 0.1600497349531767, 'max_depth': 6, 'num_leaves': 229, 'lambda_l1': 3.050067100898248e-05, 'lambda_l2': 6.568375011362379e-08, 'min_child_samples': 74, 'feature_fraction': 0.7557549286745592, 'bagging_fraction': 0.9272930046266732, 'bagging_freq': 5, 'min_split_gain': 0.8767669576798179}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:50,867] Trial 58 finished with value: 0.7600565569424907 and parameters: {'boosting_type': 'dart', 'n_estimators': 502, 'learning_rate': 0.06289904637860183, 'max_depth': 9, 'num_leaves': 245, 'lambda_l1': 1.2045635976269904e-06, 'lambda_l2': 7.296535607337364e-06, 'min_child_samples': 82, 'feature_fraction': 0.6598861615913783, 'bagging_fraction': 0.8025378035527697, 'bagging_freq': 7, 'min_split_gain': 0.7817399743780942}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:51,242] Trial 59 finished with value: 0.7599100284448013 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 318, 'learning_rate': 0.07768045944196081, 'max_depth': 12, 'num_leaves': 203, 'lambda_l1': 4.48014638072697e-07, 'lambda_l2': 0.5273062320636619, 'min_child_samples': 44, 'feature_fraction': 0.840659104712794, 'bagging_fraction': 0.850795948216006, 'bagging_freq': 6, 'min_split_gain': 0.9445075340022274}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:51,605] Trial 60 finished with value: 0.7562022481114461 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 430, 'learning_rate': 0.11034293237897072, 'max_depth': 3, 'num_leaves': 174, 'lambda_l1': 7.903363228590184e-08, 'lambda_l2': 6.246327826975098e-05, 'min_child_samples': 58, 'feature_fraction': 0.7226899048023744, 'bagging_fraction': 0.9637021658988267, 'bagging_freq': 4, 'min_split_gain': 0.8430321798845525}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:52,264] Trial 61 finished with value: 0.7615065765995145 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1017, 'learning_rate': 0.1488297320227953, 'max_depth': 11, 'num_leaves': 94, 'lambda_l1': 0.4519556185587016, 'lambda_l2': 0.0012175566823853588, 'min_child_samples': 72, 'feature_fraction': 0.9836548020355591, 'bagging_fraction': 0.6296641443776793, 'bagging_freq': 7, 'min_split_gain': 0.6035906190471221}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:52,850] Trial 62 finished with value: 0.7587320981278373 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 856, 'learning_rate': 0.15897133241273548, 'max_depth': 11, 'num_leaves': 85, 'lambda_l1': 0.7477308347213223, 'lambda_l2': 1.5549069630740717, 'min_child_samples': 75, 'feature_fraction': 0.967727123438707, 'bagging_fraction': 0.7873047562813783, 'bagging_freq': 7, 'min_split_gain': 0.4471626682962011}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:53,490] Trial 63 finished with value: 0.7384856940129145 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1041, 'learning_rate': 0.13094489345371269, 'max_depth': 10, 'num_leaves': 66, 'lambda_l1': 2.3157954119400825, 'lambda_l2': 0.0010543000071159396, 'min_child_samples': 65, 'feature_fraction': 0.902297703638425, 'bagging_fraction': 0.593569373566119, 'bagging_freq': 7, 'min_split_gain': 0.7312840337409938}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:53,963] Trial 64 finished with value: 0.747293983821431 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 706, 'learning_rate': 0.19922737937658444, 'max_depth': 11, 'num_leaves': 28, 'lambda_l1': 0.10299277706493326, 'lambda_l2': 0.25751110406907346, 'min_child_samples': 81, 'feature_fraction': 0.9969444279114524, 'bagging_fraction': 0.6716984559590564, 'bagging_freq': 7, 'min_split_gain': 0.9032987047976122}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:54,735] Trial 65 finished with value: 0.7619380060563312 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 915, 'learning_rate': 0.09108053772039584, 'max_depth': 12, 'num_leaves': 123, 'lambda_l1': 1.0080842377580227e-05, 'lambda_l2': 1.8810799605251518e-06, 'min_child_samples': 90, 'feature_fraction': 0.7049598759930034, 'bagging_fraction': 0.6509963580830073, 'bagging_freq': 7, 'min_split_gain': 0.5741558398596417}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:55,329] Trial 66 finished with value: 0.7588788892284078 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 789, 'learning_rate': 0.13465446846265627, 'max_depth': 8, 'num_leaves': 190, 'lambda_l1': 1.0889726153526975, 'lambda_l2': 0.49832359430266704, 'min_child_samples': 68, 'feature_fraction': 0.5445228781829841, 'bagging_fraction': 0.7075493938803349, 'bagging_freq': 6, 'min_split_gain': 0.34357223404386905}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:07:56,167] Trial 67 finished with value: 0.7434783325167263 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1303, 'learning_rate': 0.04718230861327681, 'max_depth': 10, 'num_leaves': 53, 'lambda_l1': 4.004634407617978, 'lambda_l2': 1.8651265925494937e-05, 'min_child_samples': 63, 'feature_fraction': 0.8630348180851989, 'bagging_fraction': 0.4936997697731449, 'bagging_freq': 5, 'min_split_gain': 0.8248175532054078}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:08:00,092] Trial 68 finished with value: 0.7529963361898755 and parameters: {'boosting_type': 'dart', 'n_estimators': 610, 'learning_rate': 0.1705424051334499, 'max_depth': 11, 'num_leaves': 76, 'lambda_l1': 0.03393994439923697, 'lambda_l2': 0.01247729844899187, 'min_child_samples': 48, 'feature_fraction': 0.5101654887178886, 'bagging_fraction': 0.8829411664067134, 'bagging_freq': 7, 'min_split_gain': 0.6895541422911832}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:08:00,517] Trial 69 finished with value: 0.7521277019067476 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 579, 'learning_rate': 0.10518856196682766, 'max_depth': 9, 'num_leaves': 144, 'lambda_l1': 4.759126189055886e-05, 'lambda_l2': 0.04567839808264617, 'min_child_samples': 85, 'feature_fraction': 0.811879892652351, 'bagging_fraction': 0.9160763691622703, 'bagging_freq': 6, 'min_split_gain': 0.7637012609669752}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:08:01,869] Trial 70 finished with value: 0.7627560319637178 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 852, 'learning_rate': 0.014964109035038014, 'max_depth': 12, 'num_leaves': 36, 'lambda_l1': 0.01249391826744782, 'lambda_l2': 0.1094704475632491, 'min_child_samples': 75, 'feature_fraction': 0.7812710143980759, 'bagging_fraction': 0.5335761695269305, 'bagging_freq': 7, 'min_split_gain': 0.9702757792799489}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:08:13,716] Trial 71 finished with value: 0.7566598690413642 and parameters: {'boosting_type': 'dart', 'n_estimators': 1078, 'learning_rate': 0.028640223220873964, 'max_depth': 12, 'num_leaves': 205, 'lambda_l1': 0.0004245391874509427, 'lambda_l2': 0.23241567191799212, 'min_child_samples': 60, 'feature_fraction': 0.760227048624907, 'bagging_fraction': 0.8416285158047775, 'bagging_freq': 6, 'min_split_gain': 0.25878346919906126}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:08:26,114] Trial 72 finished with value: 0.7691018788625185 and parameters: {'boosting_type': 'dart', 'n_estimators': 1206, 'learning_rate': 0.037474057811638095, 'max_depth': 12, 'num_leaves': 234, 'lambda_l1': 0.00021949165549430192, 'lambda_l2': 0.0868582965915102, 'min_child_samples': 70, 'feature_fraction': 0.7911972782385671, 'bagging_fraction': 0.8230622868241123, 'bagging_freq': 6, 'min_split_gain': 0.7900736862843226}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:08:38,771] Trial 73 finished with value: 0.7615507378585834 and parameters: {'boosting_type': 'dart', 'n_estimators': 1210, 'learning_rate': 0.059421935881458644, 'max_depth': 11, 'num_leaves': 232, 'lambda_l1': 0.00013764078694452898, 'lambda_l2': 4.4037231091085157e-07, 'min_child_samples': 70, 'feature_fraction': 0.8109912099028509, 'bagging_fraction': 0.7503902054975841, 'bagging_freq': 5, 'min_split_gain': 0.8529727199673723}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:08:50,095] Trial 74 finished with value: 0.7640893863909063 and parameters: {'boosting_type': 'dart', 'n_estimators': 1279, 'learning_rate': 0.08071197991130316, 'max_depth': 12, 'num_leaves': 253, 'lambda_l1': 1.4844727213421404e-05, 'lambda_l2': 1.9393956134757557, 'min_child_samples': 66, 'feature_fraction': 0.7247645676925983, 'bagging_fraction': 0.8160427253983522, 'bagging_freq': 6, 'min_split_gain': 0.8012172020840559}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:09:05,007] Trial 75 finished with value: 0.7697941042356624 and parameters: {'boosting_type': 'dart', 'n_estimators': 1400, 'learning_rate': 0.03953720685922934, 'max_depth': 11, 'num_leaves': 219, 'lambda_l1': 1.5887213385334879e-06, 'lambda_l2': 1.150210626553642, 'min_child_samples': 57, 'feature_fraction': 0.7893280221779513, 'bagging_fraction': 0.7916557861620707, 'bagging_freq': 7, 'min_split_gain': 0.9314186117310013}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:09:18,242] Trial 76 finished with value: 0.7679086998355468 and parameters: {'boosting_type': 'dart', 'n_estimators': 1357, 'learning_rate': 0.03900704660978739, 'max_depth': 10, 'num_leaves': 218, 'lambda_l1': 1.8274188511305421e-06, 'lambda_l2': 0.7383043667371623, 'min_child_samples': 56, 'feature_fraction': 0.7893004218351393, 'bagging_fraction': 0.7953807602241834, 'bagging_freq': 7, 'min_split_gain': 0.88778419564076}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:09:32,505] Trial 77 finished with value: 0.7580927715520684 and parameters: {'boosting_type': 'dart', 'n_estimators': 1349, 'learning_rate': 0.04182205420689192, 'max_depth': 10, 'num_leaves': 239, 'lambda_l1': 1.2190311267397149e-06, 'lambda_l2': 4.679844727463143, 'min_child_samples': 56, 'feature_fraction': 0.7905928897888578, 'bagging_fraction': 0.7887361954465607, 'bagging_freq': 7, 'min_split_gain': 0.9330821569220256}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:09:48,699] Trial 78 finished with value: 0.7666965998516373 and parameters: {'boosting_type': 'dart', 'n_estimators': 1493, 'learning_rate': 0.023045548796989956, 'max_depth': 12, 'num_leaves': 238, 'lambda_l1': 2.0173722477082997e-06, 'lambda_l2': 0.7093432142899113, 'min_child_samples': 64, 'feature_fraction': 0.8287106779048777, 'bagging_fraction': 0.8259685287773252, 'bagging_freq': 7, 'min_split_gain': 0.8853021526323132}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:10:01,864] Trial 79 finished with value: 0.76803986660809 and parameters: {'boosting_type': 'dart', 'n_estimators': 1397, 'learning_rate': 0.04932080710534454, 'max_depth': 5, 'num_leaves': 219, 'lambda_l1': 6.844959695964208e-07, 'lambda_l2': 1.2827469005418572, 'min_child_samples': 60, 'feature_fraction': 0.7643741599823312, 'bagging_fraction': 0.7729452861028386, 'bagging_freq': 1, 'min_split_gain': 0.9243907950391362}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:10:17,153] Trial 80 finished with value: 0.7567267730446984 and parameters: {'boosting_type': 'dart', 'n_estimators': 1498, 'learning_rate': 0.033209712199063025, 'max_depth': 4, 'num_leaves': 245, 'lambda_l1': 2.5951151162779414e-08, 'lambda_l2': 7.014463165554544, 'min_child_samples': 60, 'feature_fraction': 0.7589148930625361, 'bagging_fraction': 0.7714317776456043, 'bagging_freq': 1, 'min_split_gain': 0.981847290223993}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:10:30,566] Trial 81 finished with value: 0.7697467355883099 and parameters: {'boosting_type': 'dart', 'n_estimators': 1401, 'learning_rate': 0.04972726079416192, 'max_depth': 4, 'num_leaves': 232, 'lambda_l1': 2.104728950532198e-07, 'lambda_l2': 1.4065703205859992, 'min_child_samples': 57, 'feature_fraction': 0.7690837497053213, 'bagging_fraction': 0.8028388152079189, 'bagging_freq': 7, 'min_split_gain': 0.9224737825133423}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:10:45,067] Trial 82 finished with value: 0.7580055245057163 and parameters: {'boosting_type': 'dart', 'n_estimators': 1432, 'learning_rate': 0.05126499016197342, 'max_depth': 4, 'num_leaves': 220, 'lambda_l1': 1.550855361848007e-07, 'lambda_l2': 2.5669513303031377, 'min_child_samples': 62, 'feature_fraction': 0.7727564174666787, 'bagging_fraction': 0.7338890789580768, 'bagging_freq': 2, 'min_split_gain': 0.9236860311948739}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:10:57,547] Trial 83 finished with value: 0.7459266798435503 and parameters: {'boosting_type': 'dart', 'n_estimators': 1352, 'learning_rate': 0.0625003369720462, 'max_depth': 5, 'num_leaves': 232, 'lambda_l1': 3.2355619657890306e-07, 'lambda_l2': 0.3484888631301194, 'min_child_samples': 53, 'feature_fraction': 0.7470069088658761, 'bagging_fraction': 0.40029767767374763, 'bagging_freq': 3, 'min_split_gain': 0.9487291231119892}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:11:09,660] Trial 84 finished with value: 0.7730127899614251 and parameters: {'boosting_type': 'dart', 'n_estimators': 1388, 'learning_rate': 0.0713781896672617, 'max_depth': 4, 'num_leaves': 203, 'lambda_l1': 4.336926341115937e-06, 'lambda_l2': 1.2769787199463545, 'min_child_samples': 70, 'feature_fraction': 0.8442839852990824, 'bagging_fraction': 0.8136579268006926, 'bagging_freq': 7, 'min_split_gain': 0.8505837495652174}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:11:22,123] Trial 85 finished with value: 0.7685453552085172 and parameters: {'boosting_type': 'dart', 'n_estimators': 1225, 'learning_rate': 0.04717931923238511, 'max_depth': 4, 'num_leaves': 202, 'lambda_l1': 4.783117110239313e-06, 'lambda_l2': 1.8001201275760834, 'min_child_samples': 5, 'feature_fraction': 0.845547067025299, 'bagging_fraction': 0.833382429784783, 'bagging_freq': 1, 'min_split_gain': 0.8588317760196519}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:11:32,717] Trial 86 finished with value: 0.7650113927647988 and parameters: {'boosting_type': 'dart', 'n_estimators': 1213, 'learning_rate': 0.07185564116418512, 'max_depth': 4, 'num_leaves': 200, 'lambda_l1': 6.764472582343862e-06, 'lambda_l2': 0.19023829695509142, 'min_child_samples': 20, 'feature_fraction': 0.8446819032368593, 'bagging_fraction': 0.8384737377389052, 'bagging_freq': 7, 'min_split_gain': 0.8515980337645327}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:11:43,821] Trial 87 finished with value: 0.7618072746069536 and parameters: {'boosting_type': 'dart', 'n_estimators': 1148, 'learning_rate': 0.038178830000816115, 'max_depth': 3, 'num_leaves': 211, 'lambda_l1': 4.052698784718298e-06, 'lambda_l2': 1.2615049117430963, 'min_child_samples': 8, 'feature_fraction': 0.868439989622982, 'bagging_fraction': 0.8659469007545673, 'bagging_freq': 7, 'min_split_gain': 0.8250236777007941}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:11:58,192] Trial 88 finished with value: 0.7669469803768504 and parameters: {'boosting_type': 'dart', 'n_estimators': 1264, 'learning_rate': 0.0238657688734841, 'max_depth': 4, 'num_leaves': 192, 'lambda_l1': 4.8950189009979384e-05, 'lambda_l2': 4.256855491847171, 'min_child_samples': 26, 'feature_fraction': 0.8136999324932925, 'bagging_fraction': 0.8232037317445485, 'bagging_freq': 6, 'min_split_gain': 0.903275547499688}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:12:13,676] Trial 89 finished with value: 0.768224292047046 and parameters: {'boosting_type': 'dart', 'n_estimators': 1428, 'learning_rate': 0.044170301407354354, 'max_depth': 3, 'num_leaves': 226, 'lambda_l1': 2.272211098901191e-05, 'lambda_l2': 7.35041107876198, 'min_child_samples': 12, 'feature_fraction': 0.8541697572685819, 'bagging_fraction': 0.8057862996740405, 'bagging_freq': 7, 'min_split_gain': 0.781449568502622}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:12:26,090] Trial 90 finished with value: 0.7680072847446069 and parameters: {'boosting_type': 'dart', 'n_estimators': 1472, 'learning_rate': 0.06920494206775676, 'max_depth': 2, 'num_leaves': 256, 'lambda_l1': 3.6428982251510104e-06, 'lambda_l2': 0.0828508566016703, 'min_child_samples': 5, 'feature_fraction': 0.8299484686396874, 'bagging_fraction': 0.9047149669966655, 'bagging_freq': 2, 'min_split_gain': 0.9704615124122487}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:12:41,400] Trial 91 finished with value: 0.7662735559748141 and parameters: {'boosting_type': 'dart', 'n_estimators': 1398, 'learning_rate': 0.030876229000769084, 'max_depth': 3, 'num_leaves': 229, 'lambda_l1': 1.8468359416604328e-05, 'lambda_l2': 2.3249611718825003, 'min_child_samples': 14, 'feature_fraction': 0.8545074689943062, 'bagging_fraction': 0.8082111728200123, 'bagging_freq': 7, 'min_split_gain': 0.7834210803796398}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:12:55,244] Trial 92 finished with value: 0.7653542988312543 and parameters: {'boosting_type': 'dart', 'n_estimators': 1313, 'learning_rate': 0.047046364716692914, 'max_depth': 3, 'num_leaves': 248, 'lambda_l1': 8.980290016748693e-06, 'lambda_l2': 9.106529272959406, 'min_child_samples': 12, 'feature_fraction': 0.8805475660524675, 'bagging_fraction': 0.8483833831264741, 'bagging_freq': 7, 'min_split_gain': 0.8641205709910413}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:13:09,036] Trial 93 finished with value: 0.7618263692392523 and parameters: {'boosting_type': 'dart', 'n_estimators': 1446, 'learning_rate': 0.05680240340828615, 'max_depth': 4, 'num_leaves': 238, 'lambda_l1': 7.080214634053374e-07, 'lambda_l2': 1.0531109439564519, 'min_child_samples': 7, 'feature_fraction': 0.9017764418636056, 'bagging_fraction': 0.7992235601086202, 'bagging_freq': 7, 'min_split_gain': 0.8117979104254234}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:13:17,251] Trial 94 finished with value: 0.7717510276313814 and parameters: {'boosting_type': 'dart', 'n_estimators': 1384, 'learning_rate': 0.02720718476076812, 'max_depth': 4, 'num_leaves': 209, 'lambda_l1': 7.788336677580869e-05, 'lambda_l2': 2.9247742385460573, 'min_child_samples': 15, 'feature_fraction': 0.8061414248042329, 'bagging_fraction': 0.8280711397540473, 'bagging_freq': 7, 'min_split_gain': 0.8338981836941488}. Best is trial 27 with value: 0.7751492586811666.
# [I 2026-03-13 22:13:23,960] Trial 95 finished with value: 0.7721290797648211 and parameters: {'boosting_type': 'dart', 'n_estimators': 1239, 'learning_rate': 0.027395088225159854, 'max_depth': 4, 'num_leaves': 206, 'lambda_l1': 8.18141161707325e-05, 'lambda_l2': 0.6054506435840266, 'min_child_samples': 23, 'feature_fraction': 0.8100277638924417, 'bagging_fraction': 0.8856352040786881, 'bagging_freq': 6, 'min_split_gain': 0.8340240213766772}. Best is trial 27 with value: 0.7751492586811666.
# ...
# [I 2026-03-13 22:16:22,702] Trial 118 finished with value: 0.766292175724959 and parameters: {'boosting_type': 'dart', 'n_estimators': 1421, 'learning_rate': 0.026081270501028885, 'max_depth': 4, 'num_leaves': 202, 'lambda_l1': 8.563948352284685e-05, 'lambda_l2': 0.00016835158522979595, 'min_child_samples': 12, 'feature_fraction': 0.8190480366933586, 'bagging_fraction': 0.8460261679904794, 'bagging_freq': 7, 'min_split_gain': 0.948090878358007}. Best is trial 112 with value: 0.778045428766346.
# [I 2026-03-13 22:16:31,068] Trial 119 finished with value: 0.755272346257111 and parameters: {'boosting_type': 'dart', 'n_estimators': 1302, 'learning_rate': 0.011259307609311608, 'max_depth': 8, 'num_leaves': 172, 'lambda_l1': 0.0008743052388924867, 'lambda_l2': 0.034214042067387214, 'min_child_samples': 35, 'feature_fraction': 0.4024848661671258, 'bagging_fraction': 0.9686759228150603, 'bagging_freq': 7, 'min_split_gain': 0.9122225774717448}. Best is trial 112 with value: 0.778045428766346.
# [I 2026-03-13 22:16:38,429] Trial 120 finished with value: 0.7668291455282631 and parameters: {'boosting_type': 'dart', 'n_estimators': 1238, 'learning_rate': 0.014072235846103672, 'max_depth': 5, 'num_leaves': 161, 'lambda_l1': 0.00017058288523280732, 'lambda_l2': 0.06531035658572695, 'min_child_samples': 21, 'feature_fraction': 0.7979215185449218, 'bagging_fraction': 0.8558713229958695, 'bagging_freq': 6, 'min_split_gain': 0.8756377338372169}. Best is trial 112 with value: 0.778045428766346.
# [I 2026-03-13 22:16:46,168] Trial 121 finished with value: 0.7703461597603839 and parameters: {'boosting_type': 'dart', 'n_estimators': 1372, 'learning_rate': 0.016158419519213818, 'max_depth': 6, 'num_leaves': 211, 'lambda_l1': 0.0036290127052697337, 'lambda_l2': 0.8452897771785508, 'min_child_samples': 16, 'feature_fraction': 0.7792966136036142, 'bagging_fraction': 0.9042952845130812, 'bagging_freq': 7, 'min_split_gain': 0.9750086404856854}. Best is trial 112 with value: 0.778045428766346.
# [I 2026-03-13 22:16:53,899] Trial 122 finished with value: 0.7625463856789162 and parameters: {'boosting_type': 'dart', 'n_estimators': 1341, 'learning_rate': 0.019808226689419742, 'max_depth': 6, 'num_leaves': 203, 'lambda_l1': 0.0004243897272665605, 'lambda_l2': 2.0312320266271993, 'min_child_samples': 18, 'feature_fraction': 0.770131899594751, 'bagging_fraction': 0.888368288659634, 'bagging_freq': 7, 'min_split_gain': 0.9360177855473113}. Best is trial 112 with value: 0.778045428766346.
# [I 2026-03-13 22:17:00,461] Trial 123 finished with value: 0.7712277922158144 and parameters: {'boosting_type': 'dart', 'n_estimators': 1177, 'learning_rate': 0.01812846242905614, 'max_depth': 7, 'num_leaves': 190, 'lambda_l1': 0.0025745250499972934, 'lambda_l2': 0.6571480104894869, 'min_child_samples': 24, 'feature_fraction': 0.7897705136230969, 'bagging_fraction': 0.9272667001960126, 'bagging_freq': 7, 'min_split_gain': 0.9647226126737948}. Best is trial 112 with value: 0.778045428766346.
# [I 2026-03-13 22:17:10,089] Trial 124 finished with value: 0.7616933801526559 and parameters: {'boosting_type': 'dart', 'n_estimators': 1380, 'learning_rate': 0.00964483568515225, 'max_depth': 7, 'num_leaves': 208, 'lambda_l1': 3.286049365400726e-05, 'lambda_l2': 0.29069943803851084, 'min_child_samples': 9, 'feature_fraction': 0.7427742226731576, 'bagging_fraction': 0.8760021270558335, 'bagging_freq': 7, 'min_split_gain': 0.9965824196809256}. Best is trial 112 with value: 0.778045428766346.
# [I 2026-03-13 22:17:14,146] Trial 125 finished with value: 0.7560134922838252 and parameters: {'boosting_type': 'dart', 'n_estimators': 780, 'learning_rate': 0.006948643207706893, 'max_depth': 7, 'num_leaves': 197, 'lambda_l1': 9.785039692280628e-05, 'lambda_l2': 3.374795057538649, 'min_child_samples': 14, 'feature_fraction': 0.7545496331247337, 'bagging_fraction': 0.8380053239399067, 'bagging_freq': 7, 'min_split_gain': 0.8276668299491837}. Best is trial 112 with value: 0.778045428766346.
# [I 2026-03-13 22:17:22,480] Trial 126 finished with value: 0.7716550206280209 and parameters: {'boosting_type': 'dart', 'n_estimators': 1451, 'learning_rate': 0.024599412964857268, 'max_depth': 6, 'num_leaves': 181, 'lambda_l1': 0.007469888785357974, 'lambda_l2': 1.4514577923492602, 'min_child_samples': 17, 'feature_fraction': 0.8591402148263514, 'bagging_fraction': 0.8913216309319764, 'bagging_freq': 7, 'min_split_gain': 0.9329835643098452}. Best is trial 112 with value: 0.778045428766346.
# [I 2026-03-13 22:17:30,465] Trial 127 finished with value: 0.7623183226040336 and parameters: {'boosting_type': 'dart', 'n_estimators': 1444, 'learning_rate': 0.024826997007233346, 'max_depth': 4, 'num_leaves': 180, 'lambda_l1': 0.008877109133313977, 'lambda_l2': 1.154818577114944, 'min_child_samples': 67, 'feature_fraction': 0.8674338287278285, 'bagging_fraction': 0.8639963079552446, 'bagging_freq': 7, 'min_split_gain': 0.927628592226526}. Best is trial 112 with value: 0.778045428766346.
# [I 2026-03-13 22:17:42,563] Trial 128 finished with value: 0.7705246175186925 and parameters: {'boosting_type': 'dart', 'n_estimators': 1493, 'learning_rate': 0.028487280698665716, 'max_depth': 5, 'num_leaves': 187, 'lambda_l1': 0.0011869981553512849, 'lambda_l2': 5.078608874441177, 'min_child_samples': 30, 'feature_fraction': 0.8536367128046836, 'bagging_fraction': 0.9142490942246082, 'bagging_freq': 7, 'min_split_gain': 0.889367367647268}. Best is trial 112 with value: 0.778045428766346.
# [I 2026-03-13 22:17:55,244] Trial 129 finished with value: 0.7698947688400675 and parameters: {'boosting_type': 'dart', 'n_estimators': 1099, 'learning_rate': 0.02232039967502766, 'max_depth': 4, 'num_leaves': 150, 'lambda_l1': 0.01569067950530307, 'lambda_l2': 0.14597740625953923, 'min_child_samples': 18, 'feature_fraction': 0.8909488253791088, 'bagging_fraction': 0.8485485240350492, 'bagging_freq': 6, 'min_split_gain': 0.8451866670887402}. Best is trial 112 with value: 0.778045428766346.
# [I 2026-03-13 22:18:11,651] Trial 130 finished with value: 0.7548829411170729 and parameters: {'boosting_type': 'dart', 'n_estimators': 1421, 'learning_rate': 0.0024421945061807635, 'max_depth': 6, 'num_leaves': 179, 'lambda_l1': 0.005251229705185351, 'lambda_l2': 1.625929203021257, 'min_child_samples': 22, 'feature_fraction': 0.8236723601829071, 'bagging_fraction': 0.9375066830281041, 'bagging_freq': 7, 'min_split_gain': 0.9121262682633049}. Best is trial 112 with value: 0.778045428766346.
# [I 2026-03-13 22:18:26,163] Trial 131 finished with value: 0.767977219111641 and parameters: {'boosting_type': 'dart', 'n_estimators': 1464, 'learning_rate': 0.013819560334101469, 'max_depth': 6, 'num_leaves': 192, 'lambda_l1': 0.0015446802486120664, 'lambda_l2': 0.8918655319448943, 'min_child_samples': 16, 'feature_fraction': 0.8373001615697903, 'bagging_fraction': 0.8990131858102038, 'bagging_freq': 7, 'min_split_gain': 0.9563547171982876}. Best is trial 112 with value: 0.778045428766346.
# [I 2026-03-13 22:18:41,119] Trial 132 finished with value: 0.7693827491892912 and parameters: {'boosting_type': 'dart', 'n_estimators': 1284, 'learning_rate': 0.01665526056724766, 'max_depth': 6, 'num_leaves': 207, 'lambda_l1': 0.0004643325062096957, 'lambda_l2': 0.5805337731266456, 'min_child_samples': 12, 'feature_fraction': 0.8006646158749269, 'bagging_fraction': 0.8847601054964834, 'bagging_freq': 7, 'min_split_gain': 0.9772879024918736}. Best is trial 112 with value: 0.778045428766346.
# [I 2026-03-13 22:18:49,218] Trial 133 finished with value: 0.7672667187218546 and parameters: {'boosting_type': 'dart', 'n_estimators': 721, 'learning_rate': 0.032651789371890325, 'max_depth': 6, 'num_leaves': 197, 'lambda_l1': 0.0007740097864033483, 'lambda_l2': 2.4454345559767106, 'min_child_samples': 15, 'feature_fraction': 0.7695445783852324, 'bagging_fraction': 0.8787061882246993, 'bagging_freq': 7, 'min_split_gain': 0.9361222944070605}. Best is trial 112 with value: 0.778045428766346.
# [I 2026-03-13 22:19:05,838] Trial 134 finished with value: 0.7556070515073335 and parameters: {'boosting_type': 'dart', 'n_estimators': 1353, 'learning_rate': 0.010575869014297993, 'max_depth': 4, 'num_leaves': 214, 'lambda_l1': 0.000230562369160466, 'lambda_l2': 0.4372311197187693, 'min_child_samples': 20, 'feature_fraction': 0.8118519395583009, 'bagging_fraction': 0.4361550028580636, 'bagging_freq': 7, 'min_split_gain': 0.9557740262450414}. Best is trial 112 with value: 0.778045428766346.
# [I 2026-03-13 22:19:21,085] Trial 135 finished with value: 0.7676518753588089 and parameters: {'boosting_type': 'dart', 'n_estimators': 1389, 'learning_rate': 0.01538127625862165, 'max_depth': 5, 'num_leaves': 213, 'lambda_l1': 0.002974936173431148, 'lambda_l2': 3.202804928768084e-05, 'min_child_samples': 27, 'feature_fraction': 0.7832851317477268, 'bagging_fraction': 0.8964773751548267, 'bagging_freq': 7, 'min_split_gain': 0.8687646493743207}. Best is trial 112 with value: 0.778045428766346.
# [I 2026-03-13 22:19:38,552] Trial 136 finished with value: 0.7648270017897255 and parameters: {'boosting_type': 'dart', 'n_estimators': 1429, 'learning_rate': 0.012504020150962103, 'max_depth': 7, 'num_leaves': 203, 'lambda_l1': 0.001085647765058395, 'lambda_l2': 0.2239419409503531, 'min_child_samples': 11, 'feature_fraction': 0.8443444760273271, 'bagging_fraction': 0.8156478709489929, 'bagging_freq': 7, 'min_split_gain': 0.9085685474180413}. Best is trial 112 with value: 0.778045428766346.
# [I 2026-03-13 22:19:50,312] Trial 137 finished with value: 0.7593377338625293 and parameters: {'boosting_type': 'dart', 'n_estimators': 980, 'learning_rate': 0.01885026931558724, 'max_depth': 8, 'num_leaves': 187, 'lambda_l1': 0.005416060898662198, 'lambda_l2': 0.0005358676216077102, 'min_child_samples': 7, 'feature_fraction': 0.8704557153074132, 'bagging_fraction': 0.8339676552983271, 'bagging_freq': 7, 'min_split_gain': 0.9320072931079536}. Best is trial 112 with value: 0.778045428766346.
# [I 2026-03-13 22:19:53,481] Trial 138 finished with value: 0.7681625145331762 and parameters: {'boosting_type': 'dart', 'n_estimators': 466, 'learning_rate': 0.09693584775716291, 'max_depth': 5, 'num_leaves': 182, 'lambda_l1': 0.0017252493391000775, 'lambda_l2': 1.2816603283562251, 'min_child_samples': 18, 'feature_fraction': 0.7984011750117593, 'bagging_fraction': 0.8579023406880887, 'bagging_freq': 7, 'min_split_gain': 0.9825991342205894}. Best is trial 112 with value: 0.778045428766346.
# [I 2026-03-13 22:20:00,292] Trial 139 finished with value: 0.7610353932319388 and parameters: {'boosting_type': 'dart', 'n_estimators': 646, 'learning_rate': 0.025307866980516028, 'max_depth': 4, 'num_leaves': 199, 'lambda_l1': 0.00034917526533463926, 'lambda_l2': 0.9133104517070251, 'min_child_samples': 13, 'feature_fraction': 0.8579326267665108, 'bagging_fraction': 0.9535151321464296, 'bagging_freq': 6, 'min_split_gain': 0.8168734797228975}. Best is trial 112 with value: 0.778045428766346.
# [I 2026-03-13 22:20:15,350] Trial 140 finished with value: 0.7716295208899604 and parameters: {'boosting_type': 'dart', 'n_estimators': 1331, 'learning_rate': 0.02118373877208113, 'max_depth': 3, 'num_leaves': 206, 'lambda_l1': 0.036428205046231274, 'lambda_l2': 0.3596618934997121, 'min_child_samples': 23, 'feature_fraction': 0.8199562247097613, 'bagging_fraction': 0.9200646046243969, 'bagging_freq': 7, 'min_split_gain': 0.8832847354284894}. Best is trial 112 with value: 0.778045428766346.
# [I 2026-03-13 22:20:28,921] Trial 141 finished with value: 0.7729632929354252 and parameters: {'boosting_type': 'dart', 'n_estimators': 1303, 'learning_rate': 0.020888902553424637, 'max_depth': 3, 'num_leaves': 193, 'lambda_l1': 0.0651641345569459, 'lambda_l2': 0.4644263202552791, 'min_child_samples': 23, 'feature_fraction': 0.8167061913796227, 'bagging_fraction': 0.9232569775761182, 'bagging_freq': 7, 'min_split_gain': 0.8925556554786382}. Best is trial 112 with value: 0.778045428766346.
# [I 2026-03-13 22:20:42,976] Trial 142 finished with value: 0.774473676137537 and parameters: {'boosting_type': 'dart', 'n_estimators': 1323, 'learning_rate': 0.022764672002883065, 'max_depth': 3, 'num_leaves': 193, 'lambda_l1': 0.04923885694050664, 'lambda_l2': 0.10999899940542236, 'min_child_samples': 24, 'feature_fraction': 0.8323319440667604, 'bagging_fraction': 0.932817566654512, 'bagging_freq': 7, 'min_split_gain': 0.850161965522029}. Best is trial 112 with value: 0.778045428766346.
# [I 2026-03-13 22:20:54,557] Trial 143 finished with value: 0.7734749673279872 and parameters: {'boosting_type': 'dart', 'n_estimators': 1299, 'learning_rate': 0.027616955561617404, 'max_depth': 2, 'num_leaves': 172, 'lambda_l1': 0.11811931877309699, 'lambda_l2': 0.18620133292684923, 'min_child_samples': 25, 'feature_fraction': 0.8315832347915249, 'bagging_fraction': 0.9293978894298094, 'bagging_freq': 7, 'min_split_gain': 0.8434012496710876}. Best is trial 112 with value: 0.778045428766346.
# [I 2026-03-13 22:21:06,913] Trial 144 finished with value: 0.7638060642279351 and parameters: {'boosting_type': 'dart', 'n_estimators': 1261, 'learning_rate': 0.029710578648548404, 'max_depth': 2, 'num_leaves': 171, 'lambda_l1': 0.056398584661896366, 'lambda_l2': 0.09604592706359348, 'min_child_samples': 32, 'feature_fraction': 0.8335119067477988, 'bagging_fraction': 0.9322910096170922, 'bagging_freq': 7, 'min_split_gain': 0.8468202079977881}. Best is trial 112 with value: 0.778045428766346.
# [I 2026-03-13 22:21:20,508] Trial 145 finished with value: 0.7630264151753671 and parameters: {'boosting_type': 'dart', 'n_estimators': 1298, 'learning_rate': 0.01942028895339256, 'max_depth': 2, 'num_leaves': 194, 'lambda_l1': 0.32995413404877943, 'lambda_l2': 0.1626588155776326, 'min_child_samples': 26, 'feature_fraction': 0.8078000760850694, 'bagging_fraction': 0.9722370237812522, 'bagging_freq': 7, 'min_split_gain': 0.8072329252554091}. Best is trial 112 with value: 0.778045428766346.
# [I 2026-03-13 22:21:33,256] Trial 146 finished with value: 0.7710068308451562 and parameters: {'boosting_type': 'dart', 'n_estimators': 1189, 'learning_rate': 0.02784956800206444, 'max_depth': 3, 'num_leaves': 188, 'lambda_l1': 0.154957058169299, 'lambda_l2': 0.008975727836291896, 'min_child_samples': 24, 'feature_fraction': 0.827347068926134, 'bagging_fraction': 0.9157952903600868, 'bagging_freq': 7, 'min_split_gain': 0.8395705880455218}. Best is trial 112 with value: 0.778045428766346.
# [I 2026-03-13 22:21:34,053] Trial 147 finished with value: 0.7654364188361421 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 1327, 'learning_rate': 0.1177714881287634, 'max_depth': 2, 'num_leaves': 176, 'lambda_l1': 0.06947661112401073, 'lambda_l2': 0.10981392881274771, 'min_child_samples': 29, 'feature_fraction': 0.789543915713965, 'bagging_fraction': 0.9822598484540208, 'bagging_freq': 7, 'min_split_gain': 0.8652114395250335}. Best is trial 112 with value: 0.778045428766346.
# [I 2026-03-13 22:21:45,500] Trial 148 finished with value: 0.7603975859044994 and parameters: {'boosting_type': 'dart', 'n_estimators': 1246, 'learning_rate': 0.035205810366860664, 'max_depth': 3, 'num_leaves': 194, 'lambda_l1': 0.15566400914811845, 'lambda_l2': 0.2173575266603281, 'min_child_samples': 20, 'feature_fraction': 0.8142118376678692, 'bagging_fraction': 0.9085067278659541, 'bagging_freq': 7, 'min_split_gain': 0.8255653466340399}. Best is trial 112 with value: 0.778045428766346.
# [I 2026-03-13 22:21:59,918] Trial 149 finished with value: 0.7653457063108324 and parameters: {'boosting_type': 'dart', 'n_estimators': 1290, 'learning_rate': 0.008770128692378644, 'max_depth': 3, 'num_leaves': 190, 'lambda_l1': 0.02661214395436751, 'lambda_l2': 0.0519135697133973, 'min_child_samples': 22, 'feature_fraction': 0.8430418874324814, 'bagging_fraction': 0.952913748309735, 'bagging_freq': 7, 'min_split_gain': 0.7681418530619664}. Best is trial 112 with value: 0.778045428766346.
# Best Score: 0.778045428766346

# %% [markdown]
# ## Train model with best parameters and evaluate on test set

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import lightgbm as lgb

# Train model with best parameters and evaluate on test set
best_clf = lgb.LGBMClassifier(
        **study.best_params
)
best_clf.fit(X_train_r, y_train_r)
pred_r = best_clf.predict(X_test_r).ravel()

print("=== Baseline Classification on Random Split ===")
eval_classification(y_test_r, pred_r, name="RandomSplit")

print("\nClassification report (RandomSplit):")
print(classification_report(y_test_r, pred_r, digits=4))

cm_r = confusion_matrix(y_test_r, pred_r, labels=sorted(y_train_r.unique()))
cm_r_df = pd.DataFrame(cm_r, index=sorted(y_train_r.unique()), columns=sorted(y_train_r.unique()))
cm_r_df.to_csv("optuna_baseline_cm_random_base.csv", encoding="utf-8-sig")
print("Saved: optuna_baseline_cm_random_base.csv")

save_preds_csv(X_test_r, y_test_r.values, pred_r, "optuna_baseline_preds_random_cls_base.csv")

# Vẽ Confusion Matrix
plt.figure(figsize=(10,8))
sns.heatmap(confusion_matrix(y_test_r, pred_r), annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.7754833126847169, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7754833126847169
# [LightGBM] [Warning] lambda_l1 is set=0.00029664771707520096, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.00029664771707520096
# [LightGBM] [Warning] lambda_l2 is set=0.3007349300733531, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.3007349300733531
# [LightGBM] [Warning] bagging_fraction is set=0.8530097133359917, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8530097133359917
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] feature_fraction is set=0.7754833126847169, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7754833126847169
# [LightGBM] [Warning] lambda_l1 is set=0.00029664771707520096, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.00029664771707520096
# [LightGBM] [Warning] lambda_l2 is set=0.3007349300733531, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.3007349300733531
# [LightGBM] [Warning] bagging_fraction is set=0.8530097133359917, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8530097133359917
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000115 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1055
# [LightGBM] [Info] Number of data points in the train set: 1310, number of used features: 7
# [LightGBM] [Info] Start training from score -4.086740
# [LightGBM] [Info] Start training from score -2.689146
# [LightGBM] [Info] Start training from score -3.999729
# [LightGBM] [Info] Start training from score -2.623906
# [LightGBM] [Info] Start training from score -2.666923
# [LightGBM] [Info] Start training from score -3.919686
# [LightGBM] [Info] Start training from score -2.623906
# [LightGBM] [Info] Start training from score -1.546571
# [LightGBM] [Info] Start training from score -4.042288
# [LightGBM] [Info] Start training from score -1.957427
# [LightGBM] [Info] Start training from score -1.234983
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] feature_fraction is set=0.7754833126847169, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7754833126847169
# [LightGBM] [Warning] lambda_l1 is set=0.00029664771707520096, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.00029664771707520096
# [LightGBM] [Warning] lambda_l2 is set=0.3007349300733531, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.3007349300733531
# [LightGBM] [Warning] bagging_fraction is set=0.8530097133359917, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8530097133359917
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# === Baseline Classification on Random Split ===
# RandomSplit Accuracy: 0.7808 | F1-macro: 0.7926 | F1-weighted: 0.7654
#
# Classification report (RandomSplit):
#               precision    recall  f1-score   support
#
#            A     1.0000    1.0000    1.0000         4
#            B     1.0000    1.0000    1.0000        15
#            C     1.0000    1.0000    1.0000         2
#            D     0.7500    1.0000    0.8571         9
#            E     1.0000    0.7692    0.8696        13
#            G     0.8182    1.0000    0.9000         9
#            H     0.6486    0.7273    0.6857        33
#            I     0.3333    0.3333    0.3333         3
#            J     0.5833    0.3043    0.4000        23
#            K     0.8250    0.9429    0.8800        35
#
#     accuracy                         0.7808       146
#    macro avg     0.7958    0.8077    0.7926       146
# weighted avg     0.7727    0.7808    0.7654       146
#
# Saved: optuna_baseline_cm_random_base.csv
# Saved: optuna_baseline_preds_random_cls_base.csv
