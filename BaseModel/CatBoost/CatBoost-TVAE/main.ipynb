# %%
import warnings

from catboost import CatBoostClassifier
import pandas as pd
import numpy as np
import json, optuna, os

warnings.filterwarnings("ignore")

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix
from sklearn.model_selection import StratifiedKFold

def eval_classification(y_true, y_pred, name=""):
    acc = accuracy_score(y_true, y_pred)
    f1_macro = f1_score(y_true, y_pred, average="macro")
    f1_weighted = f1_score(y_true, y_pred, average="weighted")
    print(f"{name} Accuracy: {acc:.4f} | F1-macro: {f1_macro:.4f} | F1-weighted: {f1_weighted:.4f}")
    return acc, f1_macro, f1_weighted

def save_preds_csv(X_test, y_true, y_pred, filename):
    out = X_test.copy()
    out["y_true"] = y_true
    out["y_pred"] = y_pred
    out.to_csv(filename, index=False, encoding="utf-8-sig")
    print(f"Saved: {filename}")

def derive_groups_from_train(train_df, k_baseline_dict, min_group_size=2):
    """
    Returns: type_to_group dict, groups dict
    Uses only train_df to avoid test leakage.
    Phân loại các 'type' thành near/mid/far dựa trên trung bình độ lệch tuyệt đối (abs_diff)
    """
    df_temp = train_df.copy()
    df_temp["k_eff_expected"] = df_temp["load"].map(k_baseline_dict)
    if df_temp["k_eff_expected"].isnull().any():
        known_loads = np.array(list(k_baseline_dict.keys()))
        for idx, row in df_temp[df_temp["k_eff_expected"].isnull()].iterrows():
            closest_load = known_loads[np.abs(known_loads - row["load"]).argmin()]
            df_temp.loc[idx, "k_eff_expected"] = k_baseline_dict[closest_load]     
    df_temp["abs_diff"] = (df_temp["efficiency"] - df_temp["k_eff_expected"]).abs()
    type_stats = (
        df_temp.groupby("type")["abs_diff"]
        .agg(n="count", mean="mean")
        .sort_values("mean")
        .reset_index()
    )
    types = type_stats["type"].tolist()
    x = type_stats["mean"].to_numpy()
    n = len(x)
    # Prefix sums for O(1) segment SSE
    S1 = np.concatenate([[0.0], np.cumsum(x)])
    S2 = np.concatenate([[0.0], np.cumsum(x * x)])
    def seg_sse(i, j):
        m = j - i + 1
        sum1 = S1[j + 1] - S1[i]
        sum2 = S2[j + 1] - S2[i]
        mu = sum1 / m
        return sum2 - 2 * mu * sum1 + m * mu * mu

    K = 3
    INF = 1e18
    dp = np.full((K + 1, n + 1), INF)
    cut = np.full((K + 1, n + 1), -1, dtype=int)

    dp[0, 0] = 0.0
    for k in range(1, K + 1):
        for t in range(1, n + 1):
            p_min = (k - 1) * min_group_size
            p_max = t - min_group_size
            if p_max < p_min:
                continue
            best_cost, best_p = INF, -1
            for p in range(p_min, p_max + 1):
                cost = dp[k - 1, p] + seg_sse(p, t - 1)
                if cost < best_cost:
                    best_cost, best_p = cost, p
            dp[k, t] = best_cost
            cut[k, t] = best_p

    if np.isinf(dp[K, n]):
        raise RuntimeError("No valid split found. Try min_group_size=1 or check types count.")
    bounds = []
    t = n
    for k in range(K, 0, -1):
        p = cut[k, t]
        bounds.append((p, t))
        t = p
    bounds.reverse()
    group_names = ["near", "mid", "far"] 
    groups = {}
    for name, (a, b) in zip(group_names, bounds):
        groups[name] = types[a:b]

    type_to_group = {t: g for g, ts in groups.items() for t in ts}
    return type_to_group, groups, type_stats

def catboost_objective(trial):
    params = {
        "iterations": trial.suggest_int("iterations", 600, 1400, step=200),
        "depth": trial.suggest_int("depth", 4, 8), 
        "learning_rate": trial.suggest_float("learning_rate", 0.02, 0.15, log=True),
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1.0, 20.0, log=True),
        "random_strength": trial.suggest_float("random_strength", 0.5, 3.0),
        "bagging_temperature": trial.suggest_float("bagging_temperature", 0.0, 1.0),
        "auto_class_weights": "Balanced",
        "loss_function": "MultiClass",
        "random_seed": 42,
        "verbose": False,
    }
    skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
    f1s = []
    X = X_train_r
    y = y_train_r
    for tr_idx, va_idx in skf.split(X, y):
        X_tr, X_va = X.iloc[tr_idx], X.iloc[va_idx]
        y_tr, y_va = y.iloc[tr_idx], y.iloc[va_idx]
        model = CatBoostClassifier(**params)
        pipe_cv = Pipeline([
            ("scaler", StandardScaler()),
            ("clf", model),
        ])
        pipe_cv.fit(X_tr, y_tr)
        pred = pipe_cv.predict(X_va).ravel()
        f1s.append(f1_score(y_va, pred, average="macro"))

    return float(np.mean(f1s))

# ----- Load your saved split files -----
train_random = pd.read_csv("C:\\Users\\NFU_Power_Lab\\Desktop\\DAT_ResearchArea\\BestAwardAI2026\\GenerativeModel\\TAVEGenData\\wpt_train_random_aug_tvae.csv")
test_random  = pd.read_csv("C:\\Users\\NFU_Power_Lab\\Desktop\\DAT_ResearchArea\\BestAwardAI2026\\random-split\\wpt_test_random.csv")
catboost_json_path = r"C:\Users\NFU_Power_Lab\Desktop\DAT_ResearchArea\BestAwardAI2026\BaseModel\CatBoost\CatBoost-TVAE\catboost-tvae.json"

# Sanity check expected columns
expected_cols = {"type", "load", "efficiency"}
for name, d in [("train_random", train_random), ("test_random", test_random)]:
    missing = expected_cols - set(d.columns)
    if missing:
        raise ValueError(f"{name} is missing columns: {missing}")

# Make sure numeric columns are numeric
for d in [train_random, test_random]:
    d["load"] = pd.to_numeric(d["load"], errors="coerce")
    d["efficiency"] = pd.to_numeric(d["efficiency"], errors="coerce")
    d["type"] = d["type"].astype(str)
    d.dropna(subset=["type", "load", "efficiency"], inplace=True)

# Features / target
FEATURES = ["load", "efficiency"]
TARGET = "type"

# =========================
def add_advanced_features(df, k_baseline_dict, type_to_group_dict):
    df = df.copy()
    df["k_eff_expected"] = df["load"].map(k_baseline_dict)
    if df["k_eff_expected"].isnull().any():
        known_loads = np.array(list(k_baseline_dict.keys()))
        for idx, row in df[df["k_eff_expected"].isnull()].iterrows():
            closest_load = known_loads[np.abs(known_loads - row["load"]).argmin()]
            df.loc[idx, "k_eff_expected"] = k_baseline_dict[closest_load]  
    # 2. Độ lệch (Difference) và Tỷ lệ (Ratio)
    df["eff_diff"] = df["efficiency"] - df["k_eff_expected"]
    df["eff_ratio"] = df["efficiency"] / df["k_eff_expected"]
    # 3. Ước tính tổn hao công suất (Power Loss Proxy)
    # P_loss = Load * (1 / (Efficiency / 100) - 1)
    df["p_loss"] = df["load"] * (1 / (df["efficiency"] / 100.0) - 1)
    # Tổn hao công suất của Class K
    df["k_p_loss"] = df["load"] * (1 / (df["k_eff_expected"] / 100.0) - 1)
    # Độ lệch suy hao do vật thể lạ gây ra
    df["p_loss_diff"] = df["p_loss"] - df["k_p_loss"]

    df["dist_zone_name"] = df["type"].map(type_to_group_dict).fillna("far")
    # Mã hóa thành số
    zone_mapping = {"near": 1, "mid": 2, "far": 3}
    df["dist_zone"] = df["dist_zone_name"].map(zone_mapping)
    # 4. Phân vùng Dải tải (Load Zone)
    # Giả sử dải tải từ 0.5 đến 3.0, chia làm 3 vùng: Nhẹ (1), Vừa (2), Nặng (3)
    df['load_zone'] = pd.cut(df['load'], bins=3, labels=[1, 2, 3]).astype(float)
    return df

k_baseline_train_r = train_random[train_random["type"] == "K"].groupby("load")["efficiency"].mean().to_dict()
type_to_group, groups_dict, stats = derive_groups_from_train(train_random, k_baseline_train_r)
print("Results of grouping the Types:", groups_dict)

train_random_fe = add_advanced_features(train_random, k_baseline_train_r, type_to_group)
test_random_fe = add_advanced_features(test_random, k_baseline_train_r, type_to_group)

FEATURES_NEW = [
    "load", "efficiency", 
    "eff_diff", "eff_ratio", 
    "p_loss_diff", "load_zone", "dist_zone"
]
# =========================
X_train_r = train_random_fe[FEATURES_NEW]
y_train_r = train_random_fe[TARGET]
X_test_r  = test_random_fe[FEATURES_NEW]
y_test_r  = test_random_fe[TARGET]

# ========================
# Choose a baseline classifier
# =========================
OPTUNA_TRIALS = 100
study = optuna.create_study(direction="maximize")
study.optimize(catboost_objective, n_trials=OPTUNA_TRIALS)

print("\n=== Optuna done for CatBoost ===")
print("Best macro-F1 (CV):", study.best_value)
print("Best params:", study.best_params)

best_params = study.best_params
os.makedirs(os.path.dirname(catboost_json_path), exist_ok=True)

with open(catboost_json_path, 'w', encoding='utf-8') as f:
    json.dump(best_params, f, indent=4)
print(f"Saving optuna parameters: {catboost_json_path}")

clf = CatBoostClassifier(
    iterations=best_params.get("iterations", 1000),
    depth=best_params.get("depth", 6),
    learning_rate=best_params.get("learning_rate", 0.05),
    l2_leaf_reg=best_params.get("l2_leaf_reg", 3.0),
    random_strength=best_params.get("random_strength", 1.0),
    bagging_temperature=best_params.get("bagging_temperature", 0.0),
    auto_class_weights='Balanced',
    loss_function='MultiClass',
    random_seed=42,
    verbose=False
)

# Pipeline: scale numeric features (safe for most models)
pipe = Pipeline([
    ("scaler", StandardScaler()),
    ("clf", clf),
])

# =========================
# Train/Eval on Random Split
# =========================
pipe.fit(X_train_r, y_train_r)
pred_r = pipe.predict(X_test_r).ravel()

print("=== Baseline Classification on Random Split ===")
eval_classification(y_test_r, pred_r, name="RandomSplit")

print("\nClassification report (RandomSplit):")
print(classification_report(y_test_r, pred_r, digits=4))

cm_r = confusion_matrix(y_test_r, pred_r, labels=sorted(y_train_r.unique()))
cm_r_df = pd.DataFrame(cm_r, index=sorted(y_train_r.unique()), columns=sorted(y_train_r.unique()))
cm_r_df.to_csv("baseline_cm_random_tvae.csv", encoding="utf-8-sig")
print("Saved: baseline_cm_random_tvae.csv")

save_preds_csv(X_test_r, y_test_r.values, pred_r, "baseline_preds_random_cls_tvae.csv")
# Out:
# [I 2026-03-12 21:16:59,345] A new study created in memory with name: no-name-9766c76a-aff2-4d6e-89ea-4f15542395c1
# Results of grouping the Types: {'near': ['K', 'H', 'J'], 'mid': ['G', 'I', 'F', 'E', 'D', 'B'], 'far': ['C', 'A']}
# [I 2026-03-12 21:19:29,529] Trial 0 finished with value: 0.6993307606923561 and parameters: {'iterations': 1200, 'depth': 8, 'learning_rate': 0.02021812455937631, 'l2_leaf_reg': 13.602909687081059, 'random_strength': 0.9406523467101031, 'bagging_temperature': 0.7119150174199523}. Best is trial 0 with value: 0.6993307606923561.
# [I 2026-03-12 21:19:37,395] Trial 1 finished with value: 0.6981587292414563 and parameters: {'iterations': 600, 'depth': 4, 'learning_rate': 0.0782308423104649, 'l2_leaf_reg': 12.29775583771823, 'random_strength': 1.9961397104641883, 'bagging_temperature': 0.5554896922758442}. Best is trial 0 with value: 0.6993307606923561.
# [I 2026-03-12 21:20:09,684] Trial 2 finished with value: 0.6964786206961332 and parameters: {'iterations': 1400, 'depth': 5, 'learning_rate': 0.03107453385841126, 'l2_leaf_reg': 3.8884306259194976, 'random_strength': 1.063776423691519, 'bagging_temperature': 0.655275216803411}. Best is trial 0 with value: 0.6993307606923561.
# [I 2026-03-12 21:20:59,667] Trial 3 finished with value: 0.6741827999350019 and parameters: {'iterations': 1400, 'depth': 6, 'learning_rate': 0.13194786892550509, 'l2_leaf_reg': 11.850900724046355, 'random_strength': 1.094428752420635, 'bagging_temperature': 0.9660239093183846}. Best is trial 0 with value: 0.6993307606923561.
# [I 2026-03-12 21:22:11,344] Trial 4 finished with value: 0.702231605066888 and parameters: {'iterations': 600, 'depth': 8, 'learning_rate': 0.022879308612848294, 'l2_leaf_reg': 7.063017840533754, 'random_strength': 0.6261461071575282, 'bagging_temperature': 0.8252422138274504}. Best is trial 4 with value: 0.702231605066888.
# [I 2026-03-12 21:23:24,663] Trial 5 finished with value: 0.6613355383232592 and parameters: {'iterations': 600, 'depth': 8, 'learning_rate': 0.13081935677339057, 'l2_leaf_reg': 1.0283420411274908, 'random_strength': 1.1081242776077782, 'bagging_temperature': 0.39012056690378616}. Best is trial 4 with value: 0.702231605066888.
# [I 2026-03-12 21:23:37,232] Trial 6 finished with value: 0.6948222525588438 and parameters: {'iterations': 1200, 'depth': 4, 'learning_rate': 0.1266201195657207, 'l2_leaf_reg': 18.106640998921517, 'random_strength': 2.5367079828037267, 'bagging_temperature': 0.573257529186718}. Best is trial 4 with value: 0.702231605066888.
# [I 2026-03-12 21:24:11,507] Trial 7 finished with value: 0.6788098238944974 and parameters: {'iterations': 1000, 'depth': 6, 'learning_rate': 0.1481058316923307, 'l2_leaf_reg': 14.400788646559175, 'random_strength': 2.9544072141233024, 'bagging_temperature': 0.3254265543829764}. Best is trial 4 with value: 0.702231605066888.
# [I 2026-03-12 21:24:24,494] Trial 8 finished with value: 0.6645374981058912 and parameters: {'iterations': 1200, 'depth': 4, 'learning_rate': 0.133279227883583, 'l2_leaf_reg': 2.7420562410975418, 'random_strength': 1.0097956686494842, 'bagging_temperature': 0.3734615660854562}. Best is trial 4 with value: 0.702231605066888.
# [I 2026-03-12 21:26:20,236] Trial 9 finished with value: 0.6866107962917841 and parameters: {'iterations': 1000, 'depth': 8, 'learning_rate': 0.10637194015595676, 'l2_leaf_reg': 14.324241543892064, 'random_strength': 2.0663908515637064, 'bagging_temperature': 0.38923914040233243}. Best is trial 4 with value: 0.702231605066888.
# [I 2026-03-12 21:27:10,539] Trial 10 finished with value: 0.6948291232200813 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.038556550972988476, 'l2_leaf_reg': 6.944133791844952, 'random_strength': 0.577018956719652, 'bagging_temperature': 0.09252651366774434}. Best is trial 4 with value: 0.702231605066888.
# [I 2026-03-12 21:28:01,029] Trial 11 finished with value: 0.7013521095012316 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.02103746307079532, 'l2_leaf_reg': 7.050424427344399, 'random_strength': 0.5514896939033229, 'bagging_temperature': 0.9003088843571935}. Best is trial 4 with value: 0.702231605066888.
# [I 2026-03-12 21:28:49,700] Trial 12 finished with value: 0.7017619937502136 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.020045658282954733, 'l2_leaf_reg': 6.414701699571637, 'random_strength': 0.5311763671076783, 'bagging_temperature': 0.9915706601675301}. Best is trial 4 with value: 0.702231605066888.
# [I 2026-03-12 21:29:44,045] Trial 13 finished with value: 0.695957444998712 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.0323164821015611, 'l2_leaf_reg': 6.231005098726424, 'random_strength': 1.5646195098590938, 'bagging_temperature': 0.8157910545493898}. Best is trial 4 with value: 0.702231605066888.
# [I 2026-03-12 21:30:26,106] Trial 14 finished with value: 0.6864758936240247 and parameters: {'iterations': 600, 'depth': 7, 'learning_rate': 0.057016645099532325, 'l2_leaf_reg': 2.6375091986522246, 'random_strength': 1.4900236902382011, 'bagging_temperature': 0.8267140159307713}. Best is trial 4 with value: 0.702231605066888.
# [I 2026-03-12 21:32:03,009] Trial 15 finished with value: 0.6960566875407567 and parameters: {'iterations': 800, 'depth': 8, 'learning_rate': 0.025938023244743567, 'l2_leaf_reg': 4.936490125777546, 'random_strength': 0.5139330772047797, 'bagging_temperature': 0.9339465475244982}. Best is trial 4 with value: 0.702231605066888.
# [I 2026-03-12 21:32:38,950] Trial 16 finished with value: 0.6963187522781248 and parameters: {'iterations': 600, 'depth': 7, 'learning_rate': 0.04526239422958122, 'l2_leaf_reg': 3.2964057140652474, 'random_strength': 0.7815365225316526, 'bagging_temperature': 0.7592534513576465}. Best is trial 4 with value: 0.702231605066888.
# [I 2026-03-12 21:33:08,280] Trial 17 finished with value: 0.6989535232292997 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.025060252613877468, 'l2_leaf_reg': 9.018901983850036, 'random_strength': 1.3556888950465082, 'bagging_temperature': 0.9665083463407559}. Best is trial 4 with value: 0.702231605066888.
# [I 2026-03-12 21:33:28,070] Trial 18 finished with value: 0.6773279644973916 and parameters: {'iterations': 1000, 'depth': 5, 'learning_rate': 0.05263816044960089, 'l2_leaf_reg': 1.9336736188745782, 'random_strength': 1.8949102511763967, 'bagging_temperature': 0.005528432912851766}. Best is trial 4 with value: 0.702231605066888.
# [I 2026-03-12 21:34:31,669] Trial 19 finished with value: 0.6909282458057339 and parameters: {'iterations': 600, 'depth': 8, 'learning_rate': 0.026376291550807035, 'l2_leaf_reg': 5.197637236893912, 'random_strength': 2.3448010058560516, 'bagging_temperature': 0.8315440612217588}. Best is trial 4 with value: 0.702231605066888.
# [I 2026-03-12 21:35:32,133] Trial 20 finished with value: 0.7006030172833563 and parameters: {'iterations': 1000, 'depth': 7, 'learning_rate': 0.034909287642736674, 'l2_leaf_reg': 9.17245437249959, 'random_strength': 0.7807953618016492, 'bagging_temperature': 0.9997831528969834}. Best is trial 4 with value: 0.702231605066888.
# [I 2026-03-12 21:36:25,732] Trial 21 finished with value: 0.7027669311963147 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.020345149588951214, 'l2_leaf_reg': 7.724609369923631, 'random_strength': 0.5477574470964861, 'bagging_temperature': 0.8734478112019959}. Best is trial 21 with value: 0.7027669311963147.
# [I 2026-03-12 21:37:13,497] Trial 22 finished with value: 0.7048900447175476 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.023061193576424728, 'l2_leaf_reg': 9.14446306197259, 'random_strength': 0.7918778828614244, 'bagging_temperature': 0.6783596703010635}. Best is trial 22 with value: 0.7048900447175476.
# [I 2026-03-12 21:38:18,222] Trial 23 finished with value: 0.7028468770929326 and parameters: {'iterations': 600, 'depth': 8, 'learning_rate': 0.02409254885700121, 'l2_leaf_reg': 9.337727742613435, 'random_strength': 0.7866874338889087, 'bagging_temperature': 0.6479824250893996}. Best is trial 22 with value: 0.7048900447175476.
# [I 2026-03-12 21:38:44,233] Trial 24 finished with value: 0.7061289452966845 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.030249933176436795, 'l2_leaf_reg': 9.8796911308183, 'random_strength': 1.2266654662121603, 'bagging_temperature': 0.6362395986168734}. Best is trial 24 with value: 0.7061289452966845.
# [I 2026-03-12 21:38:54,451] Trial 25 finished with value: 0.6996198412070865 and parameters: {'iterations': 600, 'depth': 5, 'learning_rate': 0.02925360589444918, 'l2_leaf_reg': 9.645952803904045, 'random_strength': 1.2593378872956458, 'bagging_temperature': 0.6217871436531425}. Best is trial 24 with value: 0.7061289452966845.
# [I 2026-03-12 21:39:22,377] Trial 26 finished with value: 0.707257933442801 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.039491164579613255, 'l2_leaf_reg': 19.64533078910506, 'random_strength': 0.8185242279501683, 'bagging_temperature': 0.4623897879739619}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:40:04,388] Trial 27 finished with value: 0.6975896368793842 and parameters: {'iterations': 1000, 'depth': 6, 'learning_rate': 0.04087694415512083, 'l2_leaf_reg': 18.851929451524445, 'random_strength': 1.6964992823565026, 'bagging_temperature': 0.46852422587060916}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:40:20,727] Trial 28 finished with value: 0.7029699764157553 and parameters: {'iterations': 800, 'depth': 5, 'learning_rate': 0.049613745849145206, 'l2_leaf_reg': 17.525129297916163, 'random_strength': 1.2941810363323356, 'bagging_temperature': 0.25420857323158996}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:40:56,748] Trial 29 finished with value: 0.6990905716575777 and parameters: {'iterations': 1000, 'depth': 6, 'learning_rate': 0.06765735736605621, 'l2_leaf_reg': 12.176092039093781, 'random_strength': 0.8767714368067081, 'bagging_temperature': 0.7144129051341173}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:41:24,396] Trial 30 finished with value: 0.7060880563239622 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.03983251256003362, 'l2_leaf_reg': 15.041296451638026, 'random_strength': 1.2242367397843932, 'bagging_temperature': 0.5370217592316585}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:41:51,321] Trial 31 finished with value: 0.706991833851668 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.038580529051072815, 'l2_leaf_reg': 15.374069680381849, 'random_strength': 1.2386727757072278, 'bagging_temperature': 0.48168625118198394}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:42:18,241] Trial 32 finished with value: 0.705302594617149 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.037571248365114066, 'l2_leaf_reg': 15.420469637771518, 'random_strength': 1.2163439435579406, 'bagging_temperature': 0.5099965153566544}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:42:51,773] Trial 33 finished with value: 0.6997719151641347 and parameters: {'iterations': 1000, 'depth': 6, 'learning_rate': 0.043873761459938494, 'l2_leaf_reg': 11.396976887674153, 'random_strength': 1.485344845329753, 'bagging_temperature': 0.4590536624104954}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:43:05,231] Trial 34 finished with value: 0.6939770606845065 and parameters: {'iterations': 800, 'depth': 5, 'learning_rate': 0.060780006955679, 'l2_leaf_reg': 19.283465524166303, 'random_strength': 0.960493769258738, 'bagging_temperature': 0.557758492375724}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:43:31,936] Trial 35 finished with value: 0.7032811378797096 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.029527615310737283, 'l2_leaf_reg': 15.586239059764525, 'random_strength': 1.154813998975346, 'bagging_temperature': 0.27683155785113234}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:43:48,641] Trial 36 finished with value: 0.6964325576573008 and parameters: {'iterations': 1000, 'depth': 5, 'learning_rate': 0.032784919666799445, 'l2_leaf_reg': 11.253362903882461, 'random_strength': 1.4045857066576455, 'bagging_temperature': 0.500443148456817}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:44:32,339] Trial 37 finished with value: 0.6932901665423099 and parameters: {'iterations': 1400, 'depth': 6, 'learning_rate': 0.04866380431667368, 'l2_leaf_reg': 12.989332119956355, 'random_strength': 1.6389018643145215, 'bagging_temperature': 0.5948689984881489}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:44:50,787] Trial 38 finished with value: 0.7004883959637266 and parameters: {'iterations': 600, 'depth': 6, 'learning_rate': 0.03660063226097252, 'l2_leaf_reg': 16.517000024346256, 'random_strength': 1.121799124828697, 'bagging_temperature': 0.4544045038514579}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:45:28,019] Trial 39 finished with value: 0.698796025637639 and parameters: {'iterations': 1200, 'depth': 6, 'learning_rate': 0.0863040032314025, 'l2_leaf_reg': 19.965595276865937, 'random_strength': 1.8126960487178168, 'bagging_temperature': 0.21972677739103375}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:45:41,571] Trial 40 finished with value: 0.6986709435585549 and parameters: {'iterations': 800, 'depth': 5, 'learning_rate': 0.043393227475771665, 'l2_leaf_reg': 13.679304437979102, 'random_strength': 0.8794051673915366, 'bagging_temperature': 0.5381838555881382}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:46:06,170] Trial 41 finished with value: 0.7072439282874764 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.03896082809877275, 'l2_leaf_reg': 16.412128005384517, 'random_strength': 1.2035090238759438, 'bagging_temperature': 0.5101076913657299}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:46:30,746] Trial 42 finished with value: 0.7039982107616342 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.027965222888008002, 'l2_leaf_reg': 10.793961984381484, 'random_strength': 1.0523998069364557, 'bagging_temperature': 0.43533774613053894}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:46:55,260] Trial 43 finished with value: 0.7012474326763262 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.03459737038079353, 'l2_leaf_reg': 16.17340871075264, 'random_strength': 1.384141961647814, 'bagging_temperature': 0.34424809933693545}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:47:26,507] Trial 44 finished with value: 0.7012139332709765 and parameters: {'iterations': 1000, 'depth': 6, 'learning_rate': 0.03847114173911684, 'l2_leaf_reg': 13.087523020115205, 'random_strength': 0.9822124427692928, 'bagging_temperature': 0.6072896076605794}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:47:36,657] Trial 45 finished with value: 0.6911344319492182 and parameters: {'iterations': 600, 'depth': 5, 'learning_rate': 0.04124192541783916, 'l2_leaf_reg': 1.0081741539348523, 'random_strength': 1.2136938497538758, 'bagging_temperature': 0.42366270041084275}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:48:01,001] Trial 46 finished with value: 0.6986818619239333 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.031227629461795175, 'l2_leaf_reg': 15.18902786783571, 'random_strength': 2.120549200148804, 'bagging_temperature': 0.5366578414338875}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:48:25,893] Trial 47 finished with value: 0.6792294043594245 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.0477247645931236, 'l2_leaf_reg': 1.403147761721054, 'random_strength': 0.7061393712451871, 'bagging_temperature': 0.6730413962985451}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:48:34,903] Trial 48 finished with value: 0.6971915466478479 and parameters: {'iterations': 800, 'depth': 4, 'learning_rate': 0.03308501396593932, 'l2_leaf_reg': 17.423368911854006, 'random_strength': 1.5235072644991705, 'bagging_temperature': 0.3900489810718959}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:48:53,376] Trial 49 finished with value: 0.7040901204842368 and parameters: {'iterations': 600, 'depth': 6, 'learning_rate': 0.06309860105194234, 'l2_leaf_reg': 14.025089976499393, 'random_strength': 2.883407325808637, 'bagging_temperature': 0.7095663277528405}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:49:10,495] Trial 50 finished with value: 0.6941717528544008 and parameters: {'iterations': 1000, 'depth': 5, 'learning_rate': 0.05378759187197244, 'l2_leaf_reg': 7.966635109951666, 'random_strength': 0.6664735482085793, 'bagging_temperature': 0.5734929471756607}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:49:35,179] Trial 51 finished with value: 0.7069116700957913 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.037536552478853034, 'l2_leaf_reg': 15.516843689231106, 'random_strength': 1.1879441382915847, 'bagging_temperature': 0.5003812115609229}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:49:59,840] Trial 52 finished with value: 0.6970247279732563 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.04168294209379057, 'l2_leaf_reg': 10.476883930950759, 'random_strength': 1.0771667734796033, 'bagging_temperature': 0.5061011567418796}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:50:41,939] Trial 53 finished with value: 0.6995478730146939 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.03683484286574976, 'l2_leaf_reg': 12.617263273831867, 'random_strength': 1.3110795327682383, 'bagging_temperature': 0.32851583431716425}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:51:06,512] Trial 54 finished with value: 0.7024812037049252 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.028663671275947534, 'l2_leaf_reg': 17.509538657349857, 'random_strength': 1.1782558032684447, 'bagging_temperature': 0.4755287385607643}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:51:31,213] Trial 55 finished with value: 0.7038722742897704 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.046267832379568614, 'l2_leaf_reg': 19.91184629901577, 'random_strength': 1.4322391982522176, 'bagging_temperature': 0.6374385218990017}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:52:02,734] Trial 56 finished with value: 0.7002182801472863 and parameters: {'iterations': 600, 'depth': 7, 'learning_rate': 0.03973871557472837, 'l2_leaf_reg': 14.481677101835217, 'random_strength': 0.8923108905846162, 'bagging_temperature': 0.7549803509042236}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:52:27,229] Trial 57 finished with value: 0.6934395311295868 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.03386232217786459, 'l2_leaf_reg': 3.847338383183819, 'random_strength': 1.6122233931551202, 'bagging_temperature': 0.40168210785105973}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:52:58,009] Trial 58 finished with value: 0.6991828299126516 and parameters: {'iterations': 1000, 'depth': 6, 'learning_rate': 0.030686389142187274, 'l2_leaf_reg': 8.199162858743886, 'random_strength': 1.0040096467509527, 'bagging_temperature': 0.589299744343504}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:53:39,622] Trial 59 finished with value: 0.6963308272969436 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.02646420972394597, 'l2_leaf_reg': 5.86276923318662, 'random_strength': 1.3129965381112787, 'bagging_temperature': 0.5319584254059092}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:53:49,696] Trial 60 finished with value: 0.7002060663588271 and parameters: {'iterations': 600, 'depth': 5, 'learning_rate': 0.034773264169337, 'l2_leaf_reg': 10.128623704007962, 'random_strength': 1.7614909844058841, 'bagging_temperature': 0.4234247101739336}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:54:14,210] Trial 61 finished with value: 0.7052254404584467 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.03892995213354856, 'l2_leaf_reg': 15.505987872305734, 'random_strength': 1.232760852743159, 'bagging_temperature': 0.5063649306959335}. Best is trial 26 with value: 0.707257933442801.
# [I 2026-03-12 21:54:38,825] Trial 62 finished with value: 0.708279595824506 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.03703082933370238, 'l2_leaf_reg': 17.204853123603637, 'random_strength': 1.1441031432057056, 'bagging_temperature': 0.4947816087347164}. Best is trial 62 with value: 0.708279595824506.
# [I 2026-03-12 21:55:03,536] Trial 63 finished with value: 0.7046403949762086 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.035995665286880835, 'l2_leaf_reg': 17.742654621537476, 'random_strength': 1.088644135531368, 'bagging_temperature': 0.48032808506430047}. Best is trial 62 with value: 0.708279595824506.
# [I 2026-03-12 21:55:28,781] Trial 64 finished with value: 0.6973119499460637 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.04414564350427993, 'l2_leaf_reg': 11.812260543031051, 'random_strength': 0.9184450154909813, 'bagging_temperature': 0.5559880026042813}. Best is trial 62 with value: 0.708279595824506.
# [I 2026-03-12 21:55:53,468] Trial 65 finished with value: 0.7038371090524501 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.050684437911990975, 'l2_leaf_reg': 16.786320260606587, 'random_strength': 1.4532402079072357, 'bagging_temperature': 0.36919038034706353}. Best is trial 62 with value: 0.708279595824506.
# [I 2026-03-12 21:56:24,397] Trial 66 finished with value: 0.6932524533102757 and parameters: {'iterations': 1000, 'depth': 6, 'learning_rate': 0.042133346432040586, 'l2_leaf_reg': 13.701688783020002, 'random_strength': 1.1678440306039803, 'bagging_temperature': 0.6221892492594305}. Best is trial 62 with value: 0.708279595824506.
# [I 2026-03-12 21:57:06,140] Trial 67 finished with value: 0.7075800814156703 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.030904250576114303, 'l2_leaf_reg': 18.191662353638453, 'random_strength': 1.35689791183794, 'bagging_temperature': 0.4392004918573523}. Best is trial 62 with value: 0.708279595824506.
# [I 2026-03-12 21:57:47,833] Trial 68 finished with value: 0.7032690029333885 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.027050503479494573, 'l2_leaf_reg': 17.77184073084016, 'random_strength': 1.3410479033187013, 'bagging_temperature': 0.2834698251768367}. Best is trial 62 with value: 0.708279595824506.
# [I 2026-03-12 21:58:41,614] Trial 69 finished with value: 0.7056467059792544 and parameters: {'iterations': 1000, 'depth': 7, 'learning_rate': 0.030762742465325645, 'l2_leaf_reg': 18.72806413232519, 'random_strength': 1.0006986645103249, 'bagging_temperature': 0.446364141892023}. Best is trial 62 with value: 0.708279595824506.
# [I 2026-03-12 21:59:12,635] Trial 70 finished with value: 0.6939227287030239 and parameters: {'iterations': 600, 'depth': 7, 'learning_rate': 0.02450683432409703, 'l2_leaf_reg': 12.179318048942847, 'random_strength': 1.5536285221146797, 'bagging_temperature': 0.3668673187820351}. Best is trial 62 with value: 0.708279595824506.
# [I 2026-03-12 21:59:37,051] Trial 71 finished with value: 0.7022184567709884 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.03884997117411631, 'l2_leaf_reg': 14.450079632971947, 'random_strength': 1.2850062445267463, 'bagging_temperature': 0.5287749941553938}. Best is trial 62 with value: 0.708279595824506.
# [I 2026-03-12 22:00:01,505] Trial 72 finished with value: 0.7071842998202036 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.03198715527457773, 'l2_leaf_reg': 16.049413124257118, 'random_strength': 0.8291728674729387, 'bagging_temperature': 0.49030127941445983}. Best is trial 62 with value: 0.708279595824506.
# [I 2026-03-12 22:00:25,996] Trial 73 finished with value: 0.699782614681374 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.03137898247436615, 'l2_leaf_reg': 16.457116039890586, 'random_strength': 0.8172405409939052, 'bagging_temperature': 0.4128091819665044}. Best is trial 62 with value: 0.708279595824506.
# [I 2026-03-12 22:00:50,479] Trial 74 finished with value: 0.7035165165689016 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.032867975164953475, 'l2_leaf_reg': 18.757039015666557, 'random_strength': 0.6979682211576543, 'bagging_temperature': 0.4867605983865652}. Best is trial 62 with value: 0.708279595824506.
# [I 2026-03-12 22:02:12,831] Trial 75 finished with value: 0.7050517152283753 and parameters: {'iterations': 800, 'depth': 8, 'learning_rate': 0.03571677263359538, 'l2_leaf_reg': 19.98180974037738, 'random_strength': 1.045875635020342, 'bagging_temperature': 0.5851278765381637}. Best is trial 62 with value: 0.708279595824506.
# [I 2026-03-12 22:02:43,567] Trial 76 finished with value: 0.7050185423380467 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.028915731650506895, 'l2_leaf_reg': 13.117798686422132, 'random_strength': 1.1144726339402462, 'bagging_temperature': 0.4616641313610205}. Best is trial 62 with value: 0.708279595824506.
# [I 2026-03-12 22:03:16,225] Trial 77 finished with value: 0.7060809809075872 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.03736120897182592, 'l2_leaf_reg': 15.991045970364576, 'random_strength': 0.6232543785114801, 'bagging_temperature': 0.2974609916078649}. Best is trial 62 with value: 0.708279595824506.
# [I 2026-03-12 22:03:31,659] Trial 78 finished with value: 0.7030504796953525 and parameters: {'iterations': 800, 'depth': 5, 'learning_rate': 0.021998497706033435, 'l2_leaf_reg': 14.918764681732624, 'random_strength': 0.9489022473426341, 'bagging_temperature': 0.1754151655313959}. Best is trial 62 with value: 0.708279595824506.
# [I 2026-03-12 22:04:29,148] Trial 79 finished with value: 0.6861811751833166 and parameters: {'iterations': 1400, 'depth': 6, 'learning_rate': 0.1144663286079714, 'l2_leaf_reg': 18.384668295372045, 'random_strength': 0.8662072523789371, 'bagging_temperature': 0.5582886546346315}. Best is trial 62 with value: 0.708279595824506.
# [I 2026-03-12 22:05:17,834] Trial 80 finished with value: 0.7052245713110769 and parameters: {'iterations': 1200, 'depth': 6, 'learning_rate': 0.025416440815462436, 'l2_leaf_reg': 11.263603039433514, 'random_strength': 0.7292122266077591, 'bagging_temperature': 0.4397396848778521}. Best is trial 62 with value: 0.708279595824506.
# [I 2026-03-12 22:05:50,621] Trial 81 finished with value: 0.7029221570909022 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.03412636495700045, 'l2_leaf_reg': 16.403959979463526, 'random_strength': 1.2290928783227535, 'bagging_temperature': 0.5143818069957959}. Best is trial 62 with value: 0.708279595824506.
# [I 2026-03-12 22:06:22,894] Trial 82 finished with value: 0.699535339814024 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.045584934148032344, 'l2_leaf_reg': 14.61459651460899, 'random_strength': 1.1492357352809859, 'bagging_temperature': 0.4894791750019703}. Best is trial 62 with value: 0.708279595824506.
# [I 2026-03-12 22:06:53,756] Trial 83 finished with value: 0.7048120508667056 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.03218013820115092, 'l2_leaf_reg': 13.429345347496978, 'random_strength': 1.2618085312420233, 'bagging_temperature': 0.5379733726508601}. Best is trial 62 with value: 0.708279595824506.
# [I 2026-03-12 22:07:19,941] Trial 84 finished with value: 0.7043697354792732 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.040882999251000564, 'l2_leaf_reg': 15.321964241551482, 'random_strength': 1.4061933743779143, 'bagging_temperature': 0.6124312359033832}. Best is trial 62 with value: 0.708279595824506.
# [I 2026-03-12 22:07:46,499] Trial 85 finished with value: 0.7040872645283093 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.030385248635469774, 'l2_leaf_reg': 16.986674610591454, 'random_strength': 1.3576284833451346, 'bagging_temperature': 0.46664351777644564}. Best is trial 62 with value: 0.708279595824506.
# [I 2026-03-12 22:08:39,221] Trial 86 finished with value: 0.70814468905751 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.02753049067883763, 'l2_leaf_reg': 12.295837348214922, 'random_strength': 1.0436770042304429, 'bagging_temperature': 0.40043314148731884}. Best is trial 62 with value: 0.708279595824506.
# [I 2026-03-12 22:09:37,281] Trial 87 finished with value: 0.6961021303935948 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.026804821281962637, 'l2_leaf_reg': 2.4671419158739933, 'random_strength': 0.8385915636990341, 'bagging_temperature': 0.4257316017158801}. Best is trial 62 with value: 0.708279595824506.
# [I 2026-03-12 22:10:46,886] Trial 88 finished with value: 0.708295187219092 and parameters: {'iterations': 1000, 'depth': 7, 'learning_rate': 0.02266261498155453, 'l2_leaf_reg': 12.39767540354609, 'random_strength': 0.9441143359464095, 'bagging_temperature': 0.34482853858774304}. Best is trial 88 with value: 0.708295187219092.
# [I 2026-03-12 22:11:50,446] Trial 89 finished with value: 0.7068770049995843 and parameters: {'iterations': 1000, 'depth': 7, 'learning_rate': 0.02266137287715415, 'l2_leaf_reg': 12.287881593641945, 'random_strength': 1.0313771247182952, 'bagging_temperature': 0.33566565296638445}. Best is trial 88 with value: 0.708295187219092.
# [I 2026-03-12 22:12:54,802] Trial 90 finished with value: 0.71082968142535 and parameters: {'iterations': 1000, 'depth': 7, 'learning_rate': 0.02821711529399273, 'l2_leaf_reg': 18.606731276579183, 'random_strength': 0.7745834572344769, 'bagging_temperature': 0.3535571560876342}. Best is trial 90 with value: 0.71082968142535.
# [I 2026-03-12 22:14:00,909] Trial 91 finished with value: 0.7067641764004886 and parameters: {'iterations': 1000, 'depth': 7, 'learning_rate': 0.024614257933922915, 'l2_leaf_reg': 18.31937405574364, 'random_strength': 0.6144276536878233, 'bagging_temperature': 0.36411754730777235}. Best is trial 90 with value: 0.71082968142535.
# [I 2026-03-12 22:15:08,775] Trial 92 finished with value: 0.7019544906683759 and parameters: {'iterations': 1000, 'depth': 7, 'learning_rate': 0.021427979987968953, 'l2_leaf_reg': 14.171803462052607, 'random_strength': 0.7667642158382404, 'bagging_temperature': 0.3860247116020645}. Best is trial 90 with value: 0.71082968142535.
# [I 2026-03-12 22:16:16,364] Trial 93 finished with value: 0.7070494335159244 and parameters: {'iterations': 1000, 'depth': 7, 'learning_rate': 0.027693741374456633, 'l2_leaf_reg': 16.0836666010838, 'random_strength': 0.9412397974758164, 'bagging_temperature': 0.23508168415443043}. Best is trial 90 with value: 0.71082968142535.
# [I 2026-03-12 22:17:32,828] Trial 94 finished with value: 0.7045447816108122 and parameters: {'iterations': 1200, 'depth': 7, 'learning_rate': 0.023522065414230974, 'l2_leaf_reg': 17.15591886285787, 'random_strength': 0.9276824159629934, 'bagging_temperature': 0.20340940100782567}. Best is trial 90 with value: 0.71082968142535.
# [I 2026-03-12 22:19:27,458] Trial 95 finished with value: 0.7083363951308738 and parameters: {'iterations': 1000, 'depth': 8, 'learning_rate': 0.02813127810699776, 'l2_leaf_reg': 19.76648950467563, 'random_strength': 0.7637359186521551, 'bagging_temperature': 0.30811087707827367}. Best is trial 90 with value: 0.71082968142535.
# [I 2026-03-12 22:21:18,341] Trial 96 finished with value: 0.7114598136738911 and parameters: {'iterations': 1000, 'depth': 8, 'learning_rate': 0.027188282537251893, 'l2_leaf_reg': 19.187046204586384, 'random_strength': 0.8118008797982929, 'bagging_temperature': 0.3054453709851229}. Best is trial 96 with value: 0.7114598136738911.
# [I 2026-03-12 22:23:08,044] Trial 97 finished with value: 0.7082614765929162 and parameters: {'iterations': 1000, 'depth': 8, 'learning_rate': 0.02846958303053403, 'l2_leaf_reg': 18.94554459754013, 'random_strength': 0.740998755675353, 'bagging_temperature': 0.30020094387633395}. Best is trial 96 with value: 0.7114598136738911.
# [I 2026-03-12 22:24:59,198] Trial 98 finished with value: 0.7094312914789686 and parameters: {'iterations': 1000, 'depth': 8, 'learning_rate': 0.02867369935724046, 'l2_leaf_reg': 19.11750857122802, 'random_strength': 0.5173754457523767, 'bagging_temperature': 0.29829124575236565}. Best is trial 96 with value: 0.7114598136738911.
# [I 2026-03-12 22:26:51,362] Trial 99 finished with value: 0.7099261045803051 and parameters: {'iterations': 1000, 'depth': 8, 'learning_rate': 0.02566361195188481, 'l2_leaf_reg': 19.920552179040914, 'random_strength': 0.5031949037729102, 'bagging_temperature': 0.30568951230309815}. Best is trial 96 with value: 0.7114598136738911.
# === Optuna done for CatBoost ===
# Best macro-F1 (CV): 0.7114598136738911
# Best params: {'iterations': 1000, 'depth': 8, 'learning_rate': 0.027188282537251893, 'l2_leaf_reg': 19.187046204586384, 'random_strength': 0.8118008797982929, 'bagging_temperature': 0.3054453709851229}
# Saving optuna parameters: C:\Users\NFU_Power_Lab\Desktop\DAT_ResearchArea\BestAwardAI2026\BaseModel\CatBoost\CatBoost-TVAE\catboost-tvae.json
# === Baseline Classification on Random Split ===
# RandomSplit Accuracy: 0.7808 | F1-macro: 0.7287 | F1-weighted: 0.7773
#
# Classification report (RandomSplit):
#               precision    recall  f1-score   support
#
#            A     1.0000    1.0000    1.0000         4
#            B     1.0000    0.8667    0.9286        15
#            C     1.0000    1.0000    1.0000         2
#            D     0.6923    1.0000    0.8182         9
#            E     1.0000    0.6154    0.7619        13
#            F     0.0000    0.0000    0.0000         0
#            G     0.7500    1.0000    0.8571         9
#            H     0.6857    0.7273    0.7059        33
#            I     1.0000    0.3333    0.5000         3
#            J     0.6875    0.4783    0.5641        23
#            K     0.8250    0.9429    0.8800        35
#
#     accuracy                         0.7808       146
#    macro avg     0.7855    0.7240    0.7287       146
# weighted avg     0.8034    0.7808    0.7773       146
#
# Saved: baseline_cm_random_tvae.csv
# Saved: baseline_preds_random_cls_tvae.csv
