# %%
import warnings

from catboost import CatBoostClassifier
import pandas as pd
import numpy as np
import optuna

warnings.filterwarnings("ignore")

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix
from sklearn.model_selection import StratifiedKFold


def eval_classification(y_true, y_pred, name=""):
    acc = accuracy_score(y_true, y_pred)
    f1_macro = f1_score(y_true, y_pred, average="macro")
    f1_weighted = f1_score(y_true, y_pred, average="weighted")
    print(f"{name} Accuracy: {acc:.4f} | F1-macro: {f1_macro:.4f} | F1-weighted: {f1_weighted:.4f}")
    return acc, f1_macro, f1_weighted

def save_preds_csv(X_test, y_true, y_pred, filename):
    out = X_test.copy()
    out["y_true"] = y_true
    out["y_pred"] = y_pred
    out.to_csv(filename, index=False, encoding="utf-8-sig")
    print(f"Saved: {filename}")

def derive_groups_from_train(train_df, k_baseline_dict, min_group_size=2):
    """
    Returns: type_to_group dict, groups dict
    Uses only train_df to avoid test leakage.
    Phân loại các 'type' thành near/mid/far dựa trên trung bình độ lệch tuyệt đối (abs_diff)
    """
    df_temp = train_df.copy()
    df_temp["k_eff_expected"] = df_temp["load"].map(k_baseline_dict)
    if df_temp["k_eff_expected"].isnull().any():
        known_loads = np.array(list(k_baseline_dict.keys()))
        for idx, row in df_temp[df_temp["k_eff_expected"].isnull()].iterrows():
            closest_load = known_loads[np.abs(known_loads - row["load"]).argmin()]
            df_temp.loc[idx, "k_eff_expected"] = k_baseline_dict[closest_load]     
    df_temp["abs_diff"] = (df_temp["efficiency"] - df_temp["k_eff_expected"]).abs()
    type_stats = (
        df_temp.groupby("type")["abs_diff"]
        .agg(n="count", mean="mean")
        .sort_values("mean")
        .reset_index()
    )
    types = type_stats["type"].tolist()
    x = type_stats["mean"].to_numpy()
    n = len(x)
    # Prefix sums for O(1) segment SSE
    S1 = np.concatenate([[0.0], np.cumsum(x)])
    S2 = np.concatenate([[0.0], np.cumsum(x * x)])
    def seg_sse(i, j):
        m = j - i + 1
        sum1 = S1[j + 1] - S1[i]
        sum2 = S2[j + 1] - S2[i]
        mu = sum1 / m
        return sum2 - 2 * mu * sum1 + m * mu * mu

    K = 3
    INF = 1e18
    dp = np.full((K + 1, n + 1), INF)
    cut = np.full((K + 1, n + 1), -1, dtype=int)

    dp[0, 0] = 0.0
    for k in range(1, K + 1):
        for t in range(1, n + 1):
            p_min = (k - 1) * min_group_size
            p_max = t - min_group_size
            if p_max < p_min:
                continue
            best_cost, best_p = INF, -1
            for p in range(p_min, p_max + 1):
                cost = dp[k - 1, p] + seg_sse(p, t - 1)
                if cost < best_cost:
                    best_cost, best_p = cost, p
            dp[k, t] = best_cost
            cut[k, t] = best_p

    if np.isinf(dp[K, n]):
        raise RuntimeError("No valid split found. Try min_group_size=1 or check types count.")
    bounds = []
    t = n
    for k in range(K, 0, -1):
        p = cut[k, t]
        bounds.append((p, t))
        t = p
    bounds.reverse()
    group_names = ["near", "mid", "far"] 
    groups = {}
    for name, (a, b) in zip(group_names, bounds):
        groups[name] = types[a:b]

    type_to_group = {t: g for g, ts in groups.items() for t in ts}
    return type_to_group, groups, type_stats

def catboost_objective(trial):
    params = {
        "iterations": trial.suggest_int("iterations", 600, 1400, step=200),
        "depth": trial.suggest_int("depth", 4, 8), 
        "learning_rate": trial.suggest_float("learning_rate", 0.02, 0.15, log=True),
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1.0, 20.0, log=True),
        "random_strength": trial.suggest_float("random_strength", 0.5, 3.0),
        "bagging_temperature": trial.suggest_float("bagging_temperature", 0.0, 1.0),
        "auto_class_weights": "Balanced",
        "loss_function": "MultiClass",
        "random_seed": 42,
        "verbose": False,
    }
    skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
    f1s = []
    X = X_train_r
    y = y_train_r
    for tr_idx, va_idx in skf.split(X, y):
        X_tr, X_va = X.iloc[tr_idx], X.iloc[va_idx]
        y_tr, y_va = y.iloc[tr_idx], y.iloc[va_idx]
        model = CatBoostClassifier(**params)
        pipe_cv = Pipeline([
            ("scaler", StandardScaler()),
            ("clf", model),
        ])
        pipe_cv.fit(X_tr, y_tr)
        pred = pipe_cv.predict(X_va).ravel()
        f1s.append(f1_score(y_va, pred, average="macro"))

    return float(np.mean(f1s))

# ----- Load your saved split files -----
train_random = pd.read_csv("C:\\Users\\NFU_Power_Lab\\Desktop\\DAT_ResearchArea\\BestAwardAI2026\\GenerativeModel\\TabDDPM-v2\\wpt_train_random_aug_tabddpm.csv")
test_random  = pd.read_csv("C:\\Users\\NFU_Power_Lab\\Desktop\\DAT_ResearchArea\\BestAwardAI2026\\random-split\\wpt_test_random.csv")

# Sanity check expected columns
expected_cols = {"type", "load", "efficiency"}
for name, d in [("train_random", train_random), ("test_random", test_random)]:
    missing = expected_cols - set(d.columns)
    if missing:
        raise ValueError(f"{name} is missing columns: {missing}")

# Make sure numeric columns are numeric
for d in [train_random, test_random]:
    d["load"] = pd.to_numeric(d["load"], errors="coerce")
    d["efficiency"] = pd.to_numeric(d["efficiency"], errors="coerce")
    d["type"] = d["type"].astype(str)
    d.dropna(subset=["type", "load", "efficiency"], inplace=True)

# Features / target
FEATURES = ["load", "efficiency"]
TARGET = "type"

# =========================
def add_advanced_features(df, k_baseline_dict, type_to_group_dict):
    df = df.copy()
    df["k_eff_expected"] = df["load"].map(k_baseline_dict)
    if df["k_eff_expected"].isnull().any():
        known_loads = np.array(list(k_baseline_dict.keys()))
        for idx, row in df[df["k_eff_expected"].isnull()].iterrows():
            closest_load = known_loads[np.abs(known_loads - row["load"]).argmin()]
            df.loc[idx, "k_eff_expected"] = k_baseline_dict[closest_load]  
    # 2. Độ lệch (Difference) và Tỷ lệ (Ratio)
    df["eff_diff"] = df["efficiency"] - df["k_eff_expected"]
    df["eff_ratio"] = df["efficiency"] / df["k_eff_expected"]
    # 3. Ước tính tổn hao công suất (Power Loss Proxy)
    # P_loss = Load * (1 / (Efficiency / 100) - 1)
    df["p_loss"] = df["load"] * (1 / (df["efficiency"] / 100.0) - 1)
    # Tổn hao công suất của Class K
    df["k_p_loss"] = df["load"] * (1 / (df["k_eff_expected"] / 100.0) - 1)
    # Độ lệch suy hao do vật thể lạ gây ra
    df["p_loss_diff"] = df["p_loss"] - df["k_p_loss"]

    df["dist_zone_name"] = df["type"].map(type_to_group_dict).fillna("far")
    # Mã hóa thành số
    zone_mapping = {"near": 1, "mid": 2, "far": 3}
    df["dist_zone"] = df["dist_zone_name"].map(zone_mapping)
    # 4. Phân vùng Dải tải (Load Zone)
    # Giả sử dải tải từ 0.5 đến 3.0, chia làm 3 vùng: Nhẹ (1), Vừa (2), Nặng (3)
    df['load_zone'] = pd.cut(df['load'], bins=3, labels=[1, 2, 3]).astype(float)
    return df

k_baseline_train_r = train_random[train_random["type"] == "K"].groupby("load")["efficiency"].mean().to_dict()
type_to_group, groups_dict, stats = derive_groups_from_train(train_random, k_baseline_train_r)
print("Results of grouping the Types:", groups_dict)

train_random_fe = add_advanced_features(train_random, k_baseline_train_r, type_to_group)
test_random_fe = add_advanced_features(test_random, k_baseline_train_r, type_to_group)

FEATURES_NEW = [
    "load", "efficiency", 
    "eff_diff", "eff_ratio", 
    "p_loss_diff", "load_zone", "dist_zone"
]
# =========================
X_train_r = train_random_fe[FEATURES_NEW]
y_train_r = train_random_fe[TARGET]
X_test_r  = test_random_fe[FEATURES_NEW]
y_test_r  = test_random_fe[TARGET]

# ========================
# Choose a baseline classifier
# =========================
OPTUNA_TRIALS = 100
study = optuna.create_study(direction="maximize")
study.optimize(catboost_objective, n_trials=OPTUNA_TRIALS)

print("\n=== Optuna done for CatBoost ===")
print("Best macro-F1 (CV):", study.best_value)
print("Best params:", study.best_params)

best_params = study.best_params

clf = CatBoostClassifier(
    iterations=best_params.get("iterations", 1000),
    depth=best_params.get("depth", 6),
    learning_rate=best_params.get("learning_rate", 0.05),
    l2_leaf_reg=best_params.get("l2_leaf_reg", 3.0),
    random_strength=best_params.get("random_strength", 1.0),
    bagging_temperature=best_params.get("bagging_temperature", 0.0),
    auto_class_weights='Balanced',
    loss_function='MultiClass',
    random_seed=42,
    verbose=False
)

# Pipeline: scale numeric features (safe for most models)
pipe = Pipeline([
    ("scaler", StandardScaler()),
    ("clf", clf),
])

# =========================
# Train/Eval on Random Split
# =========================
pipe.fit(X_train_r, y_train_r)
pred_r = pipe.predict(X_test_r).ravel()

print("=== Baseline Classification on Random Split ===")
eval_classification(y_test_r, pred_r, name="RandomSplit")

print("\nClassification report (RandomSplit):")
print(classification_report(y_test_r, pred_r, digits=4))

cm_r = confusion_matrix(y_test_r, pred_r, labels=sorted(y_train_r.unique()))
cm_r_df = pd.DataFrame(cm_r, index=sorted(y_train_r.unique()), columns=sorted(y_train_r.unique()))
cm_r_df.to_csv("baseline_cm_random_tabddpm.csv", encoding="utf-8-sig")
print("Saved: baseline_cm_random_tabddpm.csv")

save_preds_csv(X_test_r, y_test_r.values, pred_r, "baseline_preds_random_cls_tabddpm.csv")
# Out:
# [I 2026-03-12 16:15:49,457] A new study created in memory with name: no-name-67218b11-76c2-4586-b6ba-5179c6829b2b
# Results of grouping the Types: {'near': ['K', 'H', 'J', 'I'], 'mid': ['G', 'F', 'E', 'D', 'B'], 'far': ['C', 'A']}
# [I 2026-03-12 16:16:09,002] Trial 0 finished with value: 0.7423227593054014 and parameters: {'iterations': 1200, 'depth': 5, 'learning_rate': 0.08810687391289714, 'l2_leaf_reg': 1.0453097986120108, 'random_strength': 2.432262141563438, 'bagging_temperature': 0.0047304449887123345}. Best is trial 0 with value: 0.7423227593054014.
# [I 2026-03-12 16:16:24,195] Trial 1 finished with value: 0.762945318820308 and parameters: {'iterations': 1400, 'depth': 4, 'learning_rate': 0.060587846496690446, 'l2_leaf_reg': 14.253749263098628, 'random_strength': 2.1228655275600055, 'bagging_temperature': 0.23230800972252919}. Best is trial 1 with value: 0.762945318820308.
# [I 2026-03-12 16:17:00,932] Trial 2 finished with value: 0.7740067062189327 and parameters: {'iterations': 1200, 'depth': 6, 'learning_rate': 0.022353939385863806, 'l2_leaf_reg': 5.778813289160924, 'random_strength': 1.0587679798549126, 'bagging_temperature': 0.27881045953281147}. Best is trial 2 with value: 0.7740067062189327.
# [I 2026-03-12 16:17:57,545] Trial 3 finished with value: 0.7433366296088432 and parameters: {'iterations': 600, 'depth': 8, 'learning_rate': 0.12998730658707133, 'l2_leaf_reg': 2.2729550416219215, 'random_strength': 0.8452079032091399, 'bagging_temperature': 0.4998989887221875}. Best is trial 2 with value: 0.7740067062189327.
# [I 2026-03-12 16:18:59,412] Trial 4 finished with value: 0.7517365296828572 and parameters: {'iterations': 1200, 'depth': 7, 'learning_rate': 0.05218851145805313, 'l2_leaf_reg': 1.1133476183603397, 'random_strength': 2.298022577012905, 'bagging_temperature': 0.7589681201371796}. Best is trial 2 with value: 0.7740067062189327.
# [I 2026-03-12 16:21:12,516] Trial 5 finished with value: 0.7376648945554884 and parameters: {'iterations': 1400, 'depth': 8, 'learning_rate': 0.12911401115377308, 'l2_leaf_reg': 1.9358805489219104, 'random_strength': 2.3051995136537267, 'bagging_temperature': 0.6428670185737356}. Best is trial 2 with value: 0.7740067062189327.
# [I 2026-03-12 16:21:19,323] Trial 6 finished with value: 0.7647430163765497 and parameters: {'iterations': 600, 'depth': 4, 'learning_rate': 0.060572884031964064, 'l2_leaf_reg': 2.7957152666019316, 'random_strength': 1.009082687192905, 'bagging_temperature': 0.428219627642751}. Best is trial 2 with value: 0.7740067062189327.
# [I 2026-03-12 16:21:56,604] Trial 7 finished with value: 0.7532685756834124 and parameters: {'iterations': 1200, 'depth': 6, 'learning_rate': 0.04740932030031478, 'l2_leaf_reg': 1.2675626181779234, 'random_strength': 1.8498617918023732, 'bagging_temperature': 0.03501619633197384}. Best is trial 2 with value: 0.7740067062189327.
# [I 2026-03-12 16:23:14,844] Trial 8 finished with value: 0.7528481889321451 and parameters: {'iterations': 800, 'depth': 8, 'learning_rate': 0.114360856820715, 'l2_leaf_reg': 7.312660180915544, 'random_strength': 2.722655952570933, 'bagging_temperature': 0.7100520185423426}. Best is trial 2 with value: 0.7740067062189327.
# [I 2026-03-12 16:23:48,449] Trial 9 finished with value: 0.7664763895867575 and parameters: {'iterations': 600, 'depth': 7, 'learning_rate': 0.020659855453676896, 'l2_leaf_reg': 2.0581245870590017, 'random_strength': 1.8900959347305164, 'bagging_temperature': 0.5722550489011888}. Best is trial 2 with value: 0.7740067062189327.
# [I 2026-03-12 16:24:18,999] Trial 10 finished with value: 0.7686680089092143 and parameters: {'iterations': 1000, 'depth': 6, 'learning_rate': 0.020848456266683024, 'l2_leaf_reg': 5.925171418837062, 'random_strength': 1.2522985856289495, 'bagging_temperature': 0.9936828165523846}. Best is trial 2 with value: 0.7740067062189327.
# [I 2026-03-12 16:24:49,503] Trial 11 finished with value: 0.7693867874023802 and parameters: {'iterations': 1000, 'depth': 6, 'learning_rate': 0.021388791020043554, 'l2_leaf_reg': 5.9388330161831, 'random_strength': 1.3226672682002807, 'bagging_temperature': 0.9340563645710263}. Best is trial 2 with value: 0.7740067062189327.
# [I 2026-03-12 16:25:06,765] Trial 12 finished with value: 0.7718777853503873 and parameters: {'iterations': 1000, 'depth': 5, 'learning_rate': 0.027681085515304772, 'l2_leaf_reg': 9.371271196866209, 'random_strength': 0.5191401783254437, 'bagging_temperature': 0.30000805424259563}. Best is trial 2 with value: 0.7740067062189327.
# [I 2026-03-12 16:25:19,913] Trial 13 finished with value: 0.7695985430496447 and parameters: {'iterations': 800, 'depth': 5, 'learning_rate': 0.032635962654607234, 'l2_leaf_reg': 12.631040300617128, 'random_strength': 0.5313166989489999, 'bagging_temperature': 0.29572349703163403}. Best is trial 2 with value: 0.7740067062189327.
# [I 2026-03-12 16:25:36,314] Trial 14 finished with value: 0.7710100734570307 and parameters: {'iterations': 1000, 'depth': 5, 'learning_rate': 0.03328925900277428, 'l2_leaf_reg': 9.609286321604158, 'random_strength': 0.5376123705159337, 'bagging_temperature': 0.23041166276119682}. Best is trial 2 with value: 0.7740067062189327.
# [I 2026-03-12 16:25:57,627] Trial 15 finished with value: 0.7683769766096451 and parameters: {'iterations': 1200, 'depth': 5, 'learning_rate': 0.028876304085482005, 'l2_leaf_reg': 3.5569660282667885, 'random_strength': 1.492360510893048, 'bagging_temperature': 0.37033359827000456}. Best is trial 2 with value: 0.7740067062189327.
# [I 2026-03-12 16:26:40,645] Trial 16 finished with value: 0.7736108045553981 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.026899611342692767, 'l2_leaf_reg': 19.931976874782674, 'random_strength': 0.8773734860119117, 'bagging_temperature': 0.14369988583184373}. Best is trial 2 with value: 0.7740067062189327.
# [I 2026-03-12 16:27:26,802] Trial 17 finished with value: 0.7737849126091304 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.04161538807508201, 'l2_leaf_reg': 17.948902674037626, 'random_strength': 0.9312869255213929, 'bagging_temperature': 0.12788935715412886}. Best is trial 2 with value: 0.7740067062189327.
# [I 2026-03-12 16:28:18,109] Trial 18 finished with value: 0.7751577069054175 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.04012238869905803, 'l2_leaf_reg': 19.023142825767138, 'random_strength': 1.5834842757141634, 'bagging_temperature': 0.12072356214763069}. Best is trial 18 with value: 0.7751577069054175.
# [I 2026-03-12 16:29:12,004] Trial 19 finished with value: 0.7556105402401364 and parameters: {'iterations': 1400, 'depth': 6, 'learning_rate': 0.07570229011194438, 'l2_leaf_reg': 4.6486496921842, 'random_strength': 1.5606194288648674, 'bagging_temperature': 0.10532381756251297}. Best is trial 18 with value: 0.7751577069054175.
# [I 2026-03-12 16:30:19,454] Trial 20 finished with value: 0.7704424702898783 and parameters: {'iterations': 1000, 'depth': 7, 'learning_rate': 0.04035462813371446, 'l2_leaf_reg': 9.996577300765262, 'random_strength': 1.1563122571701179, 'bagging_temperature': 0.39929545135820244}. Best is trial 18 with value: 0.7751577069054175.
# [I 2026-03-12 16:31:18,101] Trial 21 finished with value: 0.7725473027111803 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.04122209834461824, 'l2_leaf_reg': 19.73555417478331, 'random_strength': 1.5859054786253624, 'bagging_temperature': 0.14194253940892812}. Best is trial 18 with value: 0.7751577069054175.
# [I 2026-03-12 16:32:16,833] Trial 22 finished with value: 0.7757173852312328 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.03982805072944036, 'l2_leaf_reg': 14.392856876366618, 'random_strength': 0.8101149902763839, 'bagging_temperature': 0.22150880438587184}. Best is trial 22 with value: 0.7757173852312328.
# [I 2026-03-12 16:32:48,399] Trial 23 finished with value: 0.7734191451739542 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.03386341698421886, 'l2_leaf_reg': 13.762560089939809, 'random_strength': 0.7653323192026785, 'bagging_temperature': 0.24624710566437819}. Best is trial 22 with value: 0.7757173852312328.
# [I 2026-03-12 16:34:01,433] Trial 24 finished with value: 0.7712736222879859 and parameters: {'iterations': 600, 'depth': 8, 'learning_rate': 0.024680719827161725, 'l2_leaf_reg': 7.291156788078591, 'random_strength': 1.1349999286300707, 'bagging_temperature': 0.34531558823478115}. Best is trial 22 with value: 0.7757173852312328.
# [I 2026-03-12 16:35:14,902] Trial 25 finished with value: 0.769197128527965 and parameters: {'iterations': 1000, 'depth': 7, 'learning_rate': 0.07972955757790087, 'l2_leaf_reg': 11.84072069087813, 'random_strength': 1.3461270720668053, 'bagging_temperature': 0.1962163815042018}. Best is trial 22 with value: 0.7757173852312328.
# [I 2026-03-12 16:36:01,777] Trial 26 finished with value: 0.7753844988759013 and parameters: {'iterations': 1200, 'depth': 6, 'learning_rate': 0.03683904146870541, 'l2_leaf_reg': 15.446820817067044, 'random_strength': 1.6322835267091378, 'bagging_temperature': 0.06808214651372207}. Best is trial 22 with value: 0.7757173852312328.
# [I 2026-03-12 16:36:56,789] Trial 27 finished with value: 0.774166946583149 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.03659871641593157, 'l2_leaf_reg': 14.485829204808928, 'random_strength': 2.0152038181902467, 'bagging_temperature': 0.07753776017748201}. Best is trial 22 with value: 0.7757173852312328.
# [I 2026-03-12 16:37:23,475] Trial 28 finished with value: 0.773795021134334 and parameters: {'iterations': 600, 'depth': 6, 'learning_rate': 0.0480578793847243, 'l2_leaf_reg': 16.679560638868846, 'random_strength': 1.762299281036881, 'bagging_temperature': 0.05570219851422342}. Best is trial 22 with value: 0.7757173852312328.
# [I 2026-03-12 16:39:30,532] Trial 29 finished with value: 0.7633811945745128 and parameters: {'iterations': 1000, 'depth': 8, 'learning_rate': 0.060240430128259415, 'l2_leaf_reg': 11.049602622252984, 'random_strength': 2.9455708669964187, 'bagging_temperature': 0.009374378300002727}. Best is trial 22 with value: 0.7757173852312328.
# [I 2026-03-12 16:40:21,627] Trial 30 finished with value: 0.7598611453682885 and parameters: {'iterations': 1200, 'depth': 6, 'learning_rate': 0.06854742948297274, 'l2_leaf_reg': 8.435752869555518, 'random_strength': 1.4362160051296895, 'bagging_temperature': 0.1590515912483715}. Best is trial 22 with value: 0.7757173852312328.
# [I 2026-03-12 16:41:13,607] Trial 31 finished with value: 0.77133757040886 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.03533890369857426, 'l2_leaf_reg': 15.32908645503217, 'random_strength': 2.0344771349492543, 'bagging_temperature': 0.08930025276478513}. Best is trial 22 with value: 0.7757173852312328.
# [I 2026-03-12 16:42:01,903] Trial 32 finished with value: 0.7748187471054585 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.038575801141201134, 'l2_leaf_reg': 15.130257527045623, 'random_strength': 2.0514056431638696, 'bagging_temperature': 0.013676143249639172}. Best is trial 22 with value: 0.7757173852312328.
# [I 2026-03-12 16:42:51,702] Trial 33 finished with value: 0.7729624888359378 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.04605942708010447, 'l2_leaf_reg': 15.631007633476576, 'random_strength': 2.525699069846672, 'bagging_temperature': 0.1834462959298134}. Best is trial 22 with value: 0.7757173852312328.
# [I 2026-03-12 16:44:07,914] Trial 34 finished with value: 0.7709260809926413 and parameters: {'iterations': 600, 'depth': 8, 'learning_rate': 0.029816020650922172, 'l2_leaf_reg': 11.507441278560117, 'random_strength': 1.675365147645707, 'bagging_temperature': 0.01554275589816155}. Best is trial 22 with value: 0.7757173852312328.
# [I 2026-03-12 16:44:40,459] Trial 35 finished with value: 0.7699463065557071 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.038773745719861114, 'l2_leaf_reg': 16.531915953692796, 'random_strength': 2.2143566341070073, 'bagging_temperature': 0.21173908395198332}. Best is trial 22 with value: 0.7757173852312328.
# [I 2026-03-12 16:46:15,087] Trial 36 finished with value: 0.7665930080827752 and parameters: {'iterations': 1400, 'depth': 7, 'learning_rate': 0.05270481391979669, 'l2_leaf_reg': 13.366979270879138, 'random_strength': 1.9477350840615948, 'bagging_temperature': 0.4502931793868349}. Best is trial 22 with value: 0.7757173852312328.
# [I 2026-03-12 16:46:27,958] Trial 37 finished with value: 0.7727200136482693 and parameters: {'iterations': 1000, 'depth': 4, 'learning_rate': 0.045131737588350124, 'l2_leaf_reg': 7.747618253788, 'random_strength': 2.161448691259001, 'bagging_temperature': 0.060273258721752924}. Best is trial 22 with value: 0.7757173852312328.
# [I 2026-03-12 16:49:03,255] Trial 38 finished with value: 0.7636131778805767 and parameters: {'iterations': 1200, 'depth': 8, 'learning_rate': 0.055307867249823846, 'l2_leaf_reg': 19.73381048416788, 'random_strength': 2.4209649953383057, 'bagging_temperature': 0.00997451606296662}. Best is trial 22 with value: 0.7757173852312328.
# [I 2026-03-12 16:49:25,407] Trial 39 finished with value: 0.7704914707622921 and parameters: {'iterations': 600, 'depth': 6, 'learning_rate': 0.024778486305465888, 'l2_leaf_reg': 13.295452353575355, 'random_strength': 1.7313626151102084, 'bagging_temperature': 0.2837230330750261}. Best is trial 22 with value: 0.7757173852312328.
# [I 2026-03-12 16:50:44,016] Trial 40 finished with value: 0.7747874224663814 and parameters: {'iterations': 1200, 'depth': 7, 'learning_rate': 0.031143386980736487, 'l2_leaf_reg': 10.596071183133267, 'random_strength': 0.7204985767535063, 'bagging_temperature': 0.11881319476833244}. Best is trial 22 with value: 0.7757173852312328.
# [I 2026-03-12 16:51:57,125] Trial 41 finished with value: 0.7731949606925541 and parameters: {'iterations': 1200, 'depth': 7, 'learning_rate': 0.03252438321570733, 'l2_leaf_reg': 16.810709117531285, 'random_strength': 0.7078968799612806, 'bagging_temperature': 0.1016596675669349}. Best is trial 22 with value: 0.7757173852312328.
# [I 2026-03-12 16:53:17,851] Trial 42 finished with value: 0.7687566047977367 and parameters: {'iterations': 1200, 'depth': 7, 'learning_rate': 0.03914733291190604, 'l2_leaf_reg': 10.75814344942104, 'random_strength': 0.6730531017508334, 'bagging_temperature': 0.17367216711636416}. Best is trial 22 with value: 0.7757173852312328.
# [I 2026-03-12 16:54:50,031] Trial 43 finished with value: 0.7738905853133847 and parameters: {'iterations': 1400, 'depth': 7, 'learning_rate': 0.03060806666428854, 'l2_leaf_reg': 14.239378157559822, 'random_strength': 0.9405854216722769, 'bagging_temperature': 0.06170943357331435}. Best is trial 22 with value: 0.7757173852312328.
# [I 2026-03-12 16:57:46,622] Trial 44 finished with value: 0.7641175688662853 and parameters: {'iterations': 1400, 'depth': 8, 'learning_rate': 0.04382479521064384, 'l2_leaf_reg': 8.477442301553472, 'random_strength': 1.0528243302332634, 'bagging_temperature': 0.24786919111948577}. Best is trial 22 with value: 0.7757173852312328.
# [I 2026-03-12 16:58:32,651] Trial 45 finished with value: 0.7500030818170046 and parameters: {'iterations': 1200, 'depth': 6, 'learning_rate': 0.036061068961087225, 'l2_leaf_reg': 1.612186837541616, 'random_strength': 1.2378673149003465, 'bagging_temperature': 0.5708913899197086}. Best is trial 22 with value: 0.7757173852312328.
# [I 2026-03-12 16:59:40,923] Trial 46 finished with value: 0.7729891193105917 and parameters: {'iterations': 1000, 'depth': 7, 'learning_rate': 0.02454955682601757, 'l2_leaf_reg': 12.184830974889415, 'random_strength': 1.8648554479298183, 'bagging_temperature': 0.11420956400941248}. Best is trial 22 with value: 0.7757173852312328.
# [I 2026-03-12 17:01:21,574] Trial 47 finished with value: 0.7717090420151346 and parameters: {'iterations': 800, 'depth': 8, 'learning_rate': 0.05071145722889784, 'l2_leaf_reg': 17.436051793682214, 'random_strength': 0.6214066306921993, 'bagging_temperature': 0.842091579741306}. Best is trial 22 with value: 0.7757173852312328.
# [I 2026-03-12 17:02:01,139] Trial 48 finished with value: 0.7494621979267698 and parameters: {'iterations': 1000, 'depth': 6, 'learning_rate': 0.11054599044025665, 'l2_leaf_reg': 4.388305647860391, 'random_strength': 2.310564252464028, 'bagging_temperature': 0.3415861082798091}. Best is trial 22 with value: 0.7757173852312328.
# [I 2026-03-12 17:03:25,307] Trial 49 finished with value: 0.7672399827022517 and parameters: {'iterations': 1200, 'depth': 7, 'learning_rate': 0.030740453448684302, 'l2_leaf_reg': 6.512409395671151, 'random_strength': 0.8088205958022483, 'bagging_temperature': 0.042277632462032345}. Best is trial 22 with value: 0.7757173852312328.
# [I 2026-03-12 17:03:58,021] Trial 50 finished with value: 0.7663738882676526 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.03687973108419267, 'l2_leaf_reg': 2.5757499921808242, 'random_strength': 1.4200536151917762, 'bagging_temperature': 0.14817836673582693}. Best is trial 22 with value: 0.7757173852312328.
# [I 2026-03-12 17:04:52,268] Trial 51 finished with value: 0.7764718771286742 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.037983883864931976, 'l2_leaf_reg': 14.471308056242178, 'random_strength': 2.074651848285582, 'bagging_temperature': 0.07589954518523209}. Best is trial 51 with value: 0.7764718771286742.
# [I 2026-03-12 17:05:49,782] Trial 52 finished with value: 0.7739550907235554 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.042785785911028267, 'l2_leaf_reg': 18.003794727503575, 'random_strength': 2.096431548383915, 'bagging_temperature': 0.08990499428238663}. Best is trial 51 with value: 0.7764718771286742.
# [I 2026-03-12 17:06:45,680] Trial 53 finished with value: 0.7692131540261701 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.02749805596966269, 'l2_leaf_reg': 9.957570246204963, 'random_strength': 1.799224276822616, 'bagging_temperature': 0.20032056659971353}. Best is trial 51 with value: 0.7764718771286742.
# [I 2026-03-12 17:07:28,031] Trial 54 finished with value: 0.7712946575369278 and parameters: {'iterations': 600, 'depth': 7, 'learning_rate': 0.03806835476770586, 'l2_leaf_reg': 12.419913068019875, 'random_strength': 1.659642777295768, 'bagging_temperature': 0.0011286275174142713}. Best is trial 51 with value: 0.7764718771286742.
# [I 2026-03-12 17:08:24,321] Trial 55 finished with value: 0.7740908620118413 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.057072113927122664, 'l2_leaf_reg': 15.245446147930936, 'random_strength': 2.657971961458118, 'bagging_temperature': 0.12512575752833202}. Best is trial 51 with value: 0.7764718771286742.
# [I 2026-03-12 17:09:03,214] Trial 56 finished with value: 0.7721721651228052 and parameters: {'iterations': 1000, 'depth': 6, 'learning_rate': 0.04902855366726345, 'l2_leaf_reg': 19.884756607978847, 'random_strength': 1.9128818463262176, 'bagging_temperature': 0.05733331250703433}. Best is trial 51 with value: 0.7764718771286742.
# [I 2026-03-12 17:09:59,361] Trial 57 finished with value: 0.7735227164092481 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.03352731696381844, 'l2_leaf_reg': 10.677277748254024, 'random_strength': 2.2942781633945373, 'bagging_temperature': 0.24082646931691376}. Best is trial 51 with value: 0.7764718771286742.
# [I 2026-03-12 17:10:14,827] Trial 58 finished with value: 0.7732210951535511 and parameters: {'iterations': 800, 'depth': 5, 'learning_rate': 0.023049646555098384, 'l2_leaf_reg': 13.645486165051032, 'random_strength': 1.568142062920817, 'bagging_temperature': 0.15368803347033938}. Best is trial 51 with value: 0.7764718771286742.
# [I 2026-03-12 17:12:23,554] Trial 59 finished with value: 0.7458270991468022 and parameters: {'iterations': 1000, 'depth': 8, 'learning_rate': 0.1491192597595916, 'l2_leaf_reg': 9.08259453234311, 'random_strength': 0.9881540457929052, 'bagging_temperature': 0.6909344815928111}. Best is trial 51 with value: 0.7764718771286742.
# [I 2026-03-12 17:13:03,902] Trial 60 finished with value: 0.7710575377103844 and parameters: {'iterations': 600, 'depth': 7, 'learning_rate': 0.041688477127474415, 'l2_leaf_reg': 18.352420835843038, 'random_strength': 2.004555884794366, 'bagging_temperature': 0.03715091372482068}. Best is trial 51 with value: 0.7764718771286742.
# [I 2026-03-12 17:13:58,334] Trial 61 finished with value: 0.7716185837680242 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.03532838154695342, 'l2_leaf_reg': 15.794276114399455, 'random_strength': 2.141843753460626, 'bagging_temperature': 0.08316796579065222}. Best is trial 51 with value: 0.7764718771286742.
# [I 2026-03-12 17:14:54,535] Trial 62 finished with value: 0.7778096268389322 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.03123336555776226, 'l2_leaf_reg': 14.318034633231647, 'random_strength': 2.0596605430332913, 'bagging_temperature': 0.10790498437041364}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:15:50,517] Trial 63 finished with value: 0.7757926139714356 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.03131194218059768, 'l2_leaf_reg': 14.987929464946472, 'random_strength': 1.815947010415644, 'bagging_temperature': 0.1205128459641406}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:16:22,924] Trial 64 finished with value: 0.773305369180024 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.02846395164665573, 'l2_leaf_reg': 14.549570419436774, 'random_strength': 1.8126794765458702, 'bagging_temperature': 0.038015611126043916}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:17:19,068] Trial 65 finished with value: 0.7760283606481903 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.0400712676505829, 'l2_leaf_reg': 12.252952959800467, 'random_strength': 1.628623036914141, 'bagging_temperature': 0.16893540744320043}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:18:14,466] Trial 66 finished with value: 0.7728719274692395 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.026044652246075207, 'l2_leaf_reg': 12.640964785605373, 'random_strength': 1.5163018447094858, 'bagging_temperature': 0.1769946661951403}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:19:28,520] Trial 67 finished with value: 0.7675509263220817 and parameters: {'iterations': 600, 'depth': 8, 'learning_rate': 0.033946070380477776, 'l2_leaf_reg': 18.191890693967633, 'random_strength': 1.6493830510508665, 'bagging_temperature': 0.21963145117155858}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:20:02,927] Trial 68 finished with value: 0.771137173368808 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.04560208731242486, 'l2_leaf_reg': 12.15706318006628, 'random_strength': 1.9134898140927414, 'bagging_temperature': 0.3205624298413363}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:21:00,655] Trial 69 finished with value: 0.7739684633803502 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.04080847781743809, 'l2_leaf_reg': 16.456916325347745, 'random_strength': 1.3921722407017567, 'bagging_temperature': 0.2601561447786944}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:21:56,019] Trial 70 finished with value: 0.7756804550271035 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.03206923474446337, 'l2_leaf_reg': 14.054994599075842, 'random_strength': 1.739232335432967, 'bagging_temperature': 0.13773194506331254}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:22:51,850] Trial 71 finished with value: 0.7757762337974009 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.031542037922262574, 'l2_leaf_reg': 13.749452174794335, 'random_strength': 1.6332584938939818, 'bagging_temperature': 0.12493785228139347}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:23:51,044] Trial 72 finished with value: 0.7716684219583532 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.029346976984613124, 'l2_leaf_reg': 13.255082751147624, 'random_strength': 1.733954858344108, 'bagging_temperature': 0.1464694296270248}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:24:45,925] Trial 73 finished with value: 0.7717470126168329 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.031995983622851054, 'l2_leaf_reg': 14.49564036667326, 'random_strength': 1.970113242962211, 'bagging_temperature': 0.1885776079932247}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:25:43,086] Trial 74 finished with value: 0.7761337008863941 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.03487349620995036, 'l2_leaf_reg': 11.675269571267483, 'random_strength': 2.218639891816932, 'bagging_temperature': 0.08655434180589097}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:26:38,018] Trial 75 finished with value: 0.7746708948626572 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.026420545783847182, 'l2_leaf_reg': 11.533775442930697, 'random_strength': 2.214655545372425, 'bagging_temperature': 0.10246460657098594}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:27:33,043] Trial 76 finished with value: 0.775453991329099 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.03408537074669783, 'l2_leaf_reg': 12.996714296157956, 'random_strength': 2.4061701449781676, 'bagging_temperature': 0.20707900227647613}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:28:31,086] Trial 77 finished with value: 0.7774345570337943 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.0317053583277599, 'l2_leaf_reg': 9.486590176276929, 'random_strength': 2.0619278226513345, 'bagging_temperature': 0.27421874220199954}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:29:43,302] Trial 78 finished with value: 0.77229178461316 and parameters: {'iterations': 600, 'depth': 8, 'learning_rate': 0.028753727719385617, 'l2_leaf_reg': 8.911196044044091, 'random_strength': 2.3318041284663837, 'bagging_temperature': 0.2678225794530191}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:30:39,042] Trial 79 finished with value: 0.769732389455359 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.03450958454901906, 'l2_leaf_reg': 9.929747490822855, 'random_strength': 2.079802164646167, 'bagging_temperature': 0.4720390342004805}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:31:35,390] Trial 80 finished with value: 0.7726498164090692 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.03799735442189388, 'l2_leaf_reg': 11.396322855661964, 'random_strength': 2.257851170682652, 'bagging_temperature': 0.3050308710954456}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:32:30,129] Trial 81 finished with value: 0.7749880376420881 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.03143241028010984, 'l2_leaf_reg': 14.08519376016317, 'random_strength': 1.8273125173924283, 'bagging_temperature': 0.16338166548502311}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:33:26,327] Trial 82 finished with value: 0.7639304983343774 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.03253956018214862, 'l2_leaf_reg': 3.2931763550402, 'random_strength': 1.7130853877899803, 'bagging_temperature': 0.12374082593763902}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:34:20,784] Trial 83 finished with value: 0.7749882322394782 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.02982297240438314, 'l2_leaf_reg': 16.740630065329448, 'random_strength': 1.9789890702697726, 'bagging_temperature': 0.08178673884076716}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:35:15,301] Trial 84 finished with value: 0.7733739670347259 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.025740564922771148, 'l2_leaf_reg': 5.098801963760719, 'random_strength': 2.1499537892752896, 'bagging_temperature': 0.38727627196242315}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:36:09,953] Trial 85 finished with value: 0.7617479813692517 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.02208800553170187, 'l2_leaf_reg': 1.0204920271380709, 'random_strength': 1.5047422905753445, 'bagging_temperature': 0.22720531654953482}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:36:22,838] Trial 86 finished with value: 0.7764853244425599 and parameters: {'iterations': 1000, 'depth': 4, 'learning_rate': 0.03726102236962382, 'l2_leaf_reg': 11.747696460689486, 'random_strength': 1.8754968540549701, 'bagging_temperature': 0.5388340965354449}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:36:34,887] Trial 87 finished with value: 0.774277699966032 and parameters: {'iterations': 1000, 'depth': 4, 'learning_rate': 0.03651452650239138, 'l2_leaf_reg': 8.37113272239071, 'random_strength': 1.8729043337854268, 'bagging_temperature': 0.5570765933911647}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:36:55,050] Trial 88 finished with value: 0.7703140114010926 and parameters: {'iterations': 1000, 'depth': 5, 'learning_rate': 0.04338910135323281, 'l2_leaf_reg': 10.207552814590573, 'random_strength': 2.209303564521541, 'bagging_temperature': 0.5283839050921374}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:37:49,281] Trial 89 finished with value: 0.76800272210648 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.04015533605473996, 'l2_leaf_reg': 7.626047454867199, 'random_strength': 2.547010086957277, 'bagging_temperature': 0.5191061369625857}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:39:01,302] Trial 90 finished with value: 0.77213004242275 and parameters: {'iterations': 600, 'depth': 8, 'learning_rate': 0.03550706560708236, 'l2_leaf_reg': 11.301496122102035, 'random_strength': 2.0537947558491605, 'bagging_temperature': 0.17522379382476994}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:39:10,757] Trial 91 finished with value: 0.7751817609858467 and parameters: {'iterations': 800, 'depth': 4, 'learning_rate': 0.02793814647133117, 'l2_leaf_reg': 13.015840058518055, 'random_strength': 1.9543923802966974, 'bagging_temperature': 0.43060879227276105}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:40:05,495] Trial 92 finished with value: 0.7727230662094424 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.03224692572177801, 'l2_leaf_reg': 11.93603740273043, 'random_strength': 1.7678216256053685, 'bagging_temperature': 0.1334263873305225}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:40:58,796] Trial 93 finished with value: 0.7713247162553092 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.03042919768247509, 'l2_leaf_reg': 15.648203480851786, 'random_strength': 1.250723646933845, 'bagging_temperature': 0.6376062801731823}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:41:52,163] Trial 94 finished with value: 0.7685719835555492 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.037518302673527335, 'l2_leaf_reg': 9.429945371935924, 'random_strength': 1.8426366700141403, 'bagging_temperature': 0.6401079688270972}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:42:44,084] Trial 95 finished with value: 0.7773768494778145 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.0394005382020361, 'l2_leaf_reg': 14.892312678160078, 'random_strength': 2.3561349333094457, 'bagging_temperature': 0.10207832251496088}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:43:37,245] Trial 96 finished with value: 0.7756272835219699 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.03930070481858898, 'l2_leaf_reg': 15.000475411172902, 'random_strength': 2.3636768158706443, 'bagging_temperature': 0.10874857587610398}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:44:32,265] Trial 97 finished with value: 0.7748360566614266 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.04814969433688797, 'l2_leaf_reg': 10.766995096789302, 'random_strength': 2.1816134034092602, 'bagging_temperature': 0.06915330392611678}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:45:42,198] Trial 98 finished with value: 0.7696737475521461 and parameters: {'iterations': 1000, 'depth': 7, 'learning_rate': 0.04308450716304003, 'l2_leaf_reg': 12.418642200251, 'random_strength': 2.496822091595763, 'bagging_temperature': 0.5928633978054868}. Best is trial 62 with value: 0.7778096268389322.
# [I 2026-03-12 17:45:51,571] Trial 99 finished with value: 0.7696721187476224 and parameters: {'iterations': 800, 'depth': 4, 'learning_rate': 0.035521051017546774, 'l2_leaf_reg': 1.166442541480066, 'random_strength': 2.114850793161404, 'bagging_temperature': 0.022299199186154653}. Best is trial 62 with value: 0.7778096268389322.
# === Optuna done for CatBoost ===
# Best macro-F1 (CV): 0.7778096268389322
# Best params: {'iterations': 800, 'depth': 7, 'learning_rate': 0.03123336555776226, 'l2_leaf_reg': 14.318034633231647, 'random_strength': 2.0596605430332913, 'bagging_temperature': 0.10790498437041364}
# === Baseline Classification on Random Split ===
# RandomSplit Accuracy: 0.7397 | F1-macro: 0.7141 | F1-weighted: 0.7412
#
# Classification report (RandomSplit):
#               precision    recall  f1-score   support
#
#            A     1.0000    1.0000    1.0000         4
#            B     1.0000    0.9333    0.9655        15
#            C     1.0000    1.0000    1.0000         2
#            D     0.7500    1.0000    0.8571         9
#            E     1.0000    0.4615    0.6316        13
#            F     0.0000    0.0000    0.0000         0
#            G     0.8889    0.8889    0.8889         9
#            H     0.6471    0.6667    0.6567        33
#            I     0.3750    1.0000    0.5455         3
#            J     0.6154    0.3478    0.4444        23
#            K     0.8205    0.9143    0.8649        35
#
#     accuracy                         0.7397       146
#    macro avg     0.7361    0.7466    0.7141       146
# weighted avg     0.7815    0.7397    0.7412       146
#
# Saved: baseline_cm_random_tabddpm.csv
# Saved: baseline_preds_random_cls_tabddpm.csv
