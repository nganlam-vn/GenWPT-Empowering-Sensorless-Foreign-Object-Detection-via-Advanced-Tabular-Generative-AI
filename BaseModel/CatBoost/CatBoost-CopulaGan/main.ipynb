# %%
import warnings

from catboost import CatBoostClassifier
import pandas as pd
import numpy as np
import json, os, optuna

warnings.filterwarnings("ignore")

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix
from sklearn.model_selection import StratifiedKFold


def eval_classification(y_true, y_pred, name=""):
    acc = accuracy_score(y_true, y_pred)
    f1_macro = f1_score(y_true, y_pred, average="macro")
    f1_weighted = f1_score(y_true, y_pred, average="weighted")
    print(f"{name} Accuracy: {acc:.4f} | F1-macro: {f1_macro:.4f} | F1-weighted: {f1_weighted:.4f}")
    return acc, f1_macro, f1_weighted

def save_preds_csv(X_test, y_true, y_pred, filename):
    out = X_test.copy()
    out["y_true"] = y_true
    out["y_pred"] = y_pred
    out.to_csv(filename, index=False, encoding="utf-8-sig")
    print(f"Saved: {filename}")

def derive_groups_from_train(train_df, k_baseline_dict, min_group_size=2):
    """
    Returns: type_to_group dict, groups dict
    Uses only train_df to avoid test leakage.
    Phân loại các 'type' thành near/mid/far dựa trên trung bình độ lệch tuyệt đối (abs_diff)
    """
    df_temp = train_df.copy()
    df_temp["k_eff_expected"] = df_temp["load"].map(k_baseline_dict)
    if df_temp["k_eff_expected"].isnull().any():
        known_loads = np.array(list(k_baseline_dict.keys()))
        for idx, row in df_temp[df_temp["k_eff_expected"].isnull()].iterrows():
            closest_load = known_loads[np.abs(known_loads - row["load"]).argmin()]
            df_temp.loc[idx, "k_eff_expected"] = k_baseline_dict[closest_load]     
    df_temp["abs_diff"] = (df_temp["efficiency"] - df_temp["k_eff_expected"]).abs()
    type_stats = (
        df_temp.groupby("type")["abs_diff"]
        .agg(n="count", mean="mean")
        .sort_values("mean")
        .reset_index()
    )
    types = type_stats["type"].tolist()
    x = type_stats["mean"].to_numpy()
    n = len(x)
    # Prefix sums for O(1) segment SSE
    S1 = np.concatenate([[0.0], np.cumsum(x)])
    S2 = np.concatenate([[0.0], np.cumsum(x * x)])
    def seg_sse(i, j):
        m = j - i + 1
        sum1 = S1[j + 1] - S1[i]
        sum2 = S2[j + 1] - S2[i]
        mu = sum1 / m
        return sum2 - 2 * mu * sum1 + m * mu * mu

    K = 3
    INF = 1e18
    dp = np.full((K + 1, n + 1), INF)
    cut = np.full((K + 1, n + 1), -1, dtype=int)

    dp[0, 0] = 0.0
    for k in range(1, K + 1):
        for t in range(1, n + 1):
            p_min = (k - 1) * min_group_size
            p_max = t - min_group_size
            if p_max < p_min:
                continue
            best_cost, best_p = INF, -1
            for p in range(p_min, p_max + 1):
                cost = dp[k - 1, p] + seg_sse(p, t - 1)
                if cost < best_cost:
                    best_cost, best_p = cost, p
            dp[k, t] = best_cost
            cut[k, t] = best_p

    if np.isinf(dp[K, n]):
        raise RuntimeError("No valid split found. Try min_group_size=1 or check types count.")
    bounds = []
    t = n
    for k in range(K, 0, -1):
        p = cut[k, t]
        bounds.append((p, t))
        t = p
    bounds.reverse()
    group_names = ["near", "mid", "far"] 
    groups = {}
    for name, (a, b) in zip(group_names, bounds):
        groups[name] = types[a:b]

    type_to_group = {t: g for g, ts in groups.items() for t in ts}
    return type_to_group, groups, type_stats

def catboost_objective(trial):
    params = {
        "iterations": trial.suggest_int("iterations", 600, 1400, step=200),
        "depth": trial.suggest_int("depth", 4, 8), 
        "learning_rate": trial.suggest_float("learning_rate", 0.02, 0.15, log=True),
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1.0, 20.0, log=True),
        "random_strength": trial.suggest_float("random_strength", 0.5, 3.0),
        "bagging_temperature": trial.suggest_float("bagging_temperature", 0.0, 1.0),
        "auto_class_weights": "Balanced",
        "loss_function": "MultiClass",
        "random_seed": 121,
        "verbose": False,
    }
    skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=121)
    f1s = []
    X = X_train_r
    y = y_train_r
    for tr_idx, va_idx in skf.split(X, y):
        X_tr, X_va = X.iloc[tr_idx], X.iloc[va_idx]
        y_tr, y_va = y.iloc[tr_idx], y.iloc[va_idx]
        model = CatBoostClassifier(**params)
        pipe_cv = Pipeline([
            ("scaler", StandardScaler()),
            ("clf", model),
        ])
        pipe_cv.fit(X_tr, y_tr)
        pred = pipe_cv.predict(X_va).ravel()
        f1s.append(f1_score(y_va, pred, average="macro"))

    return float(np.mean(f1s))

# ----- Load your saved split files -----
train_random = pd.read_csv("C:\\Users\\NFU_Power_Lab\\Desktop\\DAT_ResearchArea\\BestAwardAI2026\\GenerativeModel\\CopulaGanGenData\\wpt_train_random_aug_copulagan.csv")
test_random  = pd.read_csv("C:\\Users\\NFU_Power_Lab\\Desktop\\DAT_ResearchArea\\BestAwardAI2026\\random-split\\wpt_test_random.csv")
catboost_json_path = r"C:\Users\NFU_Power_Lab\Desktop\DAT_ResearchArea\BestAwardAI2026\BaseModel\CatBoost\CatBoostCopulaGan\catboost-copulagan.json"


# Sanity check expected columns
expected_cols = {"type", "load", "efficiency"}
for name, d in [("train_random", train_random), ("test_random", test_random)]:
    missing = expected_cols - set(d.columns)
    if missing:
        raise ValueError(f"{name} is missing columns: {missing}")

# Make sure numeric columns are numeric
for d in [train_random, test_random]:
    d["load"] = pd.to_numeric(d["load"], errors="coerce")
    d["efficiency"] = pd.to_numeric(d["efficiency"], errors="coerce")
    d["type"] = d["type"].astype(str)
    d.dropna(subset=["type", "load", "efficiency"], inplace=True)

# Features / target
FEATURES = ["load", "efficiency"]
TARGET = "type"

# =========================
def add_advanced_features(df, k_baseline_dict, type_to_group_dict):
    df = df.copy()
    df["k_eff_expected"] = df["load"].map(k_baseline_dict)
    if df["k_eff_expected"].isnull().any():
        known_loads = np.array(list(k_baseline_dict.keys()))
        for idx, row in df[df["k_eff_expected"].isnull()].iterrows():
            closest_load = known_loads[np.abs(known_loads - row["load"]).argmin()]
            df.loc[idx, "k_eff_expected"] = k_baseline_dict[closest_load]  
    # 2. Độ lệch (Difference) và Tỷ lệ (Ratio)
    df["eff_diff"] = df["efficiency"] - df["k_eff_expected"]
    df["eff_ratio"] = df["efficiency"] / df["k_eff_expected"]
    # 3. Ước tính tổn hao công suất (Power Loss Proxy)
    # P_loss = Load * (1 / (Efficiency / 100) - 1)
    df["p_loss"] = df["load"] * (1 / (df["efficiency"] / 100.0) - 1)
    # Tổn hao công suất của Class K
    df["k_p_loss"] = df["load"] * (1 / (df["k_eff_expected"] / 100.0) - 1)
    # Độ lệch suy hao do vật thể lạ gây ra
    df["p_loss_diff"] = df["p_loss"] - df["k_p_loss"]

    df["dist_zone_name"] = df["type"].map(type_to_group_dict).fillna("far")
    # Mã hóa thành số
    zone_mapping = {"near": 1, "mid": 2, "far": 3}
    df["dist_zone"] = df["dist_zone_name"].map(zone_mapping)
    # 4. Phân vùng Dải tải (Load Zone)
    # Giả sử dải tải từ 0.5 đến 3.0, chia làm 3 vùng: Nhẹ (1), Vừa (2), Nặng (3)
    df['load_zone'] = pd.cut(df['load'], bins=3, labels=[1, 2, 3]).astype(float)
    return df

k_baseline_train_r = train_random[train_random["type"] == "K"].groupby("load")["efficiency"].mean().to_dict()
type_to_group, groups_dict, stats = derive_groups_from_train(train_random, k_baseline_train_r)
print("Results of grouping the Types:", groups_dict)

train_random_fe = add_advanced_features(train_random, k_baseline_train_r, type_to_group)
test_random_fe = add_advanced_features(test_random, k_baseline_train_r, type_to_group)

FEATURES_NEW = [
    "load", "efficiency", 
    "eff_diff", "eff_ratio", 
    "p_loss_diff", "load_zone", "dist_zone"
]
# =========================
X_train_r = train_random_fe[FEATURES_NEW]
y_train_r = train_random_fe[TARGET]
X_test_r  = test_random_fe[FEATURES_NEW]
y_test_r  = test_random_fe[TARGET]

# ========================
# Choose a baseline classifier
# =========================
OPTUNA_TRIALS = 100
study = optuna.create_study(direction="maximize")
study.optimize(catboost_objective, n_trials=OPTUNA_TRIALS)

print("\n=== Optuna done for CatBoost ===")
print("Best macro-F1 (CV):", study.best_value)
print("Best params:", study.best_params)

best_params = study.best_params
os.makedirs(os.path.dirname(catboost_json_path), exist_ok=True)

with open(catboost_json_path, 'w', encoding='utf-8') as f:
    json.dump(best_params, f, indent=4)
print(f"Saving optuna parameters: {catboost_json_path}")

clf = CatBoostClassifier(
    iterations=best_params.get("iterations", 1000),
    depth=best_params.get("depth", 6),
    learning_rate=best_params.get("learning_rate", 0.05),
    l2_leaf_reg=best_params.get("l2_leaf_reg", 3.0),
    random_strength=best_params.get("random_strength", 1.0),
    bagging_temperature=best_params.get("bagging_temperature", 0.0),
    auto_class_weights='Balanced',
    loss_function='MultiClass',
    random_seed=121,
    verbose=False
)

# Pipeline: scale numeric features (safe for most models)
pipe = Pipeline([
    ("scaler", StandardScaler()),
    ("clf", clf),
])

# =========================
# Train/Eval on Random Split
# =========================
pipe.fit(X_train_r, y_train_r)
pred_r = pipe.predict(X_test_r).ravel()

print("=== Baseline Classification on Random Split ===")
eval_classification(y_test_r, pred_r, name="RandomSplit")

print("\nClassification report (RandomSplit):")
print(classification_report(y_test_r, pred_r, digits=4))

cm_r = confusion_matrix(y_test_r, pred_r, labels=sorted(y_train_r.unique()))
cm_r_df = pd.DataFrame(cm_r, index=sorted(y_train_r.unique()), columns=sorted(y_train_r.unique()))
cm_r_df.to_csv("baseline_cm_random_copulagan.csv", encoding="utf-8-sig")
print("Saved: baseline_cm_random_copulagan.csv")                                                                                                                                                                                                                                                               

save_preds_csv(X_test_r, y_test_r.values, pred_r, "baseline_preds_random_cls_copulagan.csv")
# Out:
# [I 2026-03-12 23:26:20,159] A new study created in memory with name: no-name-903367d9-ad69-450b-88a7-996f2ce841f7
# Results of grouping the Types: {'near': ['K', 'H', 'J', 'G'], 'mid': ['E', 'I', 'F', 'D', 'B'], 'far': ['C', 'A']}
# [I 2026-03-12 23:26:52,059] Trial 0 finished with value: 0.7201199938964122 and parameters: {'iterations': 600, 'depth': 7, 'learning_rate': 0.09217286590336687, 'l2_leaf_reg': 2.9925777153782436, 'random_strength': 2.379823706315155, 'bagging_temperature': 0.2946754743811195}. Best is trial 0 with value: 0.7201199938964122.
# [I 2026-03-12 23:27:01,894] Trial 1 finished with value: 0.7308564009810653 and parameters: {'iterations': 600, 'depth': 5, 'learning_rate': 0.023927503326190182, 'l2_leaf_reg': 1.44250617820015, 'random_strength': 2.2285495782232014, 'bagging_temperature': 0.7038285620171394}. Best is trial 1 with value: 0.7308564009810653.
# [I 2026-03-12 23:27:10,576] Trial 2 finished with value: 0.7325352547517356 and parameters: {'iterations': 800, 'depth': 4, 'learning_rate': 0.03886937614295605, 'l2_leaf_reg': 2.923993359656295, 'random_strength': 2.3555049392549976, 'bagging_temperature': 0.33336831936530975}. Best is trial 2 with value: 0.7325352547517356.
# [I 2026-03-12 23:27:19,522] Trial 3 finished with value: 0.7113806806842282 and parameters: {'iterations': 800, 'depth': 4, 'learning_rate': 0.14634278082323265, 'l2_leaf_reg': 1.4407918187125783, 'random_strength': 2.021732739229411, 'bagging_temperature': 0.7660648699267285}. Best is trial 2 with value: 0.7325352547517356.
# [I 2026-03-12 23:27:26,044] Trial 4 finished with value: 0.7233664556441566 and parameters: {'iterations': 600, 'depth': 4, 'learning_rate': 0.022281919021711095, 'l2_leaf_reg': 19.153632194741835, 'random_strength': 0.7372588133501952, 'bagging_temperature': 0.8127464477568228}. Best is trial 2 with value: 0.7325352547517356.
# [I 2026-03-12 23:27:34,862] Trial 5 finished with value: 0.7411813444167743 and parameters: {'iterations': 800, 'depth': 4, 'learning_rate': 0.04613286047410979, 'l2_leaf_reg': 14.221133291756722, 'random_strength': 0.7245103631529064, 'bagging_temperature': 0.8274376049801089}. Best is trial 5 with value: 0.7411813444167743.
# [I 2026-03-12 23:28:05,476] Trial 6 finished with value: 0.7248940207719473 and parameters: {'iterations': 1000, 'depth': 6, 'learning_rate': 0.07784442235021749, 'l2_leaf_reg': 4.880676492534781, 'random_strength': 2.002565886910907, 'bagging_temperature': 0.11623100857896718}. Best is trial 5 with value: 0.7411813444167743.
# [I 2026-03-12 23:28:58,153] Trial 7 finished with value: 0.7173992195561726 and parameters: {'iterations': 1000, 'depth': 7, 'learning_rate': 0.06724998133279127, 'l2_leaf_reg': 5.460541834479321, 'random_strength': 2.763200695621469, 'bagging_temperature': 0.29543181497028215}. Best is trial 5 with value: 0.7411813444167743.
# [I 2026-03-12 23:29:29,166] Trial 8 finished with value: 0.7282581381180977 and parameters: {'iterations': 1000, 'depth': 6, 'learning_rate': 0.06366286896859362, 'l2_leaf_reg': 10.755219720776147, 'random_strength': 1.513349232597164, 'bagging_temperature': 0.7076176511583483}. Best is trial 5 with value: 0.7411813444167743.
# [I 2026-03-12 23:30:04,179] Trial 9 finished with value: 0.7094577890730931 and parameters: {'iterations': 1000, 'depth': 6, 'learning_rate': 0.08382618088806502, 'l2_leaf_reg': 2.0667897250310827, 'random_strength': 1.689461642044284, 'bagging_temperature': 0.23355222319437619}. Best is trial 5 with value: 0.7411813444167743.
# [I 2026-03-12 23:32:23,940] Trial 10 finished with value: 0.7287230230750378 and parameters: {'iterations': 1400, 'depth': 8, 'learning_rate': 0.03647706069932881, 'l2_leaf_reg': 9.7130454673839, 'random_strength': 0.6690066317832476, 'bagging_temperature': 0.9901034800277886}. Best is trial 5 with value: 0.7411813444167743.
# [I 2026-03-12 23:32:32,622] Trial 11 finished with value: 0.7350734859107453 and parameters: {'iterations': 800, 'depth': 4, 'learning_rate': 0.04008241776949915, 'l2_leaf_reg': 3.1858488919948393, 'random_strength': 1.190337613204025, 'bagging_temperature': 0.4702339850107572}. Best is trial 5 with value: 0.7411813444167743.
# [I 2026-03-12 23:32:55,501] Trial 12 finished with value: 0.7293716456789627 and parameters: {'iterations': 1400, 'depth': 5, 'learning_rate': 0.04174410521755979, 'l2_leaf_reg': 10.96017400185765, 'random_strength': 1.2150593562765315, 'bagging_temperature': 0.5326756576646763}. Best is trial 5 with value: 0.7411813444167743.
# [I 2026-03-12 23:33:08,587] Trial 13 finished with value: 0.7284900001706477 and parameters: {'iterations': 800, 'depth': 5, 'learning_rate': 0.04692981765873604, 'l2_leaf_reg': 6.869150489025681, 'random_strength': 1.094576952867671, 'bagging_temperature': 0.5217694036265673}. Best is trial 5 with value: 0.7411813444167743.
# [I 2026-03-12 23:33:21,588] Trial 14 finished with value: 0.7324240213944457 and parameters: {'iterations': 1200, 'depth': 4, 'learning_rate': 0.030256656770583347, 'l2_leaf_reg': 19.68982531897475, 'random_strength': 0.5113668846653583, 'bagging_temperature': 0.9418265062601071}. Best is trial 5 with value: 0.7411813444167743.
# [I 2026-03-12 23
. Best is trial 5 with value: 0.7411813444167743.
# [I 2026-03-13 00:00:39,616] Trial 46 finished with value: 0.737529215985994 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.043611458983675896, 'l2_leaf_reg': 14.94757543614806, 'random_strength': 0.7196018593058775, 'bagging_temperature': 0.07483248056222003}. Best is trial 5 with value: 0.7411813444167743.
# [I 2026-03-13 00:01:34,837] Trial 47 finished with value: 0.7171484507651235 and parameters: {'iterations': 600, 'depth': 8, 'learning_rate': 0.08156783292465414, 'l2_leaf_reg': 5.942872763213525, 'random_strength': 1.3279046962079202, 'bagging_temperature': 0.3661675921584177}. Best is trial 5 with value: 0.7411813444167743.
# [I 2026-03-13 00:02:15,766] Trial 48 finished with value: 0.7345602026921781 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.02081648322459914, 'l2_leaf_reg': 12.752267696168559, 'random_strength': 0.5034856184207831, 'bagging_temperature': 0.7791705353970713}. Best is trial 5 with value: 0.7411813444167743.
# [I 2026-03-13 00:02:32,103] Trial 49 finished with value: 0.7334840691537581 and parameters: {'iterations': 1000, 'depth': 5, 'learning_rate': 0.038615134675768006, 'l2_leaf_reg': 8.965288129556068, 'random_strength': 0.9613137109061695, 'bagging_temperature': 0.434369439560797}. Best is trial 5 with value: 0.7411813444167743.
# [I 2026-03-13 00:03:31,047] Trial 50 finished with value: 0.7385860156222019 and parameters: {'iterations': 600, 'depth': 8, 'learning_rate': 0.05680098881201796, 'l2_leaf_reg': 19.948748186162568, 'random_strength': 0.6082030366855128, 'bagging_temperature': 0.8528163331094928}. Best is trial 5 with value: 0.7411813444167743.
# [I 2026-03-13 00:04:28,439] Trial 51 finished with value: 0.7416037500577207 and parameters: {'iterations': 600, 'depth': 8, 'learning_rate': 0.05676251197530537, 'l2_leaf_reg': 19.823150856124343, 'random_strength': 0.6892150280682801, 'bagging_temperature': 0.8519419715458856}. Best is trial 51 with value: 0.7416037500577207.
# [I 2026-03-13 00:05:24,708] Trial 52 finished with value: 0.7337512756443729 and parameters: {'iterations': 600, 'depth': 8, 'learning_rate': 0.04988313167436116, 'l2_leaf_reg': 19.956816049274607, 'random_strength': 0.6281484493562847, 'bagging_temperature': 0.8395373020034402}. Best is trial 51 with value: 0.7416037500577207.
# [I 2026-03-13 00:06:21,754] Trial 53 finished with value: 0.7379069988423778 and parameters: {'iterations': 600, 'depth': 8, 'learning_rate': 0.058809158732805504, 'l2_leaf_reg': 17.750544584885386, 'random_strength': 0.7137275656006701, 'bagging_temperature': 0.9158694203216253}. Best is trial 51 with value: 0.7416037500577207.
# [I 2026-03-13 00:07:17,874] Trial 54 finished with value: 0.7406658881614102 and parameters: {'iterations': 600, 'depth': 8, 'learning_rate': 0.04554139605798584, 'l2_leaf_reg': 16.98208162131162, 'random_strength': 0.6048007553685605, 'bagging_temperature': 0.8804302164568112}. Best is trial 51 with value: 0.7416037500577207.
# [I 2026-03-13 00:08:35,184] Trial 55 finished with value: 0.7352060292002921 and parameters: {'iterations': 800, 'depth': 8, 'learning_rate': 0.04545182661069876, 'l2_leaf_reg': 16.684614427950127, 'random_strength': 0.9793306093523724, 'bagging_temperature': 0.8833143477252844}. Best is trial 51 with value: 0.7416037500577207.
# [I 2026-03-13 00:08:44,081] Trial 56 finished with value: 0.7463075724162848 and parameters: {'iterations': 800, 'depth': 4, 'learning_rate': 0.04198455031048873, 'l2_leaf_reg': 14.04575668168646, 'random_strength': 1.7846532230145904, 'bagging_temperature': 0.9618708269629651}. Best is trial 56 with value: 0.7463075724162848.
# [I 2026-03-13 00:08:50,900] Trial 57 finished with value: 0.7351668974130009 and parameters: {'iterations': 600, 'depth': 4, 'learning_rate': 0.036155541728482274, 'l2_leaf_reg': 4.229507923855857, 'random_strength': 1.8340028106495145, 'bagging_temperature': 0.9455031216249912}. Best is trial 56 with value: 0.7463075724162848.
# [I 2026-03-13 00:09:04,386] Trial 58 finished with value: 0.7356434530310884 and parameters: {'iterations': 1200, 'depth': 4, 'learning_rate': 0.0409598945444425, 'l2_leaf_reg': 10.523323815781799, 'random_strength': 1.669438110969226, 'bagging_temperature': 0.9750232570243559}. Best is trial 56 with value: 0.7463075724162848.
# [I 2026-03-13 00
and parameters: {'iterations': 1400, 'depth': 4, 'learning_rate': 0.035423154152607765, 'l2_leaf_reg': 16.752290717424046, 'random_strength': 1.9427604321995364, 'bagging_temperature': 0.9333101625249033}. Best is trial 64 with value: 0.7467433953423882.
# [I 2026-03-13 00:12:39,849] Trial 75 finished with value: 0.7447958081042402 and parameters: {'iterations': 600, 'depth': 4, 'learning_rate': 0.04388800901698795, 'l2_leaf_reg': 11.902498144651378, 'random_strength': 1.8481632046328418, 'bagging_temperature': 0.8236965284281866}. Best is trial 64 with value: 0.7467433953423882.
# [I 2026-03-13 00:12:48,319] Trial 76 finished with value: 0.7379859276317164 and parameters: {'iterations': 600, 'depth': 4, 'learning_rate': 0.03745197549393152, 'l2_leaf_reg': 11.773059784908613, 'random_strength': 1.8555784928092605, 'bagging_temperature': 0.8338531105087023}. Best is trial 64 with value: 0.7467433953423882.
# [I 2026-03-13 00:13:06,684] Trial 77 finished with value: 0.7388210047870708 and parameters: {'iterations': 1000, 'depth': 5, 'learning_rate': 0.03182682326350803, 'l2_leaf_reg': 7.5840282339459435, 'random_strength': 1.6308686144318083, 'bagging_temperature': 0.7660897359557857}. Best is trial 64 with value: 0.7467433953423882.
# [I 2026-03-13 00:13:13,574] Trial 78 finished with value: 0.7419135010441851 and parameters: {'iterations': 600, 'depth': 4, 'learning_rate': 0.044936011971020484, 'l2_leaf_reg': 9.297914073958005, 'random_strength': 1.7615663950671558, 'bagging_temperature': 0.9998024918314162}. Best is trial 64 with value: 0.7467433953423882.
# [I 2026-03-13 00:13:20,810] Trial 79 finished with value: 0.7383448494020411 and parameters: {'iterations': 600, 'depth': 4, 'learning_rate': 0.04353291551555375, 'l2_leaf_reg': 9.394290597749935, 'random_strength': 1.757728237331972, 'bagging_temperature': 0.9979933464810176}. Best is trial 64 with value: 0.7467433953423882.
# [I 2026-03-13 00:13:29,756] Trial 80 finished with value: 0.7424181925008462 and parameters: {'iterations': 800, 'depth': 4, 'learning_rate': 0.039845945959572665, 'l2_leaf_reg': 8.634890410828683, 'random_strength': 1.5072844057801866, 'bagging_temperature': 0.9657471735128473}. Best is trial 64 with value: 0.7467433953423882.
# [I 2026-03-13 00:13:39,168] Trial 81 finished with value: 0.7450604316130395 and parameters: {'iterations': 800, 'depth': 4, 'learning_rate': 0.038607913486091994, 'l2_leaf_reg': 9.974552355778549, 'random_strength': 1.5076073069362392, 'bagging_temperature': 0.9749785448228152}. Best is trial 64 with value: 0.7467433953423882.
# [I 2026-03-13 00:13:48,563] Trial 82 finished with value: 0.7418008625544155 and parameters: {'iterations': 800, 'depth': 4, 'learning_rate': 0.04096084153414407, 'l2_leaf_reg': 10.108524015926806, 'random_strength': 1.5037966225829629, 'bagging_temperature': 0.962415302589502}. Best is trial 64 with value: 0.7467433953423882.
# [I 2026-03-13 00:13:57,317] Trial 83 finished with value: 0.7415145786454932 and parameters: {'iterations': 800, 'depth': 4, 'learning_rate': 0.04035683105165852, 'l2_leaf_reg': 8.722856165629961, 'random_strength': 1.4529919928539323, 'bagging_temperature': 0.9556510897254538}. Best is trial 64 with value: 0.7467433953423882.
# [I 2026-03-13 00:14:06,271] Trial 84 finished with value: 0.7357886014507248 and parameters: {'iterations': 800, 'depth': 4, 'learning_rate': 0.05005506624723741, 'l2_leaf_reg': 8.583218834002743, 'random_strength': 1.4777447211862138, 'bagging_temperature': 0.9621042178389291}. Best is trial 64 with value: 0.7467433953423882.
# [I 2026-03-13 00:14:14,956] Trial 85 finished with value: 0.7433474467028701 and parameters: {'iterations': 800, 'depth': 4, 'learning_rate': 0.04027764119429046, 'l2_leaf_reg': 9.836510898198338, 'random_strength': 1.3920148430177328, 'bagging_temperature': 0.997691290675471}. Best is trial 64 with value: 0.7467433953423882.
# [I 2026-03-13 00:14:29,285] Trial 86 finished with value: 0.7342538316820092 and parameters: {'iterations': 800, 'depth': 5, 'learning_rate': 0.042178658769911996, 'l2_leaf_reg': 9.840725249803022, 'random_strength': 1.5805391813231495, 'bagging_temperature': 0.9932448044996081}. Best is trial 64 with value: 0.7467433953423882.
# [I 2026-03-13 00:14:40,429] Trial 87 finished with value: 0.7446670085301794 and parameters: {'iterations': 1000, 'depth': 4, 'learning_rate': 0.039554600185548024, 'l2_leaf_reg': 10.856902277467261, 'random_strength': 1.2818399419803403, 'bagging_temperature': 0.907061355069902}. Best is trial 64 with value: 0.7467433953423882.
# [I 2026-03-13 00:14:51,276] Trial 88 finished with value: 0.7421460907797296 and parameters: {'iterations': 1000, 'depth': 4, 'learning_rate': 0.034873736306878726, 'l2_leaf_reg': 10.752711452884656, 'random_strength': 1.2842672948589908, 'bagging_temperature': 0.9136294304309416}. Best is trial 64 with value: 0.7467433953423882.
# [I 2026-03-13 00:15:02,100] Trial 89 finished with value: 0.7414034720656023 and parameters: {'iterations': 1000, 'depth': 4, 'learning_rate': 0.03427937170364592, 'l2_leaf_reg': 11.083471484296528, 'random_strength': 1.2952334205453424, 'bagging_temperature': 0.8971645420371003}. Best is trial 64 with value: 0.7467433953423882.
# [I 2026-03-13 00:15:13,288] Trial 90 finished with value: 0.7413466131727091 and parameters: {'iterations': 1000, 'depth': 4, 'learning_rate': 0.03003663938817357, 'l2_leaf_reg': 7.201404826483799, 'random_strength': 1.4146152847538278, 'bagging_temperature': 0.9278452049880958}. Best is trial 64 with value: 0.7467433953423882.
# [I 2026-03-13 00:15:24,074] Trial 91 finished with value: 0.7434713982891216 and parameters: {'iterations': 1000, 'depth': 4, 'learning_rate': 0.03965566180015234, 'l2_leaf_reg': 10.233740659979178, 'random_strength': 1.2338268398279033, 'bagging_temperature': 0.9689442440424875}. Best is trial 64 with value: 0.7467433953423882.
# [I 2026-03-13 00:15:37,059] Trial 92 finished with value: 0.7378748081882675 and parameters: {'iterations': 1200, 'depth': 4, 'learning_rate': 0.03889544919911649, 'l2_leaf_reg': 10.605382498902593, 'random_strength': 1.2410416917391085, 'bagging_temperature': 0.98187470037083}. Best is trial 64 with value: 0.7467433953423882.
# [I 2026-03-13 00:15:48,069] Trial 93 finished with value: 0.7352821938427437 and parameters: {'iterations': 1000, 'depth': 4, 'learning_rate': 0.04467563538763138, 'l2_leaf_reg': 9.531008575427812, 'random_strength': 1.3483914674250856, 'bagging_temperature': 0.9049458532853495}. Best is trial 64 with value: 0.7467433953423882.
# [I 2026-03-13 00:15:59,104] Trial 94 finished with value: 0.7444543753896024 and parameters: {'iterations': 1000, 'depth': 4, 'learning_rate': 0.035022108347304806, 'l2_leaf_reg': 12.007887208373779, 'random_strength': 1.1634769628068844, 'bagging_temperature': 0.999871030460712}. Best is trial 64 with value: 0.7467433953423882.
# [I 2026-03-13 00:16:09,824] Trial 95 finished with value: 0.7401915488917264 and parameters: {'iterations': 1000, 'depth': 4, 'learning_rate': 0.03946585137455098, 'l2_leaf_reg': 11.977654148447726, 'random_strength': 1.1501457956006509, 'bagging_temperature': 0.9346949084635934}. Best is trial 64 with value: 0.7467433953423882.
# [I 2026-03-13 00:16:20,849] Trial 96 finished with value: 0.7392662537384247 and parameters: {'iterations': 1000, 'depth': 4, 'learning_rate': 0.03517377527690839, 'l2_leaf_reg': 10.954871564796418, 'random_strength': 1.2906477607382507, 'bagging_temperature': 0.9684935844389642}. Best is trial 64 with value: 0.7467433953423882.
# [I 2026-03-13 00:16:31,897] Trial 97 finished with value: 0.7400193532552682 and parameters: {'iterations': 1000, 'depth': 4, 'learning_rate': 0.03414294011226355, 'l2_leaf_reg': 11.966545035314285, 'random_strength': 1.5577224281990374, 'bagging_temperature': 0.9418736773069946}. Best is trial 64 with value: 0.7467433953423882.
# [I 2026-03-13 00:16:42,690] Trial 98 finished with value: 0.719586353099853 and parameters: {'iterations': 1000, 'depth': 4, 'learning_rate': 0.03715858649304074, 'l2_leaf_reg': 1.0281271151093825, 'random_strength': 1.4081917892969023, 'bagging_temperature': 0.0024512556773800265}. Best is trial 64 with value: 0.7467433953423882.
# [I 2026-03-13 00:17:02,765] Trial 99 finished with value: 0.7227741782006539 and parameters: {'iterations': 1200, 'depth': 5, 'learning_rate': 0.03599530068401304, 'l2_leaf_reg': 3.449706817385973, 'random_strength': 1.2437192289683028, 'bagging_temperature': 0.9015393060789464}. Best is trial 64 with value: 0.7467433953423882.
# === Optuna done for CatBoost ===
# Best macro-F1 (CV): 0.7467433953423882
# Best params: {'iterations': 800, 'depth': 4, 'learning_rate': 0.041088388957636536, 'l2_leaf_reg': 13.015076956023337, 'random_strength': 2.067964291848626, 'bagging_temperature': 0.7782757305660519}
# Saving optuna parameters: C:\Users\NFU_Power_Lab\Desktop\DAT_ResearchArea\BestAwardAI2026\BaseModel\CatBoost\CatBoostCopulaGan\catboost-copulagan.json
# === Baseline Classification on Random Split ===
# RandomSplit Accuracy: 0.7945 | F1-macro: 0.7811 | F1-weighted: 0.7943
#
# Classification report (RandomSplit):
#               precision    recall  f1-score   support
#
#            A     1.0000    1.0000    1.0000         4
#            B     1.0000    0.8000    0.8889        15
#            C     1.0000    1.0000    1.0000         2
#            D     0.6667    0.8889    0.7619         9
#            E     0.9091    0.7692    0.8333        13
#            F     0.0000    0.0000    0.0000         0
#            G     0.9000    1.0000    0.9474         9
#            H     0.7059    0.7273    0.7164        33
#            I     1.0000    1.0000    1.0000         3
#            J     0.6875    0.4783    0.5641        23
#            K     0.8250    0.9429    0.8800        35
#
#     accuracy                         0.7945       146
#    macro avg     0.7904    0.7824    0.7811       146
# weighted avg     0.8075    0.7945    0.7943       146
#
# Saved: baseline_cm_random_copulagan.csv
# Saved: baseline_preds_random_cls_copulagan.csv
