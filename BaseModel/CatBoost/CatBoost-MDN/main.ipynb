# %%
import os
import warnings

from catboost import CatBoostClassifier
import pandas as pd
import numpy as np
import optuna
import json

warnings.filterwarnings("ignore")

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix
from sklearn.model_selection import StratifiedKFold

def eval_classification(y_true, y_pred, name=""):
    acc = accuracy_score(y_true, y_pred)
    f1_macro = f1_score(y_true, y_pred, average="macro")
    f1_weighted = f1_score(y_true, y_pred, average="weighted")
    print(f"{name} Accuracy: {acc:.4f} | F1-macro: {f1_macro:.4f} | F1-weighted: {f1_weighted:.4f}")
    return acc, f1_macro, f1_weighted

def save_preds_csv(X_test, y_true, y_pred, filename):
    out = X_test.copy()
    out["y_true"] = y_true
    out["y_pred"] = y_pred
    out.to_csv(filename, index=False, encoding="utf-8-sig")
    print(f"Saved: {filename}")

def derive_groups_from_train(train_df, k_baseline_dict, min_group_size=2):
    """
    Returns: type_to_group dict, groups dict
    Uses only train_df to avoid test leakage.
    Phân loại các 'type' thành near/mid/far dựa trên trung bình độ lệch tuyệt đối (abs_diff)
    """
    df_temp = train_df.copy()
    df_temp["k_eff_expected"] = df_temp["load"].map(k_baseline_dict)
    if df_temp["k_eff_expected"].isnull().any():
        known_loads = np.array(list(k_baseline_dict.keys()))
        for idx, row in df_temp[df_temp["k_eff_expected"].isnull()].iterrows():
            closest_load = known_loads[np.abs(known_loads - row["load"]).argmin()]
            df_temp.loc[idx, "k_eff_expected"] = k_baseline_dict[closest_load]     
    df_temp["abs_diff"] = (df_temp["efficiency"] - df_temp["k_eff_expected"]).abs()
    type_stats = (
        df_temp.groupby("type")["abs_diff"]
        .agg(n="count", mean="mean")
        .sort_values("mean")
        .reset_index()
    )
    types = type_stats["type"].tolist()
    x = type_stats["mean"].to_numpy()
    n = len(x)
    # Prefix sums for O(1) segment SSE
    S1 = np.concatenate([[0.0], np.cumsum(x)])
    S2 = np.concatenate([[0.0], np.cumsum(x * x)])
    def seg_sse(i, j):
        m = j - i + 1
        sum1 = S1[j + 1] - S1[i]
        sum2 = S2[j + 1] - S2[i]
        mu = sum1 / m
        return sum2 - 2 * mu * sum1 + m * mu * mu

    K = 3
    INF = 1e18
    dp = np.full((K + 1, n + 1), INF)
    cut = np.full((K + 1, n + 1), -1, dtype=int)

    dp[0, 0] = 0.0
    for k in range(1, K + 1):
        for t in range(1, n + 1):
            p_min = (k - 1) * min_group_size
            p_max = t - min_group_size
            if p_max < p_min:
                continue
            best_cost, best_p = INF, -1
            for p in range(p_min, p_max + 1):
                cost = dp[k - 1, p] + seg_sse(p, t - 1)
                if cost < best_cost:
                    best_cost, best_p = cost, p
            dp[k, t] = best_cost
            cut[k, t] = best_p

    if np.isinf(dp[K, n]):
        raise RuntimeError("No valid split found. Try min_group_size=1 or check types count.")
    bounds = []
    t = n
    for k in range(K, 0, -1):
        p = cut[k, t]
        bounds.append((p, t))
        t = p
    bounds.reverse()
    group_names = ["near", "mid", "far"] 
    groups = {}
    for name, (a, b) in zip(group_names, bounds):
        groups[name] = types[a:b]

    type_to_group = {t: g for g, ts in groups.items() for t in ts}
    return type_to_group, groups, type_stats

def catboost_objective(trial):
    params = {
        "iterations": trial.suggest_int("iterations", 600, 1400, step=200),
        "depth": trial.suggest_int("depth", 4, 8), 
        "learning_rate": trial.suggest_float("learning_rate", 0.02, 0.15, log=True),
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1.0, 20.0, log=True),
        "random_strength": trial.suggest_float("random_strength", 0.5, 3.0),
        "bagging_temperature": trial.suggest_float("bagging_temperature", 0.0, 1.0),
        "auto_class_weights": "Balanced",
        "loss_function": "MultiClass",
        "random_seed": 42,
        "verbose": False,
    }
    skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
    f1s = []
    X = X_train_r
    y = y_train_r
    for tr_idx, va_idx in skf.split(X, y):
        X_tr, X_va = X.iloc[tr_idx], X.iloc[va_idx]
        y_tr, y_va = y.iloc[tr_idx], y.iloc[va_idx]
        model = CatBoostClassifier(**params)
        pipe_cv = Pipeline([
            ("scaler", StandardScaler()),
            ("clf", model),
        ])
        pipe_cv.fit(X_tr, y_tr)
        pred = pipe_cv.predict(X_va).ravel()
        f1s.append(f1_score(y_va, pred, average="macro"))

    return float(np.mean(f1s))


# ----- Load your saved split files -----
train_random = pd.read_csv("C:\\Users\\NFU_Power_Lab\\Desktop\\DAT_ResearchArea\\BestAwardAI2026\\GenerativeModel\\MDNGenData\\wpt_train_random_aug_mdn.csv")
test_random  = pd.read_csv("C:\\Users\\NFU_Power_Lab\\Desktop\\DAT_ResearchArea\\BestAwardAI2026\\random-split\\wpt_test_random.csv")
catboost_json_path = r"C:\Users\NFU_Power_Lab\Desktop\DAT_ResearchArea\BestAwardAI2026\BaseModel\CatBoost-MDN\catboost-mdn.json"

# Sanity check expected columns
expected_cols = {"type", "load", "efficiency"}
for name, d in [("train_random", train_random), ("test_random", test_random)]:
    missing = expected_cols - set(d.columns)
    if missing:
        raise ValueError(f"{name} is missing columns: {missing}")

# Make sure numeric columns are numeric
for d in [train_random, test_random]:
    d["load"] = pd.to_numeric(d["load"], errors="coerce")
    d["efficiency"] = pd.to_numeric(d["efficiency"], errors="coerce")
    d["type"] = d["type"].astype(str)
    d.dropna(subset=["type", "load", "efficiency"], inplace=True)

# Features / target
FEATURES = ["load", "efficiency"]
TARGET = "type"

# =========================
def add_advanced_features(df, k_baseline_dict, type_to_group_dict):
    df = df.copy()
    df["k_eff_expected"] = df["load"].map(k_baseline_dict)
    if df["k_eff_expected"].isnull().any():
        known_loads = np.array(list(k_baseline_dict.keys()))
        for idx, row in df[df["k_eff_expected"].isnull()].iterrows():
            closest_load = known_loads[np.abs(known_loads - row["load"]).argmin()]
            df.loc[idx, "k_eff_expected"] = k_baseline_dict[closest_load]  
    # 2. Độ lệch (Difference) và Tỷ lệ (Ratio)
    df["eff_diff"] = df["efficiency"] - df["k_eff_expected"]
    df["eff_ratio"] = df["efficiency"] / df["k_eff_expected"]
    # 3. Ước tính tổn hao công suất (Power Loss Proxy)
    # P_loss = Load * (1 / (Efficiency / 100) - 1)
    df["p_loss"] = df["load"] * (1 / (df["efficiency"] / 100.0) - 1)
    # Tổn hao công suất của Class K
    df["k_p_loss"] = df["load"] * (1 / (df["k_eff_expected"] / 100.0) - 1)
    # Độ lệch suy hao do vật thể lạ gây ra
    df["p_loss_diff"] = df["p_loss"] - df["k_p_loss"]

    df["dist_zone_name"] = df["type"].map(type_to_group_dict).fillna("far")
    # Mã hóa thành số
    zone_mapping = {"near": 1, "mid": 2, "far": 3}
    df["dist_zone"] = df["dist_zone_name"].map(zone_mapping)
    # 4. Phân vùng Dải tải (Load Zone)
    # Giả sử dải tải từ 0.5 đến 3.0, chia làm 3 vùng: Nhẹ (1), Vừa (2), Nặng (3)
    df['load_zone'] = pd.cut(df['load'], bins=3, labels=[1, 2, 3]).astype(float)
    return df

k_baseline_train_r = train_random[train_random["type"] == "K"].groupby("load")["efficiency"].mean().to_dict()
type_to_group, groups_dict, stats = derive_groups_from_train(train_random, k_baseline_train_r)
print("Results of grouping the Types:", groups_dict)

train_random_fe = add_advanced_features(train_random, k_baseline_train_r, type_to_group)
test_random_fe = add_advanced_features(test_random, k_baseline_train_r, type_to_group)

FEATURES_NEW = [
    "load", "efficiency", 
    "eff_diff", "eff_ratio", 
    "p_loss_diff", "load_zone", "dist_zone"
]
# =========================
X_train_r = train_random_fe[FEATURES_NEW]
y_train_r = train_random_fe[TARGET]
X_test_r  = test_random_fe[FEATURES_NEW]
y_test_r  = test_random_fe[TARGET]

# ========================
# Choose a baseline classifier
# =========================
OPTUNA_TRIALS = 100
study = optuna.create_study(direction="maximize")
study.optimize(catboost_objective, n_trials=OPTUNA_TRIALS)

print("\n=== Optuna done for CatBoost ===")
print("Best macro-F1 (CV):", study.best_value)
print("Best params:", study.best_params)

best_params = study.best_params
os.makedirs(os.path.dirname(catboost_json_path), exist_ok=True)

with open(catboost_json_path, 'w', encoding='utf-8') as f:
    json.dump(best_params, f, indent=4)
print(f"Saving optuna parameters: {catboost_json_path}")

clf = CatBoostClassifier(
    iterations=best_params.get("iterations", 1000),
    depth=best_params.get("depth", 6),
    learning_rate=best_params.get("learning_rate", 0.05),
    l2_leaf_reg=best_params.get("l2_leaf_reg", 3.0),
    random_strength=best_params.get("random_strength", 1.0),
    bagging_temperature=best_params.get("bagging_temperature", 0.0),
    auto_class_weights='Balanced',
    loss_function='MultiClass',
    random_seed=42,
    verbose=False
)

# Pipeline: scale numeric features (safe for most models)
pipe = Pipeline([
    ("scaler", StandardScaler()),
    ("clf", clf),
])

# Pipeline: scale numeric features (safe for most models)
pipe = Pipeline([
    ("scaler", StandardScaler()),
    ("clf", clf),
])

# =========================
# Train/Eval on Random Split
# =========================
pipe.fit(X_train_r, y_train_r)
pred_r = pipe.predict(X_test_r).ravel()

print("=== Baseline Classification on Random Split ===")
eval_classification(y_test_r, pred_r, name="RandomSplit")

print("\nClassification report (RandomSplit):")
print(classification_report(y_test_r, pred_r, digits=4))

cm_r = confusion_matrix(y_test_r, pred_r, labels=sorted(y_train_r.unique()))
cm_r_df = pd.DataFrame(cm_r, index=sorted(y_train_r.unique()), columns=sorted(y_train_r.unique()))
cm_r_df.to_csv("baseline_cm_random_mdn.csv", encoding="utf-8-sig")
print("Saved: baseline_cm_random_mdn.csv")

save_preds_csv(X_test_r, y_test_r.values, pred_r, "baseline_preds_random_cls_mdn.csv")
# Out:
# [I 2026-03-12 16:27:39,368] A new study created in memory with name: no-name-1b0dde87-358f-4809-be6e-41747135331f
# Results of grouping the Types: {'near': ['K', 'H', 'J', 'I', 'G'], 'mid': ['F', 'E', 'D', 'B'], 'far': ['C', 'A']}
# [I 2026-03-12 16:28:20,675] Trial 0 finished with value: 0.7812536304170786 and parameters: {'iterations': 600, 'depth': 7, 'learning_rate': 0.10020367095275196, 'l2_leaf_reg': 1.9376026797377168, 'random_strength': 1.5080321256725857, 'bagging_temperature': 0.5597049694331947}. Best is trial 0 with value: 0.7812536304170786.
# [I 2026-03-12 16:28:43,031] Trial 1 finished with value: 0.7942141295638878 and parameters: {'iterations': 600, 'depth': 6, 'learning_rate': 0.04650906150115029, 'l2_leaf_reg': 13.031488448885606, 'random_strength': 2.877208949728666, 'bagging_temperature': 0.12721939438686825}. Best is trial 1 with value: 0.7942141295638878.
# [I 2026-03-12 16:30:18,174] Trial 2 finished with value: 0.7828039214762922 and parameters: {'iterations': 1400, 'depth': 7, 'learning_rate': 0.11156779639834906, 'l2_leaf_reg': 13.394838401288158, 'random_strength': 1.6906052889423588, 'bagging_temperature': 0.9115508160194367}. Best is trial 1 with value: 0.7942141295638878.
# [I 2026-03-12 16:33:11,656] Trial 3 finished with value: 0.7948407361929202 and parameters: {'iterations': 1400, 'depth': 8, 'learning_rate': 0.030376787412989704, 'l2_leaf_reg': 4.256087433460212, 'random_strength': 2.113856729568959, 'bagging_temperature': 0.5005437298208893}. Best is trial 3 with value: 0.7948407361929202.
# [I 2026-03-12 16:36:06,069] Trial 4 finished with value: 0.7880397342920317 and parameters: {'iterations': 1400, 'depth': 8, 'learning_rate': 0.035759857307566374, 'l2_leaf_reg': 3.1537492792191957, 'random_strength': 0.7578484867218875, 'bagging_temperature': 0.28439841982547653}. Best is trial 3 with value: 0.7948407361929202.
# [I 2026-03-12 16:37:46,480] Trial 5 finished with value: 0.7877950712494141 and parameters: {'iterations': 1400, 'depth': 7, 'learning_rate': 0.06014644337997974, 'l2_leaf_reg': 2.9905211244524343, 'random_strength': 2.142030600772834, 'bagging_temperature': 0.21279683415833095}. Best is trial 3 with value: 0.7948407361929202.
# [I 2026-03-12 16:38:42,146] Trial 6 finished with value: 0.7941679700278481 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.041796637707574295, 'l2_leaf_reg': 8.758822490586452, 'random_strength': 1.8491614683710327, 'bagging_temperature': 0.7970711192360403}. Best is trial 3 with value: 0.7948407361929202.
# [I 2026-03-12 16:39:36,843] Trial 7 finished with value: 0.79046146647629 and parameters: {'iterations': 1200, 'depth': 6, 'learning_rate': 0.027683129416372354, 'l2_leaf_reg': 2.4472314276137612, 'random_strength': 2.424607651628683, 'bagging_temperature': 0.5029761199120643}. Best is trial 3 with value: 0.7948407361929202.
# [I 2026-03-12 16:40:32,098] Trial 8 finished with value: 0.7828787252043652 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.12752799597496214, 'l2_leaf_reg': 4.486540724735664, 'random_strength': 1.9424575267295978, 'bagging_temperature': 0.2100737998128227}. Best is trial 3 with value: 0.7948407361929202.
# [I 2026-03-12 16:41:04,713] Trial 9 finished with value: 0.7928891177721366 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.07603076797245827, 'l2_leaf_reg': 19.075602313496518, 'random_strength': 2.1250669020726294, 'bagging_temperature': 0.1043762923064051}. Best is trial 3 with value: 0.7948407361929202.
# [I 2026-03-12 16:41:29,078] Trial 10 finished with value: 0.7956302125005563 and parameters: {'iterations': 1200, 'depth': 5, 'learning_rate': 0.020904499100209695, 'l2_leaf_reg': 6.000932583398665, 'random_strength': 1.2256941888283024, 'bagging_temperature': 0.6947311843614468}. Best is trial 10 with value: 0.7956302125005563.
# [I 2026-03-12 16:41:44,924] Trial 11 finished with value: 0.7900598728369159 and parameters: {'iterations': 1200, 'depth': 4, 'learning_rate': 0.02082217070160996, 'l2_leaf_reg': 5.879156229737291, 'random_strength': 1.1904575786536973, 'bagging_temperature': 0.6857147452340216}. Best is trial 10 with value: 0.7956302125005563.
# [I 2026-03-12 16:42:00,668] Trial 12 finished with value: 0.7880997462691802 and parameters: {'iterations': 1200, 'depth': 4, 'learning_rate': 0.02014769407063786, 'l2_leaf_reg': 1.3268743892873753, 'random_strength': 1.1307490665359754, 'bagging_temperature': 0.38372516612050145}. Best is trial 10 with value: 0.7956302125005563.
# [I 2026-03-12 16:42:20,438] Trial 13 finished with value: 0.7938591336838948 and parameters: {'iterations': 1000, 'depth': 5, 'learning_rate': 0.029903020154611416, 'l2_leaf_reg': 5.78234026123733, 'random_strength': 0.7590703570670249, 'bagging_temperature': 0.6677225916124732}. Best is trial 10 with value: 0.7956302125005563.
# [I 2026-03-12 16:42:45,109] Trial 14 finished with value: 0.792806787482343 and parameters: {'iterations': 1200, 'depth': 5, 'learning_rate': 0.026688998764541352, 'l2_leaf_reg': 7.812149725222825, 'random_strength': 2.614062664534982, 'bagging_temperature': 0.9980907150605824}. Best is trial 10 with value: 0.7956302125005563.
# [I 2026-03-12 16:44:52,430] Trial 15 finished with value: 0.7939270211148329 and parameters: {'iterations': 1000, 'depth': 8, 'learning_rate': 0.03419642438471462, 'l2_leaf_reg': 4.129605364592183, 'random_strength': 1.1567448406592875, 'bagging_temperature': 0.40780452316496807}. Best is trial 10 with value: 0.7956302125005563.
# [I 2026-03-12 16:45:23,744] Trial 16 finished with value: 0.7883275202474495 and parameters: {'iterations': 1400, 'depth': 5, 'learning_rate': 0.024606402562451033, 'l2_leaf_reg': 1.1107533444381879, 'random_strength': 1.4314044675132584, 'bagging_temperature': 0.6327910760620032}. Best is trial 10 with value: 0.7956302125005563.
# [I 2026-03-12 16:45:47,751] Trial 17 finished with value: 0.7906111710845777 and parameters: {'iterations': 1200, 'depth': 5, 'learning_rate': 0.05752533849782763, 'l2_leaf_reg': 7.956683549193395, 'random_strength': 0.5000421025663746, 'bagging_temperature': 0.7836509165304726}. Best is trial 10 with value: 0.7956302125005563.
# [I 2026-03-12 16:48:48,295] Trial 18 finished with value: 0.7846879447180569 and parameters: {'iterations': 1400, 'depth': 8, 'learning_rate': 0.04154441854767358, 'l2_leaf_reg': 1.7621173645727601, 'random_strength': 2.3740928726499106, 'bagging_temperature': 0.42517624834670875}. Best is trial 10 with value: 0.7956302125005563.
# [I 2026-03-12 16:49:01,841] Trial 19 finished with value: 0.7936447472900375 and parameters: {'iterations': 1000, 'depth': 4, 'learning_rate': 0.023473128786553707, 'l2_leaf_reg': 4.37274212948275, 'random_strength': 1.4158192493987376, 'bagging_temperature': 0.7904328276830103}. Best is trial 10 with value: 0.7956302125005563.
# [I 2026-03-12 16:49:47,183] Trial 20 finished with value: 0.7925956848405762 and parameters: {'iterations': 1200, 'depth': 6, 'learning_rate': 0.0318559333499273, 'l2_leaf_reg': 11.090998333173069, 'random_strength': 2.9926882153482355, 'bagging_temperature': 0.5351731978755601}. Best is trial 10 with value: 0.7956302125005563.
# [I 2026-03-12 16:50:10,573] Trial 21 finished with value: 0.7942621148016057 and parameters: {'iterations': 600, 'depth': 6, 'learning_rate': 0.04533517103096304, 'l2_leaf_reg': 16.552313078156214, 'random_strength': 2.982447135266525, 'bagging_temperature': 0.040564734347090625}. Best is trial 10 with value: 0.7956302125005563.
# [I 2026-03-12 16:50:34,284] Trial 22 finished with value: 0.7963086719970222 and parameters: {'iterations': 600, 'depth': 6, 'learning_rate': 0.04836785582778066, 'l2_leaf_reg': 18.90127450198527, 'random_strength': 2.73202697203741, 'bagging_temperature': 0.03722884167514695}. Best is trial 22 with value: 0.7963086719970222.
# [I 2026-03-12 16:50:50,137] Trial 23 finished with value: 0.7970336243102437 and parameters: {'iterations': 800, 'depth': 5, 'learning_rate': 0.07522287481367743, 'l2_leaf_reg': 5.864517523949338, 'random_strength': 2.6562493764994946, 'bagging_temperature': 0.3396080583705371}. Best is trial 23 with value: 0.7970336243102437.
# [I 2026-03-12 16:51:05,767] Trial 24 finished with value: 0.7891992371969749 and parameters: {'iterations': 800, 'depth': 5, 'learning_rate': 0.08794232814835018, 'l2_leaf_reg': 6.279873775642113, 'random_strength': 2.528242189290005, 'bagging_temperature': 0.004482313636195001}. Best is trial 23 with value: 0.7970336243102437.
# [I 2026-03-12 16:51:17,906] Trial 25 finished with value: 0.7931154968521094 and parameters: {'iterations': 600, 'depth': 5, 'learning_rate': 0.07482632692505799, 'l2_leaf_reg': 10.154645959780789, 'random_strength': 2.666681589755825, 'bagging_temperature': 0.3173616193118509}. Best is trial 23 with value: 0.7970336243102437.
# [I 2026-03-12 16:51:27,487] Trial 26 finished with value: 0.7957642049951557 and parameters: {'iterations': 800, 'depth': 4, 'learning_rate': 0.07102820154280534, 'l2_leaf_reg': 13.995900275779134, 'random_strength': 2.7607366030287213, 'bagging_temperature': 0.17713634460159428}. Best is trial 23 with value: 0.7970336243102437.
# [I 2026-03-12 16:51:38,365] Trial 27 finished with value: 0.7954500428614865 and parameters: {'iterations': 800, 'depth': 4, 'learning_rate': 0.06275423332995544, 'l2_leaf_reg': 15.72198685969181, 'random_strength': 2.7592903406099967, 'bagging_temperature': 0.16282529547200897}. Best is trial 23 with value: 0.7970336243102437.
# [I 2026-03-12 16:51:46,092] Trial 28 finished with value: 0.7940928711799295 and parameters: {'iterations': 600, 'depth': 4, 'learning_rate': 0.07169914789112497, 'l2_leaf_reg': 19.717001829001276, 'random_strength': 2.3007385317134332, 'bagging_temperature': 0.2878311236617519}. Best is trial 23 with value: 0.7970336243102437.
# [I 2026-03-12 16:51:56,512] Trial 29 finished with value: 0.791098520259065 and parameters: {'iterations': 800, 'depth': 4, 'learning_rate': 0.08465985292139303, 'l2_leaf_reg': 13.098617248244828, 'random_strength': 2.76142615849057, 'bagging_temperature': 0.0633749991044176}. Best is trial 23 with value: 0.7970336243102437.
# [I 2026-03-12 16:52:20,478] Trial 30 finished with value: 0.7886965878433742 and parameters: {'iterations': 600, 'depth': 6, 'learning_rate': 0.09694246927417896, 'l2_leaf_reg': 10.722178963508563, 'random_strength': 2.2680506549741057, 'bagging_temperature': 0.20327645132156835}. Best is trial 23 with value: 0.7970336243102437.
# [I 2026-03-12 16:52:43,443] Trial 31 finished with value: 0.7826981086132476 and parameters: {'iterations': 1000, 'depth': 5, 'learning_rate': 0.1459608841744491, 'l2_leaf_reg': 7.22327719148433, 'random_strength': 2.49976092871741, 'bagging_temperature': 0.33659220620836433}. Best is trial 23 with value: 0.7970336243102437.
# [I 2026-03-12 16:52:57,994] Trial 32 finished with value: 0.7960239663450577 and parameters: {'iterations': 600, 'depth': 5, 'learning_rate': 0.04968342886213152, 'l2_leaf_reg': 14.6129896790813, 'random_strength': 2.8831042152642614, 'bagging_temperature': 0.15116318112209587}. Best is trial 23 with value: 0.7970336243102437.
# [I 2026-03-12 16:53:22,760] Trial 33 finished with value: 0.7970783445885142 and parameters: {'iterations': 600, 'depth': 6, 'learning_rate': 0.05021679098721864, 'l2_leaf_reg': 15.929925061019667, 'random_strength': 2.8271493116354107, 'bagging_temperature': 0.1419509803798643}. Best is trial 33 with value: 0.7970783445885142.
# [I 2026-03-12 16:53:45,572] Trial 34 finished with value: 0.7958289941612713 and parameters: {'iterations': 600, 'depth': 6, 'learning_rate': 0.05369544221251524, 'l2_leaf_reg': 16.329752665130563, 'random_strength': 2.8702923969563297, 'bagging_temperature': 0.10997088410935416}. Best is trial 33 with value: 0.7970783445885142.
# [I 2026-03-12 16:54:07,972] Trial 35 finished with value: 0.7926242385392657 and parameters: {'iterations': 600, 'depth': 6, 'learning_rate': 0.05086899934096527, 'l2_leaf_reg': 10.882286641249522, 'random_strength': 2.85994413600345, 'bagging_temperature': 0.2365782660463629}. Best is trial 33 with value: 0.7970783445885142.
# [I 2026-03-12 16:54:47,984] Trial 36 finished with value: 0.8018169442225128 and parameters: {'iterations': 600, 'depth': 7, 'learning_rate': 0.03831373613294905, 'l2_leaf_reg': 19.6439943159105, 'random_strength': 2.6211804153994507, 'bagging_temperature': 0.13009291826924274}. Best is trial 36 with value: 0.8018169442225128.
# [I 2026-03-12 16:55:31,669] Trial 37 finished with value: 0.7919911069419984 and parameters: {'iterations': 600, 'depth': 7, 'learning_rate': 0.04080942107912601, 'l2_leaf_reg': 19.31908710434408, 'random_strength': 2.5974454457003526, 'bagging_temperature': 0.008333764808020228}. Best is trial 36 with value: 0.8018169442225128.
# [I 2026-03-12 16:56:13,636] Trial 38 finished with value: 0.802119841079716 and parameters: {'iterations': 600, 'depth': 7, 'learning_rate': 0.037264786753506196, 'l2_leaf_reg': 12.606917804281286, 'random_strength': 1.6616111131347158, 'bagging_temperature': 0.08485875476826155}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 16:57:12,473] Trial 39 finished with value: 0.8003778841518899 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.03622463965787561, 'l2_leaf_reg': 11.869583695829691, 'random_strength': 1.7804225431552259, 'bagging_temperature': 0.2545194812541056}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 16:57:54,339] Trial 40 finished with value: 0.8010837033065584 and parameters: {'iterations': 600, 'depth': 7, 'learning_rate': 0.036809769413449905, 'l2_leaf_reg': 12.037467116600181, 'random_strength': 1.5687142827394518, 'bagging_temperature': 0.09708180802901395}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 16:58:32,684] Trial 41 finished with value: 0.7996321373118197 and parameters: {'iterations': 600, 'depth': 7, 'learning_rate': 0.037279562752100655, 'l2_leaf_reg': 9.365597194763474, 'random_strength': 1.6926375417095698, 'bagging_temperature': 0.08505674440481337}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 16:59:14,170] Trial 42 finished with value: 0.8009485070884796 and parameters: {'iterations': 600, 'depth': 7, 'learning_rate': 0.037232677846853926, 'l2_leaf_reg': 12.037784804185964, 'random_strength': 1.7026882883756589, 'bagging_temperature': 0.0849799196750447}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 17:00:10,368] Trial 43 finished with value: 0.7954969608472254 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.037386745049279066, 'l2_leaf_reg': 11.714939289757917, 'random_strength': 1.8913640077347433, 'bagging_temperature': 0.2572821220275189}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 17:00:52,218] Trial 44 finished with value: 0.8001691037628621 and parameters: {'iterations': 600, 'depth': 7, 'learning_rate': 0.032253144807398326, 'l2_leaf_reg': 11.857691157086517, 'random_strength': 1.5366383594437851, 'bagging_temperature': 0.103410151389626}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 17:01:47,496] Trial 45 finished with value: 0.7996803323648543 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.04355497187317705, 'l2_leaf_reg': 12.946800454780707, 'random_strength': 1.5787227023250279, 'bagging_temperature': 0.19326606850847206}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 17:02:59,200] Trial 46 finished with value: 0.7951911010392786 and parameters: {'iterations': 600, 'depth': 8, 'learning_rate': 0.038410878193455074, 'l2_leaf_reg': 9.069003223930471, 'random_strength': 1.9968118548546472, 'bagging_temperature': 0.11683268967977378}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 17:03:52,831] Trial 47 finished with value: 0.7963121840969775 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.028709902712216486, 'l2_leaf_reg': 13.225626369075172, 'random_strength': 1.7746228265808288, 'bagging_temperature': 0.24553927945960496}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 17:04:32,604] Trial 48 finished with value: 0.7989615931518403 and parameters: {'iterations': 600, 'depth': 7, 'learning_rate': 0.034242903101174144, 'l2_leaf_reg': 9.438683446578397, 'random_strength': 1.3196028949219802, 'bagging_temperature': 0.1468878921592653}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 17:06:10,164] Trial 49 finished with value: 0.8006294455458467 and parameters: {'iterations': 800, 'depth': 8, 'learning_rate': 0.0261418697473765, 'l2_leaf_reg': 17.373865335798342, 'random_strength': 1.634952225976533, 'bagging_temperature': 0.07529092460583088}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 17:07:23,650] Trial 50 finished with value: 0.7999027632139112 and parameters: {'iterations': 600, 'depth': 8, 'learning_rate': 0.026542036393504408, 'l2_leaf_reg': 16.83580596369763, 'random_strength': 1.017623923829679, 'bagging_temperature': 0.07673506573035574}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 17:08:57,416] Trial 51 finished with value: 0.7968893916995256 and parameters: {'iterations': 800, 'depth': 8, 'learning_rate': 0.02311766879760856, 'l2_leaf_reg': 14.637209912492224, 'random_strength': 2.031388577380911, 'bagging_temperature': 0.05835807492683096}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 17:09:38,951] Trial 52 finished with value: 0.7972195816935644 and parameters: {'iterations': 600, 'depth': 7, 'learning_rate': 0.03053059880779897, 'l2_leaf_reg': 17.766672069292937, 'random_strength': 1.621606140693078, 'bagging_temperature': 0.029464411756137537}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 17:11:16,481] Trial 53 finished with value: 0.793432424133324 and parameters: {'iterations': 800, 'depth': 8, 'learning_rate': 0.034880598794861474, 'l2_leaf_reg': 8.01047572278689, 'random_strength': 1.7794708229443348, 'bagging_temperature': 0.12867822563539327}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 17:12:29,071] Trial 54 finished with value: 0.8006245277804082 and parameters: {'iterations': 1000, 'depth': 7, 'learning_rate': 0.039751234038925685, 'l2_leaf_reg': 14.924218437088772, 'random_strength': 1.4353832607277786, 'bagging_temperature': 0.07753012267779887}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 17:13:37,653] Trial 55 finished with value: 0.7896403124129213 and parameters: {'iterations': 1000, 'depth': 7, 'learning_rate': 0.040263886190666606, 'l2_leaf_reg': 3.4357257152347853, 'random_strength': 1.4174967983615032, 'bagging_temperature': 0.07188788684408028}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 17:15:41,177] Trial 56 finished with value: 0.8010668779405007 and parameters: {'iterations': 1000, 'depth': 8, 'learning_rate': 0.02532694480305505, 'l2_leaf_reg': 14.806826521105961, 'random_strength': 1.295063155616194, 'bagging_temperature': 0.19196213751547628}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 17:17:43,661] Trial 57 finished with value: 0.8018996194840767 and parameters: {'iterations': 1000, 'depth': 8, 'learning_rate': 0.024966954053354317, 'l2_leaf_reg': 19.993546108232714, 'random_strength': 1.0221845621918935, 'bagging_temperature': 0.18262508846412578}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 17:19:48,496] Trial 58 finished with value: 0.7969863203515509 and parameters: {'iterations': 1000, 'depth': 8, 'learning_rate': 0.024802244579541794, 'l2_leaf_reg': 19.832122627787992, 'random_strength': 1.0032872677354494, 'bagging_temperature': 0.22428902838861345}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 17:21:51,524] Trial 59 finished with value: 0.7949105015903365 and parameters: {'iterations': 1000, 'depth': 8, 'learning_rate': 0.021890695164202095, 'l2_leaf_reg': 12.70736999659178, 'random_strength': 1.2791573619330687, 'bagging_temperature': 0.38227243889674045}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 17:23:57,621] Trial 60 finished with value: 0.7945781670241118 and parameters: {'iterations': 1000, 'depth': 8, 'learning_rate': 0.04521073463163218, 'l2_leaf_reg': 2.1887140905043925, 'random_strength': 0.8860032514429914, 'bagging_temperature': 0.17181767040514911}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 17:25:09,182] Trial 61 finished with value: 0.7949960005501882 and parameters: {'iterations': 600, 'depth': 8, 'learning_rate': 0.02575446070555685, 'l2_leaf_reg': 17.41308819119769, 'random_strength': 1.6439354103923474, 'bagging_temperature': 0.02894490169067629}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 17:27:37,346] Trial 62 finished with value: 0.8006098737440756 and parameters: {'iterations': 1200, 'depth': 8, 'learning_rate': 0.028209594644058093, 'l2_leaf_reg': 14.324981108484987, 'random_strength': 1.4939767622488977, 'bagging_temperature': 0.19492545861890143}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 17:29:44,057] Trial 63 finished with value: 0.7999914317939579 and parameters: {'iterations': 1000, 'depth': 8, 'learning_rate': 0.031050848866012382, 'l2_leaf_reg': 17.776299702050206, 'random_strength': 1.338147668569135, 'bagging_temperature': 0.10275253082426199}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 17:30:53,510] Trial 64 finished with value: 0.7962942137750147 and parameters: {'iterations': 600, 'depth': 8, 'learning_rate': 0.021893402553224976, 'l2_leaf_reg': 15.466696877403855, 'random_strength': 1.8527923675238234, 'bagging_temperature': 0.12955587903193544}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 17:31:49,430] Trial 65 finished with value: 0.796431139513219 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.032440809758002495, 'l2_leaf_reg': 18.15909102243646, 'random_strength': 1.1141594600506957, 'bagging_temperature': 0.2939291191677236}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 17:33:01,058] Trial 66 finished with value: 0.7915462918748272 and parameters: {'iterations': 600, 'depth': 8, 'learning_rate': 0.029108428528516625, 'l2_leaf_reg': 4.880279903412193, 'random_strength': 1.6854809421898211, 'bagging_temperature': 0.8777790834401388}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 17:34:09,310] Trial 67 finished with value: 0.7872873024890005 and parameters: {'iterations': 1000, 'depth': 7, 'learning_rate': 0.024141293259870977, 'l2_leaf_reg': 9.955863951685343, 'random_strength': 0.637678958852582, 'bagging_temperature': 0.4686906724459954}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 17:35:21,722] Trial 68 finished with value: 0.7958162045846344 and parameters: {'iterations': 600, 'depth': 8, 'learning_rate': 0.026694895600421847, 'l2_leaf_reg': 16.393209284016137, 'random_strength': 1.2309543965295033, 'bagging_temperature': 0.17898619001492394}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 17:36:15,442] Trial 69 finished with value: 0.7999971590852676 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.02023200140549515, 'l2_leaf_reg': 12.102012357312402, 'random_strength': 1.5292732200612322, 'bagging_temperature': 0.013752962602039828}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 17:37:23,073] Trial 70 finished with value: 0.7986039641513648 and parameters: {'iterations': 600, 'depth': 8, 'learning_rate': 0.022384887145098138, 'l2_leaf_reg': 13.940573980933832, 'random_strength': 1.0701573527201464, 'bagging_temperature': 0.04962314482076398}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 17:38:34,164] Trial 71 finished with value: 0.8007891232615809 and parameters: {'iterations': 1000, 'depth': 7, 'learning_rate': 0.03337632286073329, 'l2_leaf_reg': 14.528588713890363, 'random_strength': 1.4757643921324113, 'bagging_temperature': 0.09214205475420917}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 17:39:42,343] Trial 72 finished with value: 0.7936324802340331 and parameters: {'iterations': 1000, 'depth': 7, 'learning_rate': 0.0341956891911066, 'l2_leaf_reg': 18.38465458442164, 'random_strength': 1.3621917000933144, 'bagging_temperature': 0.6092392237788521}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 17:40:49,720] Trial 73 finished with value: 0.7972870855423123 and parameters: {'iterations': 1000, 'depth': 7, 'learning_rate': 0.03272330282839876, 'l2_leaf_reg': 13.820657473035071, 'random_strength': 1.5868168097064168, 'bagging_temperature': 0.14649248601324708}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 17:42:11,297] Trial 74 finished with value: 0.7974658939442567 and parameters: {'iterations': 1200, 'depth': 7, 'learning_rate': 0.04257822374101506, 'l2_leaf_reg': 10.88475164778114, 'random_strength': 1.4725839353419308, 'bagging_temperature': 0.09324470033725353}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 17:42:49,631] Trial 75 finished with value: 0.7946850651958153 and parameters: {'iterations': 1000, 'depth': 6, 'learning_rate': 0.030023466083002593, 'l2_leaf_reg': 15.384737955564605, 'random_strength': 1.7321540470099477, 'bagging_temperature': 0.20543920992368908}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 17:43:56,488] Trial 76 finished with value: 0.7985550273684728 and parameters: {'iterations': 1000, 'depth': 7, 'learning_rate': 0.025327931165812657, 'l2_leaf_reg': 16.860360161596716, 'random_strength': 1.9211020040208968, 'bagging_temperature': 0.05149498620754137}. Best is trial 38 with value: 0.802119841079716.
# [I 2026-03-12 17:45:33,555] Trial 77 finished with value: 0.8021460485237055 and parameters: {'iterations': 800, 'depth': 8, 'learning_rate': 0.026745705265258393, 'l2_leaf_reg': 12.94209779745631, 'random_strength': 1.194780299938833, 'bagging_temperature': 0.10779602653783772}. Best is trial 77 with value: 0.8021460485237055.
# [I 2026-03-12 17:46:12,028] Trial 78 finished with value: 0.8053177795508097 and parameters: {'iterations': 600, 'depth': 7, 'learning_rate': 0.027920784211144224, 'l2_leaf_reg': 8.477027677474748, 'random_strength': 0.8829377181878441, 'bagging_temperature': 0.1754012807905727}. Best is trial 78 with value: 0.8053177795508097.
# [I 2026-03-12 17:46:42,806] Trial 79 finished with value: 0.7998563870584322 and parameters: {'iterations': 600, 'depth': 7, 'learning_rate': 0.02736676389447536, 'l2_leaf_reg': 6.8563388002817485, 'random_strength': 0.8925554675872875, 'bagging_temperature': 0.16109753742051713}. Best is trial 78 with value: 0.8053177795508097.
# [I 2026-03-12 17:47:01,056] Trial 80 finished with value: 0.7971687067969694 and parameters: {'iterations': 600, 'depth': 6, 'learning_rate': 0.03614629245037408, 'l2_leaf_reg': 8.094197399023338, 'random_strength': 0.9684104748004114, 'bagging_temperature': 0.28720748400743157}. Best is trial 78 with value: 0.8053177795508097.
# [I 2026-03-12 17:47:33,361] Trial 81 finished with value: 0.8021292369479661 and parameters: {'iterations': 600, 'depth': 7, 'learning_rate': 0.0385377676676327, 'l2_leaf_reg': 11.942293086967178, 'random_strength': 0.7956338099549848, 'bagging_temperature': 0.12260161241166587}. Best is trial 78 with value: 0.8053177795508097.
# [I 2026-03-12 17:48:04,402] Trial 82 finished with value: 0.797299593074683 and parameters: {'iterations': 600, 'depth': 7, 'learning_rate': 0.023645175282006634, 'l2_leaf_reg': 9.956916342876033, 'random_strength': 0.9082264806512446, 'bagging_temperature': 0.12425164759557697}. Best is trial 78 with value: 0.8053177795508097.
# [I 2026-03-12 17:48:35,692] Trial 83 finished with value: 0.790516283530906 and parameters: {'iterations': 600, 'depth': 7, 'learning_rate': 0.061556882831244136, 'l2_leaf_reg': 12.704230667198933, 'random_strength': 0.6972548056915926, 'bagging_temperature': 0.21724266545711546}. Best is trial 78 with value: 0.8053177795508097.
# [I 2026-03-12 17:49:06,918] Trial 84 finished with value: 0.8011854827268552 and parameters: {'iterations': 600, 'depth': 7, 'learning_rate': 0.04471328904132145, 'l2_leaf_reg': 8.584495180864204, 'random_strength': 0.5449373780829943, 'bagging_temperature': 0.0007029158283624187}. Best is trial 78 with value: 0.8053177795508097.
# [I 2026-03-12 17:50:02,704] Trial 85 finished with value: 0.8006727724317458 and parameters: {'iterations': 600, 'depth': 8, 'learning_rate': 0.04511035447905101, 'l2_leaf_reg': 8.676788130970763, 'random_strength': 0.5369742536039914, 'bagging_temperature': 0.0028625820933780716}. Best is trial 78 with value: 0.8053177795508097.
# [I 2026-03-12 17:50:33,637] Trial 86 finished with value: 0.794677088437369 and parameters: {'iterations': 600, 'depth': 7, 'learning_rate': 0.047054804607126, 'l2_leaf_reg': 6.972218995128268, 'random_strength': 0.7534303927608879, 'bagging_temperature': 0.18125982279834899}. Best is trial 78 with value: 0.8053177795508097.
# [I 2026-03-12 17:51:29,167] Trial 87 finished with value: 0.7864297230850262 and parameters: {'iterations': 600, 'depth': 8, 'learning_rate': 0.05594572013521987, 'l2_leaf_reg': 5.186224812227239, 'random_strength': 0.6197947342513664, 'bagging_temperature': 0.26423812182236206}. Best is trial 78 with value: 0.8053177795508097.
# [I 2026-03-12 17:52:00,031] Trial 88 finished with value: 0.7983469006034246 and parameters: {'iterations': 600, 'depth': 7, 'learning_rate': 0.05195555410563681, 'l2_leaf_reg': 11.280531754655302, 'random_strength': 0.8171948416160779, 'bagging_temperature': 0.03062787439535384}. Best is trial 78 with value: 0.8053177795508097.
# [I 2026-03-12 17:52:18,046] Trial 89 finished with value: 0.8031371472870529 and parameters: {'iterations': 600, 'depth': 6, 'learning_rate': 0.042524011956262, 'l2_leaf_reg': 10.293560292068081, 'random_strength': 1.2080355338748676, 'bagging_temperature': 0.11792846930318673}. Best is trial 78 with value: 0.8053177795508097.
# [I 2026-03-12 17:52:36,087] Trial 90 finished with value: 0.7991785087807804 and parameters: {'iterations': 600, 'depth': 6, 'learning_rate': 0.03874209742462495, 'l2_leaf_reg': 8.623551987803191, 'random_strength': 1.1825787734305402, 'bagging_temperature': 0.12318379865391356}. Best is trial 78 with value: 0.8053177795508097.
# [I 2026-03-12 17:52:54,118] Trial 91 finished with value: 0.8033447730799003 and parameters: {'iterations': 600, 'depth': 6, 'learning_rate': 0.04228437490371633, 'l2_leaf_reg': 10.461293409857904, 'random_strength': 0.8145788205169849, 'bagging_temperature': 0.1518362457823908}. Best is trial 78 with value: 0.8053177795508097.
# [I 2026-03-12 17:53:12,145] Trial 92 finished with value: 0.8039554652013795 and parameters: {'iterations': 600, 'depth': 6, 'learning_rate': 0.04241276894496724, 'l2_leaf_reg': 10.063477397908752, 'random_strength': 0.8080236079363617, 'bagging_temperature': 0.1496028400230704}. Best is trial 78 with value: 0.8053177795508097.
# [I 2026-03-12 17:53:30,215] Trial 93 finished with value: 0.8014131908602561 and parameters: {'iterations': 600, 'depth': 6, 'learning_rate': 0.043485760544700415, 'l2_leaf_reg': 10.301048287339679, 'random_strength': 0.8470909531643916, 'bagging_temperature': 0.15843516716271333}. Best is trial 78 with value: 0.8053177795508097.
# [I 2026-03-12 17:53:48,245] Trial 94 finished with value: 0.8021971474654158 and parameters: {'iterations': 600, 'depth': 6, 'learning_rate': 0.04174412903258005, 'l2_leaf_reg': 10.69583770220285, 'random_strength': 0.8111118339078596, 'bagging_temperature': 0.15284352329076506}. Best is trial 78 with value: 0.8053177795508097.
# [I 2026-03-12 17:54:06,325] Trial 95 finished with value: 0.7985746569959308 and parameters: {'iterations': 600, 'depth': 6, 'learning_rate': 0.04782353469014767, 'l2_leaf_reg': 7.4279010733248985, 'random_strength': 0.7892329860813194, 'bagging_temperature': 0.14599920596695215}. Best is trial 78 with value: 0.8053177795508097.
# [I 2026-03-12 17:54:24,369] Trial 96 finished with value: 0.799157103374211 and parameters: {'iterations': 600, 'depth': 6, 'learning_rate': 0.04085481935617282, 'l2_leaf_reg': 9.435373339702123, 'random_strength': 0.9617495430957356, 'bagging_temperature': 0.23013454541171097}. Best is trial 78 with value: 0.8053177795508097.
# [I 2026-03-12 17:54:42,481] Trial 97 finished with value: 0.8009198059398027 and parameters: {'iterations': 600, 'depth': 6, 'learning_rate': 0.04199264171415708, 'l2_leaf_reg': 10.343515602889365, 'random_strength': 0.704698148093774, 'bagging_temperature': 0.11436327037764796}. Best is trial 78 with value: 0.8053177795508097.
# [I 2026-03-12 17:55:00,541] Trial 98 finished with value: 0.7986525966006573 and parameters: {'iterations': 600, 'depth': 6, 'learning_rate': 0.03895512975175069, 'l2_leaf_reg': 11.31497765634712, 'random_strength': 1.0389867441085807, 'bagging_temperature': 0.1648573785298096}. Best is trial 78 with value: 0.8053177795508097.
# [I 2026-03-12 17:55:18,573] Trial 99 finished with value: 0.7976085126522587 and parameters: {'iterations': 600, 'depth': 6, 'learning_rate': 0.035614886675907266, 'l2_leaf_reg': 6.248551277754607, 'random_strength': 1.091899329819782, 'bagging_temperature': 0.13883104031760696}. Best is trial 78 with value: 0.8053177795508097.
# === Optuna done for CatBoost ===
# Best macro-F1 (CV): 0.8053177795508097
# Best params: {'iterations': 600, 'depth': 7, 'learning_rate': 0.027920784211144224, 'l2_leaf_reg': 8.477027677474748, 'random_strength': 0.8829377181878441, 'bagging_temperature': 0.1754012807905727}
# Saving optuna parameters: C:\Users\NFU_Power_Lab\Desktop\DAT_ResearchArea\BestAwardAI2026\BaseModel\CatBoost-MDN\catboost-mdn.json
# === Baseline Classification on Random Split ===
# RandomSplit Accuracy: 0.7603 | F1-macro: 0.7161 | F1-weighted: 0.7639
#
# Classification report (RandomSplit):
#               precision    recall  f1-score   support
#
#            A     1.0000    1.0000    1.0000         4
#            B     1.0000    0.9333    0.9655        15
#            C     1.0000    1.0000    1.0000         2
#            D     0.7273    0.8889    0.8000         9
#            E     0.8571    0.4615    0.6000        13
#            F     0.0000    0.0000    0.0000         0
#            G     0.8889    0.8889    0.8889         9
#            H     0.7059    0.7273    0.7164        33
#            I     0.4000    0.6667    0.5000         3
#            J     0.6667    0.4348    0.5263        23
#            K     0.8250    0.9429    0.8800        35
#
#     accuracy                         0.7603       146
#    macro avg     0.7337    0.7222    0.7161       146
# weighted avg     0.7903    0.7603    0.7639       146
#
# Saved: baseline_cm_random_mdn.csv
# Saved: baseline_preds_random_cls_mdn.csv
