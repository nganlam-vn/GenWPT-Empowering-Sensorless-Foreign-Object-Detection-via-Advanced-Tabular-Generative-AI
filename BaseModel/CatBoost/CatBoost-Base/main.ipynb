# %%
import warnings

from catboost import CatBoostClassifier
import pandas as pd
import numpy as np

warnings.filterwarnings("ignore")

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix
from sklearn.model_selection import StratifiedKFold

import optuna

def eval_classification(y_true, y_pred, name=""):
    acc = accuracy_score(y_true, y_pred)
    f1_macro = f1_score(y_true, y_pred, average="macro")
    f1_weighted = f1_score(y_true, y_pred, average="weighted")
    print(f"{name} Accuracy: {acc:.4f} | F1-macro: {f1_macro:.4f} | F1-weighted: {f1_weighted:.4f}")
    return acc, f1_macro, f1_weighted

def save_preds_csv(X_test, y_true, y_pred, filename):
    out = X_test.copy()
    out["y_true"] = y_true
    out["y_pred"] = y_pred
    out.to_csv(filename, index=False, encoding="utf-8-sig")
    print(f"Saved: {filename}")

def derive_groups_from_train(train_df, k_baseline_dict, min_group_size=2):
    """
    Returns: type_to_group dict, groups dict
    Uses only train_df to avoid test leakage.
    Phân loại các 'type' thành near/mid/far dựa trên trung bình độ lệch tuyệt đối (abs_diff)
    """
    df_temp = train_df.copy()
    df_temp["k_eff_expected"] = df_temp["load"].map(k_baseline_dict)
    if df_temp["k_eff_expected"].isnull().any():
        known_loads = np.array(list(k_baseline_dict.keys()))
        for idx, row in df_temp[df_temp["k_eff_expected"].isnull()].iterrows():
            closest_load = known_loads[np.abs(known_loads - row["load"]).argmin()]
            df_temp.loc[idx, "k_eff_expected"] = k_baseline_dict[closest_load]     
    df_temp["abs_diff"] = (df_temp["efficiency"] - df_temp["k_eff_expected"]).abs()
    type_stats = (
        df_temp.groupby("type")["abs_diff"]
        .agg(n="count", mean="mean")
        .sort_values("mean")
        .reset_index()
    )
    types = type_stats["type"].tolist()
    x = type_stats["mean"].to_numpy()
    n = len(x)
    # Prefix sums for O(1) segment SSE
    S1 = np.concatenate([[0.0], np.cumsum(x)])
    S2 = np.concatenate([[0.0], np.cumsum(x * x)])
    def seg_sse(i, j):
        m = j - i + 1
        sum1 = S1[j + 1] - S1[i]
        sum2 = S2[j + 1] - S2[i]
        mu = sum1 / m
        return sum2 - 2 * mu * sum1 + m * mu * mu

    K = 3
    INF = 1e18
    dp = np.full((K + 1, n + 1), INF)
    cut = np.full((K + 1, n + 1), -1, dtype=int)

    dp[0, 0] = 0.0
    for k in range(1, K + 1):
        for t in range(1, n + 1):
            p_min = (k - 1) * min_group_size
            p_max = t - min_group_size
            if p_max < p_min:
                continue
            best_cost, best_p = INF, -1
            for p in range(p_min, p_max + 1):
                cost = dp[k - 1, p] + seg_sse(p, t - 1)
                if cost < best_cost:
                    best_cost, best_p = cost, p
            dp[k, t] = best_cost
            cut[k, t] = best_p

    if np.isinf(dp[K, n]):
        raise RuntimeError("No valid split found. Try min_group_size=1 or check types count.")
    bounds = []
    t = n
    for k in range(K, 0, -1):
        p = cut[k, t]
        bounds.append((p, t))
        t = p
    bounds.reverse()
    group_names = ["near", "mid", "far"] 
    groups = {}
    for name, (a, b) in zip(group_names, bounds):
        groups[name] = types[a:b]

    type_to_group = {t: g for g, ts in groups.items() for t in ts}
    return type_to_group, groups, type_stats

def catboost_objective(trial):
    params = {
        "iterations": trial.suggest_int("iterations", 600, 1400, step=200),
        "depth": trial.suggest_int("depth", 4, 8), 
        "learning_rate": trial.suggest_float("learning_rate", 0.02, 0.15, log=True),
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1.0, 20.0, log=True),
        "random_strength": trial.suggest_float("random_strength", 0.5, 3.0),
        "bagging_temperature": trial.suggest_float("bagging_temperature", 0.0, 1.0),
        "auto_class_weights": "Balanced",
        "loss_function": "MultiClass",
        "random_seed": 42,
        "verbose": False,
    }
    skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
    f1s = []
    X = X_train_r
    y = y_train_r
    for tr_idx, va_idx in skf.split(X, y):
        X_tr, X_va = X.iloc[tr_idx], X.iloc[va_idx]
        y_tr, y_va = y.iloc[tr_idx], y.iloc[va_idx]
        model = CatBoostClassifier(**params)
        pipe_cv = Pipeline([
            ("scaler", StandardScaler()),
            ("clf", model),
        ])
        pipe_cv.fit(X_tr, y_tr)
        pred = pipe_cv.predict(X_va).ravel()
        f1s.append(f1_score(y_va, pred, average="macro"))

    return float(np.mean(f1s))



# ----- Load your saved split files -----
train_random = pd.read_csv("C:\\Users\\NFU_Power_Lab\\Desktop\\DAT_ResearchArea\\BestAwardAI2026\\random-split\\wpt_train_random.csv")
test_random  = pd.read_csv("C:\\Users\\NFU_Power_Lab\\Desktop\\DAT_ResearchArea\\BestAwardAI2026\\random-split\\wpt_test_random.csv")

# Sanity check expected columns
expected_cols = {"type", "load", "efficiency"}
for name, d in [("train_random", train_random), ("test_random", test_random)]:
    missing = expected_cols - set(d.columns)
    if missing:
        raise ValueError(f"{name} is missing columns: {missing}")

# Make sure numeric columns are numeric
for d in [train_random, test_random]:
    d["load"] = pd.to_numeric(d["load"], errors="coerce")
    d["efficiency"] = pd.to_numeric(d["efficiency"], errors="coerce")
    d["type"] = d["type"].astype(str)
    d.dropna(subset=["type", "load", "efficiency"], inplace=True)

# Features / target
FEATURES = ["load", "efficiency"]
TARGET = "type"

# =========================
def add_advanced_features(df, k_baseline_dict, type_to_group_dict):
    df = df.copy()
    df["k_eff_expected"] = df["load"].map(k_baseline_dict)
    if df["k_eff_expected"].isnull().any():
        known_loads = np.array(list(k_baseline_dict.keys()))
        for idx, row in df[df["k_eff_expected"].isnull()].iterrows():
            closest_load = known_loads[np.abs(known_loads - row["load"]).argmin()]
            df.loc[idx, "k_eff_expected"] = k_baseline_dict[closest_load]  
    # 2. Độ lệch (Difference) và Tỷ lệ (Ratio)
    df["eff_diff"] = df["efficiency"] - df["k_eff_expected"]
    df["eff_ratio"] = df["efficiency"] / df["k_eff_expected"]
    # 3. Ước tính tổn hao công suất (Power Loss Proxy)
    # P_loss = Load * (1 / (Efficiency / 100) - 1)
    df["p_loss"] = df["load"] * (1 / (df["efficiency"] / 100.0) - 1)
    # Tổn hao công suất của Class K
    df["k_p_loss"] = df["load"] * (1 / (df["k_eff_expected"] / 100.0) - 1)
    # Độ lệch suy hao do vật thể lạ gây ra
    df["p_loss_diff"] = df["p_loss"] - df["k_p_loss"]

    df["dist_zone_name"] = df["type"].map(type_to_group_dict).fillna("far")
    # Mã hóa thành số
    zone_mapping = {"near": 1, "mid": 2, "far": 3}
    df["dist_zone"] = df["dist_zone_name"].map(zone_mapping)
    # 4. Phân vùng Dải tải (Load Zone)
    # Giả sử dải tải từ 0.5 đến 3.0, chia làm 3 vùng: Nhẹ (1), Vừa (2), Nặng (3)
    df['load_zone'] = pd.cut(df['load'], bins=3, labels=[1, 2, 3]).astype(float)
    return df

k_baseline_train_r = train_random[train_random["type"] == "K"].groupby("load")["efficiency"].mean().to_dict()
type_to_group, groups_dict, stats = derive_groups_from_train(train_random, k_baseline_train_r)
print("Results of grouping the Types:", groups_dict)

train_random_fe = add_advanced_features(train_random, k_baseline_train_r, type_to_group)
test_random_fe = add_advanced_features(test_random, k_baseline_train_r, type_to_group)

FEATURES_NEW = [
    "load", "efficiency", 
    "eff_diff", "eff_ratio", 
    "p_loss_diff", "load_zone", "dist_zone"
]
# =========================
X_train_r = train_random_fe[FEATURES_NEW]
y_train_r = train_random_fe[TARGET]
X_test_r  = test_random_fe[FEATURES_NEW]
y_test_r  = test_random_fe[TARGET]

# ========================
# Choose a baseline classifier
# =========================
OPTUNA_TRIALS = 100
study = optuna.create_study(direction="maximize")
study.optimize(catboost_objective, n_trials=OPTUNA_TRIALS)

print("\n=== Optuna done for CatBoost ===")
print("Best macro-F1 (CV):", study.best_value)
print("Best params:", study.best_params)

best_params = study.best_params

clf = CatBoostClassifier(
    iterations=best_params.get("iterations", 1000),
    depth=best_params.get("depth", 6),
    learning_rate=best_params.get("learning_rate", 0.05),
    l2_leaf_reg=best_params.get("l2_leaf_reg", 3.0),
    random_strength=best_params.get("random_strength", 1.0),
    bagging_temperature=best_params.get("bagging_temperature", 0.0),
    auto_class_weights='Balanced',
    loss_function='MultiClass',
    random_seed=42,
    verbose=False
)

# Pipeline: scale numeric features (safe for most models)
pipe = Pipeline([
    ("scaler", StandardScaler()),
    ("clf", clf),
])

# =========================
# Train/Eval on Random Split
# =========================
pipe.fit(X_train_r, y_train_r)
pred_r = pipe.predict(X_test_r).ravel()

print("=== Baseline Classification on Random Split ===")
eval_classification(y_test_r, pred_r, name="RandomSplit")

print("\nClassification report (RandomSplit):")
print(classification_report(y_test_r, pred_r, digits=4))

cm_r = confusion_matrix(y_test_r, pred_r, labels=sorted(y_train_r.unique()))
cm_r_df = pd.DataFrame(cm_r, index=sorted(y_train_r.unique()), columns=sorted(y_train_r.unique()))
cm_r_df.to_csv("baseline_cm_random.csv", encoding="utf-8-sig")
print("Saved: baseline_cm_random.csv")

save_preds_csv(X_test_r, y_test_r.values, pred_r, "baseline_preds_random_cls.csv")
# Out:
# [I 2026-03-12 01:16:13,061] A new study created in memory with name: no-name-d8bbec8b-1c06-4683-914e-41f98c320313
# Results of grouping the Types: {'near': ['K', 'H', 'J', 'I', 'G'], 'mid': ['F', 'E', 'D', 'B'], 'far': ['C', 'A']}
# [I 2026-03-12 01:17:05,471] Trial 0 finished with value: 0.7413570189299019 and parameters: {'iterations': 1000, 'depth': 7, 'learning_rate': 0.10093560982031026, 'l2_leaf_reg': 6.492283394850998, 'random_strength': 0.6585804615050799, 'bagging_temperature': 0.5152091564162913}. Best is trial 0 with value: 0.7413570189299019.
# [I 2026-03-12 01:17:15,103] Trial 1 finished with value: 0.7324830591648639 and parameters: {'iterations': 600, 'depth': 5, 'learning_rate': 0.09355354328729601, 'l2_leaf_reg': 1.5398236154359926, 'random_strength': 2.3540724848399845, 'bagging_temperature': 0.10239704638868063}. Best is trial 0 with value: 0.7413570189299019.
# [I 2026-03-12 01:17:38,702] Trial 2 finished with value: 0.7566583224355923 and parameters: {'iterations': 800, 'depth': 6, 'learning_rate': 0.03202053045485046, 'l2_leaf_reg': 3.024847528660035, 'random_strength': 2.4874748832771783, 'bagging_temperature': 0.6654689854626817}. Best is trial 2 with value: 0.7566583224355923.
# [I 2026-03-12 01:18:19,567] Trial 3 finished with value: 0.7303914675886812 and parameters: {'iterations': 1400, 'depth': 6, 'learning_rate': 0.08890753022190008, 'l2_leaf_reg': 4.081307809429037, 'random_strength': 1.0710586161377373, 'bagging_temperature': 0.6367860959919995}. Best is trial 2 with value: 0.7566583224355923.
# [I 2026-03-12 01:19:30,708] Trial 4 finished with value: 0.7378978902857501 and parameters: {'iterations': 800, 'depth': 8, 'learning_rate': 0.13091362007419852, 'l2_leaf_reg': 3.612348229398536, 'random_strength': 1.4935171770934945, 'bagging_temperature': 0.34609104729385165}. Best is trial 2 with value: 0.7566583224355923.
# [I 2026-03-12 01:19:44,873] Trial 5 finished with value: 0.7718318786298722 and parameters: {'iterations': 1400, 'depth': 4, 'learning_rate': 0.11246897862187553, 'l2_leaf_reg': 16.573108456816254, 'random_strength': 0.9674622520301286, 'bagging_temperature': 0.01064560860018049}. Best is trial 5 with value: 0.7718318786298722.
# [I 2026-03-12 01:20:13,000] Trial 6 finished with value: 0.7520043345975796 and parameters: {'iterations': 1000, 'depth': 6, 'learning_rate': 0.033620091193661536, 'l2_leaf_reg': 4.632406976416058, 'random_strength': 1.823064793098224, 'bagging_temperature': 0.7544009237287329}. Best is trial 5 with value: 0.7718318786298722.
# [I 2026-03-12 01:20:29,816] Trial 7 finished with value: 0.7421999333707873 and parameters: {'iterations': 600, 'depth': 6, 'learning_rate': 0.03992864106636069, 'l2_leaf_reg': 1.5342751104754906, 'random_strength': 2.2546058009079144, 'bagging_temperature': 0.7172067369806182}. Best is trial 5 with value: 0.7718318786298722.
# [I 2026-03-12 01:21:28,536] Trial 8 finished with value: 0.730780447692274 and parameters: {'iterations': 1200, 'depth': 7, 'learning_rate': 0.05105684714642106, 'l2_leaf_reg': 1.984355873631246, 'random_strength': 2.8395220367333955, 'bagging_temperature': 0.7722949644923626}. Best is trial 5 with value: 0.7718318786298722.
# [I 2026-03-12 01:21:36,614] Trial 9 finished with value: 0.7614166720752503 and parameters: {'iterations': 800, 'depth': 4, 'learning_rate': 0.02226473250697868, 'l2_leaf_reg': 6.958208827880993, 'random_strength': 1.601446341266642, 'bagging_temperature': 0.0810931897038979}. Best is trial 5 with value: 0.7718318786298722.
# [I 2026-03-12 01:21:51,076] Trial 10 finished with value: 0.7577334606727516 and parameters: {'iterations': 1400, 'depth': 4, 'learning_rate': 0.07355217669087988, 'l2_leaf_reg': 15.926529610693628, 'random_strength': 0.5053738492037771, 'bagging_temperature': 0.34417748860543335}. Best is trial 5 with value: 0.7718318786298722.
# [I 2026-03-12 01:22:03,410] Trial 11 finished with value: 0.7704643028859627 and parameters: {'iterations': 1200, 'depth': 4, 'learning_rate': 0.0213032492923966, 'l2_leaf_reg': 19.79821318716377, 'random_strength': 1.2931773917405294, 'bagging_temperature': 0.015272722919315904}. Best is trial 5 with value: 0.7718318786298722.
# [I 2026-03-12 01:22:15,692] Trial 12 finished with value: 0.7686816031634125 and parameters: {'iterations': 1200, 'depth': 4, 'learning_rate': 0.02001430010151748, 'l2_leaf_reg': 17.769778345727307, 'random_strength': 1.0950273503510854, 'bagging_temperature': 0.014438315926030352}. Best is trial 5 with value: 0.7718318786298722.
# [I 2026-03-12 01:22:34,566] Trial 13 finished with value: 0.7518582199580498 and parameters: {'iterations': 1200, 'depth': 5, 'learning_rate': 0.13994105316077113, 'l2_leaf_reg': 11.405334492110525, 'random_strength': 0.9697553394210598, 'bagging_temperature': 0.2301232541794932}. Best is trial 5 with value: 0.7718318786298722.
# [I 2026-03-12 01:22:56,446] Trial 14 finished with value: 0.7587590609434921 and parameters: {'iterations': 1400, 'depth': 5, 'learning_rate': 0.05491646685348269, 'l2_leaf_reg': 11.52614630928447, 'random_strength': 1.3528401026217445, 'bagging_temperature': 0.21603983349191153}. Best is trial 5 with value: 0.7718318786298722.
# [I 2026-03-12 01:23:08,970] Trial 15 finished with value: 0.7564654471152162 and parameters: {'iterations': 1200, 'depth': 4, 'learning_rate': 0.063210375398464, 'l2_leaf_reg': 19.805369745826713, 'random_strength': 1.8345718518314214, 'bagging_temperature': 0.9852996537789995}. Best is trial 5 with value: 0.7718318786298722.
# [I 2026-03-12 01:23:31,103] Trial 16 finished with value: 0.7611909661254627 and parameters: {'iterations': 1400, 'depth': 5, 'learning_rate': 0.026594614608711816, 'l2_leaf_reg': 9.990710557998364, 'random_strength': 0.795377053352497, 'bagging_temperature': 0.20609486581546654}. Best is trial 5 with value: 0.7718318786298722.
# [I 2026-03-12 01:23:43,465] Trial 17 finished with value: 0.7637660946644931 and parameters: {'iterations': 1200, 'depth': 4, 'learning_rate': 0.04398669057018077, 'l2_leaf_reg': 7.514552675314654, 'random_strength': 1.2720133754482261, 'bagging_temperature': 0.383690712087973}. Best is trial 5 with value: 0.7718318786298722.
# [I 2026-03-12 01:24:05,502] Trial 18 finished with value: 0.7253543790967617 and parameters: {'iterations': 1400, 'depth': 5, 'learning_rate': 0.10964399395127004, 'l2_leaf_reg': 1.0434258028088534, 'random_strength': 2.0598188465506233, 'bagging_temperature': 0.012192832834209279}. Best is trial 5 with value: 0.7718318786298722.
# [I 2026-03-12 01:24:15,791] Trial 19 finished with value: 0.7681891197962999 and parameters: {'iterations': 1000, 'depth': 4, 'learning_rate': 0.07017695055101177, 'l2_leaf_reg': 13.752908341227169, 'random_strength': 0.8509182972315055, 'bagging_temperature': 0.14370319538123244}. Best is trial 5 with value: 0.7718318786298722.
# [I 2026-03-12 01:25:04,304] Trial 20 finished with value: 0.7567959954244986 and parameters: {'iterations': 1000, 'depth': 7, 'learning_rate': 0.02590049320563751, 'l2_leaf_reg': 8.664195799341945, 'random_strength': 1.2544040337031315, 'bagging_temperature': 0.4738037500619503}. Best is trial 5 with value: 0.7718318786298722.
# [I 2026-03-12 01:25:16,772] Trial 21 finished with value: 0.7680861469507475 and parameters: {'iterations': 1200, 'depth': 4, 'learning_rate': 0.021257284311148518, 'l2_leaf_reg': 18.65394718402377, 'random_strength': 1.0950700840666763, 'bagging_temperature': 0.057601357279866136}. Best is trial 5 with value: 0.7718318786298722.
# [I 2026-03-12 01:25:29,043] Trial 22 finished with value: 0.7750162936000627 and parameters: {'iterations': 1200, 'depth': 4, 'learning_rate': 0.026519628362822924, 'l2_leaf_reg': 14.270510148741947, 'random_strength': 1.5780658517354293, 'bagging_temperature': 0.1683219213416004}. Best is trial 22 with value: 0.7750162936000627.
# [I 2026-03-12 01:25:51,035] Trial 23 finished with value: 0.7638984823881554 and parameters: {'iterations': 1400, 'depth': 5, 'learning_rate': 0.027387840880733504, 'l2_leaf_reg': 13.471441529314886, 'random_strength': 1.5116686873663967, 'bagging_temperature': 0.14770326194339156}. Best is trial 22 with value: 0.7750162936000627.
# [I 2026-03-12 01:26:03,386] Trial 24 finished with value: 0.7685443484190104 and parameters: {'iterations': 1200, 'depth': 4, 'learning_rate': 0.03577154555851704, 'l2_leaf_reg': 13.615748937394466, 'random_strength': 1.7248372229649434, 'bagging_temperature': 0.25784655227521786}. Best is trial 22 with value: 0.7750162936000627.
# [I 2026-03-12 01:26:25,233] Trial 25 finished with value: 0.762334808115201 and parameters: {'iterations': 1400, 'depth': 5, 'learning_rate': 0.029365372847243224, 'l2_leaf_reg': 5.063507800309292, 'random_strength': 1.3630280605583973, 'bagging_temperature': 0.13960464729933722}. Best is trial 22 with value: 0.7750162936000627.
# [I 2026-03-12 01:26:37,635] Trial 26 finished with value: 0.7612769331347039 and parameters: {'iterations': 1200, 'depth': 4, 'learning_rate': 0.046176131810326766, 'l2_leaf_reg': 9.41152843765375, 'random_strength': 2.0467245274715538, 'bagging_temperature': 0.018394661562704168}. Best is trial 22 with value: 0.7750162936000627.
# [I 2026-03-12 01:28:09,402] Trial 27 finished with value: 0.7688059173588688 and parameters: {'iterations': 1000, 'depth': 8, 'learning_rate': 0.023804049959552185, 'l2_leaf_reg': 15.788867476458305, 'random_strength': 0.8244120203328158, 'bagging_temperature': 0.2848932396002465}. Best is trial 22 with value: 0.7750162936000627.
# [I 2026-03-12 01:28:28,120] Trial 28 finished with value: 0.7543814196735638 and parameters: {'iterations': 1200, 'depth': 5, 'learning_rate': 0.12186506393183465, 'l2_leaf_reg': 5.642157365493001, 'random_strength': 1.6169375003482225, 'bagging_temperature': 0.15658255923263353}. Best is trial 22 with value: 0.7750162936000627.
# [I 2026-03-12 01:28:42,581] Trial 29 finished with value: 0.7539090388279157 and parameters: {'iterations': 1400, 'depth': 4, 'learning_rate': 0.07952585779712688, 'l2_leaf_reg': 11.592300309146887, 'random_strength': 0.5264520902803007, 'bagging_temperature': 0.46659227577879886}. Best is trial 22 with value: 0.7750162936000627.
# [I 2026-03-12 01:28:52,774] Trial 30 finished with value: 0.77487616033316 and parameters: {'iterations': 1000, 'depth': 4, 'learning_rate': 0.05827990013088354, 'l2_leaf_reg': 15.381958446305893, 'random_strength': 0.6760146539016778, 'bagging_temperature': 0.09338570525728422}. Best is trial 22 with value: 0.7750162936000627.
# [I 2026-03-12 01:29:03,027] Trial 31 finished with value: 0.7760331710466207 and parameters: {'iterations': 1000, 'depth': 4, 'learning_rate': 0.060233884601743726, 'l2_leaf_reg': 19.81413002513144, 'random_strength': 0.9426623268708918, 'bagging_temperature': 0.08285285822463065}. Best is trial 31 with value: 0.7760331710466207.
# [I 2026-03-12 01:29:13,298] Trial 32 finished with value: 0.7733402391295158 and parameters: {'iterations': 1000, 'depth': 4, 'learning_rate': 0.057261220077057744, 'l2_leaf_reg': 15.033241672708348, 'random_strength': 0.6903211970903247, 'bagging_temperature': 0.1197285823289464}. Best is trial 31 with value: 0.7760331710466207.
# [I 2026-03-12 01:29:28,919] Trial 33 finished with value: 0.7708615205902989 and parameters: {'iterations': 1000, 'depth': 5, 'learning_rate': 0.06320721648204433, 'l2_leaf_reg': 13.727877851123624, 'random_strength': 0.7279944446686178, 'bagging_temperature': 0.07959287696457246}. Best is trial 31 with value: 0.7760331710466207.
# [I 2026-03-12 01:29:37,125] Trial 34 finished with value: 0.7633348131231353 and parameters: {'iterations': 800, 'depth': 4, 'learning_rate': 0.05791649243422927, 'l2_leaf_reg': 7.76792385213922, 'random_strength': 0.6642393032590853, 'bagging_temperature': 0.28488830523140996}. Best is trial 31 with value: 0.7760331710466207.
# [I 2026-03-12 01:29:52,748] Trial 35 finished with value: 0.7526496426362056 and parameters: {'iterations': 1000, 'depth': 5, 'learning_rate': 0.08623508972313589, 'l2_leaf_reg': 10.090177512054934, 'random_strength': 0.5993156110041749, 'bagging_temperature': 0.18372089765490957}. Best is trial 31 with value: 0.7760331710466207.
# [I 2026-03-12 01:30:01,032] Trial 36 finished with value: 0.7699383490032475 and parameters: {'iterations': 800, 'depth': 4, 'learning_rate': 0.04998390140463849, 'l2_leaf_reg': 15.492067688948495, 'random_strength': 0.9257877586624874, 'bagging_temperature': 0.10429374183836768}. Best is trial 31 with value: 0.7760331710466207.
# [I 2026-03-12 01:30:16,726] Trial 37 finished with value: 0.7560660188188999 and parameters: {'iterations': 1000, 'depth': 5, 'learning_rate': 0.03935765794351865, 'l2_leaf_reg': 2.648787626357866, 'random_strength': 0.680480637974668, 'bagging_temperature': 0.6028813328401353}. Best is trial 31 with value: 0.7760331710466207.
# [I 2026-03-12 01:30:24,992] Trial 38 finished with value: 0.7709936994544243 and parameters: {'iterations': 800, 'depth': 4, 'learning_rate': 0.06125969327169636, 'l2_leaf_reg': 5.873661905646425, 'random_strength': 2.7048541592765885, 'bagging_temperature': 0.4072151715672454}. Best is trial 31 with value: 0.7760331710466207.
# [I 2026-03-12 01:30:42,173] Trial 39 finished with value: 0.7661842684035061 and parameters: {'iterations': 600, 'depth': 6, 'learning_rate': 0.06854640725850834, 'l2_leaf_reg': 12.402777429691742, 'random_strength': 1.1634819050095069, 'bagging_temperature': 0.3237640330475347}. Best is trial 31 with value: 0.7760331710466207.
# [I 2026-03-12 01:31:31,574] Trial 40 finished with value: 0.7439729523863902 and parameters: {'iterations': 1000, 'depth': 7, 'learning_rate': 0.04673821862750054, 'l2_leaf_reg': 3.679928634768462, 'random_strength': 0.9200209664142459, 'bagging_temperature': 0.09842374520596987}. Best is trial 31 with value: 0.7760331710466207.
# [I 2026-03-12 01:31:41,963] Trial 41 finished with value: 0.7649505261183923 and parameters: {'iterations': 1000, 'depth': 4, 'learning_rate': 0.10146712323661765, 'l2_leaf_reg': 16.65673982142122, 'random_strength': 1.012006085011326, 'bagging_temperature': 0.06352122508678468}. Best is trial 31 with value: 0.7760331710466207.
# [I 2026-03-12 01:31:52,128] Trial 42 finished with value: 0.7671069099083315 and parameters: {'iterations': 1000, 'depth': 4, 'learning_rate': 0.08016928545691739, 'l2_leaf_reg': 15.349989843348576, 'random_strength': 0.7589186042897991, 'bagging_temperature': 0.11426025361963849}. Best is trial 31 with value: 0.7760331710466207.
# [I 2026-03-12 01:32:00,345] Trial 43 finished with value: 0.771752118984217 and parameters: {'iterations': 800, 'depth': 4, 'learning_rate': 0.051805420169935675, 'l2_leaf_reg': 19.923101910197794, 'random_strength': 0.5566050034851571, 'bagging_temperature': 0.1835711036694065}. Best is trial 31 with value: 0.7760331710466207.
# [I 2026-03-12 01:32:10,660] Trial 44 finished with value: 0.7669832512354596 and parameters: {'iterations': 1000, 'depth': 4, 'learning_rate': 0.09633333886142999, 'l2_leaf_reg': 16.57317077348576, 'random_strength': 1.1787984689541255, 'bagging_temperature': 0.04622802782869409}. Best is trial 31 with value: 0.7760331710466207.
# [I 2026-03-12 01:32:39,034] Trial 45 finished with value: 0.758442833353239 and parameters: {'iterations': 1000, 'depth': 6, 'learning_rate': 0.04018791383749859, 'l2_leaf_reg': 10.927864630906473, 'random_strength': 2.4196764851588957, 'bagging_temperature': 0.8538875182872314}. Best is trial 31 with value: 0.7760331710466207.
# [I 2026-03-12 01:32:51,271] Trial 46 finished with value: 0.753058577066991 and parameters: {'iterations': 1200, 'depth': 4, 'learning_rate': 0.14636685907254246, 'l2_leaf_reg': 14.022705896440794, 'random_strength': 0.8940385593166126, 'bagging_temperature': 0.554368933384487}. Best is trial 31 with value: 0.7760331710466207.
# [I 2026-03-12 01:32:59,593] Trial 47 finished with value: 0.765419426001826 and parameters: {'iterations': 800, 'depth': 4, 'learning_rate': 0.03281316341985028, 'l2_leaf_reg': 17.48874248154652, 'random_strength': 1.0443821298532405, 'bagging_temperature': 0.0037821688773265055}. Best is trial 31 with value: 0.7760331710466207.
# [I 2026-03-12 01:33:15,193] Trial 48 finished with value: 0.7560505006316675 and parameters: {'iterations': 1000, 'depth': 5, 'learning_rate': 0.05692991362226535, 'l2_leaf_reg': 9.325110965180315, 'random_strength': 1.4428559964166694, 'bagging_temperature': 0.22031176779190728}. Best is trial 31 with value: 0.7760331710466207.
# [I 2026-03-12 01:33:27,447] Trial 49 finished with value: 0.7601948105115902 and parameters: {'iterations': 1200, 'depth': 4, 'learning_rate': 0.11552912009266154, 'l2_leaf_reg': 8.349680094624517, 'random_strength': 0.6432070194664705, 'bagging_temperature': 0.053492658311802985}. Best is trial 31 with value: 0.7760331710466207.
# [I 2026-03-12 01:33:56,036] Trial 50 finished with value: 0.7628815604288247 and parameters: {'iterations': 1000, 'depth': 6, 'learning_rate': 0.07385473165696285, 'l2_leaf_reg': 12.445705584744662, 'random_strength': 2.034289999947644, 'bagging_temperature': 0.1029657962152038}. Best is trial 31 with value: 0.7760331710466207.
# [I 2026-03-12 01:34:02,285] Trial 51 finished with value: 0.7715709592833987 and parameters: {'iterations': 600, 'depth': 4, 'learning_rate': 0.05269356861159133, 'l2_leaf_reg': 19.979920506140736, 'random_strength': 0.5288096633274084, 'bagging_temperature': 0.18921434716782887}. Best is trial 31 with value: 0.7760331710466207.
# [I 2026-03-12 01:34:10,419] Trial 52 finished with value: 0.7683248856234016 and parameters: {'iterations': 800, 'depth': 4, 'learning_rate': 0.04199559511238976, 'l2_leaf_reg': 17.563251814611558, 'random_strength': 0.7626707432954632, 'bagging_temperature': 0.1759914571958387}. Best is trial 31 with value: 0.7760331710466207.
# [I 2026-03-12 01:34:18,781] Trial 53 finished with value: 0.7595114782333384 and parameters: {'iterations': 800, 'depth': 4, 'learning_rate': 0.03601210768983324, 'l2_leaf_reg': 15.112807070766749, 'random_strength': 0.6148663242738018, 'bagging_temperature': 0.24507622044089483}. Best is trial 31 with value: 0.7760331710466207.
# [I 2026-03-12 01:34:26,928] Trial 54 finished with value: 0.7721265327145144 and parameters: {'iterations': 800, 'depth': 4, 'learning_rate': 0.04955284551663089, 'l2_leaf_reg': 18.77533041535327, 'random_strength': 0.8264353500811231, 'bagging_temperature': 0.12751451954165643}. Best is trial 31 with value: 0.7760331710466207.
# [I 2026-03-12 01:34:33,200] Trial 55 finished with value: 0.7708640378506484 and parameters: {'iterations': 600, 'depth': 4, 'learning_rate': 0.06729192826063439, 'l2_leaf_reg': 17.839892524120398, 'random_strength': 0.9742681019752433, 'bagging_temperature': 0.04271855964988133}. Best is trial 31 with value: 0.7760331710466207.
# [I 2026-03-12 01:34:55,042] Trial 56 finished with value: 0.7683438276208449 and parameters: {'iterations': 1400, 'depth': 5, 'learning_rate': 0.060352306590819714, 'l2_leaf_reg': 12.541056240158946, 'random_strength': 1.1696778596089157, 'bagging_temperature': 0.10780191446689472}. Best is trial 31 with value: 0.7760331710466207.
# [I 2026-03-12 01:35:07,426] Trial 57 finished with value: 0.7669328770901344 and parameters: {'iterations': 1200, 'depth': 4, 'learning_rate': 0.04871099752717958, 'l2_leaf_reg': 10.723207374214807, 'random_strength': 0.8418106197512366, 'bagging_temperature': 0.13946215934823153}. Best is trial 31 with value: 0.7760331710466207.
# [I 2026-03-12 01:35:21,637] Trial 58 finished with value: 0.7635844273676686 and parameters: {'iterations': 1000, 'depth': 4, 'learning_rate': 0.08779823847084597, 'l2_leaf_reg': 14.988113074953644, 'random_strength': 1.0643007175487305, 'bagging_temperature': 0.07320500533473143}. Best is trial 31 with value: 0.7760331710466207.
# [I 2026-03-12 01:35:34,036] Trial 59 finished with value: 0.7606232846677496 and parameters: {'iterations': 1200, 'depth': 4, 'learning_rate': 0.02997135264186219, 'l2_leaf_reg': 2.807218151387329, 'random_strength': 1.894554397094428, 'bagging_temperature': 0.0014620983735784687}. Best is trial 31 with value: 0.7760331710466207.
# [I 2026-03-12 01:36:45,114] Trial 60 finished with value: 0.7616519743118855 and parameters: {'iterations': 800, 'depth': 8, 'learning_rate': 0.07638155107758114, 'l2_leaf_reg': 18.310998345923398, 'random_strength': 2.2179361268061513, 'bagging_temperature': 0.2759031237122196}. Best is trial 31 with value: 0.7760331710466207.
# [I 2026-03-12 01:36:53,315] Trial 61 finished with value: 0.7765826874114019 and parameters: {'iterations': 800, 'depth': 4, 'learning_rate': 0.054333471239470306, 'l2_leaf_reg': 19.34244204057607, 'random_strength': 0.5670313449684629, 'bagging_temperature': 0.16525513241239054}. Best is trial 61 with value: 0.7765826874114019.
# [I 2026-03-12 01:37:01,588] Trial 62 finished with value: 0.7710344745108761 and parameters: {'iterations': 800, 'depth': 4, 'learning_rate': 0.054284843149840396, 'l2_leaf_reg': 16.66202183383741, 'random_strength': 0.7272492918800566, 'bagging_temperature': 0.13341756575876493}. Best is trial 61 with value: 0.7765826874114019.
# [I 2026-03-12 01:37:09,748] Trial 63 finished with value: 0.7668851880736044 and parameters: {'iterations': 800, 'depth': 4, 'learning_rate': 0.044676150064318076, 'l2_leaf_reg': 14.53929281141373, 'random_strength': 0.8048571606623108, 'bagging_temperature': 0.31955902834393}. Best is trial 61 with value: 0.7765826874114019.
# [I 2026-03-12 01:37:20,028] Trial 64 finished with value: 0.7613951890123315 and parameters: {'iterations': 1000, 'depth': 4, 'learning_rate': 0.06617016320084577, 'l2_leaf_reg': 12.63690187520165, 'random_strength': 0.6757772176232029, 'bagging_temperature': 0.22065959149689274}. Best is trial 61 with value: 0.7765826874114019.
# [I 2026-03-12 01:37:34,434] Trial 65 finished with value: 0.774279537204599 and parameters: {'iterations': 1400, 'depth': 4, 'learning_rate': 0.059843929131610255, 'l2_leaf_reg': 18.439768540611478, 'random_strength': 0.86964713530034, 'bagging_temperature': 0.039001364664825205}. Best is trial 61 with value: 0.7765826874114019.
# [I 2026-03-12 01:37:50,058] Trial 66 finished with value: 0.7718429937941957 and parameters: {'iterations': 1000, 'depth': 5, 'learning_rate': 0.058002923098893544, 'l2_leaf_reg': 18.637992696416735, 'random_strength': 0.9088036281095272, 'bagging_temperature': 0.041301655776554876}. Best is trial 61 with value: 0.7765826874114019.
# [I 2026-03-12 01:37:56,159] Trial 67 finished with value: 0.7563352187153783 and parameters: {'iterations': 600, 'depth': 4, 'learning_rate': 0.06422332562254664, 'l2_leaf_reg': 1.39445568114121, 'random_strength': 0.5732079798667882, 'bagging_temperature': 0.15773123981092246}. Best is trial 61 with value: 0.7765826874114019.
# [I 2026-03-12 01:38:08,674] Trial 68 finished with value: 0.7709213145929766 and parameters: {'iterations': 800, 'depth': 5, 'learning_rate': 0.05492756880152147, 'l2_leaf_reg': 19.84130113691845, 'random_strength': 0.7219894654089379, 'bagging_temperature': 0.08259513810630785}. Best is trial 61 with value: 0.7765826874114019.
# [I 2026-03-12 01:38:23,089] Trial 69 finished with value: 0.7645429132008424 and parameters: {'iterations': 1400, 'depth': 4, 'learning_rate': 0.04865693724762279, 'l2_leaf_reg': 16.619983210158907, 'random_strength': 0.8604917500144562, 'bagging_temperature': 0.3949870508533806}. Best is trial 61 with value: 0.7765826874114019.
# [I 2026-03-12 01:38:33,385] Trial 70 finished with value: 0.7732822719799627 and parameters: {'iterations': 1000, 'depth': 4, 'learning_rate': 0.05912836350946674, 'l2_leaf_reg': 18.22852583930522, 'random_strength': 0.6273464515421069, 'bagging_temperature': 0.12421686249411092}. Best is trial 61 with value: 0.7765826874114019.
# [I 2026-03-12 01:38:43,601] Trial 71 finished with value: 0.7695885926802326 and parameters: {'iterations': 1000, 'depth': 4, 'learning_rate': 0.059690872099347626, 'l2_leaf_reg': 18.05078592673506, 'random_strength': 0.6008384434476524, 'bagging_temperature': 0.1274633269773833}. Best is trial 61 with value: 0.7765826874114019.
# [I 2026-03-12 01:38:54,012] Trial 72 finished with value: 0.7606283365515109 and parameters: {'iterations': 1000, 'depth': 4, 'learning_rate': 0.07054742377698144, 'l2_leaf_reg': 13.747707607613977, 'random_strength': 0.6768970849885008, 'bagging_temperature': 0.16362160934160452}. Best is trial 61 with value: 0.7765826874114019.
# [I 2026-03-12 01:39:04,319] Trial 73 finished with value: 0.7709559660986668 and parameters: {'iterations': 1000, 'depth': 4, 'learning_rate': 0.05589887087998196, 'l2_leaf_reg': 15.893890004319088, 'random_strength': 0.809933419214226, 'bagging_temperature': 0.203434041559445}. Best is trial 61 with value: 0.7765826874114019.
# [I 2026-03-12 01:39:14,455] Trial 74 finished with value: 0.7705985054091937 and parameters: {'iterations': 1000, 'depth': 4, 'learning_rate': 0.060810023979150384, 'l2_leaf_reg': 14.585761317270942, 'random_strength': 0.9528657114827617, 'bagging_temperature': 0.034172165735050025}. Best is trial 61 with value: 0.7765826874114019.
# [I 2026-03-12 01:39:26,829] Trial 75 finished with value: 0.7480605132230617 and parameters: {'iterations': 1200, 'depth': 4, 'learning_rate': 0.05153591796002889, 'l2_leaf_reg': 2.2227817868718325, 'random_strength': 2.6936965313706134, 'bagging_temperature': 0.09281498668905408}. Best is trial 61 with value: 0.7765826874114019.
# [I 2026-03-12 01:39:35,095] Trial 76 finished with value: 0.7634053521980974 and parameters: {'iterations': 800, 'depth': 4, 'learning_rate': 0.023925550452729528, 'l2_leaf_reg': 18.667614214770065, 'random_strength': 0.5254190302816298, 'bagging_temperature': 0.24726650118705165}. Best is trial 61 with value: 0.7765826874114019.
# [I 2026-03-12 01:39:50,654] Trial 77 finished with value: 0.7616368272232864 and parameters: {'iterations': 1000, 'depth': 5, 'learning_rate': 0.07142427788195654, 'l2_leaf_reg': 11.839043218798553, 'random_strength': 0.7521027789185571, 'bagging_temperature': 0.12253925908330038}. Best is trial 61 with value: 0.7765826874114019.
# [I 2026-03-12 01:40:02,748] Trial 78 finished with value: 0.7660882999344089 and parameters: {'iterations': 1200, 'depth': 4, 'learning_rate': 0.06307969139936048, 'l2_leaf_reg': 13.17495741906515, 'random_strength': 1.114318841495697, 'bagging_temperature': 0.07807251218321544}. Best is trial 61 with value: 0.7765826874114019.
# [I 2026-03-12 01:40:13,139] Trial 79 finished with value: 0.7667095182394102 and parameters: {'iterations': 1000, 'depth': 4, 'learning_rate': 0.0475281805618769, 'l2_leaf_reg': 16.439443965670225, 'random_strength': 1.6960692175645105, 'bagging_temperature': 0.17120900411202492}. Best is trial 61 with value: 0.7765826874114019.
# [I 2026-03-12 01:41:23,564] Trial 80 finished with value: 0.7753555990702967 and parameters: {'iterations': 1400, 'depth': 7, 'learning_rate': 0.043145259254165305, 'l2_leaf_reg': 18.39741146566633, 'random_strength': 0.5064462531081511, 'bagging_temperature': 0.023146533725578677}. Best is trial 61 with value: 0.7765826874114019.
# [I 2026-03-12 01:42:37,210] Trial 81 finished with value: 0.781533010951046 and parameters: {'iterations': 1400, 'depth': 7, 'learning_rate': 0.04351716392382374, 'l2_leaf_reg': 18.653420100808198, 'random_strength': 0.6384363276747702, 'bagging_temperature': 0.06130221038264175}. Best is trial 81 with value: 0.781533010951046.
# [I 2026-03-12 01:43:47,667] Trial 82 finished with value: 0.7726215200183834 and parameters: {'iterations': 1400, 'depth': 7, 'learning_rate': 0.04083400619749986, 'l2_leaf_reg': 15.693387463671217, 'random_strength': 0.6204960060377214, 'bagging_temperature': 0.04054022160617599}. Best is trial 81 with value: 0.781533010951046.
# [I 2026-03-12 01:44:57,840] Trial 83 finished with value: 0.7762864410507917 and parameters: {'iterations': 1400, 'depth': 7, 'learning_rate': 0.03565710291903075, 'l2_leaf_reg': 17.136964508588775, 'random_strength': 0.5394074275445934, 'bagging_temperature': 0.025244340326562517}. Best is trial 81 with value: 0.781533010951046.
# [I 2026-03-12 01:46:09,101] Trial 84 finished with value: 0.7835207420021112 and parameters: {'iterations': 1400, 'depth': 7, 'learning_rate': 0.035896278624472464, 'l2_leaf_reg': 17.050361407261413, 'random_strength': 0.5213833325071646, 'bagging_temperature': 0.021225405607478542}. Best is trial 84 with value: 0.7835207420021112.
# [I 2026-03-12 01:47:19,633] Trial 85 finished with value: 0.7807436852971229 and parameters: {'iterations': 1400, 'depth': 7, 'learning_rate': 0.04256050087265682, 'l2_leaf_reg': 19.99999830242628, 'random_strength': 0.5001777208018107, 'bagging_temperature': 0.002240731452343568}. Best is trial 84 with value: 0.7835207420021112.
# [I 2026-03-12 01:48:29,837] Trial 86 finished with value: 0.7818048848459339 and parameters: {'iterations': 1400, 'depth': 7, 'learning_rate': 0.03663300379029998, 'l2_leaf_reg': 17.40549137914592, 'random_strength': 0.5652548619025272, 'bagging_temperature': 0.017334737980773285}. Best is trial 84 with value: 0.7835207420021112.
# [I 2026-03-12 01:49:40,676] Trial 87 finished with value: 0.7815233480179961 and parameters: {'iterations': 1400, 'depth': 7, 'learning_rate': 0.0373135681903944, 'l2_leaf_reg': 19.81019963790731, 'random_strength': 0.5160232272854037, 'bagging_temperature': 0.02422060735377294}. Best is trial 84 with value: 0.7835207420021112.
# [I 2026-03-12 01:50:51,311] Trial 88 finished with value: 0.7789207788901016 and parameters: {'iterations': 1400, 'depth': 7, 'learning_rate': 0.03734937003097049, 'l2_leaf_reg': 19.73721785202155, 'random_strength': 0.5146148621412681, 'bagging_temperature': 0.024038489658038342}. Best is trial 84 with value: 0.7835207420021112.
# [I 2026-03-12 01:52:02,643] Trial 89 finished with value: 0.7848787777379295 and parameters: {'iterations': 1400, 'depth': 7, 'learning_rate': 0.03638421366674581, 'l2_leaf_reg': 19.94566807832586, 'random_strength': 0.5611096514546443, 'bagging_temperature': 0.00658712807917973}. Best is trial 89 with value: 0.7848787777379295.
# [I 2026-03-12 01:53:13,450] Trial 90 finished with value: 0.7792630883541024 and parameters: {'iterations': 1400, 'depth': 7, 'learning_rate': 0.037415767214908885, 'l2_leaf_reg': 17.3023058495092, 'random_strength': 0.5753325970084389, 'bagging_temperature': 0.0013213402147064538}. Best is trial 89 with value: 0.7848787777379295.
# [I 2026-03-12 01:54:24,465] Trial 91 finished with value: 0.7815831176045821 and parameters: {'iterations': 1400, 'depth': 7, 'learning_rate': 0.03559880048866451, 'l2_leaf_reg': 17.004346840165617, 'random_strength': 0.5653427639784936, 'bagging_temperature': 0.02581873708010135}. Best is trial 89 with value: 0.7848787777379295.
# [I 2026-03-12 01:55:35,302] Trial 92 finished with value: 0.7829754202463554 and parameters: {'iterations': 1400, 'depth': 7, 'learning_rate': 0.03788288192992855, 'l2_leaf_reg': 19.911319635870363, 'random_strength': 0.5611787469862685, 'bagging_temperature': 0.013442887205924469}. Best is trial 89 with value: 0.7848787777379295.
# [I 2026-03-12 01:56:50,193] Trial 93 finished with value: 0.7772725647213757 and parameters: {'iterations': 1400, 'depth': 7, 'learning_rate': 0.03798023806600798, 'l2_leaf_reg': 17.110119568561725, 'random_strength': 0.5087494129448993, 'bagging_temperature': 0.005131795370558939}. Best is trial 89 with value: 0.7848787777379295.
# [I 2026-03-12 01:58:01,135] Trial 94 finished with value: 0.7733926417332447 and parameters: {'iterations': 1400, 'depth': 7, 'learning_rate': 0.03071508473796494, 'l2_leaf_reg': 16.26107322483412, 'random_strength': 0.5823633042334686, 'bagging_temperature': 0.0007582472907168777}. Best is trial 89 with value: 0.7848787777379295.
# [I 2026-03-12 01:59:12,472] Trial 95 finished with value: 0.7798061999313455 and parameters: {'iterations': 1400, 'depth': 7, 'learning_rate': 0.03754945272187207, 'l2_leaf_reg': 17.223669945137036, 'random_strength': 0.6402133047028546, 'bagging_temperature': 0.02778417106980532}. Best is trial 89 with value: 0.7848787777379295.
# [I 2026-03-12 02:00:23,446] Trial 96 finished with value: 0.7764039768545627 and parameters: {'iterations': 1400, 'depth': 7, 'learning_rate': 0.03393451071205976, 'l2_leaf_reg': 17.454321471870166, 'random_strength': 0.7054885700745146, 'bagging_temperature': 0.06239397616554511}. Best is trial 89 with value: 0.7848787777379295.
# [I 2026-03-12 02:01:34,803] Trial 97 finished with value: 0.7701371597072185 and parameters: {'iterations': 1400, 'depth': 7, 'learning_rate': 0.03381667811246108, 'l2_leaf_reg': 14.367865047082464, 'random_strength': 0.6077591774903179, 'bagging_temperature': 0.05445732255559979}. Best is trial 89 with value: 0.7848787777379295.
# [I 2026-03-12 02:02:47,563] Trial 98 finished with value: 0.7817416842261107 and parameters: {'iterations': 1400, 'depth': 7, 'learning_rate': 0.02824197302586484, 'l2_leaf_reg': 15.902557087703517, 'random_strength': 0.6444360791973002, 'bagging_temperature': 0.06021549140260343}. Best is trial 89 with value: 0.7848787777379295.
# [I 2026-03-12 02:04:59,764] Trial 99 finished with value: 0.7669201639821787 and parameters: {'iterations': 1400, 'depth': 8, 'learning_rate': 0.028816734350821684, 'l2_leaf_reg': 13.044275093838264, 'random_strength': 0.6440432506566058, 'bagging_temperature': 0.06570307150439539}. Best is trial 89 with value: 0.7848787777379295.
# === Optuna done for CatBoost ===
# Best macro-F1 (CV): 0.7848787777379295
# Best params: {'iterations': 1400, 'depth': 7, 'learning_rate': 0.03638421366674581, 'l2_leaf_reg': 19.94566807832586, 'random_strength': 0.5611096514546443, 'bagging_temperature': 0.00658712807917973}
# === Baseline Classification on Random Split ===
# RandomSplit Accuracy: 0.7534 | F1-macro: 0.7130 | F1-weighted: 0.7585
#
# Classification report (RandomSplit):
#               precision    recall  f1-score   support
#
#            A     1.0000    1.0000    1.0000         4
#            B     1.0000    0.8667    0.9286        15
#            C     1.0000    1.0000    1.0000         2
#            D     0.6667    0.8889    0.7619         9
#            E     0.8750    0.5385    0.6667        13
#            F     0.0000    0.0000    0.0000         0
#            G     0.8889    0.8889    0.8889         9
#            H     0.7143    0.7576    0.7353        33
#            I     0.4000    0.6667    0.5000         3
#            J     0.6250    0.4348    0.5128        23
#            K     0.8158    0.8857    0.8493        35
#
#     accuracy                         0.7534       146
#    macro avg     0.7260    0.7207    0.7130       146
# weighted avg     0.7813    0.7534    0.7585       146
#
# Saved: baseline_cm_random.csv
# Saved: baseline_preds_random_cls.csv
