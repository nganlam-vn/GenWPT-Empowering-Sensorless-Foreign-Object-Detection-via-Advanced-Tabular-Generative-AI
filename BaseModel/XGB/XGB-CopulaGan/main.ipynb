# %% [markdown]
# ## Baseline Model

# %%
import warnings

from sklearn.preprocessing import LabelEncoder
import pandas as pd
import numpy as np

warnings.filterwarnings("ignore")

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix
from sklearn.ensemble import HistGradientBoostingClassifier, RandomForestClassifier

def eval_classification(y_true, y_pred, name=""):
    acc = accuracy_score(y_true, y_pred)
    f1_macro = f1_score(y_true, y_pred, average="macro")
    f1_weighted = f1_score(y_true, y_pred, average="weighted")
    print(f"{name} Accuracy: {acc:.4f} | F1-macro: {f1_macro:.4f} | F1-weighted: {f1_weighted:.4f}")
    return acc, f1_macro, f1_weighted

def save_preds_csv(X_test, y_true, y_pred, filename):
    out = X_test.copy()
    out["y_true"] = y_true
    out["y_pred"] = y_pred
    out.to_csv(filename, index=False, encoding="utf-8-sig")
    print(f"Saved: {filename}")

def derive_groups_from_train(train_df, k_baseline_dict, min_group_size=2):
    df_temp = train_df.copy()
    df_temp["k_eff_expected"] = df_temp["load"].map(k_baseline_dict)
    if df_temp["k_eff_expected"].isnull().any():
        known_loads = np.array(list(k_baseline_dict.keys()))
        for idx, row in df_temp[df_temp["k_eff_expected"].isnull()].iterrows():
            closest_load = known_loads[np.abs(known_loads - row["load"]).argmin()]
            df_temp.loc[idx, "k_eff_expected"] = k_baseline_dict[closest_load]     
    df_temp["abs_diff"] = (df_temp["efficiency"] - df_temp["k_eff_expected"]).abs()
    type_stats = (
        df_temp.groupby("type")["abs_diff"]
        .agg(n="count", mean="mean")
        .sort_values("mean")
        .reset_index()
    )
    types = type_stats["type"].tolist()
    x = type_stats["mean"].to_numpy()
    n = len(x)
    # Prefix sums for O(1) segment SSE
    S1 = np.concatenate([[0.0], np.cumsum(x)])
    S2 = np.concatenate([[0.0], np.cumsum(x * x)])
    def seg_sse(i, j):
        m = j - i + 1
        sum1 = S1[j + 1] - S1[i]
        sum2 = S2[j + 1] - S2[i]
        mu = sum1 / m
        return sum2 - 2 * mu * sum1 + m * mu * mu

    K = 3
    INF = 1e18
    dp = np.full((K + 1, n + 1), INF)
    cut = np.full((K + 1, n + 1), -1, dtype=int)

    dp[0, 0] = 0.0
    for k in range(1, K + 1):
        for t in range(1, n + 1):
            p_min = (k - 1) * min_group_size
            p_max = t - min_group_size
            if p_max < p_min:
                continue
            best_cost, best_p = INF, -1
            for p in range(p_min, p_max + 1):
                cost = dp[k - 1, p] + seg_sse(p, t - 1)
                if cost < best_cost:
                    best_cost, best_p = cost, p
            dp[k, t] = best_cost
            cut[k, t] = best_p

    if np.isinf(dp[K, n]):
        raise RuntimeError("No valid split found. Try min_group_size=1 or check types count.")
    bounds = []
    t = n
    for k in range(K, 0, -1):
        p = cut[k, t]
        bounds.append((p, t))
        t = p
    bounds.reverse()
    group_names = ["near", "mid", "far"] 
    groups = {}
    for name, (a, b) in zip(group_names, bounds):
        groups[name] = types[a:b]

    type_to_group = {t: g for g, ts in groups.items() for t in ts}
    return type_to_group, groups, type_stats


# ----- Load split files -----
train_random = pd.read_csv('../../../GenerativeModel/CopulaGanGenData/wpt_train_random_aug_copulagan.csv')
test_random  = pd.read_csv('../../../random-split/wpt_test_random.csv')

# Sanity check expected columns
expected_cols = {"type", "load", "efficiency"}
for name, d in [("train_random", train_random), ("test_random", test_random)]:
    missing = expected_cols - set(d.columns)
    if missing:
        raise ValueError(f"{name} is missing columns: {missing}")

# Make sure numeric columns are numeric
for d in [train_random, test_random]:
    d["load"] = pd.to_numeric(d["load"], errors="coerce")
    d["efficiency"] = pd.to_numeric(d["efficiency"], errors="coerce")
    d["type"] = d["type"].astype(str)
    d.dropna(subset=["type", "load", "efficiency"], inplace=True)

# Features / target
FEATURES = ["load", "efficiency"]
TARGET = "type"

# =========================
def add_advanced_features(df, k_baseline_dict, type_to_group_dict):
    df = df.copy()
    df["k_eff_expected"] = df["load"].map(k_baseline_dict)
    if df["k_eff_expected"].isnull().any():
        known_loads = np.array(list(k_baseline_dict.keys()))
        for idx, row in df[df["k_eff_expected"].isnull()].iterrows():
            closest_load = known_loads[np.abs(known_loads - row["load"]).argmin()]
            df.loc[idx, "k_eff_expected"] = k_baseline_dict[closest_load]  
    # 2. Độ lệch (Difference) và Tỷ lệ (Ratio)
    df["eff_diff"] = df["efficiency"] - df["k_eff_expected"]
    df["eff_ratio"] = df["efficiency"] / df["k_eff_expected"]
    # 3. Ước tính tổn hao công suất (Power Loss Proxy)
    # P_loss = Load * (1 / (Efficiency / 100) - 1)
    df["p_loss"] = df["load"] * (1 / (df["efficiency"] / 100.0) - 1)
    # Tổn hao công suất của Class K
    df["k_p_loss"] = df["load"] * (1 / (df["k_eff_expected"] / 100.0) - 1)
    # Độ lệch suy hao do vật thể lạ gây ra
    df["p_loss_diff"] = df["p_loss"] - df["k_p_loss"]

    df["dist_zone_name"] = df["type"].map(type_to_group_dict).fillna("far")
    # Mã hóa thành số
    zone_mapping = {"near": 1, "mid": 2, "far": 3}
    df["dist_zone"] = df["dist_zone_name"].map(zone_mapping)
    # 4. Phân vùng Dải tải (Load Zone)
    # Giả sử dải tải từ 0.5 đến 3.0, chia làm 3 vùng: Nhẹ (1), Vừa (2), Nặng (3)
    df['load_zone'] = pd.cut(df['load'], bins=3, labels=[1, 2, 3]).astype(float)
    return df

k_baseline_train_r = train_random[train_random["type"] == "K"].groupby("load")["efficiency"].mean().to_dict()
type_to_group, groups_dict, stats = derive_groups_from_train(train_random, k_baseline_train_r)
print("Results of grouping the Types:", groups_dict)

train_random_fe = add_advanced_features(train_random, k_baseline_train_r, type_to_group)
test_random_fe = add_advanced_features(test_random, k_baseline_train_r, type_to_group)

FEATURES_NEW = [
    "load", "efficiency", 
    "eff_diff", "eff_ratio", 
    "p_loss_diff", "load_zone", "dist_zone"
]
# =========================
X_train_r = train_random_fe[FEATURES_NEW]
X_test_r  = test_random_fe[FEATURES_NEW]

# 2. Khởi tạo Label Encoder để dịch chữ sang số cho XGBoost
le = LabelEncoder()

# Fit và transform trên tập Train
y_train_r = le.fit_transform(train_random_fe[TARGET])

# Chỉ transform (không fit) trên tập Test
y_test_r = le.transform(test_random_fe[TARGET])

print("Encoded:", le.classes_)
print("Train dataset is ready:", X_train_r.shape, y_train_r.shape)
# Out:
# Results of grouping the Types: {'near': ['K', 'H', 'J', 'G'], 'mid': ['E', 'I', 'F', 'D', 'B'], 'far': ['C', 'A']}
# Encoded: ['A' 'B' 'C' 'D' 'E' 'F' 'G' 'H' 'I' 'J' 'K']
# Train dataset is ready: (1502, 7) (1502,)

# %% [markdown]
# ## Optuna

# %%
import optuna

import xgboost as xgb
import json
from sklearn.model_selection import StratifiedKFold, cross_val_score

def objective(trial):
    param = {
        'objective': 'multi:softprob',  # Dùng cho phân loại đa lớp
        'num_class': 11,
        'random_state': 30,
        'verbosity': 0,
        
        # 1. Boosting Type: XGB dùng 'gbtree' (mặc định) hoặc 'dart'
        'booster': trial.suggest_categorical('booster', ['gbtree']),
        
        # 2. Quy mô cây và tốc độ học
        'n_estimators': trial.suggest_int('n_estimators', 100, 1500),
        'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        
        # 3. Chống Overfitting (Đặc trưng của XGB)
        'gamma': trial.suggest_float('gamma', 1e-8, 1.0, log=True), # Càng cao càng tránh overfit
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 20),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.4, 1.0),
        
        # 4. Regularization L1, L2
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-8, 10.0, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-8, 10.0, log=True),
        
        # # Combo kích hoạt GPU an toàn
        'tree_method': 'hist',
        'device': 'cuda',
    }

    # Lưu ý: XGBoost không có 'class_weight' trực tiếp như LGBM 
    # Nếu dữ liệu cực kỳ lệch, ta thường dùng sample_weight trong lúc fit
    clf = xgb.XGBClassifier(**param)
    
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    
    # Tính điểm số trung bình (Dùng f1_macro cho 11 lớp)
    scores = cross_val_score(clf, X_train_r, y_train_r, cv=cv, scoring='f1_macro', n_jobs=1)
    
    return scores.mean()

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=200, show_progress_bar=True)

best_params = study.best_params
best_params.update({
    'objective': 'multi:softprob',
    'num_class': 11,
    'random_state': 30
})

with open("best_xgb_params.json", "w") as f:
    json.dump(best_params, f, indent=4)

print(f"Best Score: {study.best_value}")
# Out:
# [I 2026-03-14 11:41:23,441] A new study created in memory with name: no-name-e9c169fc-9adf-4308-9b2f-3373d926cf09
#   0%|          | 0/200 [00:00<?, ?it/s]
# [I 2026-03-14 11:41:29,086] Trial 0 finished with value: 0.5859830270751413 and parameters: {'booster': 'gbtree', 'n_estimators': 656, 'learning_rate': 0.0014005769158591042, 'max_depth': 8, 'gamma': 1.924942758392618e-06, 'min_child_weight': 15, 'subsample': 0.6823264534312017, 'colsample_bytree': 0.8347551142420822, 'reg_alpha': 4.442014534318247e-07, 'reg_lambda': 0.00017610242131901348}. Best is trial 0 with value: 0.5859830270751413.
# [I 2026-03-14 11:41:34,852] Trial 1 finished with value: 0.6780657497276772 and parameters: {'booster': 'gbtree', 'n_estimators': 936, 'learning_rate': 0.08604733962008666, 'max_depth': 9, 'gamma': 0.22689602627836766, 'min_child_weight': 15, 'subsample': 0.7651461863663858, 'colsample_bytree': 0.9422267531845381, 'reg_alpha': 0.004199261235775023, 'reg_lambda': 0.11599744611691047}. Best is trial 1 with value: 0.6780657497276772.
# [I 2026-03-14 11:41:45,025] Trial 2 finished with value: 0.6518664787619317 and parameters: {'booster': 'gbtree', 'n_estimators': 1447, 'learning_rate': 0.0031909419745444565, 'max_depth': 9, 'gamma': 0.005701942019360406, 'min_child_weight': 19, 'subsample': 0.5759940598325481, 'colsample_bytree': 0.5670757576361889, 'reg_alpha': 4.3094436694343893e-07, 'reg_lambda': 1.2363925332190957}. Best is trial 1 with value: 0.6780657497276772.
# [I 2026-03-14 11:41:47,663] Trial 3 finished with value: 0.6872904888528503 and parameters: {'booster': 'gbtree', 'n_estimators': 286, 'learning_rate': 0.0041984078761084075, 'max_depth': 7, 'gamma': 1.6889579215724123e-07, 'min_child_weight': 10, 'subsample': 0.8259620461623166, 'colsample_bytree': 0.9969539598124854, 'reg_alpha': 0.0002064295174653338, 'reg_lambda': 0.0002693281456775594}. Best is trial 3 with value: 0.6872904888528503.
# [I 2026-03-14 11:41:50,993] Trial 4 finished with value: 0.6593993464625764 and parameters: {'booster': 'gbtree', 'n_estimators': 554, 'learning_rate': 0.09809584205689152, 'max_depth': 4, 'gamma': 3.9462263386115615e-08, 'min_child_weight': 16, 'subsample': 0.636238870676434, 'colsample_bytree': 0.565447404031139, 'reg_alpha': 0.0005553948171153091, 'reg_lambda': 4.8053405291014646e-05}. Best is trial 3 with value: 0.6872904888528503.
# [I 2026-03-14 11:41:57,775] Trial 5 finished with value: 0.640982585734271 and parameters: {'booster': 'gbtree', 'n_estimators': 935, 'learning_rate': 0.0045923339670468945, 'max_depth': 7, 'gamma': 4.0073228190461914e-08, 'min_child_weight': 17, 'subsample': 0.6199481124137239, 'colsample_bytree': 0.427985219162192, 'reg_alpha': 7.485313843407813e-08, 'reg_lambda': 5.135665299086361e-07}. Best is trial 3 with value: 0.6872904888528503.
# [I 2026-03-14 11:41:59,164] Trial 6 finished with value: 0.6723427162592087 and parameters: {'booster': 'gbtree', 'n_estimators': 215, 'learning_rate': 0.14120155878277765, 'max_depth': 5, 'gamma': 4.245755870251565e-06, 'min_child_weight': 17, 'subsample': 0.681725324427841, 'colsample_bytree': 0.9909622772960653, 'reg_alpha': 1.1424952231201089e-07, 'reg_lambda': 6.406037663932492e-07}. Best is trial 3 with value: 0.6872904888528503.
# [I 2026-03-14 11:42:12,275] Trial 7 finished with value: 0.7283007180503435 and parameters: {'booster': 'gbtree', 'n_estimators': 1254, 'learning_rate': 0.002828839301035123, 'max_depth': 9, 'gamma': 0.003924508057095864, 'min_child_weight': 8, 'subsample': 0.9167364207386888, 'colsample_bytree': 0.7614496377741153, 'reg_alpha': 3.220810569507825e-06, 'reg_lambda': 1.929350901108636e-06}. Best is trial 7 with value: 0.7283007180503435.
# [I 2026-03-14 11:42:20,378] Trial 8 finished with value: 0.6886971129170933 and parameters: {'booster': 'gbtree', 'n_estimators': 1043, 'learning_rate': 0.0132010860708829, 'max_depth': 11, 'gamma': 0.0002995725334419726, 'min_child_weight': 16, 'subsample': 0.8886080483847724, 'colsample_bytree': 0.5039081379134193, 'reg_alpha': 0.0002855888878079923, 'reg_lambda': 0.00018841618258673144}. Best is trial 7 with value: 0.7283007180503435.
# [I 2026-03-14 11:42:29,414] Trial 9 finished with value: 0.692370194146238 and parameters: {'booster': 'gbtree', 'n_estimators': 992, 'learning_rate': 0.002637543266778514, 'max_depth': 9, 'gamma': 4.5831339170017967e-07, 'min_child_weight': 16, 'subsample': 0.9620524865204024, 'colsample_bytree': 0.9751591573583168, 'reg_alpha': 0.025279513351864052, 'reg_lambda': 3.915142102319253e-07}. Best is trial 7 with value: 0.7283007180503435.
# [I 2026-03-14 11:42:36,786] Trial 10 finished with value: 0.7330373562542161 and parameters: {'booster': 'gbtree', 'n_estimators': 1428, 'learning_rate': 0.017566404657547358, 'max_depth': 12, 'gamma': 0.9056724421026897, 'min_child_weight': 3, 'subsample': 0.9948776716504433, 'colsample_bytree': 0.7105542275116538, 'reg_alpha': 8.884604534161027e-06, 'reg_lambda': 3.888194702130884e-08}. Best is trial 10 with value: 0.7330373562542161.
# [I 2026-03-14 11:42:43,978] Trial 11 finished with value: 0.7227369666799058 and parameters: {'booster': 'gbtree', 'n_estimators': 1497, 'learning_rate': 0.022200400382347735, 'max_depth': 12, 'gamma': 0.7647377072281284, 'min_child_weight': 3, 'subsample': 0.9781065220787658, 'colsample_bytree': 0.7221314064306426, 'reg_alpha': 4.659158679502723, 'reg_lambda': 1.0957870799476358e-08}. Best is trial 10 with value: 0.7330373562542161.
# [I 2026-03-14 11:42:59,772] Trial 12 finished with value: 0.7027820907880289 and parameters: {'booster': 'gbtree', 'n_estimators': 1252, 'learning_rate': 0.015843394945835993, 'max_depth': 11, 'gamma': 0.01575153546830314, 'min_child_weight': 4, 'subsample': 0.8960227050833492, 'colsample_bytree': 0.7129069854712442, 'reg_alpha': 9.773547382541948e-06, 'reg_lambda': 9.504068401198686e-08}. Best is trial 10 with value: 0.7330373562542161.
# [I 2026-03-14 11:43:18,512] Trial 13 finished with value: 0.6981269915644631 and parameters: {'booster': 'gbtree', 'n_estimators': 1238, 'learning_rate': 0.035220124368402723, 'max_depth': 12, 'gamma': 0.00025946424868849476, 'min_child_weight': 7, 'subsample': 0.9920456831510229, 'colsample_bytree': 0.8088824732793436, 'reg_alpha': 5.321755123054367e-06, 'reg_lambda': 5.115963893936797e-06}. Best is trial 10 with value: 0.7330373562542161.
# [I 2026-03-14 11:43:57,734] Trial 14 finished with value: 0.6994670281093625 and parameters: {'booster': 'gbtree', 'n_estimators': 1282, 'learning_rate': 0.0074619755071098325, 'max_depth': 10, 'gamma': 0.013817708571893204, 'min_child_weight': 1, 'subsample': 0.8899699956534143, 'colsample_bytree': 0.6355482113293746, 'reg_alpha': 1.752244990994513e-05, 'reg_lambda': 0.01810089053691806}. Best is trial 10 with value: 0.7330373562542161.
# [I 2026-03-14 11:44:16,927] Trial 15 finished with value: 0.6964480966137263 and parameters: {'booster': 'gbtree', 'n_estimators': 1173, 'learning_rate': 0.0012586903836581727, 'max_depth': 6, 'gamma': 0.14618845989162252, 'min_child_weight': 8, 'subsample': 0.8069049774514854, 'colsample_bytree': 0.81493585485249, 'reg_alpha': 2.2351868131995353e-08, 'reg_lambda': 1.3693353235830869e-08}. Best is trial 10 with value: 0.7330373562542161.
# [I 2026-03-14 11:44:32,284] Trial 16 finished with value: 0.6921451360091393 and parameters: {'booster': 'gbtree', 'n_estimators': 1370, 'learning_rate': 0.04975176917989168, 'max_depth': 3, 'gamma': 0.0012198858296608294, 'min_child_weight': 5, 'subsample': 0.9268004276740539, 'colsample_bytree': 0.6601518169698514, 'reg_alpha': 2.471123966162218e-06, 'reg_lambda': 5.521212282797159e-06}. Best is trial 10 with value: 0.7330373562542161.
# [I 2026-03-14 11:44:44,685] Trial 17 finished with value: 0.7292884242443124 and parameters: {'booster': 'gbtree', 'n_estimators': 787, 'learning_rate': 0.008523475571883895, 'max_depth': 10, 'gamma': 3.329204115225836e-05, 'min_child_weight': 10, 'subsample': 0.8251596030269148, 'colsample_bytree': 0.895679514571263, 'reg_alpha': 0.07785065559560664, 'reg_lambda': 0.00834534344522079}. Best is trial 10 with value: 0.7330373562542161.
# [I 2026-03-14 11:44:55,167] Trial 18 finished with value: 0.7207208038601277 and parameters: {'booster': 'gbtree', 'n_estimators': 703, 'learning_rate': 0.009200084643022187, 'max_depth': 11, 'gamma': 1.1470300321841042e-05, 'min_child_weight': 12, 'subsample': 0.8337526248609914, 'colsample_bytree': 0.8869130699689746, 'reg_alpha': 0.6031215526503645, 'reg_lambda': 0.005543269328817902}. Best is trial 10 with value: 0.7330373562542161.
# [I 2026-03-14 11:45:00,544] Trial 19 finished with value: 0.7086931193736499 and parameters: {'booster': 'gbtree', 'n_estimators': 405, 'learning_rate': 0.030408492787012055, 'max_depth': 12, 'gamma': 2.372906060410547e-05, 'min_child_weight': 12, 'subsample': 0.7602099035860614, 'colsample_bytree': 0.9127513523409747, 'reg_alpha': 0.05513878694167626, 'reg_lambda': 0.0033264820939156586}. Best is trial 10 with value: 0.7330373562542161.
# [I 2026-03-14 11:45:21,251] Trial 20 finished with value: 0.717156091918843 and parameters: {'booster': 'gbtree', 'n_estimators': 799, 'learning_rate': 0.007946639123756804, 'max_depth': 10, 'gamma': 7.931329382230171e-05, 'min_child_weight': 1, 'subsample': 0.5449591905513227, 'colsample_bytree': 0.872394158655204, 'reg_alpha': 0.3010050828649974, 'reg_lambda': 0.6781465912493261}. Best is trial 10 with value: 0.7330373562542161.
# [I 2026-03-14 11:47:31,183] Trial 21 finished with value: 0.7162393492532826 and parameters: {'booster': 'gbtree', 'n_estimators': 1100, 'learning_rate': 0.0021301574022531615, 'max_depth': 10, 'gamma': 0.001477254631195809, 'min_child_weight': 7, 'subsample': 0.9333871220899358, 'colsample_bytree': 0.7628581438218193, 'reg_alpha': 9.740575054733833e-05, 'reg_lambda': 1.0576128800216913e-05}. Best is trial 10 with value: 0.7330373562542161.
# [I 2026-03-14 11:47:42,397] Trial 22 finished with value: 0.7140703408932154 and parameters: {'booster': 'gbtree', 'n_estimators': 821, 'learning_rate': 0.005910893250475395, 'max_depth': 8, 'gamma': 0.10939043341506492, 'min_child_weight': 10, 'subsample': 0.8710024693124981, 'colsample_bytree': 0.7629354328613831, 'reg_alpha': 0.0024090517981825315, 'reg_lambda': 8.62459070544351}. Best is trial 10 with value: 0.7330373562542161.
# [I 2026-03-14 11:49:57,851] Trial 23 finished with value: 0.7130000821971553 and parameters: {'booster': 'gbtree', 'n_estimators': 1354, 'learning_rate': 0.015128810357323315, 'max_depth': 10, 'gamma': 3.7743635959344066e-05, 'min_child_weight': 8, 'subsample': 0.9317496301548754, 'colsample_bytree': 0.6374337238295872, 'reg_alpha': 1.8693968613892733e-06, 'reg_lambda': 9.681129961921136e-08}. Best is trial 10 with value: 0.7330373562542161.
# [I 2026-03-14 11:50:56,557] Trial 24 finished with value: 0.6839046873825385 and parameters: {'booster': 'gbtree', 'n_estimators': 539, 'learning_rate': 0.0018920788909964244, 'max_depth': 11, 'gamma': 0.026285212203698515, 'min_child_weight': 12, 'subsample': 0.9959005663645912, 'colsample_bytree': 0.7644286295615669, 'reg_alpha': 1.8973441634484103e-05, 'reg_lambda': 0.0018052692663074585}. Best is trial 10 with value: 0.7330373562542161.
# [I 2026-03-14 11:51:09,081] Trial 25 finished with value: 0.7156052879120102 and parameters: {'booster': 'gbtree', 'n_estimators': 1145, 'learning_rate': 0.009966390996270846, 'max_depth': 9, 'gamma': 0.0020129072640259135, 'min_child_weight': 5, 'subsample': 0.8415003179103071, 'colsample_bytree': 0.6879290062120913, 'reg_alpha': 7.538033873944793, 'reg_lambda': 7.458427280555133e-08}. Best is trial 10 with value: 0.7330373562542161.
# [I 2026-03-14 11:51:28,254] Trial 26 finished with value: 0.7153999158497883 and parameters: {'booster': 'gbtree', 'n_estimators': 817, 'learning_rate': 0.004119660124489406, 'max_depth': 12, 'gamma': 0.00025794769467493077, 'min_child_weight': 3, 'subsample': 0.7205187976953058, 'colsample_bytree': 0.8298417845747248, 'reg_alpha': 5.377371881814537e-05, 'reg_lambda': 0.03328994605072136}. Best is trial 10 with value: 0.7330373562542161.
# [I 2026-03-14 11:51:48,764] Trial 27 finished with value: 0.6995656877334449 and parameters: {'booster': 'gbtree', 'n_estimators': 1363, 'learning_rate': 0.023514959750711047, 'max_depth': 8, 'gamma': 3.3542631061805e-06, 'min_child_weight': 6, 'subsample': 0.9524599810293365, 'colsample_bytree': 0.5723761799477226, 'reg_alpha': 0.0010145665933980808, 'reg_lambda': 0.0011572344482622212}. Best is trial 10 with value: 0.7330373562542161.
# [I 2026-03-14 11:52:03,266] Trial 28 finished with value: 0.7234515368369798 and parameters: {'booster': 'gbtree', 'n_estimators': 1432, 'learning_rate': 0.005914723773931202, 'max_depth': 11, 'gamma': 0.9581491015690472, 'min_child_weight': 9, 'subsample': 0.7789585781904648, 'colsample_bytree': 0.8718354673287, 'reg_alpha': 0.010994231759686285, 'reg_lambda': 2.826391986745069e-05}. Best is trial 10 with value: 0.7330373562542161.
# [I 2026-03-14 11:52:11,272] Trial 29 finished with value: 0.6945877455190304 and parameters: {'booster': 'gbtree', 'n_estimators': 683, 'learning_rate': 0.04934629543451101, 'max_depth': 10, 'gamma': 0.04418912058350551, 'min_child_weight': 13, 'subsample': 0.8678521112726175, 'colsample_bytree': 0.7875977983601339, 'reg_alpha': 3.8134356957072283e-07, 'reg_lambda': 1.2388144674699192e-06}. Best is trial 10 with value: 0.7330373562542161.
# [I 2026-03-14 11:52:15,726] Trial 30 finished with value: 0.549882589470596 and parameters: {'booster': 'gbtree', 'n_estimators': 524, 'learning_rate': 0.0011901290032695973, 'max_depth': 8, 'gamma': 0.004546797379590746, 'min_child_weight': 14, 'subsample': 0.9191990430679009, 'colsample_bytree': 0.9254335735495975, 'reg_alpha': 1.280413469129824e-06, 'reg_lambda': 4.574538743100049e-05}. Best is trial 10 with value: 0.7330373562542161.
# [I 2026-03-14 11:52:25,618] Trial 31 finished with value: 0.7257148398091066 and parameters: {'booster': 'gbtree', 'n_estimators': 1442, 'learning_rate': 0.005634878434116177, 'max_depth': 11, 'gamma': 0.8926668989736578, 'min_child_weight': 9, 'subsample': 0.7854978098947989, 'colsample_bytree': 0.8684071938549096, 'reg_alpha': 0.017160634469780403, 'reg_lambda': 4.805488028635349e-05}. Best is trial 10 with value: 0.7330373562542161.
# [I 2026-03-14 11:52:34,509] Trial 32 finished with value: 0.7106294100887103 and parameters: {'booster': 'gbtree', 'n_estimators': 1293, 'learning_rate': 0.011368536164420785, 'max_depth': 11, 'gamma': 0.4533045785998336, 'min_child_weight': 9, 'subsample': 0.7120269042316169, 'colsample_bytree': 0.8422910353913019, 'reg_alpha': 0.12778024572612603, 'reg_lambda': 2.4954222519784694e-06}. Best is trial 10 with value: 0.7330373562542161.
# [I 2026-03-14 11:52:45,820] Trial 33 finished with value: 0.7257817514945346 and parameters: {'booster': 'gbtree', 'n_estimators': 1451, 'learning_rate': 0.0035213388086661047, 'max_depth': 9, 'gamma': 0.07772776160785137, 'min_child_weight': 11, 'subsample': 0.7970157851691504, 'colsample_bytree': 0.9496414899856505, 'reg_alpha': 1.3027246365211, 'reg_lambda': 1.589809579395923e-05}. Best is trial 10 with value: 0.7330373562542161.
# [I 2026-03-14 11:52:57,574] Trial 34 finished with value: 0.7203573293455141 and parameters: {'booster': 'gbtree', 'n_estimators': 1480, 'learning_rate': 0.003107647856299137, 'max_depth': 9, 'gamma': 0.08558392642508318, 'min_child_weight': 11, 'subsample': 0.8175653480904954, 'colsample_bytree': 0.9498627348397443, 'reg_alpha': 1.386807025184581, 'reg_lambda': 0.0006204285206516122}. Best is trial 10 with value: 0.7330373562542161.
# [I 2026-03-14 11:53:04,460] Trial 35 finished with value: 0.6908219913718735 and parameters: {'booster': 'gbtree', 'n_estimators': 920, 'learning_rate': 0.0016979135866015205, 'max_depth': 7, 'gamma': 0.18020861977107996, 'min_child_weight': 11, 'subsample': 0.8551840013396322, 'colsample_bytree': 0.9614402942843601, 'reg_alpha': 1.7356099781401852, 'reg_lambda': 0.23977855735236783}. Best is trial 10 with value: 0.7330373562542161.
# [I 2026-03-14 11:53:14,007] Trial 36 finished with value: 0.6943312701816333 and parameters: {'booster': 'gbtree', 'n_estimators': 1197, 'learning_rate': 0.00266311636442911, 'max_depth': 9, 'gamma': 0.007010832198491819, 'min_child_weight': 14, 'subsample': 0.7303483544915761, 'colsample_bytree': 0.9104089952875298, 'reg_alpha': 0.17889490807605507, 'reg_lambda': 3.479863173929787e-08}. Best is trial 10 with value: 0.7330373562542161.
# [I 2026-03-14 11:53:25,463] Trial 37 finished with value: 0.7245826309714452 and parameters: {'booster': 'gbtree', 'n_estimators': 1073, 'learning_rate': 0.0034613537605805342, 'max_depth': 6, 'gamma': 0.04409548650446505, 'min_child_weight': 2, 'subsample': 0.501555613094563, 'colsample_bytree': 0.7231552083506858, 'reg_alpha': 0.004502586672293452, 'reg_lambda': 2.7874082816972397e-07}. Best is trial 10 with value: 0.7330373562542161.
# [I 2026-03-14 11:53:26,383] Trial 38 finished with value: 0.10961579733203523 and parameters: {'booster': 'gbtree', 'n_estimators': 123, 'learning_rate': 0.004426437676776264, 'max_depth': 8, 'gamma': 7.725038334317782e-07, 'min_child_weight': 20, 'subsample': 0.6487530436112254, 'colsample_bytree': 0.6130677188360655, 'reg_alpha': 5.164637098255488e-07, 'reg_lambda': 0.00012620494794279158}. Best is trial 10 with value: 0.7330373562542161.
# [I 2026-03-14 11:53:38,126] Trial 39 finished with value: 0.6637295310250173 and parameters: {'booster': 'gbtree', 'n_estimators': 1388, 'learning_rate': 0.0010006295583643225, 'max_depth': 10, 'gamma': 0.27756747921785624, 'min_child_weight': 10, 'subsample': 0.8023148563517519, 'colsample_bytree': 0.488398740901068, 'reg_alpha': 0.00016072016264147157, 'reg_lambda': 1.7818999174237995e-05}. Best is trial 10 with value: 0.7330373562542161.
# [I 2026-03-14 11:53:50,244] Trial 40 finished with value: 0.7069833684738882 and parameters: {'booster': 'gbtree', 'n_estimators': 1297, 'learning_rate': 0.016671180972349712, 'max_depth': 9, 'gamma': 1.1199817308483987e-08, 'min_child_weight': 6, 'subsample': 0.9012220723772753, 'colsample_bytree': 0.7451214125656912, 'reg_alpha': 8.698453687369158e-08, 'reg_lambda': 1.5959219657052335e-06}. Best is trial 10 with value: 0.7330373562542161.
# [I 2026-03-14 11:54:00,586] Trial 41 finished with value: 0.7267643228118174 and parameters: {'booster': 'gbtree', 'n_estimators': 1419, 'learning_rate': 0.005976707660729479, 'max_depth': 12, 'gamma': 0.5774847278172069, 'min_child_weight': 9, 'subsample': 0.7844994571833754, 'colsample_bytree': 0.8592174761575444, 'reg_alpha': 0.06514825921609009, 'reg_lambda': 0.00012804555992721752}. Best is trial 10 with value: 0.7330373562542161.
# [I 2026-03-14 11:54:11,931] Trial 42 finished with value: 0.7248350194749505 and parameters: {'booster': 'gbtree', 'n_estimators': 1490, 'learning_rate': 0.006600805042652818, 'max_depth': 12, 'gamma': 0.4323686248006417, 'min_child_weight': 8, 'subsample': 0.7461410538424371, 'colsample_bytree': 0.8447292866179361, 'reg_alpha': 0.05305947640572167, 'reg_lambda': 9.714379485668336e-05}. Best is trial 10 with value: 0.7330373562542161.
# [I 2026-03-14 11:54:22,594] Trial 43 finished with value: 0.7014349516506593 and parameters: {'booster': 'gbtree', 'n_estimators': 1406, 'learning_rate': 0.002427480446525249, 'max_depth': 12, 'gamma': 0.06521060070709668, 'min_child_weight': 11, 'subsample': 0.7912333093672981, 'colsample_bytree': 0.6864972683160693, 'reg_alpha': 1.3723417936868376, 'reg_lambda': 0.0002857228502541437}. Best is trial 10 with value: 0.7330373562542161.
# [I 2026-03-14 11:54:35,898] Trial 44 finished with value: 0.73405553978726 and parameters: {'booster': 'gbtree', 'n_estimators': 1325, 'learning_rate': 0.0035989464779980977, 'max_depth': 10, 'gamma': 0.0005063094438241491, 'min_child_weight': 7, 'subsample': 0.9662677610470024, 'colsample_bytree': 0.935050812401174, 'reg_alpha': 0.5699625360439552, 'reg_lambda': 7.666089552395416e-06}. Best is trial 44 with value: 0.73405553978726.
# [I 2026-03-14 11:54:45,700] Trial 45 finished with value: 0.7146910363075699 and parameters: {'booster': 'gbtree', 'n_estimators': 963, 'learning_rate': 0.011838027957144944, 'max_depth': 10, 'gamma': 0.0008338733754440423, 'min_child_weight': 7, 'subsample': 0.9756458269112619, 'colsample_bytree': 0.9991001149124189, 'reg_alpha': 0.0006459056465353513, 'reg_lambda': 2.6046776448206137e-07}. Best is trial 44 with value: 0.73405553978726.
# [I 2026-03-14 11:54:58,851] Trial 46 finished with value: 0.6990494206744554 and parameters: {'booster': 'gbtree', 'n_estimators': 1222, 'learning_rate': 0.01966856885131914, 'max_depth': 12, 'gamma': 0.0005534904079859065, 'min_child_weight': 4, 'subsample': 0.9558865985616048, 'colsample_bytree': 0.794595548431867, 'reg_alpha': 0.06472353706000802, 'reg_lambda': 0.013942486257777692}. Best is trial 44 with value: 0.73405553978726.
# [I 2026-03-14 11:55:13,698] Trial 47 finished with value: 0.7225937019385069 and parameters: {'booster': 'gbtree', 'n_estimators': 1331, 'learning_rate': 0.004816872294111295, 'max_depth': 11, 'gamma': 0.00013900891985389662, 'min_child_weight': 6, 'subsample': 0.968835733543728, 'colsample_bytree': 0.9211482715834975, 'reg_alpha': 4.222513591068553e-05, 'reg_lambda': 7.292135753165634e-07}. Best is trial 44 with value: 0.73405553978726.
# [I 2026-03-14 11:55:21,775] Trial 48 finished with value: 0.7248595779153146 and parameters: {'booster': 'gbtree', 'n_estimators': 894, 'learning_rate': 0.008241847851711752, 'max_depth': 10, 'gamma': 1.3315139870886817e-05, 'min_child_weight': 9, 'subsample': 0.909626914852583, 'colsample_bytree': 0.8493732257499577, 'reg_alpha': 0.5928714396511539, 'reg_lambda': 5.318784591474831e-06}. Best is trial 44 with value: 0.73405553978726.
# [I 2026-03-14 11:55:26,648] Trial 49 finished with value: 0.6924409076665716 and parameters: {'booster': 'gbtree', 'n_estimators': 606, 'learning_rate': 0.16824775073691284, 'max_depth': 11, 'gamma': 0.003354000810147902, 'min_child_weight': 5, 'subsample': 0.9467427809730581, 'colsample_bytree': 0.903711246484742, 'reg_alpha': 5.258116542452408e-06, 'reg_lambda': 0.0005263852797136294}. Best is trial 44 with value: 0.73405553978726.
# [I 2026-03-14 11:55:37,875] Trial 50 finished with value: 0.7275635919024038 and parameters: {'booster': 'gbtree', 'n_estimators': 1138, 'learning_rate': 0.001583417827364761, 'max_depth': 12, 'gamma': 0.011184226434763397, 'min_child_weight': 3, 'subsample': 0.9991304755633238, 'colsample_bytree': 0.9748812646012608, 'reg_alpha': 3.4613960382258178, 'reg_lambda': 0.08077501412355927}. Best is trial 44 with value: 0.73405553978726.
# [I 2026-03-14 11:55:49,760] Trial 51 finished with value: 0.7276349612747433 and parameters: {'booster': 'gbtree', 'n_estimators': 1147, 'learning_rate': 0.0014020667614746743, 'max_depth': 12, 'gamma': 8.885247644047562e-05, 'min_child_weight': 3, 'subsample': 0.9996668326102249, 'colsample_bytree': 0.982934080624782, 'reg_alpha': 3.0661220643313745, 'reg_lambda': 0.0441975053594925}. Best is trial 44 with value: 0.73405553978726.
# [I 2026-03-14 11:55:59,767] Trial 52 finished with value: 0.7268545010352823 and parameters: {'booster': 'gbtree', 'n_estimators': 1004, 'learning_rate': 0.0015046466329229993, 'max_depth': 12, 'gamma': 6.204818837186058e-05, 'min_child_weight': 2, 'subsample': 0.9912236274993741, 'colsample_bytree': 0.9744087894157349, 'reg_alpha': 5.355537238491175, 'reg_lambda': 0.09947315195986409}. Best is trial 44 with value: 0.73405553978726.
# [I 2026-03-14 11:56:11,028] Trial 53 finished with value: 0.7253275819712187 and parameters: {'booster': 'gbtree', 'n_estimators': 1132, 'learning_rate': 0.0015078763203266521, 'max_depth': 11, 'gamma': 0.0005047511370583096, 'min_child_weight': 3, 'subsample': 0.985440127307816, 'colsample_bytree': 0.9739021271527839, 'reg_alpha': 2.7290474607751376, 'reg_lambda': 0.2875505764046308}. Best is trial 44 with value: 0.73405553978726.
# [I 2026-03-14 11:56:26,351] Trial 54 finished with value: 0.714924338259703 and parameters: {'booster': 'gbtree', 'n_estimators': 1028, 'learning_rate': 0.0022646157135321164, 'max_depth': 12, 'gamma': 0.009408472024460596, 'min_child_weight': 2, 'subsample': 0.9434151965804813, 'colsample_bytree': 0.9344550805738701, 'reg_alpha': 0.3144772058983999, 'reg_lambda': 0.0720233364473964}. Best is trial 44 with value: 0.73405553978726.
# [I 2026-03-14 11:56:36,094] Trial 55 finished with value: 0.7237138861901613 and parameters: {'booster': 'gbtree', 'n_estimators': 749, 'learning_rate': 0.0018878398372765043, 'max_depth': 10, 'gamma': 0.00021318907500729963, 'min_child_weight': 1, 'subsample': 0.971816692337476, 'colsample_bytree': 0.8888836641010975, 'reg_alpha': 0.6495912276499629, 'reg_lambda': 2.601325554932942}. Best is trial 44 with value: 0.73405553978726.
# [I 2026-03-14 11:56:45,961] Trial 56 finished with value: 0.6834112139366579 and parameters: {'booster': 'gbtree', 'n_estimators': 1261, 'learning_rate': 0.0010669498238407623, 'max_depth': 11, 'gamma': 7.210921189230649e-06, 'min_child_weight': 4, 'subsample': 0.9944004444459764, 'colsample_bytree': 0.9683576952995779, 'reg_alpha': 9.897821987788365, 'reg_lambda': 0.007725017665463229}. Best is trial 44 with value: 0.73405553978726.
# [I 2026-03-14 11:57:00,476] Trial 57 finished with value: 0.7218083239455012 and parameters: {'booster': 'gbtree', 'n_estimators': 1199, 'learning_rate': 0.0028738755228053985, 'max_depth': 6, 'gamma': 0.0024082484272345958, 'min_child_weight': 3, 'subsample': 0.8781280646305442, 'colsample_bytree': 0.9973493578904907, 'reg_alpha': 1.0987370875520154e-08, 'reg_lambda': 0.03902120057785298}. Best is trial 44 with value: 0.73405553978726.
# [I 2026-03-14 11:57:08,117] Trial 58 finished with value: 0.7040778049956424 and parameters: {'booster': 'gbtree', 'n_estimators': 877, 'learning_rate': 0.0013526241731801468, 'max_depth': 4, 'gamma': 4.901643286211083e-05, 'min_child_weight': 5, 'subsample': 0.9239071310815741, 'colsample_bytree': 0.897813452098766, 'reg_alpha': 0.6876917788439392, 'reg_lambda': 0.8308315745568553}. Best is trial 44 with value: 0.73405553978726.
# [I 2026-03-14 11:57:18,885] Trial 59 finished with value: 0.7191516253733881 and parameters: {'booster': 'gbtree', 'n_estimators': 1154, 'learning_rate': 0.0019310879610404052, 'max_depth': 12, 'gamma': 0.0001315163694164752, 'min_child_weight': 7, 'subsample': 0.966214465498093, 'colsample_bytree': 0.9377326365032111, 'reg_alpha': 2.716247805762427, 'reg_lambda': 2.219662802294539e-08}. Best is trial 44 with value: 0.73405553978726.
# [I 2026-03-14 11:57:34,079] Trial 60 finished with value: 0.7151066660345123 and parameters: {'booster': 'gbtree', 'n_estimators': 1086, 'learning_rate': 0.0037570266228201254, 'max_depth': 10, 'gamma': 0.017632972505088836, 'min_child_weight': 4, 'subsample': 0.9993881691728218, 'colsample_bytree': 0.6751693814299485, 'reg_alpha': 2.3620253785107483e-07, 'reg_lambda': 0.002864809639043731}. Best is trial 44 with value: 0.73405553978726.
# [I 2026-03-14 11:57:47,223] Trial 61 finished with value: 0.7294364554372983 and parameters: {'booster': 'gbtree', 'n_estimators': 1321, 'learning_rate': 0.0014844205676551, 'max_depth': 12, 'gamma': 2.197949772039254e-05, 'min_child_weight': 2, 'subsample': 0.9776215269205264, 'colsample_bytree': 0.9866609273486363, 'reg_alpha': 4.12554624057277, 'reg_lambda': 0.1395754779271083}. Best is trial 44 with value: 0.73405553978726.
# [I 2026-03-14 11:58:01,102] Trial 62 finished with value: 0.7347073287880016 and parameters: {'booster': 'gbtree', 'n_estimators': 1340, 'learning_rate': 0.0016276715863082186, 'max_depth': 12, 'gamma': 2.0896927524685896e-05, 'min_child_weight': 1, 'subsample': 0.9409649207025581, 'colsample_bytree': 0.9841935782817304, 'reg_alpha': 3.88949735204027, 'reg_lambda': 0.02600471169762365}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 11:58:10,273] Trial 63 finished with value: 0.7295181725053761 and parameters: {'booster': 'gbtree', 'n_estimators': 1308, 'learning_rate': 0.028903905333386312, 'max_depth': 11, 'gamma': 2.6316703785778028e-05, 'min_child_weight': 1, 'subsample': 0.9467161973118219, 'colsample_bytree': 0.9478664959406605, 'reg_alpha': 5.874545636509295, 'reg_lambda': 0.27155237481755506}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 11:58:28,491] Trial 64 finished with value: 0.6974944170521135 and parameters: {'booster': 'gbtree', 'n_estimators': 1289, 'learning_rate': 0.02861161630607512, 'max_depth': 11, 'gamma': 2.8785301561114987e-05, 'min_child_weight': 1, 'subsample': 0.9387451624384204, 'colsample_bytree': 0.9462657044983568, 'reg_alpha': 0.3170882260138138, 'reg_lambda': 2.399922960857722}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 11:58:37,121] Trial 65 finished with value: 0.7313468112218322 and parameters: {'booster': 'gbtree', 'n_estimators': 1343, 'learning_rate': 0.03498183417180795, 'max_depth': 11, 'gamma': 1.7803129386354175e-06, 'min_child_weight': 2, 'subsample': 0.904557265348505, 'colsample_bytree': 0.7409188243395168, 'reg_alpha': 5.186360167646303, 'reg_lambda': 0.2325669014021681}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 11:58:44,193] Trial 66 finished with value: 0.7261701901603851 and parameters: {'booster': 'gbtree', 'n_estimators': 1322, 'learning_rate': 0.05748817057786827, 'max_depth': 11, 'gamma': 8.45670536657815e-07, 'min_child_weight': 2, 'subsample': 0.8953711672846207, 'colsample_bytree': 0.8213890879175422, 'reg_alpha': 9.708855379089071, 'reg_lambda': 0.43579013911607833}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 11:58:52,266] Trial 67 finished with value: 0.7318095886112563 and parameters: {'booster': 'gbtree', 'n_estimators': 1368, 'learning_rate': 0.040188674769007685, 'max_depth': 11, 'gamma': 2.4171380707135113e-06, 'min_child_weight': 1, 'subsample': 0.911381675454316, 'colsample_bytree': 0.7408750882879497, 'reg_alpha': 5.669470372194597, 'reg_lambda': 0.1967644336247316}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 11:59:01,116] Trial 68 finished with value: 0.7295389599932394 and parameters: {'booster': 'gbtree', 'n_estimators': 1391, 'learning_rate': 0.03959049376314491, 'max_depth': 11, 'gamma': 1.7261099667055473e-06, 'min_child_weight': 1, 'subsample': 0.9168673956767606, 'colsample_bytree': 0.7292441615894494, 'reg_alpha': 5.291466585216887, 'reg_lambda': 0.21525016564492414}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 11:59:16,304] Trial 69 finished with value: 0.7305754034176004 and parameters: {'booster': 'gbtree', 'n_estimators': 1366, 'learning_rate': 0.03940971871600901, 'max_depth': 11, 'gamma': 1.5906935388060128e-07, 'min_child_weight': 1, 'subsample': 0.854451767649507, 'colsample_bytree': 0.7328503646716845, 'reg_alpha': 5.110866137304928, 'reg_lambda': 2.325117952143388}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 11:59:32,440] Trial 70 finished with value: 0.7089799971027523 and parameters: {'booster': 'gbtree', 'n_estimators': 1368, 'learning_rate': 0.08497017673993343, 'max_depth': 11, 'gamma': 1.6076884974690088e-07, 'min_child_weight': 1, 'subsample': 0.8498780158730255, 'colsample_bytree': 0.7325574996917695, 'reg_alpha': 1.9679269923683267, 'reg_lambda': 2.834404473393234}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 11:59:49,177] Trial 71 finished with value: 0.7287462052519899 and parameters: {'booster': 'gbtree', 'n_estimators': 1456, 'learning_rate': 0.03894489205882706, 'max_depth': 11, 'gamma': 2.123047976865578e-06, 'min_child_weight': 1, 'subsample': 0.9106751329163582, 'colsample_bytree': 0.7827886573935702, 'reg_alpha': 6.081607739454572, 'reg_lambda': 1.4622606479938767}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:00:30,325] Trial 72 finished with value: 0.7115001749838391 and parameters: {'booster': 'gbtree', 'n_estimators': 1394, 'learning_rate': 0.03909648218683242, 'max_depth': 11, 'gamma': 1.867496044681492e-07, 'min_child_weight': 1, 'subsample': 0.8814708504482212, 'colsample_bytree': 0.7061624706197409, 'reg_alpha': 0.9707039838047045, 'reg_lambda': 9.079029641223691}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:00:42,232] Trial 73 finished with value: 0.7278938793942176 and parameters: {'booster': 'gbtree', 'n_estimators': 1341, 'learning_rate': 0.06106152144157278, 'max_depth': 11, 'gamma': 4.951593595001339e-06, 'min_child_weight': 2, 'subsample': 0.9283305577207492, 'colsample_bytree': 0.6552004574633894, 'reg_alpha': 5.407934545334298, 'reg_lambda': 0.17630253011461955}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:00:58,538] Trial 74 finished with value: 0.7269104496443923 and parameters: {'booster': 'gbtree', 'n_estimators': 1235, 'learning_rate': 0.030203295956552637, 'max_depth': 11, 'gamma': 2.6164886153102286e-07, 'min_child_weight': 1, 'subsample': 0.9555792090489477, 'colsample_bytree': 0.7491974874694138, 'reg_alpha': 2.567062242932284, 'reg_lambda': 0.4987417017475744}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:01:21,045] Trial 75 finished with value: 0.6989044774029165 and parameters: {'booster': 'gbtree', 'n_estimators': 1409, 'learning_rate': 0.02495042890404654, 'max_depth': 11, 'gamma': 7.268548127981157e-08, 'min_child_weight': 2, 'subsample': 0.8633403939568101, 'colsample_bytree': 0.4053722732715042, 'reg_alpha': 0.4474014178749154, 'reg_lambda': 5.173190660885267}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:01:41,434] Trial 76 finished with value: 0.6848847095261448 and parameters: {'booster': 'gbtree', 'n_estimators': 1271, 'learning_rate': 0.04590655939291277, 'max_depth': 12, 'gamma': 1.3087636071174412e-06, 'min_child_weight': 3, 'subsample': 0.8961025256549436, 'colsample_bytree': 0.6099283557452623, 'reg_alpha': 0.17580379461389634, 'reg_lambda': 0.8646998128335796}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:01:53,296] Trial 77 finished with value: 0.7114202574322921 and parameters: {'booster': 'gbtree', 'n_estimators': 1468, 'learning_rate': 0.01831251671867929, 'max_depth': 10, 'gamma': 2.6882946678952613e-06, 'min_child_weight': 4, 'subsample': 0.9115869009507517, 'colsample_bytree': 0.6951605000879626, 'reg_alpha': 9.074272312951402, 'reg_lambda': 0.30336866223829667}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:02:09,792] Trial 78 finished with value: 0.7062668487315735 and parameters: {'booster': 'gbtree', 'n_estimators': 1367, 'learning_rate': 0.08233365446385071, 'max_depth': 12, 'gamma': 1.257542733662214e-05, 'min_child_weight': 2, 'subsample': 0.9485608313269338, 'colsample_bytree': 0.7218196796529224, 'reg_alpha': 0.9705830389096028, 'reg_lambda': 0.02359109902554845}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:02:23,481] Trial 79 finished with value: 0.7310114387485396 and parameters: {'booster': 'gbtree', 'n_estimators': 1427, 'learning_rate': 0.03717713569015818, 'max_depth': 10, 'gamma': 1.19510920628219e-06, 'min_child_weight': 1, 'subsample': 0.9210460298392952, 'colsample_bytree': 0.7773793448881575, 'reg_alpha': 4.371942918658989, 'reg_lambda': 0.053715727216629344}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:02:40,385] Trial 80 finished with value: 0.7085004988927862 and parameters: {'booster': 'gbtree', 'n_estimators': 1499, 'learning_rate': 0.07012676708625631, 'max_depth': 10, 'gamma': 1.2675322757899495e-06, 'min_child_weight': 1, 'subsample': 0.9314207352613828, 'colsample_bytree': 0.7701796869618581, 'reg_alpha': 1.475984852434684, 'reg_lambda': 0.055125145727671035}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:02:54,509] Trial 81 finished with value: 0.7339154718623755 and parameters: {'booster': 'gbtree', 'n_estimators': 1431, 'learning_rate': 0.03646961026976225, 'max_depth': 10, 'gamma': 4.4215667813216165e-07, 'min_child_weight': 1, 'subsample': 0.8872848834795217, 'colsample_bytree': 0.7409681768877188, 'reg_alpha': 4.285324995577309, 'reg_lambda': 1.4814562759635765}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:03:07,720] Trial 82 finished with value: 0.7325345996956563 and parameters: {'booster': 'gbtree', 'n_estimators': 1416, 'learning_rate': 0.10901843457200454, 'max_depth': 10, 'gamma': 3.6984179499940484e-07, 'min_child_weight': 2, 'subsample': 0.8779375824067294, 'colsample_bytree': 0.7382479365555951, 'reg_alpha': 4.24308686005569, 'reg_lambda': 1.4253970677757892}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:03:23,994] Trial 83 finished with value: 0.7131334650276375 and parameters: {'booster': 'gbtree', 'n_estimators': 1437, 'learning_rate': 0.10226905091457214, 'max_depth': 9, 'gamma': 4.992028226988373e-07, 'min_child_weight': 2, 'subsample': 0.8358998819826382, 'colsample_bytree': 0.7067017889151992, 'reg_alpha': 2.115707396236993, 'reg_lambda': 1.2083307887829056}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:04:40,994] Trial 84 finished with value: 0.6995172917516299 and parameters: {'booster': 'gbtree', 'n_estimators': 1347, 'learning_rate': 0.10389845410534218, 'max_depth': 10, 'gamma': 3.6140111227619177e-07, 'min_child_weight': 3, 'subsample': 0.8798080483378016, 'colsample_bytree': 0.7504879579296297, 'reg_alpha': 0.9624194110553814, 'reg_lambda': 3.559480510027876}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:04:55,589] Trial 85 finished with value: 0.7342178706723275 and parameters: {'booster': 'gbtree', 'n_estimators': 1426, 'learning_rate': 0.04512101294101497, 'max_depth': 9, 'gamma': 9.15441059936633e-08, 'min_child_weight': 2, 'subsample': 0.8583182307882956, 'colsample_bytree': 0.8001630729108445, 'reg_alpha': 3.6304313646953905, 'reg_lambda': 1.5783213106443845}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:05:07,903] Trial 86 finished with value: 0.7244911686550146 and parameters: {'booster': 'gbtree', 'n_estimators': 1431, 'learning_rate': 0.12631184340156204, 'max_depth': 9, 'gamma': 1.2599056016802517e-08, 'min_child_weight': 4, 'subsample': 0.8196391740912926, 'colsample_bytree': 0.8041461406891887, 'reg_alpha': 3.9320263820932024, 'reg_lambda': 1.3214671471167683}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:05:27,815] Trial 87 finished with value: 0.7278135654747189 and parameters: {'booster': 'gbtree', 'n_estimators': 1465, 'learning_rate': 0.03403610436360675, 'max_depth': 10, 'gamma': 1.0827293991483033e-07, 'min_child_weight': 2, 'subsample': 0.9019766318304099, 'colsample_bytree': 0.7681387402620559, 'reg_alpha': 2.0824805119810623, 'reg_lambda': 4.9939474230267225}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:05:43,036] Trial 88 finished with value: 0.6853585558087588 and parameters: {'booster': 'gbtree', 'n_estimators': 1500, 'learning_rate': 0.021813080504150546, 'max_depth': 9, 'gamma': 3.424598060297129e-08, 'min_child_weight': 18, 'subsample': 0.882556440132076, 'colsample_bytree': 0.7917676046366509, 'reg_alpha': 0.3538330066584559, 'reg_lambda': 0.6379729749705608}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:05:50,172] Trial 89 finished with value: 0.7032000772489099 and parameters: {'booster': 'gbtree', 'n_estimators': 420, 'learning_rate': 0.046150832036037405, 'max_depth': 10, 'gamma': 5.624212357489658e-07, 'min_child_weight': 3, 'subsample': 0.8727616055221608, 'colsample_bytree': 0.7796627547410944, 'reg_alpha': 0.1765123396065037, 'reg_lambda': 0.012006712747864034}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:06:07,155] Trial 90 finished with value: 0.7000070606178826 and parameters: {'booster': 'gbtree', 'n_estimators': 1410, 'learning_rate': 0.059798910327056747, 'max_depth': 8, 'gamma': 6.334115103325195e-08, 'min_child_weight': 2, 'subsample': 0.9607839045589925, 'colsample_bytree': 0.7452984711536805, 'reg_alpha': 1.0283085867414326, 'reg_lambda': 0.12617984518524522}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:06:22,577] Trial 91 finished with value: 0.7297824051146059 and parameters: {'booster': 'gbtree', 'n_estimators': 1367, 'learning_rate': 0.03439570006785076, 'max_depth': 10, 'gamma': 2.5838478828149146e-07, 'min_child_weight': 1, 'subsample': 0.8508113770745468, 'colsample_bytree': 0.6759166294291864, 'reg_alpha': 3.979120306079894, 'reg_lambda': 5.415715437521179}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:06:34,038] Trial 92 finished with value: 0.7211469588723558 and parameters: {'booster': 'gbtree', 'n_estimators': 1261, 'learning_rate': 0.026398518009828956, 'max_depth': 10, 'gamma': 2.2627529583605338e-08, 'min_child_weight': 2, 'subsample': 0.8611738778419993, 'colsample_bytree': 0.7155682796396942, 'reg_alpha': 8.629165810350205, 'reg_lambda': 1.3461774263798993}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:06:47,591] Trial 93 finished with value: 0.7294339530312322 and parameters: {'booster': 'gbtree', 'n_estimators': 1436, 'learning_rate': 0.06913206708218488, 'max_depth': 9, 'gamma': 4.794611422903755e-06, 'min_child_weight': 3, 'subsample': 0.9026361736409543, 'colsample_bytree': 0.7355216054242311, 'reg_alpha': 3.2802196537657453, 'reg_lambda': 0.4353253600721559}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:07:00,982] Trial 94 finished with value: 0.6910116400983466 and parameters: {'booster': 'gbtree', 'n_estimators': 1341, 'learning_rate': 0.19597210403495147, 'max_depth': 10, 'gamma': 8.588998972269504e-07, 'min_child_weight': 1, 'subsample': 0.8864634689019022, 'colsample_bytree': 0.7502899441559848, 'reg_alpha': 1.6047157885854144, 'reg_lambda': 0.024124806793921608}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:07:31,401] Trial 95 finished with value: 0.7038614853030388 and parameters: {'booster': 'gbtree', 'n_estimators': 1386, 'learning_rate': 0.013640111427872359, 'max_depth': 10, 'gamma': 1.164890513203855e-07, 'min_child_weight': 1, 'subsample': 0.9246166119388958, 'colsample_bytree': 0.655632289057956, 'reg_alpha': 0.5878010013326367, 'reg_lambda': 2.3739229079618207}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:07:41,433] Trial 96 finished with value: 0.7286068026748171 and parameters: {'booster': 'gbtree', 'n_estimators': 1304, 'learning_rate': 0.045418385006461906, 'max_depth': 11, 'gamma': 3.0659594328921734e-07, 'min_child_weight': 3, 'subsample': 0.9824285010210609, 'colsample_bytree': 0.7994417588876239, 'reg_alpha': 6.604085423867109, 'reg_lambda': 3.1856170962362733e-06}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:08:01,555] Trial 97 finished with value: 0.6981045281818349 and parameters: {'booster': 'gbtree', 'n_estimators': 1199, 'learning_rate': 0.020083214525579034, 'max_depth': 9, 'gamma': 5.642183992316129e-07, 'min_child_weight': 4, 'subsample': 0.9384984679681125, 'colsample_bytree': 0.8181886032268235, 'reg_alpha': 4.506746999126324e-08, 'reg_lambda': 1.3073687618454316e-07}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:08:25,135] Trial 98 finished with value: 0.6807574702589637 and parameters: {'booster': 'gbtree', 'n_estimators': 1467, 'learning_rate': 0.05615339812161302, 'max_depth': 12, 'gamma': 1.2848950137402678e-06, 'min_child_weight': 2, 'subsample': 0.8418393063096955, 'colsample_bytree': 0.6941758607123691, 'reg_alpha': 1.4866922847188632e-05, 'reg_lambda': 0.9367866241352061}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:08:42,386] Trial 99 finished with value: 0.6935217133521002 and parameters: {'booster': 'gbtree', 'n_estimators': 1223, 'learning_rate': 0.05255585392560875, 'max_depth': 10, 'gamma': 6.1774749813825475e-06, 'min_child_weight': 5, 'subsample': 0.808530700795469, 'colsample_bytree': 0.7769060285060996, 'reg_alpha': 0.001909920905084219, 'reg_lambda': 1.8037124790398211}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:09:04,070] Trial 100 finished with value: 0.6861778725516281 and parameters: {'booster': 'gbtree', 'n_estimators': 1405, 'learning_rate': 0.04199931571232797, 'max_depth': 8, 'gamma': 3.332163095314717e-06, 'min_child_weight': 1, 'subsample': 0.6930444117481036, 'colsample_bytree': 0.7601134236762394, 'reg_alpha': 0.031639653499839195, 'reg_lambda': 0.38580578795979353}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:09:13,560] Trial 101 finished with value: 0.7272343226952904 and parameters: {'booster': 'gbtree', 'n_estimators': 1353, 'learning_rate': 0.03289608528469658, 'max_depth': 10, 'gamma': 2.2217617919281067e-07, 'min_child_weight': 1, 'subsample': 0.8534294800813508, 'colsample_bytree': 0.6732054993591257, 'reg_alpha': 4.373693701536851, 'reg_lambda': 6.529766135739938}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:09:23,252] Trial 102 finished with value: 0.7311036299067462 and parameters: {'booster': 'gbtree', 'n_estimators': 1382, 'learning_rate': 0.0350549468751723, 'max_depth': 10, 'gamma': 7.479161215341014e-08, 'min_child_weight': 2, 'subsample': 0.8921250260632863, 'colsample_bytree': 0.6812597558747152, 'reg_alpha': 3.7694993899389804, 'reg_lambda': 3.93965352084351}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:09:35,962] Trial 103 finished with value: 0.7288727211891242 and parameters: {'booster': 'gbtree', 'n_estimators': 1437, 'learning_rate': 0.026985667859132, 'max_depth': 11, 'gamma': 6.22362235377248e-08, 'min_child_weight': 2, 'subsample': 0.889485406571945, 'colsample_bytree': 0.7367365181068894, 'reg_alpha': 2.3748744400799366, 'reg_lambda': 4.095722163604961}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:09:44,667] Trial 104 finished with value: 0.7141836620499508 and parameters: {'booster': 'gbtree', 'n_estimators': 1322, 'learning_rate': 0.03255184545056523, 'max_depth': 10, 'gamma': 4.1796125482154086e-08, 'min_child_weight': 2, 'subsample': 0.866596103549155, 'colsample_bytree': 0.7141026946525717, 'reg_alpha': 6.887298878949892, 'reg_lambda': 1.8227187064349588}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:09:54,695] Trial 105 finished with value: 0.7014020269320144 and parameters: {'booster': 'gbtree', 'n_estimators': 1287, 'learning_rate': 0.06990652465089292, 'max_depth': 9, 'gamma': 1.1742515370951537e-07, 'min_child_weight': 2, 'subsample': 0.9209052118224303, 'colsample_bytree': 0.6308713484867655, 'reg_alpha': 1.3371565012120394, 'reg_lambda': 0.5346157193020482}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:10:03,884] Trial 106 finished with value: 0.7288781798216187 and parameters: {'booster': 'gbtree', 'n_estimators': 1379, 'learning_rate': 0.0365615224829591, 'max_depth': 11, 'gamma': 8.57272195759623e-06, 'min_child_weight': 3, 'subsample': 0.906912381495797, 'colsample_bytree': 0.7014571363134101, 'reg_alpha': 2.971470338382045, 'reg_lambda': 5.270648931874452e-08}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:10:16,437] Trial 107 finished with value: 0.6938490857954183 and parameters: {'booster': 'gbtree', 'n_estimators': 1470, 'learning_rate': 0.051128598593744454, 'max_depth': 12, 'gamma': 4.1792012621808203e-07, 'min_child_weight': 1, 'subsample': 0.9654556203062028, 'colsample_bytree': 0.6868677399106181, 'reg_alpha': 0.7931081212143573, 'reg_lambda': 0.06665059389560132}. Best is trial 62 with value: 0.7347073287880016.
# [I 2026-03-14 12:10:32,086] Trial 108 finished with value: 0.7013007458102356 and parameters: {'booster': 'gbtree', 'n_estimators': 1421, 'learning_rate': 0.011247218803735639, 'max_depth': 9, 'gamma': 1.4986247334056534e-07, 'min_child_weight': 3, 'subsample': 0.8290039351358038, 'colsample_bytree': 0.7558321983250966, 'reg_alpha': 0.0003023785991802802, 'reg_lambda': 0.1831974487088981}. Best is trial 62 with value: 0.7347073287880016.
# ...
# [I 2026-03-14 12:22:13,509] Trial 164 finished with value: 0.7324685539317035 and parameters: {'booster': 'gbtree', 'n_estimators': 1220, 'learning_rate': 0.0012870287749726904, 'max_depth': 6, 'gamma': 0.0009996735096384221, 'min_child_weight': 2, 'subsample': 0.6647386380874405, 'colsample_bytree': 0.8876463989929506, 'reg_alpha': 1.3808226533334658, 'reg_lambda': 1.0881497843815228e-05}. Best is trial 155 with value: 0.7417185539454649.
# [I 2026-03-14 12:22:24,088] Trial 165 finished with value: 0.7286529038292804 and parameters: {'booster': 'gbtree', 'n_estimators': 1276, 'learning_rate': 0.0021203465089373124, 'max_depth': 4, 'gamma': 0.004473844064189169, 'min_child_weight': 1, 'subsample': 0.5293453065989315, 'colsample_bytree': 0.8541644380998934, 'reg_alpha': 0.22853090941744025, 'reg_lambda': 3.811350986507207e-05}. Best is trial 155 with value: 0.7417185539454649.
# [I 2026-03-14 12:22:35,963] Trial 166 finished with value: 0.7248700473483869 and parameters: {'booster': 'gbtree', 'n_estimators': 1334, 'learning_rate': 0.0016507212287985092, 'max_depth': 6, 'gamma': 0.0003368688327562037, 'min_child_weight': 2, 'subsample': 0.5504579222248179, 'colsample_bytree': 0.881594154371779, 'reg_alpha': 2.4000994534628233, 'reg_lambda': 0.00014212740101655466}. Best is trial 155 with value: 0.7417185539454649.
# [I 2026-03-14 12:22:48,697] Trial 167 finished with value: 0.7175910608916093 and parameters: {'booster': 'gbtree', 'n_estimators': 1298, 'learning_rate': 0.0018233577376821101, 'max_depth': 5, 'gamma': 0.0017875962507077833, 'min_child_weight': 1, 'subsample': 0.9480372892673383, 'colsample_bytree': 0.9296110206799874, 'reg_alpha': 0.09093235074662163, 'reg_lambda': 1.5644269929411693e-05}. Best is trial 155 with value: 0.7417185539454649.
# [I 2026-03-14 12:23:01,072] Trial 168 finished with value: 0.7310264890076195 and parameters: {'booster': 'gbtree', 'n_estimators': 1200, 'learning_rate': 0.00255692271162145, 'max_depth': 6, 'gamma': 0.0006984425154345422, 'min_child_weight': 2, 'subsample': 0.6869429970126368, 'colsample_bytree': 0.9150968496845405, 'reg_alpha': 0.5795249766868519, 'reg_lambda': 0.0027044393543327137}. Best is trial 155 with value: 0.7417185539454649.
# [I 2026-03-14 12:23:11,822] Trial 169 finished with value: 0.736162486616607 and parameters: {'booster': 'gbtree', 'n_estimators': 1353, 'learning_rate': 0.002317088447919812, 'max_depth': 4, 'gamma': 0.0026013670286589813, 'min_child_weight': 1, 'subsample': 0.713377236694543, 'colsample_bytree': 0.8778951416813219, 'reg_alpha': 3.776942001464614, 'reg_lambda': 6.026108685600043e-05}. Best is trial 155 with value: 0.7417185539454649.
# [I 2026-03-14 12:23:21,914] Trial 170 finished with value: 0.7340075529890158 and parameters: {'booster': 'gbtree', 'n_estimators': 1238, 'learning_rate': 0.0022593560368064976, 'max_depth': 4, 'gamma': 0.00293068365427076, 'min_child_weight': 1, 'subsample': 0.6970195828350773, 'colsample_bytree': 0.8812275646488461, 'reg_alpha': 3.3921071665767837, 'reg_lambda': 2.2829905295739897e-05}. Best is trial 155 with value: 0.7417185539454649.
# [I 2026-03-14 12:23:31,436] Trial 171 finished with value: 0.7340549944340321 and parameters: {'booster': 'gbtree', 'n_estimators': 1171, 'learning_rate': 0.0021229218055442557, 'max_depth': 4, 'gamma': 0.006331153121001833, 'min_child_weight': 1, 'subsample': 0.7082581851003257, 'colsample_bytree': 0.8756468436304682, 'reg_alpha': 3.2730998138676926, 'reg_lambda': 5.864338156736269e-05}. Best is trial 155 with value: 0.7417185539454649.
# [I 2026-03-14 12:23:40,810] Trial 172 finished with value: 0.7298815177433557 and parameters: {'booster': 'gbtree', 'n_estimators': 1177, 'learning_rate': 0.002158707933062124, 'max_depth': 4, 'gamma': 0.0075099698392819166, 'min_child_weight': 1, 'subsample': 0.6993093644127345, 'colsample_bytree': 0.8710583649962148, 'reg_alpha': 2.5180987819114424, 'reg_lambda': 5.8016098598393855e-05}. Best is trial 155 with value: 0.7417185539454649.
# [I 2026-03-14 12:23:51,060] Trial 173 finished with value: 0.734763799971929 and parameters: {'booster': 'gbtree', 'n_estimators': 1226, 'learning_rate': 0.0022968502804957516, 'max_depth': 4, 'gamma': 0.002288965890836767, 'min_child_weight': 1, 'subsample': 0.723774955605309, 'colsample_bytree': 0.8409180600877899, 'reg_alpha': 1.3598167016103084, 'reg_lambda': 2.5840937165444217e-05}. Best is trial 155 with value: 0.7417185539454649.
# [I 2026-03-14 12:24:01,333] Trial 174 finished with value: 0.7331315020936386 and parameters: {'booster': 'gbtree', 'n_estimators': 1269, 'learning_rate': 0.0014252949959454196, 'max_depth': 4, 'gamma': 0.0020388606704323416, 'min_child_weight': 1, 'subsample': 0.7157104217679607, 'colsample_bytree': 0.8578855092589484, 'reg_alpha': 0.9293167361150153, 'reg_lambda': 3.8996095157620496e-05}. Best is trial 155 with value: 0.7417185539454649.
# [I 2026-03-14 12:24:10,070] Trial 175 finished with value: 0.7287359439956264 and parameters: {'booster': 'gbtree', 'n_estimators': 1227, 'learning_rate': 0.0019982229873840157, 'max_depth': 3, 'gamma': 0.0064483737778692155, 'min_child_weight': 2, 'subsample': 0.7299002910157396, 'colsample_bytree': 0.8436900350593615, 'reg_alpha': 1.5654549450820259, 'reg_lambda': 7.232757184063738e-06}. Best is trial 155 with value: 0.7417185539454649.
# [I 2026-03-14 12:24:23,072] Trial 176 finished with value: 0.729004697512343 and parameters: {'booster': 'gbtree', 'n_estimators': 1334, 'learning_rate': 0.002714178479162086, 'max_depth': 5, 'gamma': 0.00145484400112943, 'min_child_weight': 1, 'subsample': 0.7563405755042757, 'colsample_bytree': 0.8386870710036669, 'reg_alpha': 0.442474125620112, 'reg_lambda': 1.5530711707313118e-05}. Best is trial 155 with value: 0.7417185539454649.
# [I 2026-03-14 12:24:33,413] Trial 177 finished with value: 0.738374087252479 and parameters: {'booster': 'gbtree', 'n_estimators': 1274, 'learning_rate': 0.0024018008622017774, 'max_depth': 4, 'gamma': 0.004857646827555415, 'min_child_weight': 2, 'subsample': 0.7101173704282783, 'colsample_bytree': 0.8964831630395997, 'reg_alpha': 1.328417916489883, 'reg_lambda': 0.00010711244740294449}. Best is trial 155 with value: 0.7417185539454649.
# [I 2026-03-14 12:24:45,447] Trial 178 finished with value: 0.7389319611275843 and parameters: {'booster': 'gbtree', 'n_estimators': 1302, 'learning_rate': 0.002331190357675988, 'max_depth': 5, 'gamma': 0.017780318973422745, 'min_child_weight': 2, 'subsample': 0.6736600739343079, 'colsample_bytree': 0.9133790528858736, 'reg_alpha': 0.7858954312264603, 'reg_lambda': 0.00012767168134790837}. Best is trial 155 with value: 0.7417185539454649.
# [I 2026-03-14 12:24:57,015] Trial 179 finished with value: 0.7369966103247773 and parameters: {'booster': 'gbtree', 'n_estimators': 1262, 'learning_rate': 0.0016164026308823141, 'max_depth': 5, 'gamma': 0.011991793935442915, 'min_child_weight': 2, 'subsample': 0.6784979397393178, 'colsample_bytree': 0.9028069316963224, 'reg_alpha': 0.8312337204695412, 'reg_lambda': 0.0001624915127469156}. Best is trial 155 with value: 0.7417185539454649.
# [I 2026-03-14 12:25:08,929] Trial 180 finished with value: 0.7275981517687936 and parameters: {'booster': 'gbtree', 'n_estimators': 1255, 'learning_rate': 0.0015558548094512918, 'max_depth': 5, 'gamma': 0.018545673201802348, 'min_child_weight': 2, 'subsample': 0.6756953367675101, 'colsample_bytree': 0.8950381527095246, 'reg_alpha': 0.20941213605701997, 'reg_lambda': 0.00011718575033920136}. Best is trial 155 with value: 0.7417185539454649.
# [I 2026-03-14 12:25:20,455] Trial 181 finished with value: 0.7378245293174278 and parameters: {'booster': 'gbtree', 'n_estimators': 1290, 'learning_rate': 0.0025923380152363925, 'max_depth': 5, 'gamma': 0.03441055740196149, 'min_child_weight': 2, 'subsample': 0.6423017922842059, 'colsample_bytree': 0.9063595339840242, 'reg_alpha': 0.9498044869389288, 'reg_lambda': 0.00016074007543409808}. Best is trial 155 with value: 0.7417185539454649.
# [I 2026-03-14 12:25:32,206] Trial 182 finished with value: 0.7378245293174278 and parameters: {'booster': 'gbtree', 'n_estimators': 1281, 'learning_rate': 0.0025878671074666677, 'max_depth': 5, 'gamma': 0.03344634831265227, 'min_child_weight': 2, 'subsample': 0.6740050088289609, 'colsample_bytree': 0.9091109693226157, 'reg_alpha': 0.942524753202973, 'reg_lambda': 0.00016231280604189421}. Best is trial 155 with value: 0.7417185539454649.
# [I 2026-03-14 12:25:44,023] Trial 183 finished with value: 0.7378489797979405 and parameters: {'booster': 'gbtree', 'n_estimators': 1281, 'learning_rate': 0.0024053475203561266, 'max_depth': 5, 'gamma': 0.02810427067369696, 'min_child_weight': 2, 'subsample': 0.6701364702062051, 'colsample_bytree': 0.9183103026765784, 'reg_alpha': 0.7926060159012395, 'reg_lambda': 0.00023267459065234262}. Best is trial 155 with value: 0.7417185539454649.
# [I 2026-03-14 12:25:55,509] Trial 184 finished with value: 0.736263198048928 and parameters: {'booster': 'gbtree', 'n_estimators': 1268, 'learning_rate': 0.0025327852780739155, 'max_depth': 5, 'gamma': 0.032576535734622505, 'min_child_weight': 3, 'subsample': 0.678201916972525, 'colsample_bytree': 0.9105807846848493, 'reg_alpha': 0.723711401665203, 'reg_lambda': 0.00014936970093847808}. Best is trial 155 with value: 0.7417185539454649.
# [I 2026-03-14 12:26:05,587] Trial 185 finished with value: 0.7313452293872794 and parameters: {'booster': 'gbtree', 'n_estimators': 1113, 'learning_rate': 0.0024725266523991304, 'max_depth': 5, 'gamma': 0.048461803792958905, 'min_child_weight': 3, 'subsample': 0.6713669298786815, 'colsample_bytree': 0.918497502261299, 'reg_alpha': 0.27043229305225164, 'reg_lambda': 0.00015365088430076504}. Best is trial 155 with value: 0.7417185539454649.
# [I 2026-03-14 12:26:16,695] Trial 186 finished with value: 0.7346762881742113 and parameters: {'booster': 'gbtree', 'n_estimators': 1212, 'learning_rate': 0.001907154343034269, 'max_depth': 5, 'gamma': 0.03605555817573903, 'min_child_weight': 3, 'subsample': 0.6365788968999742, 'colsample_bytree': 0.9102865762424498, 'reg_alpha': 0.4273082099711132, 'reg_lambda': 0.00012380731229513943}. Best is trial 155 with value: 0.7417185539454649.
# [I 2026-03-14 12:26:28,471] Trial 187 finished with value: 0.7338042601470827 and parameters: {'booster': 'gbtree', 'n_estimators': 1243, 'learning_rate': 0.0022938447135475585, 'max_depth': 5, 'gamma': 0.02380086622084188, 'min_child_weight': 2, 'subsample': 0.7086246499680218, 'colsample_bytree': 0.9395548169241215, 'reg_alpha': 0.6288766400141598, 'reg_lambda': 8.77758983398907e-05}. Best is trial 155 with value: 0.7417185539454649.
# [I 2026-03-14 12:26:39,853] Trial 188 finished with value: 0.736765396042584 and parameters: {'booster': 'gbtree', 'n_estimators': 1292, 'learning_rate': 0.002756374773345932, 'max_depth': 5, 'gamma': 0.010323492221396348, 'min_child_weight': 2, 'subsample': 0.6447242345469586, 'colsample_bytree': 0.9014499727435277, 'reg_alpha': 1.309082358003017, 'reg_lambda': 0.000286885963358826}. Best is trial 155 with value: 0.7417185539454649.
# [I 2026-03-14 12:26:51,165] Trial 189 finished with value: 0.734428212889551 and parameters: {'booster': 'gbtree', 'n_estimators': 1276, 'learning_rate': 0.0023359607488594096, 'max_depth': 5, 'gamma': 0.012682627653489553, 'min_child_weight': 3, 'subsample': 0.6830206660714889, 'colsample_bytree': 0.8993795847480789, 'reg_alpha': 1.0701244419770344, 'reg_lambda': 0.00032567584401232584}. Best is trial 155 with value: 0.7417185539454649.
# [I 2026-03-14 12:27:01,513] Trial 190 finished with value: 0.735768032163062 and parameters: {'booster': 'gbtree', 'n_estimators': 1252, 'learning_rate': 0.002699201224393401, 'max_depth': 4, 'gamma': 0.02631438506955899, 'min_child_weight': 2, 'subsample': 0.6444421086505197, 'colsample_bytree': 0.9261241334565578, 'reg_alpha': 0.8100315342492067, 'reg_lambda': 0.00016469810078393628}. Best is trial 155 with value: 0.7417185539454649.
# [I 2026-03-14 12:27:11,733] Trial 191 finished with value: 0.7337909462135522 and parameters: {'booster': 'gbtree', 'n_estimators': 1256, 'learning_rate': 0.002678072366917161, 'max_depth': 4, 'gamma': 0.0293707971578176, 'min_child_weight': 2, 'subsample': 0.6365256005454903, 'colsample_bytree': 0.926508857184991, 'reg_alpha': 0.7145421339725254, 'reg_lambda': 0.00017955793214382372}. Best is trial 155 with value: 0.7417185539454649.
# [I 2026-03-14 12:27:22,260] Trial 192 finished with value: 0.7382626330008177 and parameters: {'booster': 'gbtree', 'n_estimators': 1293, 'learning_rate': 0.0026171159534654786, 'max_depth': 4, 'gamma': 0.07020179354139947, 'min_child_weight': 2, 'subsample': 0.6713160915236702, 'colsample_bytree': 0.9053655409139585, 'reg_alpha': 1.2411980652416896, 'reg_lambda': 0.0006510026919347932}. Best is trial 155 with value: 0.7417185539454649.
# [I 2026-03-14 12:27:34,257] Trial 193 finished with value: 0.7382382286959955 and parameters: {'booster': 'gbtree', 'n_estimators': 1303, 'learning_rate': 0.0026477104707509375, 'max_depth': 5, 'gamma': 0.06824227111547121, 'min_child_weight': 3, 'subsample': 0.6537943230247446, 'colsample_bytree': 0.9111145162647901, 'reg_alpha': 0.357691171558144, 'reg_lambda': 0.0005266737867680059}. Best is trial 155 with value: 0.7417185539454649.
# [I 2026-03-14 12:27:45,935] Trial 194 finished with value: 0.7393075513443504 and parameters: {'booster': 'gbtree', 'n_estimators': 1302, 'learning_rate': 0.0025674375886138344, 'max_depth': 5, 'gamma': 0.057552198366375464, 'min_child_weight': 3, 'subsample': 0.6454130641655695, 'colsample_bytree': 0.9053202334667086, 'reg_alpha': 0.6403629770229945, 'reg_lambda': 0.0005992433920309768}. Best is trial 155 with value: 0.7417185539454649.
# [I 2026-03-14 12:27:57,930] Trial 195 finished with value: 0.7284223672418985 and parameters: {'booster': 'gbtree', 'n_estimators': 1303, 'learning_rate': 0.0027529681276078593, 'max_depth': 5, 'gamma': 0.09021148472074596, 'min_child_weight': 3, 'subsample': 0.6450309778387939, 'colsample_bytree': 0.9071511454297763, 'reg_alpha': 0.13054171157556052, 'reg_lambda': 0.0006236380806108221}. Best is trial 155 with value: 0.7417185539454649.
# [I 2026-03-14 12:28:09,525] Trial 196 finished with value: 0.7292691605171788 and parameters: {'booster': 'gbtree', 'n_estimators': 1274, 'learning_rate': 0.0034401233074614016, 'max_depth': 5, 'gamma': 0.14809738289805166, 'min_child_weight': 3, 'subsample': 0.6734492369148695, 'colsample_bytree': 0.9082911772052129, 'reg_alpha': 0.3750823843967846, 'reg_lambda': 0.0005649212391000414}. Best is trial 155 with value: 0.7417185539454649.
# [I 2026-03-14 12:28:19,257] Trial 197 finished with value: 0.7325726404120997 and parameters: {'booster': 'gbtree', 'n_estimators': 1176, 'learning_rate': 0.002583114286475201, 'max_depth': 4, 'gamma': 0.057658839741868445, 'min_child_weight': 3, 'subsample': 0.6227138200153621, 'colsample_bytree': 0.9502441858995662, 'reg_alpha': 0.49205324907123216, 'reg_lambda': 0.0002876589528141928}. Best is trial 155 with value: 0.7417185539454649.
# [I 2026-03-14 12:28:30,742] Trial 198 finished with value: 0.7379747234696601 and parameters: {'booster': 'gbtree', 'n_estimators': 1310, 'learning_rate': 0.0029276490300101103, 'max_depth': 5, 'gamma': 0.020369287124289415, 'min_child_weight': 3, 'subsample': 0.652074071101095, 'colsample_bytree': 0.8954143455887605, 'reg_alpha': 0.8159304683575096, 'reg_lambda': 0.0008606087009682646}. Best is trial 155 with value: 0.7417185539454649.
# [I 2026-03-14 12:28:42,541] Trial 199 finished with value: 0.7296237960177896 and parameters: {'booster': 'gbtree', 'n_estimators': 1292, 'learning_rate': 0.0030401440186855204, 'max_depth': 5, 'gamma': 0.020646349561619832, 'min_child_weight': 4, 'subsample': 0.6500205936122121, 'colsample_bytree': 0.8770977804818294, 'reg_alpha': 0.2866382453497117, 'reg_lambda': 0.0008434360517069882}. Best is trial 155 with value: 0.7417185539454649.
# Best Score: 0.7417185539454649

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import xgboost as xgb
import json
import pandas as pd

file_name = "best_xgb_params.json" 

with open(file_name, "r") as f:
    params = json.load(f)
params.update({
    'objective': 'multi:softprob',
    'num_class': 11,
    'n_jobs': -1 
})

best_clf = xgb.XGBClassifier(**params)
best_clf.fit(X_train_r, y_train_r) 

pred_r = best_clf.predict(X_test_r).ravel()

y_test_text = le.inverse_transform(y_test_r)
pred_text = le.inverse_transform(pred_r)
class_names = le.classes_ 

print("=== Baseline Classification on Random Split ===")
eval_classification(y_test_r, pred_r, name="RandomSplit")

print("\nClassification report (RandomSplit):")

print(classification_report(y_test_text, pred_text, digits=4))

cm_r = confusion_matrix(y_test_text, pred_text, labels=class_names)
cm_r_df = pd.DataFrame(cm_r, index=class_names, columns=class_names)
cm_r_df.to_csv("optuna_baseline_cm_random_copulagan.csv", encoding="utf-8-sig")
print("Saved: optuna_baseline_cm_random_copulagan.csv")

save_preds_csv(X_test_r, y_test_text, pred_text, "optuna_baseline_preds_random_cls_copulagan.csv")

# Confusion Matrix
plt.figure(figsize=(12, 9)) 
sns.heatmap(cm_r, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix - XGBoost (Optuna Optimized)', fontsize=14)
plt.xlabel('Predicted', fontsize=12)
plt.ylabel('Actual', fontsize=12)
plt.show()
# Out:
# === Baseline Classification on Random Split ===
# RandomSplit Accuracy: 0.7877 | F1-macro: 0.7891 | F1-weighted: 0.7788
#
# Classification report (RandomSplit):
#               precision    recall  f1-score   support
#
#            A     1.0000    0.5000    0.6667         4
#            B     1.0000    0.8667    0.9286        15
#            C     0.5000    1.0000    0.6667         2
#            D     0.6923    1.0000    0.8182         9
#            E     1.0000    0.7692    0.8696        13
#            G     1.0000    1.0000    1.0000         9
#            H     0.6579    0.7576    0.7042        33
#            I     0.7500    1.0000    0.8571         3
#            J     0.6923    0.3913    0.5000        23
#            K     0.8250    0.9429    0.8800        35
#
#     accuracy                         0.7877       146
#    macro avg     0.8118    0.8228    0.7891       146
# weighted avg     0.8013    0.7877    0.7788       146
#
# Saved: optuna_baseline_cm_random_copulagan.csv
# Saved: optuna_baseline_preds_random_cls_copulagan.csv
